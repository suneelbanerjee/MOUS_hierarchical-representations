# %%
import pandas as pd
from pathlib import Path
import numpy as np
import scipy.io

# %%
subtlex_v2 = pd.read_excel('/home/neel/Desktop/sublexical_crossmodal/SUBTLEX-NL with pos and Zipf.xlsx')
subtlex_v1 = pd.read_csv('/home/neel/Desktop/sublexical_crossmodal/SUBTLEX-NL-utf8.txt',delimiter = '\t')
subtlex = subtlex_v2
subtlex
# Out:
#                 Word  FREQcount  CDcount  FREQlow  CDlow  FREQlemma  \
# 0                 ik    1744062     8054   778704   3125    1744527
# 1                 je    1600888     8060  1315051   6535    1600923
# 2                het    1068396     8066   780771   5578    1913811
# 3                 de    1061177     8070   903872   6512    1063827
# 4                dat     965424     8063   715570   6107     965431
# ...              ...        ...      ...      ...    ...        ...
# 437498       &_blake          1        1        1      1          1
# 437499      &_barbie          1        1        1      1          1
# 437500  &_bake_pizza          1        1        1      1          1
# 437501        &_bach          1        1        1      1          1
# 437502    &_atlantic          1        1        1      1          1
#
#          SUBTLEXWF      Zipf  SUBTLEXCD  Lg10CD dominant.pos  \
# 0       39883.0334  7.597064    99.8017  3.9061          VNW
# 1       36608.9449  7.559864    99.8761  3.9064          VNW
# 2       24431.9717  7.384235    99.9504  3.9067          VNW
# 3       24266.8883  7.381291   100.0000  3.9069          LID
# 4       22077.2184  7.340221    99.9133  3.9066          VNW
# ...            ...       ...        ...     ...          ...
# 437498      0.0229  1.656532     0.0124  0.3010         SPEC
# 437499      0.0229  1.656532     0.0124  0.3010         SPEC
# 437500      0.0229  1.656532     0.0124  0.3010         SPEC
# 437501      0.0229  1.656532     0.0124  0.3010         SPEC
# 437502      0.0229  1.656532     0.0124  0.3010         SPEC
#
#         dominant.pos.freq dominant.pos.lemma  dominant.pos.lemma.freq  \
# 0                 1743609                 ik                  1743944
# 1                 1600798                 je                  1600798
# 2                  735390                het                   735395
# 3                 1060098                 de                  1062748
# 4                  532576                dat                   532576
# ...                   ...                ...                      ...
# 437498                  1            &_blake                        1
# 437499                  1           &_barbie                        1
# 437500                  1       &_bake_pizza                        1
# 437501                  1             &_bach                        1
# 437502                  1         &_atlantic                        1
#
#                     all.pos             all.pos.freq  \
# 0           .VNW.SPEC.N.VZ.        .1743609.448.4.1.
# 1       .VNW.SPEC.N.BW.LID.      .1600798.72.15.2.1.
# 2       .VNW.LID.SPEC.WW.N.  .735390.332929.53.22.2.
# 3         .LID.VNW.SPEC.VZ.      .1060098.806.272.1.
# 4        .VNW.VG.SPEC.N.WW.   .532576.432794.51.2.1.
# ...                     ...                      ...
# 437498               .SPEC.                      .1.
# 437499               .SPEC.                      .1.
# 437500               .SPEC.                      .1.
# 437501               .SPEC.                      .1.
# 437502               .SPEC.                      .1.
#
#                   all.pos.lemma.freq
# 0                .1743944.448.134.1.
# 1                .1600798.72.50.2.1.
# 2       .735395.332929.53.845403.31.
# 3                .1062748.806.272.1.
# 4             .532576.432794.51.9.1.
# ...                              ...
# 437498                           .1.
# 437499                           .1.
# 437500                           .1.
# 437501                           .1.
# 437502                           .1.
#
# [437503 rows x 17 columns]

# %%
celex_syllables = pd.read_csv('/home/neel/Desktop/sublexical_crossmodal/dutch_celex_database_updated.csv')

# %%
celex_syllables
# Out:
#         n_word   IdNum       Head  phone_full  syl_num  phone_num phone_clean  \
# 0            1       1          a          'a        1          1         .a.
# 1            2       5      Aagje      'ax-j@        2          4      .axj@.
# 2            3       6       aagt        'axt        1          3       .axt.
# 3            4       7  aagtappel  'axt-A-p@l        3          7   .axtAp@l.
# 4            5       8        aai         'aj        1          2        .aj.
# ...        ...     ...        ...         ...      ...        ...         ...
# 117232  117233  124132     zygoot     zi-'Got        2          5     .ziGot.
# 117233  117234  124133     zygote   zi-'Go-t@        3          6    .ziGot@.
# 117234  117235  124134     zymase   zi-'ma-z@        3          6    .zimaz@.
# 117235  117236  124135     zymose   zi-'mo-z@        3          6    .zimoz@.
# 117236  117237  124136  zymotisch  zi-'mo-tis        3          7   .zimotis.
#
#          phone_CV syl_num_sequence phone_position_syl phone_position_syl_onc  \
# 0             .V.              .1.                .1.                    .n.
# 1          .VCCV.           .1122.             .1212.                 .ncon.
# 2           .VCC.            .111.              .123.                  .ncc.
# 3       .VCCVCVC.        .1112333.          .1231123.              .nccnonc.
# 4            .VC.             .11.               .12.                   .nc.
# ...           ...              ...                ...                    ...
# 117232    .CVCVC.          .11222.            .12123.                .ononc.
# 117233   .CVCVCV.         .112233.           .121212.               .ononon.
# 117234   .CVCVCV.         .112233.           .121212.               .ononon.
# 117235   .CVCVCV.         .112233.           .121212.               .ononon.
# 117236  .CVCVCVC.        .1122333.          .1212123.              .onononc.
#
#        phone_cluster_size phone_cluster_position stress_pattern
# 0                     .1.                    .1.            .s.
# 1                  .1111.                 .1111.           .su.
# 2                   .122.                  .112.            .s.
# 3               .1221111.              .1121111.          .suu.
# 4                    .11.                   .11.            .s.
# ...                   ...                    ...            ...
# 117232            .11111.                .11111.           .us.
# 117233           .111111.               .111111.          .usu.
# 117234           .111111.               .111111.          .usu.
# 117235           .111111.               .111111.          .usu.
# 117236          .1111111.              .1111111.          .usu.
#
# [117237 rows x 14 columns]

# %%
syllables = celex_syllables['phone_full'].apply(lambda x: x.split('-'))
syllables_unique = []
for word in syllables:
    for syl in word:
            syllables_unique.append(syl)

# %%
len(syllables_unique)
# Out:
# 396195

# %%
# #remove apostrophes from every term in syllables_unique
# syllables_unique = [syl.replace("'", "") for syl in syllables_unique]  
# #remove apostrophes from every term in celex_syllables['phone_full']
# celex_syllables['phone_full'] = celex_syllables['phone_full'].apply(lambda x: x.replace("'", ""))

# %%
celex_syllables
# Out:
#         n_word   IdNum       Head  phone_full  syl_num  phone_num phone_clean  \
# 0            1       1          a          'a        1          1         .a.
# 1            2       5      Aagje      'ax-j@        2          4      .axj@.
# 2            3       6       aagt        'axt        1          3       .axt.
# 3            4       7  aagtappel  'axt-A-p@l        3          7   .axtAp@l.
# 4            5       8        aai         'aj        1          2        .aj.
# ...        ...     ...        ...         ...      ...        ...         ...
# 117232  117233  124132     zygoot     zi-'Got        2          5     .ziGot.
# 117233  117234  124133     zygote   zi-'Go-t@        3          6    .ziGot@.
# 117234  117235  124134     zymase   zi-'ma-z@        3          6    .zimaz@.
# 117235  117236  124135     zymose   zi-'mo-z@        3          6    .zimoz@.
# 117236  117237  124136  zymotisch  zi-'mo-tis        3          7   .zimotis.
#
#          phone_CV syl_num_sequence phone_position_syl phone_position_syl_onc  \
# 0             .V.              .1.                .1.                    .n.
# 1          .VCCV.           .1122.             .1212.                 .ncon.
# 2           .VCC.            .111.              .123.                  .ncc.
# 3       .VCCVCVC.        .1112333.          .1231123.              .nccnonc.
# 4            .VC.             .11.               .12.                   .nc.
# ...           ...              ...                ...                    ...
# 117232    .CVCVC.          .11222.            .12123.                .ononc.
# 117233   .CVCVCV.         .112233.           .121212.               .ononon.
# 117234   .CVCVCV.         .112233.           .121212.               .ononon.
# 117235   .CVCVCV.         .112233.           .121212.               .ononon.
# 117236  .CVCVCVC.        .1122333.          .1212123.              .onononc.
#
#        phone_cluster_size phone_cluster_position stress_pattern
# 0                     .1.                    .1.            .s.
# 1                  .1111.                 .1111.           .su.
# 2                   .122.                  .112.            .s.
# 3               .1221111.              .1121111.          .suu.
# 4                    .11.                   .11.            .s.
# ...                   ...                    ...            ...
# 117232            .11111.                .11111.           .us.
# 117233           .111111.               .111111.          .usu.
# 117234           .111111.               .111111.          .usu.
# 117235           .111111.               .111111.          .usu.
# 117236          .1111111.              .1111111.          .usu.
#
# [117237 rows x 14 columns]

# %%
new_df = celex_syllables[['Head','phone_full']]
new_df.rename(columns = {'Head':'Word', 'phone_full':'Syllables'}, inplace = True)
#merge new_df with subtlex on 'Word' but only keep 'FREQcount' and 'Zipf' from subtlex
new_df = new_df.merge(subtlex[['Word','FREQcount','Zipf']], on = 'Word', how = 'left')
new_df
# Out:
# /tmp/ipykernel_2283657/297149493.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns = {'Head':'Word', 'phone_full':'Syllables'}, inplace = True)
#              Word   Syllables  FREQcount      Zipf
# 0               a          'a     1462.0  4.520747
# 1           Aagje      'ax-j@        NaN       NaN
# 2            aagt        'axt        NaN       NaN
# 3       aagtappel  'axt-A-p@l        NaN       NaN
# 4             aai         'aj       31.0  2.860652
# ...           ...         ...        ...       ...
# 117232     zygoot     zi-'Got        1.0  1.656532
# 117233     zygote   zi-'Go-t@        1.0  1.656532
# 117234     zymase   zi-'ma-z@        NaN       NaN
# 117235     zymose   zi-'mo-z@        NaN       NaN
# 117236  zymotisch  zi-'mo-tis        NaN       NaN
#
# [117237 rows x 4 columns]

# %%
#drop rows with NaN values in FREQcount
#new_df = new_df.dropna(subset = ['FREQcount'])
#reset index
new_df = new_df.reset_index(drop = True)
new_df
# Out:
#              Word   Syllables  FREQcount      Zipf
# 0               a          'a     1462.0  4.520747
# 1           Aagje      'ax-j@        NaN       NaN
# 2            aagt        'axt        NaN       NaN
# 3       aagtappel  'axt-A-p@l        NaN       NaN
# 4             aai         'aj       31.0  2.860652
# ...           ...         ...        ...       ...
# 117232     zygoot     zi-'Got        1.0  1.656532
# 117233     zygote   zi-'Go-t@        1.0  1.656532
# 117234     zymase   zi-'ma-z@        NaN       NaN
# 117235     zymose   zi-'mo-z@        NaN       NaN
# 117236  zymotisch  zi-'mo-tis        NaN       NaN
#
# [117237 rows x 4 columns]

# %%
new_df.rename(columns ={'Syllables':'Phonetic'}, inplace = True)
new_df['Syllables'] = new_df['Phonetic'].apply(lambda x: x.split('-'))
new_df
# Out:
#              Word    Phonetic  FREQcount      Zipf       Syllables
# 0               a          'a     1462.0  4.520747            ['a]
# 1           Aagje      'ax-j@        NaN       NaN       ['ax, j@]
# 2            aagt        'axt        NaN       NaN          ['axt]
# 3       aagtappel  'axt-A-p@l        NaN       NaN  ['axt, A, p@l]
# 4             aai         'aj       31.0  2.860652           ['aj]
# ...           ...         ...        ...       ...             ...
# 117232     zygoot     zi-'Got        1.0  1.656532      [zi, 'Got]
# 117233     zygote   zi-'Go-t@        1.0  1.656532   [zi, 'Go, t@]
# 117234     zymase   zi-'ma-z@        NaN       NaN   [zi, 'ma, z@]
# 117235     zymose   zi-'mo-z@        NaN       NaN   [zi, 'mo, z@]
# 117236  zymotisch  zi-'mo-tis        NaN       NaN  [zi, 'mo, tis]
#
# [117237 rows x 5 columns]

# %%
new_df.to_csv('/home/neel/Desktop/sublexical_crossmodal/subtlex_v2_celex_intersect_phonetic_counts.csv', index = False)
#new_df.to_excel('/home/neel/Desktop/sublexical_crossmodal/subtlex_v2_celex_intersect_phonetic_counts.xlsx', index = False)

# %%
#drop duplicates in syllables_unique
syllables_unique = list(set(syllables_unique))
len(syllables_unique)
# Out:
# 13034

# %%
# Initialize a dictionary to count occurrences of each syllable
syllable_counts = {syllable: 0 for syllable in syllables_unique}
print(len(syllable_counts))
# Out:
# 13034

# %%
# Iterate through each syllable and use list comprehension to count occurrences
for syllable in syllables_unique:
    # Create a boolean mask where the syllable is present in the 'Syllables' column
    mask = new_df['Syllables'].apply(lambda x: syllable in x)
    # Sum the 'FREQcount' values where the mask is True
    syllable_counts[syllable] = new_df.loc[mask, 'FREQcount'].sum()

# Print the count of each syllable
for syllable, count in syllable_counts.items():
    print(f"Syllable: {syllable}, Count: {count}")
# Out:
# Syllable: drwA, Count: 0.0
# Syllable: daG, Count: 0.0
# Syllable: sxOg, Count: 3.0
# Syllable: 'trop, Count: 44.0
# Syllable: 'hLf, Count: 22.0
# Syllable: 'vKx, Count: 10.0
# Syllable: 'il, Count: 9.0
# Syllable: 'm}lt, Count: 29.0
# Syllable: t@ns, Count: 33.0
# Syllable: 'blIk, Count: 2402.0
# Syllable: 'wOtS, Count: 2.0
# Syllable: bOks, Count: 49.0
# Syllable: kek, Count: 39.0
# Syllable: 'trEf, Count: 188.0
# Syllable: 'stM, Count: 30.0
# Syllable: 'x}st, Count: 28.0
# Syllable: 'klAn, Count: 37.0
# Syllable: 'l}nS, Count: 2106.0
# Syllable: 'buts, Count: 34.0
# Syllable: vOlkt, Count: 22.0
# Syllable: 'kOrps, Count: 79.0
# Syllable: 'tat, Count: 1033.0
# Syllable: Ges, Count: 0.0
# Syllable: 'Md, Count: 32.0
# Syllable: fux, Count: 0.0
# Syllable: 'huts, Count: 8.0
# Syllable: 'wOlkt, Count: 74.0
# Syllable: 'b}rxt, Count: 36.0
# Syllable: 'pl}g, Count: 1.0
# Syllable: kAr, Count: 1629.0
# Syllable: GrAxt, Count: 0.0
# Syllable: 'INk, Count: 4.0
# Syllable: 'klOt, Count: 2.0
# Syllable: 'kOt, Count: 376.0
# Syllable: dErm, Count: 0.0
# Syllable: stOr, Count: 717.0
# Syllable: Zu, Count: 2.0
# Syllable: twar, Count: 0.0
# Syllable: 'drIl, Count: 43.0
# Syllable: has, Count: 153.0
# Syllable: xAlx, Count: 0.0
# Syllable: 'hAS, Count: 162.0
# Syllable: 'kek, Count: 432.0
# Syllable: 'knO, Count: 476.0
# Syllable: fr}s, Count: 233.0
# Syllable: sxrK, Count: 986.0
# Syllable: pEnt, Count: 0.0
# Syllable: 'dar, Count: 131707.0
# Syllable: 'zor, Count: 0.0
# Syllable: 'plAs, Count: 501.0
# Syllable: 'dAm, Count: 569.0
# Syllable: 'n}k, Count: 2.0
# Syllable: 'brAn, Count: 2165.0
# Syllable: p}r, Count: 4.0
# Syllable: 'fKt, Count: 1949.0
# Syllable: 'blMw, Count: 1559.0
# Syllable: 'my, Count: 879.0
# Syllable: vlAx, Count: 2.0
# Syllable: 'jun, Count: 7981.0
# Syllable: n}l, Count: 75.0
# Syllable: 'drKns, Count: 0.0
# Syllable: 'gr), Count: 101.0
# Syllable: 'stels, Count: 1.0
# Syllable: 'tEts, Count: 0.0
# Syllable: 'zwef, Count: 64.0
# Syllable: 'sx}l, Count: 8708.0
# Syllable: dwe, Count: 1.0
# Syllable: S@n, Count: 24.0
# Syllable: kno, Count: 108.0
# Syllable: 'lAkt, Count: 13.0
# Syllable: 'Gral, Count: 9.0
# Syllable: rog, Count: 1.0
# Syllable: drAj, Count: 6.0
# Syllable: d@lt, Count: 179.0
# Syllable: pKt, Count: 13.0
# Syllable: 'swE, Count: 69.0
# Syllable: 'tAg, Count: 4.0
# Syllable: 'wElp, Count: 32.0
# Syllable: 'tAp, Count: 35.0
# Syllable: 'plats, Count: 9623.0
# Syllable: 'bOx, Count: 4.0
# Syllable: 'trAps, Count: 1.0
# Syllable: 's}, Count: 2246.0
# Syllable: pr}, Count: 5.0
# Syllable: lANs, Count: 1017.0
# Syllable: jEnt, Count: 0.0
# Syllable: p}lk, Count: 0.0
# Syllable: 'rLn, Count: 22.0
# Syllable: por, Count: 1.0
# Syllable: 'wIs, Count: 1970.0
# Syllable: 'sn|, Count: 178.0
# Syllable: wAn, Count: 1031.0
# Syllable: 'kryt, Count: 90.0
# Syllable: 'xOt, Count: 271.0
# Syllable: GrKn, Count: 1.0
# Syllable: 'So, Count: 147.0
# Syllable: gO, Count: 0.0
# Syllable: dEn, Count: 3263.0
# Syllable: he, Count: 28355.0
# Syllable: wIn, Count: 501.0
# Syllable: 'griN, Count: 1.0
# Syllable: kOG, Count: 1.0
# Syllable: G|l, Count: 16.0
# Syllable: 'wErp, Count: 423.0
# Syllable: 'lEnt, Count: 1730.0
# Syllable: 'dAx, Count: 43430.0
# Syllable: 'wIk, Count: 5.0
# Syllable: krAxt, Count: 1266.0
# Syllable: 'kES, Count: 382.0
# Syllable: dAn, Count: 375.0
# Syllable: dar, Count: 22959.0
# Syllable: tros, Count: 4.0
# Syllable: SIn, Count: 0.0
# Syllable: 'zwIt, Count: 0.0
# Syllable: 'saj, Count: 1396.0
# Syllable: 'gu, Count: 16.0
# Syllable: 'rMnt, Count: 1.0
# Syllable: 'boxt, Count: 0.0
# Syllable: 'kaps, Count: 0.0
# Syllable: 'lom, Count: 21.0
# Syllable: stEnt, Count: 26.0
# Syllable: 'SwuN, Count: 2.0
# Syllable: r@G, Count: 16.0
# Syllable: torts, Count: 0.0
# Syllable: 'sx}rk, Count: 506.0
# Syllable: rumt, Count: 41.0
# Syllable: 'psAl, Count: 0.0
# Syllable: 'Grift, Count: 9.0
# Syllable: 'tirs, Count: 1.0
# Syllable: 'xMw, Count: 2652.0
# Syllable: '_Ak, Count: 0.0
# Syllable: 'w@, Count: 443891.0
# Syllable: 'pM, Count: 1208.0
# Syllable: lKmt, Count: 0.0
# Syllable: 'bas, Count: 7422.0
# Syllable: 'vris, Count: 78.0
# Syllable: 'vAmp, Count: 11.0
# Syllable: 'mOnts, Count: 1.0
# Syllable: 'vlOt, Count: 307.0
# Syllable: nAs, Count: 503.0
# Syllable: 'plA, Count: 1061.0
# Syllable: 'spir, Count: 243.0
# Syllable: 'dEn, Count: 1055.0
# Syllable: 'kElt, Count: 0.0
# Syllable: 'tret, Count: 0.0
# Syllable: 'rKgz, Count: 17.0
# Syllable: 'brigz, Count: 0.0
# Syllable: I, Count: 2648.0
# Syllable: 'Elk, Count: 6244.0
# Syllable: 'nIn, Count: 0.0
# Syllable: Glut, Count: 4.0
# Syllable: n@nt, Count: 1061.0
# Syllable: 'ardz, Count: 148.0
# Syllable: ars, Count: 0.0
# Syllable: rIn, Count: 0.0
# Syllable: 'z}x, Count: 54.0
# Syllable: rIp, Count: 2.0
# Syllable: tjO, Count: 0.0
# Syllable: 'st|m, Count: 36.0
# Syllable: zAk, Count: 200.0
# Syllable: 'xaz, Count: 0.0
# Syllable: 'stard, Count: 3.0
# Syllable: sx|, Count: 49.0
# Syllable: 'bOm, Count: 2389.0
# Syllable: GrLs, Count: 8.0
# Syllable: rMw, Count: 0.0
# Syllable: 'Grujd, Count: 0.0
# Syllable: 'zIt, Count: 48568.0
# Syllable: 'mKl, Count: 719.0
# Syllable: 'krEnt, Count: 67.0
# Syllable: dEr, Count: 351.0
# Syllable: nAx, Count: 0.0
# Syllable: 'mEl, Count: 1726.0
# Syllable: bor, Count: 133.0
# Syllable: 'b}ks, Count: 9.0
# Syllable: 'vlK, Count: 180.0
# Syllable: 'drM, Count: 28.0
# Syllable: sonz, Count: 26.0
# Syllable: 'drAs, Count: 103.0
# Syllable: 'fr}l, Count: 0.0
# Syllable: v}, Count: 388.0
# Syllable: slaG, Count: 0.0
# Syllable: 'pleG, Count: 98.0
# Syllable: fam, Count: 2.0
# Syllable: lir, Count: 84.0
# Syllable: 'krAxts, Count: 1.0
# Syllable: 'pLt, Count: 304.0
# Syllable: xlIt, Count: 0.0
# Syllable: 'Ex, Count: 859.0
# Syllable: 'trax, Count: 449.0
# Syllable: slIp, Count: 1.0
# Syllable: 'wem, Count: 0.0
# Syllable: 'kruG, Count: 10.0
# Syllable: t@, Count: 603753.0
# Syllable: 'dox, Count: 0.0
# Syllable: GEns, Count: 12.0
# Syllable: xik, Count: 0.0
# Syllable: 'gri, Count: 11.0
# Syllable: 'l}t, Count: 6.0
# Syllable: kl|rt, Count: 6.0
# Syllable: 'vrint, Count: 23285.0
# Syllable: 'grin, Count: 332.0
# Syllable: 'sAxt, Count: 4.0
# Syllable: 'pr}l, Count: 46.0
# Syllable: spIl, Count: 1.0
# Syllable: tEnt, Count: 120.0
# Syllable: 'bl}f, Count: 149.0
# Syllable: 'SIst, Count: 111.0
# Syllable: 'plKt, Count: 154.0
# Syllable: 'smel, Count: 0.0
# Syllable: 'fKnt, Count: 2.0
# Syllable: 'zwe, Count: 1043.0
# Syllable: 'ki, Count: 7063.0
# Syllable: 'nart, Count: 0.0
# Syllable: 'dOrs, Count: 24.0
# Syllable: 'nIm, Count: 19.0
# Syllable: tem, Count: 621.0
# Syllable: kMw, Count: 20.0
# Syllable: Gud, Count: 43.0
# Syllable: duS, Count: 1.0
# Syllable: 'kl|ms, Count: 0.0
# Syllable: 'zEx, Count: 48766.0
# Syllable: mOk, Count: 0.0
# Syllable: GOn, Count: 22.0
# Syllable: 'dirs, Count: 0.0
# Syllable: os, Count: 5.0
# Syllable: 'bAjn, Count: 7.0
# Syllable: 'krI, Count: 177.0
# Syllable: 'ham, Count: 0.0
# Syllable: 'trOn, Count: 153.0
# Syllable: snM, Count: 8.0
# Syllable: GAst, Count: 115.0
# Syllable: 'numt, Count: 1671.0
# Syllable: lax, Count: 577.0
# Syllable: fyr, Count: 250.0
# Syllable: 'smEG, Count: 1.0
# Syllable: Oj, Count: 3.0
# Syllable: kaj, Count: 7.0
# Syllable: sIks, Count: 0.0
# Syllable: 'myr, Count: 3021.0
# Syllable: 'luS, Count: 77.0
# Syllable: 'skAlt, Count: 0.0
# Syllable: GrOn, Count: 0.0
# Syllable: zOr, Count: 94.0
# Syllable: vIdz, Count: 0.0
# Syllable: 'lars, Count: 183.0
# Syllable: plAn, Count: 768.0
# Syllable: 'dLN, Count: 0.0
# Syllable: 'tru, Count: 525.0
# Syllable: sixts, Count: 0.0
# Syllable: l@ns, Count: 36.0
# Syllable: lANk, Count: 6.0
# Syllable: 'tint, Count: 0.0
# Syllable: At, Count: 8152.0
# Syllable: 'vMw, Count: 77.0
# Syllable: tjAN, Count: 0.0
# Syllable: 'wAz, Count: 168.0
# Syllable: 'm|r, Count: 452.0
# Syllable: 'Zirz, Count: 2.0
# Syllable: 'xlK, Count: 266.0
# Syllable: 'trEv, Count: 13.0
# Syllable: flOt, Count: 9.0
# Syllable: 'bler, Count: 0.0
# Syllable: sxAbz, Count: 42.0
# Syllable: sprON, Count: 602.0
# Syllable: 'kju, Count: 15.0
# Syllable: 'hIpt, Count: 0.0
# Syllable: 'wri, Count: 14.0
# Syllable: l@N, Count: 0.0
# Syllable: 'smES, Count: 11.0
# Syllable: 'drOG, Count: 3.0
# Syllable: 'zem, Count: 5.0
# Syllable: 'wOr, Count: 54147.0
# Syllable: G}l, Count: 0.0
# Syllable: 'deG, Count: 3.0
# Syllable: 'drENg, Count: 0.0
# Syllable: 'drONk, Count: 753.0
# Syllable: 'fi, Count: 2343.0
# Syllable: 'bomt, Count: 0.0
# Syllable: 'hAgd, Count: 50.0
# Syllable: braf, Count: 0.0
# Syllable: 'xri, Count: 636.0
# Syllable: 'med, Count: 17.0
# Syllable: twA, Count: 2049.0
# Syllable: xans, Count: 30.0
# Syllable: nIN, Count: 24287.0
# Syllable: 'pAx, Count: 9.0
# Syllable: 'ens, Count: 65553.0
# Syllable: 'stLp, Count: 18.0
# Syllable: 'lir, Count: 849.0
# Syllable: 'SAr, Count: 368.0
# Syllable: 'blekt, Count: 0.0
# Syllable: 'lys, Count: 0.0
# Syllable: kEr, Count: 3.0
# Syllable: 'vrest, Count: 146.0
# Syllable: 'stIxt, Count: 309.0
# Syllable: ver, Count: 29.0
# Syllable: 'kr|, Count: 257.0
# Syllable: 'drEz, Count: 35.0
# Syllable: plEx, Count: 12.0
# Syllable: 'xrKs, Count: 387.0
# Syllable: 'xEm, Count: 73.0
# Syllable: 'hOnts, Count: 22.0
# Syllable: 'tSAj, Count: 0.0
# Syllable: vKf, Count: 23.0
# Syllable: 'k|, Count: 6708.0
# Syllable: b}dz, Count: 0.0
# Syllable: rOf, Count: 0.0
# Syllable: 'vwA, Count: 32.0
# Syllable: 'prLk, Count: 285.0
# Syllable: 'spreg, Count: 87.0
# Syllable: 'plEmp, Count: 0.0
# Syllable: 'pAn, Count: 2723.0
# Syllable: 'pra, Count: 28286.0
# Syllable: 'sprInt, Count: 48.0
# Syllable: kys, Count: 0.0
# Syllable: sert, Count: 0.0
# Syllable: vju, Count: 0.0
# Syllable: 'Gly, Count: 38.0
# Syllable: 'vElt, Count: 909.0
# Syllable: 'tLs, Count: 18006.0
# Syllable: boms, Count: 0.0
# Syllable: wEns, Count: 6.0
# Syllable: jIxt, Count: 4.0
# Syllable: 'kin, Count: 15.0
# Syllable: 'wOnt, Count: 3330.0
# Syllable: 'kart, Count: 1418.0
# Syllable: v@nt, Count: 3385.0
# Syllable: 'wel, Count: 2081.0
# Syllable: 'nuxt, Count: 13.0
# Syllable: 'vrMws, Count: 2.0
# Syllable: ler, Count: 105.0
# Syllable: 'drKf, Count: 3396.0
# Syllable: f@ns, Count: 10.0
# Syllable: mants, Count: 0.0
# Syllable: kErk, Count: 32.0
# Syllable: hoft, Count: 1274.0
# Syllable: 'vri, Count: 500.0
# Syllable: trAr, Count: 1.0
# Syllable: 'rAms, Count: 0.0
# Syllable: pArt, Count: 164.0
# Syllable: kEst, Count: 17.0
# Syllable: pOs, Count: 99.0
# Syllable: 'druft, Count: 241.0
# Syllable: 'stLt, Count: 50.0
# Syllable: 'sputs, Count: 0.0
# Syllable: bEk, Count: 166.0
# Syllable: 'slir, Count: 0.0
# Syllable: bOrs, Count: 24.0
# Syllable: 'krLs, Count: 1399.0
# Syllable: wOl, Count: 19.0
# Syllable: El, Count: 25338.0
# Syllable: 'kMz, Count: 1.0
# Syllable: lIm, Count: 269.0
# Syllable: 'tum, Count: 1.0
# Syllable: 'vir, Count: 14640.0
# Syllable: brAnt, Count: 368.0
# Syllable: 'ur, Count: 222.0
# Syllable: lKnt, Count: 8.0
# Syllable: 'bOns, Count: 147.0
# Syllable: 'pAft, Count: 0.0
# Syllable: hud, Count: 5.0
# Syllable: 'swAs, Count: 5.0
# Syllable: kret, Count: 40.0
# Syllable: brus, Count: 0.0
# Syllable: tIN, Count: 12923.0
# Syllable: wis, Count: 0.0
# Syllable: drIn, Count: 29.0
# Syllable: 'rMt, Count: 10.0
# Syllable: frL, Count: 0.0
# Syllable: 'tKN, Count: 2.0
# Syllable: klOmp, Count: 22.0
# Syllable: 'ler, Count: 3530.0
# Syllable: prEz, Count: 4.0
# Syllable: lest, Count: 0.0
# Syllable: smIt, Count: 49.0
# Syllable: 'ber, Count: 1178.0
# Syllable: fLk, Count: 1.0
# Syllable: 'jal, Count: 3650.0
# Syllable: 'tSum, Count: 0.0
# Syllable: sxOd, Count: 0.0
# Syllable: 'kIk, Count: 312.0
# Syllable: 'stem, Count: 57.0
# Syllable: 'pAGd, Count: 2.0
# Syllable: plM, Count: 43.0
# Syllable: 'GIN, Count: 5.0
# Syllable: 'klOn, Count: 8.0
# Syllable: krK, Count: 306.0
# Syllable: 'bLlt, Count: 0.0
# Syllable: 'het, Count: 14866.0
# Syllable: 'kry, Count: 60.0
# Syllable: krAs, Count: 6.0
# Syllable: 'wan, Count: 932.0
# Syllable: 'sxOkt, Count: 0.0
# Syllable: 'sn}r, Count: 60.0
# Syllable: 'tIrs, Count: 0.0
# Syllable: 'kOts, Count: 216.0
# Syllable: 'mjEn, Count: 0.0
# Syllable: mEst, Count: 52.0
# Syllable: 'rir, Count: 297.0
# Syllable: 'xryw, Count: 0.0
# Syllable: 'pKlt, Count: 0.0
# Syllable: vIz, Count: 0.0
# Syllable: wK, Count: 2383.0
# Syllable: hAn, Count: 1485.0
# Syllable: 'lIp, Count: 451.0
# Syllable: 'kil, Count: 393.0
# Syllable: 'strK, Count: 1335.0
# Syllable: 'jAnt, Count: 1131.0
# Syllable: 'lArf, Count: 0.0
# Syllable: 'mInst, Count: 13.0
# Syllable: h}t, Count: 55.0
# Syllable: 'lArk, Count: 17.0
# Syllable: Gir, Count: 0.0
# Syllable: 'tr)r, Count: 2.0
# Syllable: weg, Count: 0.0
# Syllable: 'pOp, Count: 1513.0
# Syllable: 'bEkt, Count: 6.0
# Syllable: 'ax, Count: 0.0
# Syllable: z@, Count: 133611.0
# Syllable: h}lst, Count: 0.0
# Syllable: 'fInt, Count: 0.0
# Syllable: fi, Count: 16404.0
# Syllable: 'pAk, Count: 14916.0
# Syllable: fAj, Count: 8.0
# Syllable: 'skI, Count: 4.0
# Syllable: 'druf, Count: 85.0
# Syllable: 'lAjnz, Count: 0.0
# Syllable: zM, Count: 1.0
# Syllable: 'nAnt, Count: 2786.0
# Syllable: hOp, Count: 0.0
# Syllable: 'drEm, Count: 122.0
# Syllable: 'GrA, Count: 1664.0
# Syllable: SIN, Count: 0.0
# Syllable: bret, Count: 33.0
# Syllable: 'Lt, Count: 187852.0
# Syllable: 'krag, Count: 29.0
# Syllable: 'frAN, Count: 98.0
# Syllable: 'zOt, Count: 169.0
# Syllable: 'tIs, Count: 281.0
# Syllable: wElf, Count: 5.0
# Syllable: 'bEnt, Count: 3467.0
# Syllable: 'vOs, Count: 332.0
# Syllable: 'SrEp, Count: 2.0
# Syllable: 'vOr, Count: 1563.0
# Syllable: sat, Count: 6.0
# Syllable: f}Nk, Count: 298.0
# Syllable: 'trAm, Count: 89.0
# Syllable: dOns, Count: 6.0
# Syllable: bem, Count: 1.0
# Syllable: 'drINg, Count: 24.0
# Syllable: 'GAp, Count: 1.0
# Syllable: 'brLks, Count: 50.0
# Syllable: pol, Count: 294.0
# Syllable: wef, Count: 37.0
# Syllable: 'vler, Count: 141.0
# Syllable: 'jK, Count: 195609.0
# Syllable: 'dwKl, Count: 73.0
# Syllable: 'jIx, Count: 0.0
# Syllable: 'lAns, Count: 510.0
# Syllable: j@ns, Count: 0.0
# Syllable: z}, Count: 0.0
# Syllable: 'sx}p, Count: 8.0
# Syllable: 'tErn, Count: 97.0
# Syllable: 'fIk, Count: 483.0
# Syllable: pil, Count: 13.0
# Syllable: 'stIg, Count: 8.0
# Syllable: fe, Count: 1837.0
# Syllable: 'sint, Count: 4.0
# Syllable: N@rt, Count: 603.0
# Syllable: 'lInS, Count: 31.0
# Syllable: xOr, Count: 314.0
# Syllable: 'sANkt, Count: 0.0
# Syllable: tEst, Count: 97.0
# Syllable: 'hLl, Count: 67.0
# Syllable: 'smet, Count: 71.0
# Syllable: 'jap, Count: 20.0
# Syllable: j|, Count: 11.0
# Syllable: klet, Count: 313.0
# Syllable: 'vKj, Count: 1.0
# Syllable: Girst, Count: 0.0
# Syllable: 'kAlf, Count: 135.0
# Syllable: kwIk, Count: 0.0
# Syllable: sprANk, Count: 0.0
# Syllable: 'tEs, Count: 1228.0
# Syllable: 'z), Count: 0.0
# Syllable: wax, Count: 7.0
# Syllable: kwAs, Count: 0.0
# Syllable: 'xO, Count: 1162.0
# Syllable: 'twIN, Count: 13.0
# Syllable: 'vr|G, Count: 635.0
# Syllable: g@l, Count: 971.0
# Syllable: 'snLf, Count: 125.0
# Syllable: 'k}p, Count: 63.0
# Syllable: kAf, Count: 0.0
# Syllable: 'xyr, Count: 5.0
# Syllable: j}n, Count: 0.0
# Syllable: j@t, Count: 0.0
# Syllable: 'ZAm, Count: 0.0
# Syllable: 'bOg, Count: 0.0
# Syllable: kwAm, Count: 0.0
# Syllable: 'lIs, Count: 1256.0
# Syllable: 'krAk, Count: 7.0
# Syllable: jL, Count: 30.0
# Syllable: pElt, Count: 0.0
# Syllable: 'em, Count: 40.0
# Syllable: 'bron, Count: 0.0
# Syllable: 'd|xt, Count: 374.0
# Syllable: 'bus, Count: 2.0
# Syllable: wIst, Count: 0.0
# Syllable: 'flLs, Count: 284.0
# Syllable: 'tS}t, Count: 10.0
# Syllable: 'zAkt, Count: 264.0
# Syllable: 'bOn, Count: 2296.0
# Syllable: 'zwInt, Count: 14.0
# Syllable: b}x, Count: 4.0
# Syllable: bEn, Count: 1378.0
# Syllable: laG, Count: 6.0
# Syllable: slEm, Count: 0.0
# Syllable: 'splKt, Count: 26.0
# Syllable: wE, Count: 1563.0
# Syllable: krek, Count: 0.0
# Syllable: 'bris, Count: 121.0
# Syllable: hir, Count: 2227.0
# Syllable: 'Sert, Count: 27.0
# Syllable: 'if, Count: 1.0
# Syllable: mAj, Count: 0.0
# Syllable: 'fIs, Count: 87.0
# Syllable: hOnt, Count: 401.0
# Syllable: 'zKnz, Count: 0.0
# Syllable: 'wAk, Count: 18.0
# Syllable: 'hErfst, Count: 410.0
# Syllable: 'n*, Count: 67.0
# Syllable: 'spEx, Count: 0.0
# Syllable: 'fA, Count: 2572.0
# Syllable: knop, Count: 25.0
# Syllable: n@rs, Count: 6.0
# Syllable: trIk, Count: 13.0
# Syllable: vMts, Count: 1.0
# Syllable: 'stju, Count: 61.0
# Syllable: sINs, Count: 90.0
# Syllable: tre, Count: 604.0
# Syllable: dAp, Count: 1.0
# Syllable: 'xEn, Count: 86.0
# Syllable: 'SEm, Count: 0.0
# Syllable: lEb, Count: 0.0
# Syllable: 'tiS, Count: 6.0
# Syllable: 'tuf, Count: 6.0
# Syllable: tro, Count: 3728.0
# Syllable: 'rKt, Count: 2161.0
# Syllable: 'jObz, Count: 0.0
# Syllable: sprak, Count: 6863.0
# Syllable: swaj, Count: 0.0
# Syllable: 'vjuw, Count: 26.0
# Syllable: 'dLm, Count: 520.0
# Syllable: 'b}nt, Count: 0.0
# Syllable: 's)r, Count: 241.0
# Syllable: 'swAx, Count: 0.0
# Syllable: 's), Count: 335.0
# Syllable: 'mAxts, Count: 77.0
# Syllable: 'p}lz, Count: 0.0
# Syllable: f}, Count: 66.0
# Syllable: s@mt, Count: 2.0
# Syllable: GANz, Count: 14.0
# Syllable: sIl, Count: 7.0
# Syllable: 'wunz, Count: 933.0
# Syllable: 'nuG, Count: 59.0
# Syllable: 'lAn, Count: 3799.0
# Syllable: st@xt, Count: 0.0
# Syllable: 'sxEnt, Count: 0.0
# Syllable: dAnt, Count: 79.0
# Syllable: 'krOb, Count: 0.0
# Syllable: 'waf, Count: 0.0
# Syllable: ris, Count: 753.0
# Syllable: vIr, Count: 71.0
# Syllable: 'k}t, Count: 552.0
# Syllable: 'xel, Count: 451.0
# Syllable: 'hers, Count: 0.0
# Syllable: 'Ge, Count: 31147.0
# Syllable: 'zIlt, Count: 1.0
# Syllable: 'blEk, Count: 0.0
# Syllable: 'lur, Count: 122.0
# Syllable: t@m, Count: 129.0
# Syllable: ramt, Count: 0.0
# Syllable: dwA, Count: 1.0
# Syllable: 'sxAxt, Count: 109.0
# Syllable: ')n, Count: 0.0
# Syllable: 'dwK, Count: 2167.0
# Syllable: 'kArt, Count: 25.0
# Syllable: kl|m, Count: 1.0
# Syllable: la, Count: 9432.0
# Syllable: djOp, Count: 0.0
# Syllable: 'ksit, Count: 4.0
# Syllable: 'strEks, Count: 0.0
# Syllable: 'zAnt, Count: 1163.0
# Syllable: 'krIN, Count: 182.0
# Syllable: 'tun, Count: 47826.0
# Syllable: 'mAm, Count: 6865.0
# Syllable: @m, Count: 15.0
# Syllable: 'vlEt, Count: 0.0
# Syllable: Ent, Count: 4.0
# Syllable: 'niz, Count: 3.0
# Syllable: 'tEf, Count: 15.0
# Syllable: 'stor, Count: 89.0
# Syllable: zoj, Count: 211.0
# Syllable: 'tKl, Count: 6.0
# Syllable: strEkt, Count: 42.0
# Syllable: brENst, Count: 150.0
# Syllable: jan, Count: 0.0
# Syllable: 'daG, Count: 79.0
# Syllable: 'zOx, Count: 7.0
# Syllable: tint, Count: 0.0
# Syllable: rEG, Count: 331.0
# Syllable: ku, Count: 776.0
# Syllable: 'mas, Count: 19.0
# Syllable: brItS, Count: 0.0
# Syllable: fis, Count: 187.0
# Syllable: 'hErvzd, Count: 2.0
# Syllable: 'slAj, Count: 8.0
# Syllable: 'vrom, Count: 70.0
# Syllable: 'stLd, Count: 17.0
# Syllable: SrAm, Count: 12.0
# Syllable: 'Zirs, Count: 76.0
# Syllable: t}s, Count: 1568.0
# Syllable: 'xOrz, Count: 0.0
# Syllable: trAns, Count: 1400.0
# Syllable: 'kLp, Count: 39.0
# Syllable: 'smul, Count: 236.0
# Syllable: 'f*r, Count: 50.0
# Syllable: 'sn}, Count: 224.0
# Syllable: sm}k, Count: 8.0
# Syllable: 'trOj, Count: 0.0
# Syllable: 'knEr, Count: 0.0
# Syllable: pos, Count: 3.0
# Syllable: ZEs, Count: 0.0
# Syllable: warts, Count: 1267.0
# Syllable: d@n, Count: 27.0
# Syllable: nes, Count: 38.0
# Syllable: 'gos, Count: 11.0
# Syllable: kir, Count: 0.0
# Syllable: bOn, Count: 245.0
# Syllable: bus, Count: 0.0
# Syllable: 'hEs, Count: 8.0
# Syllable: SOk, Count: 22.0
# Syllable: 'st}x, Count: 55.0
# Syllable: 'strOf, Count: 5.0
# Syllable: tSIp, Count: 4.0
# Syllable: korts, Count: 110.0
# Syllable: 'mju, Count: 185.0
# Syllable: 'k|s, Count: 2696.0
# Syllable: 'sEk, Count: 1324.0
# Syllable: 'plEn, Count: 11.0
# Syllable: 'tSem, Count: 1.0
# Syllable: kul, Count: 47.0
# Syllable: 'k}rk, Count: 71.0
# Syllable: G|r, Count: 3.0
# Syllable: kIt, Count: 19.0
# Syllable: slLp, Count: 0.0
# Syllable: 'fON, Count: 27.0
# Syllable: son, Count: 577.0
# Syllable: 'del, Count: 8346.0
# Syllable: 'sxAlks, Count: 0.0
# Syllable: x}nst, Count: 68.0
# Syllable: tym, Count: 15.0
# Syllable: 'klOp, Count: 645.0
# Syllable: 'lOz, Count: 99.0
# Syllable: 'rAsp, Count: 6.0
# Syllable: rym, Count: 0.0
# Syllable: 'drist, Count: 7.0
# Syllable: 'dLx, Count: 0.0
# Syllable: 'frwA, Count: 0.0
# Syllable: 'nas, Count: 68.0
# Syllable: GrI, Count: 2.0
# Syllable: 'virt, Count: 149.0
# Syllable: 'dKk, Count: 36.0
# Syllable: 'sprO, Count: 22.0
# Syllable: 'prAxt, Count: 238.0
# Syllable: sEt, Count: 827.0
# Syllable: 'uf, Count: 10.0
# Syllable: z}xt, Count: 46.0
# Syllable: 'mEm, Count: 47.0
# Syllable: pE, Count: 349.0
# Syllable: 'vKn, Count: 212.0
# Syllable: 'sid, Count: 0.0
# Syllable: 'knap, Count: 383.0
# Syllable: rep, Count: 5.0
# Syllable: spI, Count: 320.0
# Syllable: Grep, Count: 156.0
# Syllable: 'kram, Count: 84.0
# Syllable: sxref, Count: 0.0
# Syllable: l@ms, Count: 0.0
# Syllable: 'rirs, Count: 0.0
# Syllable: dunt, Count: 7.0
# Syllable: kil, Count: 2.0
# Syllable: b@l, Count: 4822.0
# Syllable: het, Count: 75.0
# Syllable: 'flArt, Count: 1.0
# Syllable: 'dAxt, Count: 2888.0
# Syllable: 'slKt, Count: 3.0
# Syllable: 'ZEn, Count: 0.0
# Syllable: fat, Count: 4.0
# Syllable: 'tOs, Count: 41.0
# Syllable: snut, Count: 0.0
# Syllable: 'vrMw, Count: 45934.0
# Syllable: kK, Count: 2752.0
# Syllable: 'fEs, Count: 217.0
# Syllable: 'zAxs, Count: 4.0
# Syllable: 'wAjz, Count: 0.0
# Syllable: dyl, Count: 0.0
# Syllable: 'krOxt, Count: 1.0
# Syllable: 'hOrm, Count: 0.0
# Syllable: 'ra, Count: 22473.0
# Syllable: 'mest, Count: 5274.0
# Syllable: Gri, Count: 211.0
# Syllable: 'jLm, Count: 0.0
# Syllable: stL, Count: 8.0
# Syllable: 'kron, Count: 722.0
# Syllable: 'zun, Count: 1481.0
# Syllable: left, Count: 23.0
# Syllable: zIk, Count: 102.0
# Syllable: 'd}m, Count: 547.0
# Syllable: 'v|s, Count: 1879.0
# Syllable: 'pK, Count: 1627.0
# Syllable: 'naf, Count: 16.0
# Syllable: st|r, Count: 0.0
# Syllable: 'erzd, Count: 0.0
# Syllable: 'jE, Count: 147.0
# Syllable: 'tArn, Count: 3.0
# Syllable: 'kr}ks, Count: 9.0
# Syllable: spak, Count: 1.0
# Syllable: frax, Count: 91.0
# Syllable: hElft, Count: 55.0
# Syllable: 'blAN, Count: 2026.0
# Syllable: fIm, Count: 0.0
# Syllable: tEks, Count: 89.0
# Syllable: 'stArd, Count: 63.0
# Syllable: 'wart, Count: 4975.0
# Syllable: 'hO_, Count: 4.0
# Syllable: lyt, Count: 2.0
# Syllable: 'kyp, Count: 2.0
# Syllable: 'flIt, Count: 110.0
# Syllable: 'hAlf, Count: 5152.0
# Syllable: 'xrots, Count: 858.0
# Syllable: dLg, Count: 3.0
# Syllable: 'hAl, Count: 6133.0
# Syllable: 'xIft, Count: 215.0
# Syllable: 'lext, Count: 0.0
# Syllable: 'slOmp, Count: 0.0
# Syllable: dwArz, Count: 0.0
# Syllable: 'lik, Count: 504.0
# Syllable: krOs, Count: 15.0
# Syllable: 'l}st, Count: 837.0
# Syllable: xlM, Count: 10.0
# Syllable: 'zAGd, Count: 0.0
# Syllable: 'Ak, Count: 2443.0
# Syllable: G@rs, Count: 104.0
# Syllable: 'fAl, Count: 0.0
# Syllable: sprIN, Count: 0.0
# Syllable: 'tik, Count: 3955.0
# Syllable: k}ms, Count: 0.0
# Syllable: r@ld, Count: 665.0
# Syllable: vKn, Count: 0.0
# Syllable: z}s, Count: 701.0
# Syllable: 'hag, Count: 2.0
# Syllable: rEkt, Count: 99.0
# Syllable: 'zArt, Count: 42.0
# Syllable: pIN, Count: 2529.0
# Syllable: sxat, Count: 57.0
# Syllable: 'brom, Count: 27.0
# Syllable: 'bAks, Count: 83.0
# Syllable: bruj, Count: 0.0
# Syllable: b|k, Count: 0.0
# Syllable: rarz, Count: 0.0
# Syllable: pot, Count: 103.0
# Syllable: 'L, Count: 4609.0
# Syllable: hIs, Count: 4.0
# Syllable: 'kAt, Count: 2396.0
# Syllable: 'mEtS, Count: 168.0
# Syllable: 'zef, Count: 25.0
# Syllable: 'dOns, Count: 48.0
# Syllable: 'tim, Count: 5488.0
# Syllable: zEp, Count: 0.0
# Syllable: 'zIxts, Count: 159.0
# Syllable: 'bom, Count: 2469.0
# Syllable: kMn, Count: 3.0
# Syllable: 'hAft, Count: 2.0
# Syllable: 'frL, Count: 25.0
# Syllable: @n, Count: 208.0
# Syllable: nAN, Count: 1.0
# Syllable: 'snMw, Count: 13.0
# Syllable: del, Count: 3994.0
# Syllable: ts@, Count: 68.0
# Syllable: klAx, Count: 23.0
# Syllable: '_O, Count: 269.0
# Syllable: 'tIps, Count: 223.0
# Syllable: 'zLt, Count: 393.0
# Syllable: hElm, Count: 10.0
# Syllable: 'O, Count: 6101.0
# Syllable: 'wakt, Count: 17.0
# Syllable: lAr, Count: 10364.0
# Syllable: 'byst, Count: 11.0
# Syllable: p}G, Count: 0.0
# Syllable: 'boz, Count: 32.0
# Syllable: 'stOpt, Count: 3581.0
# Syllable: 'm}x, Count: 99.0
# Syllable: 'n|x, Count: 0.0
# Syllable: 'sl}r, Count: 19.0
# Syllable: 'njel, Count: 14.0
# Syllable: ser, Count: 37.0
# Syllable: dIx, Count: 33.0
# Syllable: r}x, Count: 138.0
# Syllable: blOk, Count: 134.0
# Syllable: 'SErp, Count: 30.0
# Syllable: Gaj, Count: 0.0
# Syllable: fen, Count: 0.0
# Syllable: j@rz, Count: 0.0
# Syllable: 'sa, Count: 7941.0
# Syllable: slAN, Count: 189.0
# Syllable: 'spAts, Count: 46.0
# Syllable: 'hAN, Count: 2512.0
# Syllable: swer, Count: 78.0
# Syllable: 'sat, Count: 2.0
# Syllable: r@k, Count: 0.0
# Syllable: 'tLG, Count: 2.0
# Syllable: 'log, Count: 0.0
# Syllable: Iks, Count: 0.0
# Syllable: 'bleg, Count: 0.0
# Syllable: pram, Count: 0.0
# Syllable: Ern, Count: 4.0
# Syllable: 'sxril, Count: 11.0
# Syllable: dOxt, Count: 48.0
# Syllable: xams, Count: 61.0
# Syllable: 'fran, Count: 14.0
# Syllable: 'kwes, Count: 27.0
# Syllable: 'mInt, Count: 91.0
# Syllable: 'nO, Count: 147.0
# Syllable: 'staN, Count: 0.0
# Syllable: g@n, Count: 62.0
# Syllable: 'pOz, Count: 36.0
# Syllable: hENst, Count: 90.0
# Syllable: hEx, Count: 5.0
# Syllable: dwO, Count: 11.0
# Syllable: 'sxof, Count: 61.0
# Syllable: 'blot, Count: 523.0
# Syllable: ket, Count: 1.0
# Syllable: 'pIts, Count: 1.0
# Syllable: leN, Count: 0.0
# Syllable: kIst, Count: 366.0
# Syllable: zuN, Count: 3.0
# Syllable: sxLf, Count: 0.0
# Syllable: 'sxOks, Count: 0.0
# Syllable: 'stir, Count: 430.0
# Syllable: xez, Count: 19.0
# Syllable: sxErt, Count: 0.0
# Syllable: sOn, Count: 657.0
# Syllable: 'xrAv, Count: 50.0
# Syllable: tAlk, Count: 27.0
# Syllable: 'tarts, Count: 0.0
# Syllable: zIN, Count: 2723.0
# Syllable: 'krOmt, Count: 4.0
# Syllable: zEst, Count: 0.0
# Syllable: 'trEnt, Count: 210.0
# Syllable: pj@z, Count: 0.0
# Syllable: rurt, Count: 21.0
# Syllable: }r, Count: 64.0
# Syllable: 'dEnts, Count: 56.0
# Syllable: slets, Count: 0.0
# Syllable: 'SA, Count: 30.0
# Syllable: 'tr}k, Count: 1541.0
# Syllable: 'Erv, Count: 11.0
# Syllable: 'jes, Count: 1.0
# Syllable: brOns, Count: 1.0
# Syllable: nor, Count: 0.0
# Syllable: 'nan, Count: 233.0
# Syllable: sIt, Count: 96.0
# Syllable: 'mAms, Count: 196.0
# Syllable: kol, Count: 193.0
# Syllable: N@rs, Count: 82.0
# Syllable: 'h}lp, Count: 11101.0
# Syllable: 'krIm, Count: 90.0
# Syllable: tr}st, Count: 0.0
# Syllable: fr|G, Count: 22.0
# Syllable: pKp, Count: 173.0
# Syllable: bLl, Count: 34.0
# Syllable: zwKn, Count: 49.0
# Syllable: 'trA, Count: 1120.0
# Syllable: maj, Count: 1.0
# Syllable: 'm@, Count: 323465.0
# Syllable: 'zAr, Count: 371.0
# Syllable: 'st}d, Count: 1.0
# Syllable: klM, Count: 78.0
# Syllable: 'wKd, Count: 8.0
# Syllable: slet, Count: 0.0
# Syllable: hem, Count: 0.0
# Syllable: b|x, Count: 0.0
# Syllable: 'tris, Count: 49.0
# Syllable: lAjn, Count: 266.0
# Syllable: 'trons, Count: 4.0
# Syllable: 'kri, Count: 873.0
# Syllable: 'lEl, Count: 114.0
# Syllable: lExt, Count: 699.0
# Syllable: bots, Count: 0.0
# Syllable: stI, Count: 1179.0
# Syllable: 'klAb, Count: 8.0
# Syllable: 'skrin, Count: 24.0
# Syllable: 'dOnz, Count: 3.0
# Syllable: 'zAN, Count: 236.0
# Syllable: 'lKst, Count: 2925.0
# Syllable: j|r, Count: 66.0
# Syllable: bMnt, Count: 25.0
# Syllable: 'pOnz, Count: 0.0
# Syllable: flEs, Count: 150.0
# Syllable: 'wM, Count: 751.0
# Syllable: 'vOnt, Count: 11801.0
# Syllable: 'vOlt, Count: 65.0
# Syllable: 'nKl, Count: 73.0
# Syllable: 'Ged, Count: 2.0
# Syllable: kOrn, Count: 361.0
# Syllable: 'hax, Count: 14.0
# Syllable: 'flem, Count: 3.0
# Syllable: 'bak, Count: 4.0
# Syllable: 'brLs, Count: 7.0
# Syllable: pas, Count: 2.0
# Syllable: 'kwEt, Count: 601.0
# Syllable: 'kI, Count: 1482.0
# Syllable: blu, Count: 342.0
# Syllable: t}m, Count: 904.0
# Syllable: 'skrEt, Count: 7.0
# Syllable: 'erst, Count: 271.0
# Syllable: 'tro, Count: 449.0
# Syllable: 'bur, Count: 663.0
# Syllable: 'briv, Count: 1.0
# Syllable: sIft, Count: 0.0
# Syllable: 'lIN, Count: 1323.0
# Syllable: fEst, Count: 76.0
# Syllable: lad, Count: 0.0
# Syllable: 'l}r, Count: 14.0
# Syllable: 'vlEk, Count: 299.0
# Syllable: 'en, Count: 797401.0
# Syllable: mew, Count: 25.0
# Syllable: drON, Count: 97.0
# Syllable: Ger, Count: 1.0
# Syllable: plAN, Count: 1.0
# Syllable: 'dra, Count: 12790.0
# Syllable: zer, Count: 6.0
# Syllable: h)d, Count: 0.0
# Syllable: blots, Count: 37.0
# Syllable: 'slEks, Count: 0.0
# Syllable: 'xrKp, Count: 1275.0
# Syllable: f@n, Count: 225.0
# Syllable: 'brukt, Count: 0.0
# Syllable: vIn, Count: 33.0
# Syllable: 'plAst, Count: 0.0
# Syllable: xK, Count: 13.0
# Syllable: b@rts, Count: 0.0
# Syllable: GAt, Count: 360.0
# Syllable: 'kraN, Count: 0.0
# Syllable: vIks, Count: 9.0
# Syllable: fEl, Count: 12.0
# Syllable: 'tSal, Count: 16.0
# Syllable: wOlfs, Count: 0.0
# Syllable: kElk, Count: 5.0
# Syllable: 'it, Count: 145.0
# Syllable: buts, Count: 13.0
# Syllable: 'stAt, Count: 11933.0
# Syllable: 'bug, Count: 14.0
# Syllable: luj, Count: 0.0
# Syllable: sxElb, Count: 0.0
# Syllable: o, Count: 33065.0
# Syllable: 'brots, Count: 0.0
# Syllable: 'klIk, Count: 63.0
# Syllable: na, Count: 56112.0
# Syllable: sAks, Count: 0.0
# Syllable: 'vlit, Count: 1.0
# Syllable: 'sxLv, Count: 18.0
# Syllable: kAns, Count: 55.0
# Syllable: 'mad, Count: 6.0
# Syllable: 'INkt, Count: 335.0
# Syllable: loft, Count: 73.0
# Syllable: 'mil, Count: 467.0
# Syllable: 'aN, Count: 14469.0
# Syllable: 'bArs, Count: 402.0
# Syllable: fl|, Count: 45.0
# Syllable: hIm, Count: 0.0
# Syllable: kAmp, Count: 311.0
# Syllable: bit, Count: 576.0
# Syllable: tAr, Count: 49.0
# Syllable: nal, Count: 106.0
# Syllable: l@x, Count: 21003.0
# Syllable: dIxt, Count: 299.0
# Syllable: 'hErfs, Count: 0.0
# Syllable: 'k}ns, Count: 1.0
# Syllable: sAlm, Count: 0.0
# Syllable: bom, Count: 409.0
# Syllable: 'spOx, Count: 0.0
# Syllable: 'k)r, Count: 131.0
# Syllable: 'r<, Count: 840.0
# Syllable: xruf, Count: 0.0
# Syllable: 'dOmt, Count: 1336.0
# Syllable: 'krLd, Count: 14.0
# Syllable: 'drOx, Count: 420.0
# Syllable: 'baN, Count: 0.0
# Syllable: 'dwO, Count: 743.0
# Syllable: 'klK, Count: 12063.0
# Syllable: 'sels, Count: 0.0
# Syllable: gem, Count: 5.0
# Syllable: GrO, Count: 0.0
# Syllable: t@rn, Count: 131.0
# Syllable: 'h}N, Count: 31.0
# Syllable: vremt, Count: 1.0
# Syllable: 'pul, Count: 81.0
# Syllable: mAk, Count: 466.0
# Syllable: 'lLk, Count: 303.0
# Syllable: hMts, Count: 21.0
# Syllable: pe, Count: 2984.0
# Syllable: 'ram, Count: 3138.0
# Syllable: Ix, Count: 1.0
# Syllable: mOn, Count: 1790.0
# Syllable: 'tLx, Count: 781.0
# Syllable: 'lok, Count: 168.0
# Syllable: 'sxIx, Count: 17.0
# Syllable: 'stadz, Count: 129.0
# Syllable: klut, Count: 0.0
# Syllable: 'tElx, Count: 18.0
# Syllable: enz, Count: 0.0
# Syllable: dI, Count: 212.0
# Syllable: n@d, Count: 25.0
# Syllable: lAmb, Count: 0.0
# Syllable: 'blik, Count: 2179.0
# Syllable: 'bAr, Count: 3329.0
# Syllable: Ad, Count: 1171.0
# Syllable: 'mal, Count: 67069.0
# Syllable: skri, Count: 0.0
# Syllable: 'dEns, Count: 18.0
# Syllable: 'SEt, Count: 72.0
# Syllable: bKdz, Count: 40.0
# Syllable: ZI, Count: 0.0
# Syllable: 'kojs, Count: 15.0
# Syllable: 'sp|r, Count: 195.0
# Syllable: 'slets, Count: 0.0
# Syllable: 'kMw, Count: 509.0
# Syllable: drLl, Count: 0.0
# Syllable: xen, Count: 62.0
# Syllable: 'nirt, Count: 47.0
# Syllable: 'kwElm, Count: 0.0
# Syllable: 'plInt, Count: 0.0
# Syllable: 'sEgz, Count: 15.0
# Syllable: slIN, Count: 0.0
# Syllable: 'raz, Count: 0.0
# Syllable: vAxt, Count: 0.0
# Syllable: sprI, Count: 176.0
# Syllable: let, Count: 5.0
# Syllable: p}nts, Count: 2.0
# Syllable: gri, Count: 12.0
# Syllable: 'sly, Count: 0.0
# Syllable: zat, Count: 64.0
# Syllable: 'put, Count: 381.0
# Syllable: 'zut, Count: 614.0
# Syllable: 'prInz, Count: 2.0
# Syllable: '_us, Count: 71.0
# Syllable: 'sxir, Count: 46.0
# Syllable: stok, Count: 0.0
# Syllable: 'rEGdz, Count: 53.0
# Syllable: z@l, Count: 2340.0
# Syllable: saj, Count: 1.0
# Syllable: 'dom, Count: 346.0
# Syllable: n@rz, Count: 0.0
# Syllable: 'f}n, Count: 0.0
# Syllable: 'vAt, Count: 977.0
# Syllable: pla, Count: 2663.0
# Syllable: d|, Count: 8.0
# Syllable: 'fKm, Count: 15.0
# Syllable: zwEr, Count: 0.0
# Syllable: SI, Count: 0.0
# Syllable: 'kr|k, Count: 8.0
# Syllable: 'h}f, Count: 998.0
# Syllable: 'Gr|s, Count: 0.0
# Syllable: bAst, Count: 1.0
# Syllable: strin, Count: 0.0
# Syllable: 'bord, Count: 6.0
# Syllable: 'trun, Count: 263.0
# Syllable: 'Eg, Count: 0.0
# Syllable: xat, Count: 1.0
# Syllable: 'fOrm, Count: 1131.0
# Syllable: kni, Count: 9.0
# Syllable: 'xEs, Count: 19.0
# Syllable: 'smAr, Count: 13.0
# Syllable: 'dLd, Count: 0.0
# Syllable: 'zwEm, Count: 1245.0
# Syllable: 's}p, Count: 56.0
# Syllable: 'zIn, Count: 12071.0
# Syllable: 'wOrp, Count: 294.0
# Syllable: 'b}z, Count: 6.0
# Syllable: 'mOd, Count: 0.0
# Syllable: 'rKpt, Count: 17.0
# Syllable: 'dIl, Count: 307.0
# Syllable: pOns, Count: 1.0
# Syllable: pik, Count: 0.0
# Syllable: wIN, Count: 1868.0
# Syllable: brur, Count: 252.0
# Syllable: 'zwan, Count: 87.0
# Syllable: xAs, Count: 248.0
# Syllable: fra, Count: 725.0
# Syllable: tr@, Count: 6.0
# Syllable: kErst, Count: 282.0
# Syllable: 'trKs, Count: 34.0
# Syllable: vrux, Count: 32.0
# Syllable: zut, Count: 28.0
# Syllable: 'stent, Count: 30.0
# Syllable: 'bAlx, Count: 1.0
# Syllable: flAx, Count: 0.0
# Syllable: Slus, Count: 5.0
# Syllable: my, Count: 10535.0
# Syllable: 'hOrk, Count: 27.0
# Syllable: 'ZAs, Count: 193.0
# Syllable: zAr, Count: 3.0
# Syllable: 'stE, Count: 11889.0
# Syllable: tIp, Count: 0.0
# Syllable: 'kAz, Count: 24.0
# Syllable: jal, Count: 328.0
# Syllable: n@nst, Count: 0.0
# Syllable: 'jAG, Count: 0.0
# Syllable: 'knOpt, Count: 13.0
# Syllable: 'bys, Count: 30.0
# Syllable: 'GrOl, Count: 0.0
# Syllable: 'ti, Count: 8188.0
# Syllable: 'pert, Count: 18.0
# Syllable: snup, Count: 0.0
# Syllable: G}nst, Count: 2.0
# Syllable: 'mAks, Count: 1.0
# Syllable: 'zif, Count: 1176.0
# Syllable: 'sted, Count: 1.0
# Syllable: 'o, Count: 193944.0
# Syllable: 'krit, Count: 212.0
# Syllable: 'wip, Count: 0.0
# Syllable: stra, Count: 3498.0
# Syllable: mud, Count: 20.0
# Syllable: ro, Count: 6384.0
# Syllable: kAk, Count: 4.0
# Syllable: Ep, Count: 0.0
# Syllable: tOpf, Count: 0.0
# Syllable: 't}r, Count: 692.0
# Syllable: mAf, Count: 0.0
# Syllable: sxAps, Count: 97.0
# Syllable: frAk, Count: 22.0
# Syllable: 'st|r, Count: 12.0
# Syllable: l@gz, Count: 43.0
# Syllable: GrEs, Count: 9.0
# Syllable: br|, Count: 20.0
# Syllable: sxars, Count: 0.0
# Syllable: 'dumz, Count: 3.0
# Syllable: 'stek, Count: 351.0
# Syllable: brLks, Count: 14.0
# Syllable: krAm, Count: 0.0
# Syllable: pris, Count: 68.0
# Syllable: nwa, Count: 0.0
# Syllable: 'troj, Count: 15.0
# Syllable: slan, Count: 1378.0
# Syllable: 'west, Count: 1.0
# Syllable: 'zews, Count: 0.0
# Syllable: lIft, Count: 21.0
# Syllable: wel, Count: 47.0
# Syllable: w@rs, Count: 0.0
# Syllable: 'frAnz, Count: 0.0
# Syllable: 'kOrst, Count: 71.0
# Syllable: 'pit, Count: 131.0
# Syllable: p}nt, Count: 1886.0
# Syllable: j@x, Count: 9.0
# Syllable: tle, Count: 0.0
# Syllable: blANk, Count: 4.0
# Syllable: bLG, Count: 0.0
# Syllable: vex, Count: 10.0
# Syllable: 'mAx, Count: 1755.0
# Syllable: tLx, Count: 5185.0
# Syllable: 'brAt, Count: 2.0
# Syllable: 'klik, Count: 3.0
# Syllable: 'spo, Count: 2255.0
# Syllable: fEs, Count: 193.0
# Syllable: 'sxruf, Count: 92.0
# Syllable: 'k}, Count: 78134.0
# Syllable: 'lan, Count: 111.0
# Syllable: zOrxs, Count: 60.0
# Syllable: tra, Count: 2376.0
# Syllable: frM, Count: 84.0
# Syllable: bars, Count: 4.0
# Syllable: 'pruv, Count: 41.0
# Syllable: }n, Count: 31.0
# Syllable: mum, Count: 0.0
# Syllable: 'blak, Count: 0.0
# Syllable: lod, Count: 0.0
# Syllable: strept, Count: 0.0
# Syllable: n@s, Count: 4539.0
# Syllable: 'sx|r, Count: 299.0
# Syllable: 'lAnts, Count: 33.0
# Syllable: vluk, Count: 5.0
# Syllable: vIN, Count: 5016.0
# Syllable: 'stens, Count: 0.0
# Syllable: liv, Count: 520.0
# Syllable: 'p}t, Count: 529.0
# Syllable: gAm, Count: 0.0
# Syllable: bEnt, Count: 18.0
# Syllable: 'smMd, Count: 0.0
# Syllable: 'spOrts, Count: 1.0
# Syllable: wErkt, Count: 269.0
# Syllable: drax, Count: 0.0
# Syllable: frOn, Count: 372.0
# Syllable: zOn, Count: 615.0
# Syllable: gAr, Count: 0.0
# Syllable: 'tref, Count: 0.0
# Syllable: 'rOks, Count: 49.0
# Syllable: 'lag, Count: 6.0
# Syllable: 'yr, Count: 15778.0
# Syllable: 'da, Count: 23990.0
# Syllable: 'Art, Count: 6.0
# Syllable: 'dwEl, Count: 22.0
# Syllable: 'rEns, Count: 3.0
# Syllable: 'best, Count: 2464.0
# Syllable: 'xrAx, Count: 0.0
# Syllable: 'wrON, Count: 7.0
# Syllable: 'hast, Count: 3471.0
# Syllable: 'writ, Count: 0.0
# Syllable: 'plot, Count: 0.0
# Syllable: 'wat, Count: 93.0
# Syllable: 'bErk, Count: 10.0
# Syllable: l}r, Count: 5.0
# Syllable: dOk, Count: 337.0
# Syllable: 'hEp, Count: 314899.0
# Syllable: 'pl}rk, Count: 3.0
# Syllable: 'NAnt, Count: 0.0
# Syllable: fANst, Count: 7.0
# Syllable: 'klA, Count: 1839.0
# Syllable: 'tOr, Count: 84.0
# Syllable: 'tEns, Count: 264.0
# Syllable: 'skMt, Count: 120.0
# Syllable: p}l, Count: 145.0
# Syllable: 'nOx, Count: 2526.0
# Syllable: 'stErg, Count: 0.0
# Syllable: 'frOns, Count: 17.0
# Syllable: vur, Count: 359.0
# Syllable: 'tAst, Count: 261.0
# Syllable: 'Mts, Count: 76.0
# Syllable: 'nLt, Count: 3.0
# Syllable: 'wOlvz, Count: 0.0
# Syllable: 'jEn, Count: 388.0
# Syllable: s}x, Count: 0.0
# Syllable: drI, Count: 680.0
# Syllable: 'p|t, Count: 17.0
# Syllable: 'art, Count: 1912.0
# Syllable: 'rKts, Count: 0.0
# Syllable: 'but, Count: 0.0
# Syllable: stEnd, Count: 207.0
# Syllable: 'sxrab, Count: 0.0
# Syllable: 'zwu, Count: 70.0
# Syllable: Z@n, Count: 296.0
# Syllable: 'styrt, Count: 2.0
# Syllable: 'lens, Count: 0.0
# Syllable: 'sxrAN, Count: 0.0
# Syllable: sxL, Count: 190.0
# Syllable: 'v}r, Count: 5.0
# Syllable: klos, Count: 108.0
# Syllable: 'hoN, Count: 2.0
# Syllable: mur, Count: 17.0
# Syllable: 'xrus, Count: 0.0
# Syllable: bl}, Count: 83.0
# Syllable: GOt, Count: 28.0
# Syllable: 'krM, Count: 1.0
# Syllable: 'kIp, Count: 1679.0
# Syllable: 'sxEts, Count: 91.0
# Syllable: SEk, Count: 15.0
# Syllable: 'strAnt, Count: 1788.0
# Syllable: 'stAd, Count: 0.0
# Syllable: 'bluj, Count: 102.0
# Syllable: nid, Count: 4734.0
# Syllable: 'zKN, Count: 0.0
# Syllable: fel, Count: 145.0
# Syllable: 'xEnt, Count: 11.0
# Syllable: 'mEns, Count: 7278.0
# Syllable: 'dAxs, Count: 0.0
# Syllable: mor, Count: 478.0
# Syllable: stAnts, Count: 2.0
# Syllable: 'd|k, Count: 118.0
# Syllable: 'xla, Count: 731.0
# Syllable: wEt, Count: 563.0
# Syllable: 'kEnd, Count: 118.0
# Syllable: fes, Count: 42.0
# Syllable: vAN, Count: 312.0
# Syllable: 'lKd, Count: 0.0
# Syllable: 'bElx, Count: 0.0
# Syllable: 'les, Count: 39.0
# Syllable: 'xEms, Count: 1.0
# Syllable: kOf, Count: 0.0
# Syllable: 'blOm, Count: 15.0
# Syllable: xIts, Count: 28.0
# Syllable: v}lt, Count: 0.0
# Syllable: 'mEt, Count: 298057.0
# Syllable: b}n, Count: 16.0
# Syllable: 'roms, Count: 10.0
# Syllable: noj, Count: 3.0
# Syllable: 'pris, Count: 1464.0
# Syllable: GAs, Count: 155.0
# Syllable: 'blOkt, Count: 14.0
# Syllable: 'zExs, Count: 19.0
# Syllable: w@rt, Count: 81.0
# Syllable: lMts, Count: 0.0
# Syllable: xa, Count: 3053.0
# Syllable: 'rat, Count: 7311.0
# Syllable: sxErp, Count: 109.0
# Syllable: 'tK, Count: 8747.0
# Syllable: belt, Count: 3539.0
# Syllable: zwE, Count: 24.0
# Syllable: 'dAk, Count: 2846.0
# Syllable: zwO, Count: 108.0
# Syllable: 'vlod, Count: 0.0
# Syllable: kse, Count: 2.0
# Syllable: xlAz, Count: 2.0
# Syllable: 'knExts, Count: 0.0
# Syllable: 'vErft, Count: 0.0
# Syllable: 'vut, Count: 4228.0
# Syllable: strIx, Count: 25.0
# Syllable: 'kert, Count: 5560.0
# Syllable: 'sxAmp, Count: 30.0
# Syllable: 'wa, Count: 61687.0
# Syllable: 'n}, Count: 10275.0
# Syllable: 'tAn, Count: 5146.0
# Syllable: hed, Count: 1.0
# Syllable: sEnd, Count: 32.0
# Syllable: 'hornt, Count: 1.0
# Syllable: 'wIntS, Count: 2.0
# Syllable: r}s, Count: 2460.0
# Syllable: 'brOt, Count: 0.0
# Syllable: Gys, Count: 3.0
# Syllable: 'rar, Count: 3712.0
# Syllable: 'max, Count: 1214.0
# Syllable: 'tAjp, Count: 3.0
# Syllable: b}r, Count: 2051.0
# Syllable: 'hard, Count: 0.0
# Syllable: t@n, Count: 1951.0
# Syllable: xrOx, Count: 0.0
# Syllable: t@rt, Count: 657.0
# Syllable: 'hov, Count: 267.0
# Syllable: 'gOt, Count: 0.0
# Syllable: 'vlEkt, Count: 22.0
# Syllable: dref, Count: 0.0
# Syllable: muj, Count: 3.0
# Syllable: v@x, Count: 1832.0
# Syllable: vrMw, Count: 297.0
# Syllable: 'ak, Count: 5.0
# Syllable: kne, Count: 0.0
# Syllable: trEst, Count: 14.0
# Syllable: wil, Count: 87.0
# Syllable: 'snE, Count: 350.0
# Syllable: zax, Count: 82.0
# Syllable: tSMw, Count: 4.0
# Syllable: 'rEg, Count: 23.0
# Syllable: lOl, Count: 1.0
# Syllable: 'taN, Count: 0.0
# Syllable: koj, Count: 47.0
# Syllable: 'fIts, Count: 1.0
# Syllable: bINk, Count: 0.0
# Syllable: 'r}rx, Count: 387.0
# Syllable: spre, Count: 1617.0
# Syllable: dyr, Count: 60.0
# Syllable: 'd}x, Count: 7.0
# Syllable: mo, Count: 23015.0
# Syllable: 'jart, Count: 34.0
# Syllable: 'dEmp, Count: 0.0
# Syllable: 'zul, Count: 0.0
# Syllable: lEr, Count: 82.0
# Syllable: net, Count: 2.0
# Syllable: SIp, Count: 3.0
# Syllable: 'mEnst, Count: 0.0
# Syllable: 'r}pt, Count: 285.0
# Syllable: 'ben, Count: 2498.0
# Syllable: kIr, Count: 10.0
# Syllable: 'vremp, Count: 0.0
# Syllable: So, Count: 4786.0
# Syllable: 'AN, Count: 435.0
# Syllable: 'trKz, Count: 0.0
# Syllable: 'twe, Count: 51758.0
# Syllable: doj, Count: 0.0
# Syllable: 'kned, Count: 18.0
# Syllable: 'smIts, Count: 3.0
# Syllable: tOrs, Count: 5.0
# Syllable: hArd, Count: 395.0
# Syllable: t@nd, Count: 0.0
# Syllable: 'kers, Count: 227.0
# Syllable: sxErf, Count: 25.0
# Syllable: 'mor, Count: 14646.0
# Syllable: 'trIkts, Count: 18.0
# Syllable: GOr, Count: 69.0
# Syllable: 'h}ts, Count: 12.0
# Syllable: blI, Count: 20.0
# Syllable: hEsp, Count: 0.0
# Syllable: 'r|g, Count: 0.0
# Syllable: ANst, Count: 399.0
# Syllable: GAm, Count: 0.0
# Syllable: 'gOn, Count: 1.0
# Syllable: 'Kk, Count: 70.0
# Syllable: 'strEtS, Count: 16.0
# Syllable: 'kEts, Count: 2.0
# Syllable: 'zwIxt, Count: 0.0
# Syllable: 'kwAl, Count: 78.0
# Syllable: 'sxon, Count: 6017.0
# Syllable: fremt, Count: 11.0
# Syllable: 'kal, Count: 997.0
# Syllable: 'strem, Count: 389.0
# Syllable: kr}, Count: 0.0
# Syllable: rAr, Count: 0.0
# Syllable: 'tEn, Count: 3111.0
# Syllable: pl}n, Count: 4.0
# Syllable: 'rAspt, Count: 1.0
# Syllable: wAp, Count: 1.0
# Syllable: 'wor, Count: 5754.0
# Syllable: _Et, Count: 0.0
# Syllable: 'sxEl, Count: 185.0
# Syllable: 'kars, Count: 363.0
# Syllable: 'knIp, Count: 368.0
# Syllable: tIt, Count: 5.0
# Syllable: tSu, Count: 0.0
# Syllable: spel, Count: 70.0
# Syllable: 'drKG, Count: 11.0
# Syllable: tsa, Count: 1069.0
# Syllable: pK, Count: 389.0
# Syllable: 'dj|, Count: 74.0
# Syllable: 'slEx, Count: 357.0
# Syllable: 'pLk, Count: 76.0
# Syllable: jart, Count: 39.0
# Syllable: xlO, Count: 1.0
# Syllable: 'ozd, Count: 17.0
# Syllable: 'prIg, Count: 27.0
# Syllable: 'bra, Count: 370.0
# Syllable: tiN, Count: 0.0
# Syllable: 'leb, Count: 0.0
# Syllable: kwEs, Count: 64.0
# Syllable: 'knuj, Count: 155.0
# Syllable: 'j|xt, Count: 1387.0
# Syllable: Gox, Count: 0.0
# Syllable: 'ker, Count: 34330.0
# Syllable: 'sxa, Count: 6113.0
# Syllable: GOrs, Count: 0.0
# Syllable: 'zuns, Count: 7.0
# Syllable: slLs, Count: 86.0
# Syllable: 'zEp, Count: 0.0
# Syllable: 'kler, Count: 270.0
# Syllable: 'fu, Count: 1028.0
# Syllable: n@m, Count: 4.0
# Syllable: haf, Count: 0.0
# Syllable: 'dOnt, Count: 7.0
# Syllable: 'sonz, Count: 7.0
# Syllable: bl}n, Count: 0.0
# Syllable: sInd, Count: 18.0
# Syllable: 'mEN, Count: 125.0
# Syllable: spL, Count: 69.0
# Syllable: r@ls, Count: 0.0
# Syllable: 'Ark, Count: 248.0
# Syllable: lAn, Count: 1163.0
# Syllable: 'sxrAm, Count: 72.0
# Syllable: GEm, Count: 0.0
# Syllable: 'plIGd, Count: 1.0
# Syllable: 'kAft, Count: 31.0
# Syllable: 'krAmp, Count: 154.0
# Syllable: sxak, Count: 137.0
# Syllable: 'kog, Count: 53.0
# Syllable: 'stuj, Count: 31.0
# Syllable: 'knep, Count: 101.0
# Syllable: nis, Count: 1692.0
# Syllable: wat, Count: 10.0
# Syllable: 'SIl, Count: 0.0
# Syllable: tjAn, Count: 0.0
# Syllable: hAns, Count: 23.0
# Syllable: vlOk, Count: 14.0
# Syllable: ArG, Count: 28.0
# Syllable: 'S|s, Count: 121.0
# Syllable: 'nojt, Count: 63864.0
# Syllable: 'strOp, Count: 191.0
# Syllable: 'nut, Count: 0.0
# Syllable: 'fEnt, Count: 0.0
# Syllable: Md, Count: 11.0
# Syllable: 'vuxt, Count: 400.0
# Syllable: t@ls, Count: 0.0
# Syllable: 'fr|s, Count: 2.0
# Syllable: Gla, Count: 15.0
# Syllable: grIl, Count: 2.0
# Syllable: 'spitS, Count: 542.0
# Syllable: 'knAk, Count: 11.0
# Syllable: xrOm, Count: 2.0
# Syllable: 'bl), Count: 0.0
# Syllable: bErm, Count: 3.0
# Syllable: b|l, Count: 3.0
# Syllable: 'xro, Count: 519.0
# Syllable: 'hOl, Count: 632.0
# Syllable: 'krat, Count: 153.0
# Syllable: 'lOg, Count: 0.0
# Syllable: 'tAG, Count: 0.0
# Syllable: 'hal, Count: 22291.0
# Syllable: 'fOnts, Count: 167.0
# Syllable: 'wal, Count: 4.0
# Syllable: sxKt, Count: 1683.0
# Syllable: 'x}p, Count: 3.0
# Syllable: 'sxMw, Count: 131.0
# Syllable: dM, Count: 16.0
# Syllable: bAk, Count: 1559.0
# Syllable: 'brK, Count: 156.0
# Syllable: 'kEsp, Count: 0.0
# Syllable: 'zAj, Count: 14.0
# Syllable: 'Ent, Count: 107.0
# Syllable: 'lj|, Count: 264.0
# Syllable: kl@t, Count: 0.0
# Syllable: 'kwEdz, Count: 585.0
# Syllable: S|r, Count: 16.0
# Syllable: 'tApt, Count: 10.0
# Syllable: 'trEt, Count: 268.0
# Syllable: boxs, Count: 0.0
# Syllable: 't}, Count: 14009.0
# Syllable: 'dr}kt, Count: 402.0
# Syllable: fArkt, Count: 31.0
# Syllable: val, Count: 3.0
# Syllable: bMt, Count: 149.0
# Syllable: 'wust, Count: 1033.0
# Syllable: rON, Count: 6.0
# Syllable: tEmp, Count: 0.0
# Syllable: wAm, Count: 13.0
# Syllable: sxLt, Count: 39.0
# Syllable: g@r, Count: 1.0
# Syllable: pl@, Count: 5981.0
# Syllable: v}l, Count: 327.0
# Syllable: 'flANk, Count: 83.0
# Syllable: 'jO, Count: 21069.0
# Syllable: n@l, Count: 1533.0
# Syllable: dra, Count: 2745.0
# Syllable: xlAs, Count: 57.0
# Syllable: 'bA, Count: 4730.0
# Syllable: 'tOns, Count: 3.0
# Syllable: 'mIz, Count: 3406.0
# Syllable: hLt, Count: 86.0
# Syllable: NINs, Count: 6.0
# Syllable: slav, Count: 4.0
# Syllable: 'bul, Count: 2459.0
# Syllable: 'kAm, Count: 827.0
# Syllable: 'blim, Count: 48.0
# Syllable: klEt, Count: 11.0
# Syllable: 'GrAm, Count: 676.0
# Syllable: smArt, Count: 0.0
# Syllable: 'pAg, Count: 2.0
# Syllable: xAns, Count: 1.0
# Syllable: 'bl}ts, Count: 1.0
# Syllable: 's}ft, Count: 28.0
# Syllable: 'pEls, Count: 38.0
# Syllable: zKnz, Count: 1.0
# Syllable: low, Count: 55.0
# Syllable: 'wad, Count: 2.0
# Syllable: 'strOm, Count: 22.0
# Syllable: '}b, Count: 9.0
# Syllable: 'zaks, Count: 0.0
# Syllable: ni, Count: 18731.0
# Syllable: nju, Count: 3.0
# Syllable: fiz, Count: 0.0
# Syllable: 'hKls, Count: 0.0
# Syllable: dir, Count: 1071.0
# Syllable: 'knOk, Count: 68.0
# Syllable: pap, Count: 0.0
# Syllable: zwurt, Count: 0.0
# Syllable: 'dwAN, Count: 331.0
# Syllable: 'lLmt, Count: 10.0
# Syllable: tyr, Count: 349.0
# Syllable: 'frAt, Count: 1.0
# Syllable: mOm, Count: 0.0
# Syllable: 'zOrxt, Count: 2786.0
# Syllable: friz, Count: 0.0
# Syllable: 'kut, Count: 16.0
# Syllable: r}N, Count: 0.0
# Syllable: vits, Count: 1.0
# Syllable: 'lOts, Count: 1.0
# Syllable: nun, Count: 0.0
# Syllable: 'kwAlm, Count: 0.0
# Syllable: vre, Count: 148.0
# Syllable: 'lEns, Count: 187.0
# Syllable: 'try, Count: 3.0
# Syllable: dKks, Count: 0.0
# Syllable: 'bles, Count: 0.0
# Syllable: 'kAS, Count: 47.0
# Syllable: 'sIt, Count: 5.0
# Syllable: 'wEN, Count: 26.0
# Syllable: lEs, Count: 800.0
# Syllable: ti, Count: 12797.0
# Syllable: zKn, Count: 619.0
# Syllable: djO, Count: 1.0
# Syllable: 'zwAkt, Count: 1.0
# Syllable: 'spik, Count: 1.0
# Syllable: 'spOnz, Count: 0.0
# Syllable: 'wAs, Count: 232330.0
# Syllable: 'dOk, Count: 11960.0
# Syllable: 'zAlv, Count: 21.0
# Syllable: rKgz, Count: 1.0
# Syllable: trAkt, Count: 149.0
# Syllable: 'sErpt, Count: 0.0
# Syllable: 'miz, Count: 0.0
# Syllable: 'fOk, Count: 45.0
# Syllable: bil, Count: 0.0
# Syllable: 'huk, Count: 2258.0
# Syllable: 'smMs, Count: 12.0
# Syllable: baj, Count: 2.0
# Syllable: 'sx|k, Count: 0.0
# Syllable: 'gwIs, Count: 0.0
# Syllable: 'hEsp, Count: 4.0
# Syllable: mArs, Count: 68.0
# Syllable: fl|r, Count: 8.0
# Syllable: sxElp, Count: 5.0
# Syllable: dOs, Count: 10.0
# Syllable: 'tKg, Count: 0.0
# Syllable: 'mAxt, Count: 3701.0
# Syllable: 'sIp, Count: 82.0
# Syllable: 'Glo, Count: 0.0
# Syllable: kly, Count: 821.0
# Syllable: rOmp, Count: 1.0
# Syllable: ), Count: 2.0
# Syllable: 'smIdz, Count: 0.0
# Syllable: 'plAg, Count: 161.0
# Syllable: flAj, Count: 53.0
# Syllable: 'mElg, Count: 66.0
# Syllable: }l, Count: 111.0
# Syllable: t}lp, Count: 0.0
# Syllable: n@_, Count: 169.0
# Syllable: '_a, Count: 0.0
# Syllable: 'nIs, Count: 2095.0
# Syllable: sty, Count: 5224.0
# Syllable: 'rot, Count: 2230.0
# Syllable: p}k, Count: 3.0
# Syllable: klErk, Count: 9.0
# Syllable: xly, Count: 17.0
# Syllable: tINz, Count: 32.0
# Syllable: 'talt, Count: 3855.0
# Syllable: l|s, Count: 0.0
# Syllable: 'wInst, Count: 971.0
# Syllable: t@l, Count: 7789.0
# Syllable: '}k, Count: 26.0
# Syllable: k}n, Count: 1361.0
# Syllable: sxrA, Count: 2.0
# Syllable: spOn, Count: 312.0
# Syllable: 'vOx, Count: 574.0
# Syllable: rel, Count: 34.0
# Syllable: 'zwArt, Count: 2606.0
# Syllable: 'krOk, Count: 2.0
# Syllable: dAxt, Count: 2489.0
# Syllable: xOl, Count: 0.0
# Syllable: dwArs, Count: 0.0
# Syllable: stOl, Count: 7.0
# Syllable: 'knAp, Count: 3000.0
# Syllable: 'sEnd, Count: 253.0
# Syllable: t@t, Count: 143.0
# Syllable: 'zOns, Count: 75.0
# Syllable: 'rom, Count: 406.0
# Syllable: 'pAlts, Count: 0.0
# Syllable: spE, Count: 384.0
# Syllable: 'klM, Count: 280.0
# Syllable: p|l, Count: 0.0
# Syllable: 'blEn, Count: 0.0
# Syllable: 'wAlx, Count: 219.0
# Syllable: 'rOn, Count: 1028.0
# Syllable: 'twer, Count: 0.0
# Syllable: nINz, Count: 23.0
# Syllable: 'bux, Count: 249.0
# Syllable: 'bl|, Count: 17.0
# Syllable: stro, Count: 161.0
# Syllable: Ze, Count: 11.0
# Syllable: wart, Count: 0.0
# Syllable: rAjt, Count: 9.0
# Syllable: 'h}p, Count: 644.0
# Syllable: wrIxt, Count: 4.0
# Syllable: dOf, Count: 0.0
# Syllable: jarz, Count: 22.0
# Syllable: 'slu, Count: 194.0
# Syllable: 'spid, Count: 41.0
# Syllable: log, Count: 16.0
# Syllable: 'z}lk, Count: 307.0
# Syllable: 'lOrt, Count: 949.0
# Syllable: tINk, Count: 1.0
# Syllable: Got, Count: 0.0
# Syllable: 'slit, Count: 0.0
# Syllable: rLm, Count: 616.0
# Syllable: 'spyG, Count: 8.0
# Syllable: 'snK, Count: 1217.0
# Syllable: 'sAnt, Count: 3065.0
# Syllable: 'tErts, Count: 5.0
# Syllable: 'prEz, Count: 3.0
# Syllable: l)r, Count: 0.0
# Syllable: 'ner, Count: 53551.0
# Syllable: 'fIrn, Count: 0.0
# Syllable: 'vEs, Count: 1385.0
# Syllable: 'sxKm, Count: 226.0
# Syllable: tLG, Count: 15.0
# Syllable: 'hop, Count: 16722.0
# Syllable: j@rt, Count: 22.0
# Syllable: 'xrAf, Count: 1775.0
# Syllable: m}l, Count: 34.0
# Syllable: x@, Count: 587329.0
# Syllable: 'kOrts, Count: 0.0
# ...
# Syllable: prLk, Count: 1.0
# Syllable: 'pIls, Count: 40.0
# Syllable: 'd}rf, Count: 2082.0
# Syllable: Ex, Count: 0.0
# Syllable: 'fOs, Count: 17.0
# Syllable: 'kwIl, Count: 0.0
# Syllable: fOrk, Count: 2.0
# Syllable: 'jON, Count: 4087.0
# Syllable: 'sEpt, Count: 806.0
# Syllable: wM, Count: 0.0
# Syllable: sxKts, Count: 153.0
# Syllable: 'dr|, Count: 27.0
# Syllable: 'sxaps, Count: 36.0
# Syllable: 'fIn, Count: 6.0
# Syllable: rKm, Count: 2.0
# Syllable: 'klEmt, Count: 6.0
# Syllable: 'knIs, Count: 5.0
# Syllable: knAr, Count: 2.0
# Syllable: 'blO, Count: 288.0
# Syllable: x@rs, Count: 0.0
# Syllable: blE, Count: 143.0
# Syllable: fIN, Count: 420.0
# Syllable: gry, Count: 0.0
# Syllable: 'vorn, Count: 2.0
# Syllable: wre, Count: 0.0
# Syllable: try, Count: 14.0
# Syllable: ZEn, Count: 56.0
# Syllable: 'xIvd, Count: 0.0
# Syllable: lE, Count: 5844.0
# Syllable: tAG, Count: 0.0
# Syllable: lAs, Count: 320.0
# Syllable: 'p}Nk, Count: 56.0
# Syllable: 'blOn, Count: 478.0
# Syllable: Ext, Count: 1.0
# Syllable: vlur, Count: 2.0
# Syllable: 'dry, Count: 0.0
# Syllable: 'pES, Count: 0.0
# Syllable: dju, Count: 0.0
# Syllable: wa, Count: 4342.0
# Syllable: 'strom, Count: 1443.0
# Syllable: 'kOp, Count: 12071.0
# Syllable: 'plEd, Count: 0.0
# Syllable: vAl, Count: 8070.0
# Syllable: 'bOrm, Count: 0.0
# Syllable: Gats, Count: 0.0
# Syllable: 'knKb, Count: 0.0
# Syllable: stAx, Count: 0.0
# Syllable: 'l|, Count: 3196.0
# Syllable: wud, Count: 0.0
# Syllable: 'GnI, Count: 4.0
# Syllable: 'n}x, Count: 531.0
# Syllable: m}ts, Count: 116.0
# Syllable: wEls, Count: 0.0
# Syllable: 'flEks, Count: 59.0
# Syllable: 'hExt, Count: 623.0
# Syllable: 'burs, Count: 12.0
# Syllable: 'lIk, Count: 39.0
# Syllable: 'xIps, Count: 109.0
# Syllable: ap, Count: 89.0
# Syllable: 'IntS, Count: 73.0
# Syllable: 'hi, Count: 374.0
# Syllable: 'flEk, Count: 76.0
# Syllable: 'tOrn, Count: 3.0
# Syllable: 'blKk, Count: 201.0
# Syllable: 'rExt, Count: 11680.0
# Syllable: 'zwart, Count: 1748.0
# Syllable: 'p}l, Count: 134.0
# Syllable: 'd|, Count: 261.0
# Syllable: 'jars, Count: 408.0
# Syllable: 'fOnd, Count: 0.0
# Syllable: 'nOk, Count: 37.0
# Syllable: 'sxIf, Count: 6.0
# Syllable: 'xAk, Count: 4.0
# Syllable: 'tAm, Count: 88.0
# Syllable: 'vis, Count: 1041.0
# Syllable: 'sxKN, Count: 2.0
# Syllable: 'tron, Count: 1223.0
# Syllable: zLl, Count: 2.0
# Syllable: 'nM, Count: 66024.0
# Syllable: nEk, Count: 17.0
# Syllable: stof, Count: 0.0
# Syllable: v|, Count: 8.0
# Syllable: 'rExts, Count: 2973.0
# Syllable: fl}xt, Count: 117.0
# Syllable: 'Goj, Count: 2.0
# Syllable: jy, Count: 1659.0
# Syllable: 'bry, Count: 29.0
# Syllable: 'dIn, Count: 8082.0
# Syllable: 'drEk, Count: 28.0
# Syllable: 'GElt, Count: 0.0
# Syllable: 'pon, Count: 13.0
# Syllable: 'wurt, Count: 0.0
# Syllable: 'ry, Count: 2890.0
# Syllable: tOn, Count: 1336.0
# Syllable: m|r, Count: 19.0
# Syllable: 'oxt, Count: 0.0
# Syllable: stEk, Count: 36.0
# Syllable: vy, Count: 21.0
# Syllable: 'vr}xt, Count: 179.0
# Syllable: swI, Count: 0.0
# Syllable: nez, Count: 0.0
# Syllable: trAN, Count: 0.0
# Syllable: 'rutS, Count: 7.0
# Syllable: gArt, Count: 104.0
# Syllable: 'G}nt, Count: 0.0
# Syllable: 'Em, Count: 1984.0
# Syllable: 'Arts, Count: 1436.0
# Syllable: 'lOs, Count: 9810.0
# Syllable: 'tSa, Count: 684.0
# Syllable: styrt, Count: 11.0
# Syllable: kEn, Count: 181.0
# Syllable: kuk, Count: 361.0
# Syllable: tj@, Count: 23965.0
# Syllable: SEn, Count: 21.0
# Syllable: slep, Count: 16.0
# Syllable: 'tOp, Count: 2075.0
# Syllable: 'slaft, Count: 577.0
# Syllable: rLt, Count: 156.0
# Syllable: zin, Count: 2627.0
# Syllable: 'bars, Count: 134.0
# Syllable: 'flM, Count: 10.0
# Syllable: 'drEns, Count: 1.0
# Syllable: stakt, Count: 22.0
# Syllable: 'brLk, Count: 4627.0
# Syllable: hAp, Count: 2.0
# Syllable: 'j}rk, Count: 2438.0
# Syllable: 'slep, Count: 383.0
# Syllable: lOrt, Count: 0.0
# Syllable: vrint, Count: 143.0
# Syllable: 'xrEnz, Count: 0.0
# Syllable: fE, Count: 572.0
# Syllable: kwEt, Count: 6.0
# Syllable: fElt, Count: 1973.0
# Syllable: st@n, Count: 115.0
# Syllable: 'kat, Count: 4823.0
# Syllable: trOx, Count: 1.0
# Syllable: bix, Count: 162.0
# Syllable: 'Smi, Count: 1.0
# Syllable: 'rIk, Count: 15.0
# Syllable: 'vlim, Count: 0.0
# Syllable: 'xlOp, Count: 0.0
# Syllable: 'gOj, Count: 6.0
# Syllable: mAl, Count: 40.0
# Syllable: 'kwAk, Count: 93.0
# Syllable: zuk, Count: 5370.0
# Syllable: tir, Count: 663.0
# Syllable: xra, Count: 1417.0
# Syllable: 'b|ls, Count: 0.0
# Syllable: nOt, Count: 2.0
# Syllable: 'knurt, Count: 3.0
# Syllable: 'huv, Count: 4.0
# Syllable: rEmt, Count: 13.0
# Syllable: Syt, Count: 1.0
# Syllable: p), Count: 0.0
# Syllable: 'xON, Count: 21.0
# Syllable: kans, Count: 0.0
# Syllable: 'jAs, Count: 2948.0
# Syllable: prInt, Count: 0.0
# Syllable: bEN, Count: 0.0
# Syllable: 'kAnz, Count: 12.0
# Syllable: 'klOmp, Count: 45.0
# Syllable: 'rats, Count: 453.0
# Syllable: 'sxErp, Count: 1121.0
# Syllable: 'nA, Count: 77.0
# Syllable: 'bent, Count: 0.0
# Syllable: 'kim, Count: 36.0
# Syllable: pn|, Count: 8.0
# Syllable: 'tLz, Count: 319.0
# Syllable: 'wIm, Count: 42.0
# Syllable: 'dul, Count: 4774.0
# Syllable: xlAn, Count: 0.0
# Syllable: b@ls, Count: 94.0
# Syllable: xran, Count: 0.0
# Syllable: t@x, Count: 55061.0
# Syllable: plE, Count: 5.0
# Syllable: 'strad, Count: 18.0
# Syllable: 'plIx, Count: 638.0
# Syllable: 't@, Count: 343019.0
# Syllable: 'wret, Count: 820.0
# Syllable: 'kl}p, Count: 2366.0
# Syllable: 'krut, Count: 0.0
# Syllable: zEs, Count: 0.0
# Syllable: 'grO, Count: 10.0
# Syllable: 'plEts, Count: 1.0
# Syllable: 'sxrEt, Count: 0.0
# Syllable: 'smLkt, Count: 0.0
# Syllable: 'trKN, Count: 30.0
# Syllable: sxLv, Count: 0.0
# Syllable: tSArt, Count: 0.0
# Syllable: 'plO, Count: 722.0
# Syllable: d@ns, Count: 5920.0
# Syllable: kAlk, Count: 2.0
# Syllable: 'GOt, Count: 12.0
# Syllable: wI, Count: 1396.0
# Syllable: sxEt, Count: 0.0
# Syllable: x@n, Count: 0.0
# Syllable: 'bOrs, Count: 0.0
# Syllable: pu, Count: 365.0
# Syllable: zwar, Count: 122.0
# Syllable: 'sIN, Count: 180.0
# Syllable: 'bOxt, Count: 366.0
# Syllable: 'l|k, Count: 26044.0
# Syllable: hom, Count: 2.0
# Syllable: strAn, Count: 0.0
# Syllable: brut, Count: 20.0
# Syllable: zEk, Count: 9.0
# Syllable: 'sxEnd, Count: 46.0
# Syllable: 'was, Count: 40.0
# Syllable: smEt, Count: 0.0
# Syllable: 'jup, Count: 0.0
# Syllable: mK, Count: 9.0
# Syllable: 'buf, Count: 307.0
# Syllable: 'klLt, Count: 17.0
# Syllable: dAj, Count: 16.0
# Syllable: 'lots, Count: 116.0
# Syllable: 'sxKt, Count: 472.0
# Syllable: 'snuj, Count: 20.0
# Syllable: 'xEsp, Count: 42.0
# Syllable: kum, Count: 0.0
# Syllable: klaxt, Count: 5.0
# Syllable: mKn, Count: 2514.0
# Syllable: 'bANk, Count: 4502.0
# Syllable: bu, Count: 868.0
# Syllable: 'ken, Count: 2.0
# Syllable: 'dAs, Count: 598.0
# Syllable: 'xEks, Count: 0.0
# Syllable: 'slaf, Count: 776.0
# Syllable: 'bArt, Count: 22.0
# Syllable: 'trent, Count: 516.0
# Syllable: '_Ojnt, Count: 285.0
# Syllable: xamz, Count: 91.0
# Syllable: 'xil, Count: 0.0
# Syllable: lO, Count: 3480.0
# Syllable: pi, Count: 15890.0
# Syllable: f@, Count: 15068.0
# Syllable: 'bej, Count: 1.0
# Syllable: 'pOv, Count: 3.0
# Syllable: wErp, Count: 1407.0
# Syllable: 'sxL, Count: 731.0
# Syllable: tOx, Count: 455.0
# Syllable: 'mel, Count: 533.0
# Syllable: 'tr), Count: 27.0
# Syllable: vLl, Count: 15.0
# Syllable: fy, Count: 349.0
# Syllable: kops, Count: 3.0
# Syllable: 'nom, Count: 78.0
# Syllable: 'lIps, Count: 1.0
# Syllable: 'mElk, Count: 2057.0
# Syllable: 'sLt, Count: 0.0
# Syllable: 'jEf, Count: 0.0
# Syllable: tOns, Count: 1.0
# Syllable: pit, Count: 82.0
# Syllable: jOm, Count: 30.0
# Syllable: dre, Count: 1.0
# Syllable: 'krOm, Count: 272.0
# Syllable: 'frOn, Count: 29.0
# Syllable: kl|n, Count: 26.0
# Syllable: 'vAnt, Count: 313.0
# Syllable: hers, Count: 0.0
# Syllable: mErG, Count: 2.0
# Syllable: 'kEtS, Count: 22.0
# Syllable: stral, Count: 102.0
# Syllable: 'xit, Count: 14.0
# Syllable: vIts, Count: 0.0
# Syllable: sxyw, Count: 78.0
# Syllable: vKl, Count: 18.0
# Syllable: 'krAp, Count: 180.0
# Syllable: zon, Count: 757.0
# Syllable: 'stIkt, Count: 96.0
# Syllable: 'riv, Count: 0.0
# Syllable: 'zIs, Count: 34.0
# Syllable: stOrt, Count: 4.0
# Syllable: 'dIrk, Count: 131.0
# Syllable: m@nt, Count: 934.0
# Syllable: 'hem, Count: 6.0
# Syllable: vor, Count: 41977.0
# Syllable: 'x}l, Count: 467.0
# Syllable: xElts, Count: 0.0
# Syllable: pIs, Count: 34.0
# Syllable: m}s, Count: 198.0
# Syllable: 'twit, Count: 30.0
# Syllable: 'kril, Count: 5.0
# Syllable: 'enz, Count: 0.0
# Syllable: 'sx}b, Count: 0.0
# Syllable: 'skE, Count: 293.0
# Syllable: 'skEp, Count: 107.0
# Syllable: bLs, Count: 178.0
# Syllable: sOrs, Count: 0.0
# Syllable: stMt, Count: 21.0
# Syllable: 'Gals, Count: 0.0
# Syllable: splIt, Count: 114.0
# Syllable: 'fits, Count: 970.0
# Syllable: spAd, Count: 0.0
# Syllable: 't}l, Count: 42.0
# Syllable: 'sprak, Count: 130.0
# Syllable: 'Ord, Count: 1.0
# Syllable: bort, Count: 482.0
# Syllable: 'Ol, Count: 6.0
# Syllable: nOr, Count: 5748.0
# Syllable: pri, Count: 935.0
# Syllable: 'klIb, Count: 0.0
# Syllable: kord, Count: 0.0
# Syllable: xla, Count: 143.0
# Syllable: 'kep, Count: 153.0
# Syllable: 'hElft, Count: 2872.0
# Syllable: 'xlud, Count: 104.0
# Syllable: 'frLd, Count: 2.0
# Syllable: sAr, Count: 1135.0
# Syllable: frAns, Count: 2.0
# Syllable: 'borts, Count: 0.0
# Syllable: dik, Count: 0.0
# Syllable: 'rIt, Count: 1208.0
# Syllable: w}lp, Count: 0.0
# Syllable: sEns, Count: 1.0
# Syllable: 'jam, Count: 0.0
# Syllable: 'sxAlk, Count: 1.0
# Syllable: 'Alt, Count: 17.0
# Syllable: 'w}s, Count: 764.0
# Syllable: sxAxt, Count: 60.0
# Syllable: drIx, Count: 16.0
# Syllable: bif, Count: 98.0
# Syllable: 'tut, Count: 180.0
# Syllable: 'lEx, Count: 5958.0
# Syllable: 'knu, Count: 242.0
# Syllable: 'klANg, Count: 7.0
# Syllable: 'pl}G, Count: 0.0
# Syllable: 'mElt, Count: 461.0
# Syllable: 'swis, Count: 3.0
# Syllable: 'Ov, Count: 514.0
# Syllable: 'stut, Count: 47.0
# Syllable: 'pEt, Count: 751.0
# Syllable: pMs, Count: 3.0
# Syllable: 'Zur, Count: 126.0
# Syllable: 'bi, Count: 3311.0
# Syllable: bol, Count: 21.0
# Syllable: 'trEk, Count: 2373.0
# Syllable: 'vrInt, Count: 26.0
# Syllable: sOns, Count: 0.0
# Syllable: din, Count: 210.0
# Syllable: 'tENg, Count: 1.0
# Syllable: 'S}rt, Count: 966.0
# Syllable: nert, Count: 0.0
# Syllable: sprit, Count: 12.0
# Syllable: pEs, Count: 33.0
# Syllable: 'trONk, Count: 0.0
# Syllable: 'vEx, Count: 5934.0
# Syllable: stINk, Count: 66.0
# Syllable: INs, Count: 1.0
# Syllable: 'sxOt, Count: 130.0
# Syllable: 'kurz, Count: 0.0
# Syllable: spOr, Count: 168.0
# Syllable: smL, Count: 0.0
# Syllable: sEm, Count: 11.0
# Syllable: Knt, Count: 46.0
# Syllable: Mt, Count: 104.0
# Syllable: 'drox, Count: 988.0
# Syllable: 'lAnd, Count: 313.0
# Syllable: vurt, Count: 104.0
# Syllable: 'tIN, Count: 3.0
# Syllable: 'kl}x, Count: 1.0
# Syllable: wOlf, Count: 231.0
# Syllable: fri, Count: 219.0
# Syllable: 'dr}g, Count: 42.0
# Syllable: 'klANk, Count: 64.0
# Syllable: 'st}ks, Count: 0.0
# Syllable: fwA, Count: 80.0
# Syllable: rAn, Count: 1273.0
# Syllable: zIxts, Count: 1.0
# Syllable: 'slKp, Count: 15.0
# Syllable: zINk, Count: 0.0
# Syllable: 'Ax, Count: 36063.0
# Syllable: vAnt, Count: 0.0
# Syllable: GOl, Count: 6.0
# Syllable: xut, Count: 1448.0
# Syllable: 'larst, Count: 0.0
# Syllable: 'knAs, Count: 0.0
# Syllable: 'dAr, Count: 127.0
# Syllable: d@l, Count: 7870.0
# Syllable: 'bOj, Count: 412.0
# Syllable: vAs, Count: 207.0
# Syllable: 'xrOx, Count: 12.0
# Syllable: 'fAn, Count: 26.0
# Syllable: 'delt, Count: 617.0
# Syllable: S}, Count: 0.0
# Syllable: ur, Count: 0.0
# Syllable: l|k, Count: 24.0
# Syllable: 'zEnd, Count: 26.0
# Syllable: 'stElp, Count: 2.0
# Syllable: nMwt, Count: 34.0
# Syllable: 'stOrm, Count: 1373.0
# Syllable: 'klaf, Count: 20.0
# Syllable: stadz, Count: 3.0
# Syllable: 'dOt, Count: 82.0
# Syllable: tEk, Count: 1202.0
# Syllable: knLst, Count: 0.0
# Syllable: mL, Count: 109.0
# Syllable: 'de, Count: 109775.0
# Syllable: Gas, Count: 1.0
# Syllable: t@d, Count: 29.0
# Syllable: 'nIz, Count: 0.0
# Syllable: lKst, Count: 400.0
# Syllable: 'spIts, Count: 144.0
# Syllable: 'G}, Count: 516.0
# Syllable: fest, Count: 1381.0
# Syllable: sxrI, Count: 183.0
# Syllable: flOp, Count: 0.0
# Syllable: lLk, Count: 59.0
# Syllable: skrIp, Count: 3.0
# Syllable: 'pIl, Count: 480.0
# Syllable: 'nar, Count: 195818.0
# Syllable: wEG, Count: 16.0
# Syllable: 'bI, Count: 37833.0
# Syllable: 'us, Count: 62.0
# Syllable: 'xrod, Count: 124.0
# Syllable: 'snIt, Count: 13.0
# Syllable: 'xas, Count: 42.0
# Syllable: vExt, Count: 278.0
# Syllable: dint, Count: 20.0
# Syllable: 'p}N, Count: 19.0
# Syllable: mOlm, Count: 1.0
# Syllable: kwEnt, Count: 12.0
# Syllable: 'blEs, Count: 4.0
# Syllable: tAnt, Count: 82.0
# Syllable: 'bot, Count: 7974.0
# Syllable: vEk, Count: 2.0
# Syllable: xef, Count: 23.0
# Syllable: h}, Count: 8.0
# Syllable: ardz, Count: 0.0
# Syllable: 'hof, Count: 24.0
# Syllable: 'wLt, Count: 0.0
# Syllable: kak, Count: 63.0
# Syllable: 'ste, Count: 9847.0
# Syllable: 'lOf, Count: 1843.0
# Syllable: 'dro, Count: 4756.0
# Syllable: plIx, Count: 0.0
# Syllable: mon, Count: 0.0
# Syllable: 'sx}lt, Count: 8157.0
# Syllable: 'dKs, Count: 662.0
# Syllable: 'b}lk, Count: 6.0
# Syllable: GrOnt, Count: 705.0
# Syllable: 'sx}t, Count: 232.0
# Syllable: 'pri, Count: 12265.0
# Syllable: 'traf, Count: 0.0
# Syllable: rOjt, Count: 38.0
# Syllable: 'd|Gd, Count: 0.0
# Syllable: '_ip, Count: 337.0
# Syllable: flo, Count: 52.0
# Syllable: xest, Count: 53.0
# Syllable: 'kl|m, Count: 0.0
# Syllable: 'rM, Count: 300.0
# Syllable: 'tKts, Count: 271.0
# Syllable: n@xst, Count: 13.0
# Syllable: 'slo, Count: 5068.0
# Syllable: 'radz, Count: 0.0
# Syllable: ksi, Count: 8.0
# Syllable: 'stIfts, Count: 0.0
# Syllable: 'nIk, Count: 41.0
# Syllable: d@N, Count: 0.0
# Syllable: 'zwENkt, Count: 0.0
# Syllable: fik, Count: 0.0
# Syllable: Ert, Count: 3.0
# Syllable: mAks, Count: 66.0
# Syllable: 'jat, Count: 111.0
# Syllable: 'dAg, Count: 2.0
# Syllable: stAf, Count: 64.0
# Syllable: nAr, Count: 436.0
# Syllable: 'GIl, Count: 124.0
# Syllable: stAN, Count: 8.0
# Syllable: 'x}m, Count: 21.0
# Syllable: ot, Count: 6.0
# Syllable: sEst, Count: 60.0
# Syllable: br|t, Count: 0.0
# Syllable: rimz, Count: 0.0
# Syllable: 've, Count: 6482.0
# Syllable: tel, Count: 243.0
# Syllable: 'lINks, Count: 3290.0
# Syllable: 'xik, Count: 3.0
# Syllable: klir, Count: 55.0
# Syllable: Ol, Count: 22.0
# Syllable: GE, Count: 1.0
# Syllable: 'klMs, Count: 73.0
# Syllable: 'b|, Count: 9604.0
# Syllable: 'jOk, Count: 4.0
# Syllable: 'Zans, Count: 0.0
# Syllable: 'sm}l, Count: 6.0
# Syllable: 'drAxt, Count: 6.0
# Syllable: hErfst, Count: 0.0
# Syllable: ljEf, Count: 0.0
# Syllable: 'r}Gd, Count: 9.0
# Syllable: lEst, Count: 0.0
# Syllable: INkt, Count: 17.0
# Syllable: 'su, Count: 206.0
# Syllable: 'zLG, Count: 8.0
# Syllable: 'fAjn, Count: 0.0
# Syllable: 'f|t, Count: 2.0
# Syllable: 'klEdz, Count: 0.0
# Syllable: 'strI, Count: 451.0
# Syllable: s@ms, Count: 14.0
# Syllable: 'brLt, Count: 1076.0
# Syllable: telt, Count: 49.0
# Syllable: frAxt, Count: 1.0
# Syllable: hMw, Count: 5.0
# Syllable: fAndz, Count: 0.0
# Syllable: sIns, Count: 350.0
# Syllable: sxApt, Count: 0.0
# Syllable: 'sxrIf, Count: 61.0
# Syllable: sAn, Count: 11.0
# Syllable: g}m, Count: 31.0
# Syllable: 'sxom, Count: 56.0
# Syllable: 'xrOt, Count: 763.0
# Syllable: klik, Count: 0.0
# Syllable: 'klAd, Count: 14.0
# Syllable: 'hON, Count: 45.0
# Syllable: rKt, Count: 47.0
# Syllable: flEt, Count: 27.0
# Syllable: pIk, Count: 317.0
# Syllable: 'd@, Count: 1061177.0
# Syllable: 'krIst, Count: 1.0
# Syllable: 'xno, Count: 4.0
# Syllable: 'prOnt, Count: 1.0
# Syllable: 'splet, Count: 162.0
# Syllable: 'vI, Count: 3701.0
# Syllable: 'wKk, Count: 484.0
# Syllable: 'lyd, Count: 0.0
# Syllable: 'bri, Count: 583.0
# Syllable: 'kwIps, Count: 0.0
# Syllable: 'tep, Count: 752.0
# Syllable: 'vlErkt, Count: 0.0
# Syllable: 'GrIn, Count: 0.0
# Syllable: slEx, Count: 0.0
# Syllable: 'wont, Count: 59.0
# Syllable: mAG, Count: 473.0
# Syllable: sxIxt, Count: 30.0
# Syllable: krAmp, Count: 29.0
# Syllable: drK, Count: 773.0
# Syllable: 'bEk, Count: 294.0
# Syllable: 'ZAst, Count: 479.0
# Syllable: 'dans, Count: 0.0
# Syllable: 'xran, Count: 248.0
# Syllable: 'kordz, Count: 0.0
# Syllable: kOrf, Count: 60.0
# Syllable: 'snes, Count: 0.0
# Syllable: 'dwKm, Count: 1.0
# Syllable: 'hom, Count: 97.0
# Syllable: 'tipt, Count: 47.0
# Syllable: 'lOn, Count: 605.0
# Syllable: 'sirz, Count: 0.0
# Syllable: 'trKp, Count: 0.0
# Syllable: 'pOnd, Count: 0.0
# Syllable: 'weps, Count: 0.0
# Syllable: 'bIt, Count: 216.0
# Syllable: zins, Count: 17.0
# Syllable: sxAf, Count: 16.0
# Syllable: 'wElk, Count: 4040.0
# Syllable: 'vrE, Count: 10.0
# Syllable: 'zwO, Count: 80.0
# Syllable: hIN, Count: 0.0
# Syllable: zAnt, Count: 83.0
# Syllable: Kl, Count: 0.0
# Syllable: 'skIf, Count: 1.0
# Syllable: 'brItS, Count: 138.0
# Syllable: fOnts, Count: 80.0
# Syllable: vlEkt, Count: 0.0
# Syllable: 'sx}lpt, Count: 0.0
# Syllable: 'spIn, Count: 360.0

# %%
len(syllable_counts)
# Out:
# 13034

# %%
#save syllable_counts to a csv file
syllable_counts_df = pd.DataFrame.from_dict(syllable_counts, orient = 'index', columns = ['Count'])
syllable_counts_df.to_csv('syllable_counts.csv')

# %%
# # Load the CSV file
# csv_file_path = 'syllable_counts.csv'
# syllable_counts_df = pd.read_csv(csv_file_path)

# # Ensure the column names are valid MATLAB variable names
# syllable_counts_df.columns = ['syllable', 'Count']

# # Convert the DataFrame to a dictionary of arrays, making sure each column is a separate entry
# syllable_table_dict = {}
# for col in syllable_counts_df.columns:
#     syllable_table_dict[col] = syllable_counts_df[col].values

# # Save the dictionary as a MATLAB file
# new_mat_file_path = 'syllable_freq_table_new.mat'
# scipy.io.savemat(new_mat_file_path, syllable_table_dict)

# print(f"Updated .mat file saved at: {new_mat_file_path}")

# %%
#MOUS word phonetic transcriptions. how many words are there whose syllables are uncounted?

# %%
stimuli = 'stimuli.txt'
#remove all numbers and make every word in the txt a row in a dataframe column
with open(stimuli, 'r') as f:
    words = f.read().splitlines()
#remove all numbers
mous_words = []
for line in words:
    tokens = line.split(" ")
    for token in tokens:
        if token.isdigit():
            tokens.remove(token)
    mous_words.extend([token.lower() for token in tokens if token != ''])
#make a dataframe
mous_words = pd.DataFrame(mous_words, columns = ['Word'])
mous_words.drop_duplicates(inplace = True)
mous_words.reset_index(drop = True, inplace = True)
mous_words
# Out:
#             Word
# 0           toen
# 1             de
# 2      barkeeper
# 3            die
# 4      irritante
# ...          ...
# 1937       blije
# 1938    jongeren
# 1939      intens
# 1940     plezier
# 1941  woonplaats
#
# [1942 rows x 1 columns]

# %%
#find the word in words that contains an apostrophe
for word in mous_words['Word']:
    if "'" in word:
        print(word)
# Out:
# collega's
# fotocamera's
# auto's
# dorien's

# %%
#intersect mous_words with new_df on 'Word'
# mous_words = mous_words.merge(new_df[['Word','Syllables']], on = 'Word', how = 'left')
# mous_words.drop_duplicates(subset = 'Word', inplace = True)
# mous_words = mous_words.reset_index(drop = True)
# mous_words
# Out:
#             Word        Syllables
# 0           toen           ['tun]
# 1             de            ['d@]
# 2      barkeeper  ['bAr, ki, p@r]
# 3            die            ['di]
# 4      irritante              NaN
# ...          ...              ...
# 1937       blije              NaN
# 1938    jongeren              NaN
# 1939      intens      [In, 'tEns]
# 1940     plezier      [pl@, 'zir]
# 1941  woonplaats    ['wom, plats]
#
# [1942 rows x 2 columns]

# %%
#intesect mous_words with IPA
ipa_df =pd.read_csv('/home/neel/Desktop/MOUS_hierarchical-representations/MOUS_IPA_SyllableFrequencies_ijfix2.csv')
mous_words = mous_words.merge(ipa_df, on = 'Word', how = 'left')
mous_words.drop_duplicates(subset = 'Word', inplace = True)
mous_words = mous_words.reset_index(drop = True)
#drop column  'Unnamed: 0' and IPA_y and rename IPA_x to IPA
mous_words.drop(columns = ['Unnamed: 0'], inplace = True)
mous_words.rename(columns = {'IPA_x':'IPA'}, inplace = True)
mous_words
# Out:
#             Word           IPA           Syllables  Min_Freq_Count  \
# 0           toen          tˈun                 tun           177.0
# 1             de           dˈə                  də        208410.0
# 2      barkeeper    bˈɑrkeːpər     bɑr - keː - pər          1201.0
# 3            die           dˈi                  di        441857.0
# 4      irritante   ˌɪɾritˈɑntə  ɪɾ - ri - tɑn - tə             8.0
# ...          ...           ...                 ...             ...
# 1937       blije        blˈɛɪə            blɛɪ - ə          1796.0
# 1938    jongeren      jˈɔŋərən       jɔŋ - ə - rən          6659.0
# 1939      intens       ˈɪntəns           ɪn - təns           575.0
# 1940     plezier      pleːzˈir          pleː - zir          1573.0
# 1941  woonplaats  ʋˈoːnplˌaːts       ʋoːn - plaːts          2198.0
#
#       Max_Freq_Count  Mean_Freq_Count
# 0              177.0     1.770000e+02
# 1           208410.0     2.084100e+05
# 2            22550.0     1.399933e+04
# 3           441857.0     4.418570e+05
# 4           995799.0     2.623075e+05
# ...              ...              ...
# 1937       2281166.0     1.141481e+06
# 1938       2281166.0     7.780040e+05
# 1939        214096.0     1.073355e+05
# 1940          6109.0     3.841000e+03
# 1941         14293.0     8.245500e+03
#
# [1942 rows x 6 columns]

# %%
#drop nan values
#mous_words = mous_words.dropna()
mous_words.reset_index(drop = True, inplace = True)
mous_words
# Out:
#             Word           IPA           Syllables  Min_Freq_Count  \
# 0           toen          tˈun                 tun           177.0
# 1             de           dˈə                  də        208410.0
# 2      barkeeper    bˈɑrkeːpər     bɑr - keː - pər          1201.0
# 3            die           dˈi                  di        441857.0
# 4      irritante   ˌɪɾritˈɑntə  ɪɾ - ri - tɑn - tə             8.0
# ...          ...           ...                 ...             ...
# 1937       blije        blˈɛɪə            blɛɪ - ə          1796.0
# 1938    jongeren      jˈɔŋərən       jɔŋ - ə - rən          6659.0
# 1939      intens       ˈɪntəns           ɪn - təns           575.0
# 1940     plezier      pleːzˈir          pleː - zir          1573.0
# 1941  woonplaats  ʋˈoːnplˌaːts       ʋoːn - plaːts          2198.0
#
#       Max_Freq_Count  Mean_Freq_Count
# 0              177.0     1.770000e+02
# 1           208410.0     2.084100e+05
# 2            22550.0     1.399933e+04
# 3           441857.0     4.418570e+05
# 4           995799.0     2.623075e+05
# ...              ...              ...
# 1937       2281166.0     1.141481e+06
# 1938       2281166.0     7.780040e+05
# 1939        214096.0     1.073355e+05
# 1940          6109.0     3.841000e+03
# 1941         14293.0     8.245500e+03
#
# [1942 rows x 6 columns]

# %%
def handle_syllables(x):
    # Check if x is a list (or any iterable except for strings), then proceed with the original operation.
    if isinstance(x, list):
        return [syllable_counts[syl] for syl in x]
    # If x is not a list, return a default value, e.g., an empty list or a list with a specific value indicating the error.
    else:
        return []  # or return [0] or any other placeholder value that makes sense in your context

# # Apply the modified function
# mous_words['Syllable Occurrence Counts'] = mous_words['Syllables'].apply(handle_syllables)
# mous_words

# %%
mous_words
# Out:
#             Word           IPA           Syllables  Min_Freq_Count  \
# 0           toen          tˈun                 tun           177.0
# 1             de           dˈə                  də        208410.0
# 2      barkeeper    bˈɑrkeːpər     bɑr - keː - pər          1201.0
# 3            die           dˈi                  di        441857.0
# 4      irritante   ˌɪɾritˈɑntə  ɪɾ - ri - tɑn - tə             8.0
# ...          ...           ...                 ...             ...
# 1937       blije        blˈɛɪə            blɛɪ - ə          1796.0
# 1938    jongeren      jˈɔŋərən       jɔŋ - ə - rən          6659.0
# 1939      intens       ˈɪntəns           ɪn - təns           575.0
# 1940     plezier      pleːzˈir          pleː - zir          1573.0
# 1941  woonplaats  ʋˈoːnplˌaːts       ʋoːn - plaːts          2198.0
#
#       Max_Freq_Count  Mean_Freq_Count
# 0              177.0     1.770000e+02
# 1           208410.0     2.084100e+05
# 2            22550.0     1.399933e+04
# 3           441857.0     4.418570e+05
# 4           995799.0     2.623075e+05
# ...              ...              ...
# 1937       2281166.0     1.141481e+06
# 1938       2281166.0     7.780040e+05
# 1939        214096.0     1.073355e+05
# 1940          6109.0     3.841000e+03
# 1941         14293.0     8.245500e+03
#
# [1942 rows x 6 columns]

# %% [markdown]
# Bigrams

# %%
#generate a list of all bigrams possible in the alphabet
import string
alphabet = string.ascii_lowercase
bigrams = []
for letter1 in alphabet:
    for letter2 in alphabet:
        bigrams.append(letter1 + letter2)
bigrams
# Out:
# ['aa',
#  'ab',
#  'ac',
#  'ad',
#  'ae',
#  'af',
#  'ag',
#  'ah',
#  'ai',
#  'aj',
#  'ak',
#  'al',
#  'am',
#  'an',
#  'ao',
#  'ap',
#  'aq',
#  'ar',
#  'as',
#  'at',
#  'au',
#  'av',
#  'aw',
#  'ax',
#  'ay',
#  'az',
#  'ba',
#  'bb',
#  'bc',
#  'bd',
#  'be',
#  'bf',
#  'bg',
#  'bh',
#  'bi',
#  'bj',
#  'bk',
#  'bl',
#  'bm',
#  'bn',
#  'bo',
#  'bp',
#  'bq',
#  'br',
#  'bs',
#  'bt',
#  'bu',
#  'bv',
#  'bw',
#  'bx',
#  'by',
#  'bz',
#  'ca',
#  'cb',
#  'cc',
#  'cd',
#  'ce',
#  'cf',
#  'cg',
#  'ch',
#  'ci',
#  'cj',
#  'ck',
#  'cl',
#  'cm',
#  'cn',
#  'co',
#  'cp',
#  'cq',
#  'cr',
#  'cs',
#  'ct',
#  'cu',
#  'cv',
#  'cw',
#  'cx',
#  'cy',
#  'cz',
#  'da',
#  'db',
#  'dc',
#  'dd',
#  'de',
#  'df',
#  'dg',
#  'dh',
#  'di',
#  'dj',
#  'dk',
#  'dl',
#  'dm',
#  'dn',
#  'do',
#  'dp',
#  'dq',
#  'dr',
#  'ds',
#  'dt',
#  'du',
#  'dv',
#  'dw',
#  'dx',
#  'dy',
#  'dz',
#  'ea',
#  'eb',
#  'ec',
#  'ed',
#  'ee',
#  'ef',
#  'eg',
#  'eh',
#  'ei',
#  'ej',
#  'ek',
#  'el',
#  'em',
#  'en',
#  'eo',
#  'ep',
#  'eq',
#  'er',
#  'es',
#  'et',
#  'eu',
#  'ev',
#  'ew',
#  'ex',
#  'ey',
#  'ez',
#  'fa',
#  'fb',
#  'fc',
#  'fd',
#  'fe',
#  'ff',
#  'fg',
#  'fh',
#  'fi',
#  'fj',
#  'fk',
#  'fl',
#  'fm',
#  'fn',
#  'fo',
#  'fp',
#  'fq',
#  'fr',
#  'fs',
#  'ft',
#  'fu',
#  'fv',
#  'fw',
#  'fx',
#  'fy',
#  'fz',
#  'ga',
#  'gb',
#  'gc',
#  'gd',
#  'ge',
#  'gf',
#  'gg',
#  'gh',
#  'gi',
#  'gj',
#  'gk',
#  'gl',
#  'gm',
#  'gn',
#  'go',
#  'gp',
#  'gq',
#  'gr',
#  'gs',
#  'gt',
#  'gu',
#  'gv',
#  'gw',
#  'gx',
#  'gy',
#  'gz',
#  'ha',
#  'hb',
#  'hc',
#  'hd',
#  'he',
#  'hf',
#  'hg',
#  'hh',
#  'hi',
#  'hj',
#  'hk',
#  'hl',
#  'hm',
#  'hn',
#  'ho',
#  'hp',
#  'hq',
#  'hr',
#  'hs',
#  'ht',
#  'hu',
#  'hv',
#  'hw',
#  'hx',
#  'hy',
#  'hz',
#  'ia',
#  'ib',
#  'ic',
#  'id',
#  'ie',
#  'if',
#  'ig',
#  'ih',
#  'ii',
#  'ij',
#  'ik',
#  'il',
#  'im',
#  'in',
#  'io',
#  'ip',
#  'iq',
#  'ir',
#  'is',
#  'it',
#  'iu',
#  'iv',
#  'iw',
#  'ix',
#  'iy',
#  'iz',
#  'ja',
#  'jb',
#  'jc',
#  'jd',
#  'je',
#  'jf',
#  'jg',
#  'jh',
#  'ji',
#  'jj',
#  'jk',
#  'jl',
#  'jm',
#  'jn',
#  'jo',
#  'jp',
#  'jq',
#  'jr',
#  'js',
#  'jt',
#  'ju',
#  'jv',
#  'jw',
#  'jx',
#  'jy',
#  'jz',
#  'ka',
#  'kb',
#  'kc',
#  'kd',
#  'ke',
#  'kf',
#  'kg',
#  'kh',
#  'ki',
#  'kj',
#  'kk',
#  'kl',
#  'km',
#  'kn',
#  'ko',
#  'kp',
#  'kq',
#  'kr',
#  'ks',
#  'kt',
#  'ku',
#  'kv',
#  'kw',
#  'kx',
#  'ky',
#  'kz',
#  'la',
#  'lb',
#  'lc',
#  'ld',
#  'le',
#  'lf',
#  'lg',
#  'lh',
#  'li',
#  'lj',
#  'lk',
#  'll',
#  'lm',
#  'ln',
#  'lo',
#  'lp',
#  'lq',
#  'lr',
#  'ls',
#  'lt',
#  'lu',
#  'lv',
#  'lw',
#  'lx',
#  'ly',
#  'lz',
#  'ma',
#  'mb',
#  'mc',
#  'md',
#  'me',
#  'mf',
#  'mg',
#  'mh',
#  'mi',
#  'mj',
#  'mk',
#  'ml',
#  'mm',
#  'mn',
#  'mo',
#  'mp',
#  'mq',
#  'mr',
#  'ms',
#  'mt',
#  'mu',
#  'mv',
#  'mw',
#  'mx',
#  'my',
#  'mz',
#  'na',
#  'nb',
#  'nc',
#  'nd',
#  'ne',
#  'nf',
#  'ng',
#  'nh',
#  'ni',
#  'nj',
#  'nk',
#  'nl',
#  'nm',
#  'nn',
#  'no',
#  'np',
#  'nq',
#  'nr',
#  'ns',
#  'nt',
#  'nu',
#  'nv',
#  'nw',
#  'nx',
#  'ny',
#  'nz',
#  'oa',
#  'ob',
#  'oc',
#  'od',
#  'oe',
#  'of',
#  'og',
#  'oh',
#  'oi',
#  'oj',
#  'ok',
#  'ol',
#  'om',
#  'on',
#  'oo',
#  'op',
#  'oq',
#  'or',
#  'os',
#  'ot',
#  'ou',
#  'ov',
#  'ow',
#  'ox',
#  'oy',
#  'oz',
#  'pa',
#  'pb',
#  'pc',
#  'pd',
#  'pe',
#  'pf',
#  'pg',
#  'ph',
#  'pi',
#  'pj',
#  'pk',
#  'pl',
#  'pm',
#  'pn',
#  'po',
#  'pp',
#  'pq',
#  'pr',
#  'ps',
#  'pt',
#  'pu',
#  'pv',
#  'pw',
#  'px',
#  'py',
#  'pz',
#  'qa',
#  'qb',
#  'qc',
#  'qd',
#  'qe',
#  'qf',
#  'qg',
#  'qh',
#  'qi',
#  'qj',
#  'qk',
#  'ql',
#  'qm',
#  'qn',
#  'qo',
#  'qp',
#  'qq',
#  'qr',
#  'qs',
#  'qt',
#  'qu',
#  'qv',
#  'qw',
#  'qx',
#  'qy',
#  'qz',
#  'ra',
#  'rb',
#  'rc',
#  'rd',
#  're',
#  'rf',
#  'rg',
#  'rh',
#  'ri',
#  'rj',
#  'rk',
#  'rl',
#  'rm',
#  'rn',
#  'ro',
#  'rp',
#  'rq',
#  'rr',
#  'rs',
#  'rt',
#  'ru',
#  'rv',
#  'rw',
#  'rx',
#  'ry',
#  'rz',
#  'sa',
#  'sb',
#  'sc',
#  'sd',
#  'se',
#  'sf',
#  'sg',
#  'sh',
#  'si',
#  'sj',
#  'sk',
#  'sl',
#  'sm',
#  'sn',
#  'so',
#  'sp',
#  'sq',
#  'sr',
#  'ss',
#  'st',
#  'su',
#  'sv',
#  'sw',
#  'sx',
#  'sy',
#  'sz',
#  'ta',
#  'tb',
#  'tc',
#  'td',
#  'te',
#  'tf',
#  'tg',
#  'th',
#  'ti',
#  'tj',
#  'tk',
#  'tl',
#  'tm',
#  'tn',
#  'to',
#  'tp',
#  'tq',
#  'tr',
#  'ts',
#  'tt',
#  'tu',
#  'tv',
#  'tw',
#  'tx',
#  'ty',
#  'tz',
#  'ua',
#  'ub',
#  'uc',
#  'ud',
#  'ue',
#  'uf',
#  'ug',
#  'uh',
#  'ui',
#  'uj',
#  'uk',
#  'ul',
#  'um',
#  'un',
#  'uo',
#  'up',
#  'uq',
#  'ur',
#  'us',
#  'ut',
#  'uu',
#  'uv',
#  'uw',
#  'ux',
#  'uy',
#  'uz',
#  'va',
#  'vb',
#  'vc',
#  'vd',
#  've',
#  'vf',
#  'vg',
#  'vh',
#  'vi',
#  'vj',
#  'vk',
#  'vl',
#  'vm',
#  'vn',
#  'vo',
#  'vp',
#  'vq',
#  'vr',
#  'vs',
#  'vt',
#  'vu',
#  'vv',
#  'vw',
#  'vx',
#  'vy',
#  'vz',
#  'wa',
#  'wb',
#  'wc',
#  'wd',
#  'we',
#  'wf',
#  'wg',
#  'wh',
#  'wi',
#  'wj',
#  'wk',
#  'wl',
#  'wm',
#  'wn',
#  'wo',
#  'wp',
#  'wq',
#  'wr',
#  'ws',
#  'wt',
#  'wu',
#  'wv',
#  'ww',
#  'wx',
#  'wy',
#  'wz',
#  'xa',
#  'xb',
#  'xc',
#  'xd',
#  'xe',
#  'xf',
#  'xg',
#  'xh',
#  'xi',
#  'xj',
#  'xk',
#  'xl',
#  'xm',
#  'xn',
#  'xo',
#  'xp',
#  'xq',
#  'xr',
#  'xs',
#  'xt',
#  'xu',
#  'xv',
#  'xw',
#  'xx',
#  'xy',
#  'xz',
#  'ya',
#  'yb',
#  'yc',
#  'yd',
#  'ye',
#  'yf',
#  'yg',
#  'yh',
#  'yi',
#  'yj',
#  'yk',
#  'yl',
#  'ym',
#  'yn',
#  'yo',
#  'yp',
#  'yq',
#  'yr',
#  'ys',
#  'yt',
#  'yu',
#  'yv',
#  'yw',
#  'yx',
#  'yy',
#  'yz',
#  'za',
#  'zb',
#  'zc',
#  'zd',
#  'ze',
#  'zf',
#  'zg',
#  'zh',
#  'zi',
#  'zj',
#  'zk',
#  'zl',
#  'zm',
#  'zn',
#  'zo',
#  'zp',
#  'zq',
#  'zr',
#  'zs',
#  'zt',
#  'zu',
#  'zv',
#  'zw',
#  'zx',
#  'zy',
#  'zz']

# %%
# Find the cumulative occurrence of each bigram in the subtlex dataframe
bigram_counts = {bigram: 0 for bigram in bigrams}
for bigram in bigrams:
    # Ensure x is treated as a string, even if it's originally a float
    mask = subtlex_v2['Word'].apply(lambda x: bigram in str(x))
    bigram_counts[bigram] = new_df.loc[mask, 'FREQcount'].sum()

# %%
#make dataframe and csv from bigram_counts
bigram_counts_df = pd.DataFrame.from_dict(bigram_counts, orient = 'index', columns = ['Count'])
#make index a column
bigram_counts_df.reset_index(inplace = True)
bigram_counts_df.rename(columns = {'index':'Bigram'}, inplace = True)
bigram_counts_df.to_csv('/home/neel/Desktop/sublexical_crossmodal/bigram_counts.csv')

# %%
bigram_counts_df = pd.read_csv('/home/neel/Desktop/MOUS_hierarchical-representations/bigram_counts.csv')

# %%
def split_word_bigrams(word):
    # Split the word into bigrams
    bigrams = [word[i:i+2] for i in range(len(word) - 1)]
    return bigrams

# %%
mous_words['Bigrams'] = mous_words['Word'].apply(split_word_bigrams)
mous_words
# Out:
#             Word           IPA           Syllables  Min_Freq_Count  \
# 0           toen          tˈun                 tun           177.0
# 1             de           dˈə                  də        208410.0
# 2      barkeeper    bˈɑrkeːpər     bɑr - keː - pər          1201.0
# 3            die           dˈi                  di        441857.0
# 4      irritante   ˌɪɾritˈɑntə  ɪɾ - ri - tɑn - tə             8.0
# ...          ...           ...                 ...             ...
# 1937       blije        blˈɛɪə            blɛɪ - ə          1796.0
# 1938    jongeren      jˈɔŋərən       jɔŋ - ə - rən          6659.0
# 1939      intens       ˈɪntəns           ɪn - təns           575.0
# 1940     plezier      pleːzˈir          pleː - zir          1573.0
# 1941  woonplaats  ʋˈoːnplˌaːts       ʋoːn - plaːts          2198.0
#
#       Max_Freq_Count  Mean_Freq_Count                               Bigrams
# 0              177.0     1.770000e+02                          [to, oe, en]
# 1           208410.0     2.084100e+05                                  [de]
# 2            22550.0     1.399933e+04      [ba, ar, rk, ke, ee, ep, pe, er]
# 3           441857.0     4.418570e+05                              [di, ie]
# 4           995799.0     2.623075e+05      [ir, rr, ri, it, ta, an, nt, te]
# ...              ...              ...                                   ...
# 1937       2281166.0     1.141481e+06                      [bl, li, ij, je]
# 1938       2281166.0     7.780040e+05          [jo, on, ng, ge, er, re, en]
# 1939        214096.0     1.073355e+05                  [in, nt, te, en, ns]
# 1940          6109.0     3.841000e+03              [pl, le, ez, zi, ie, er]
# 1941         14293.0     8.245500e+03  [wo, oo, on, np, pl, la, aa, at, ts]
#
# [1942 rows x 7 columns]

# %%
mous_words['Bigram Occurrence Counts'] = mous_words['Bigrams'].apply(lambda x: [bigram_counts.get(bigram, 0) for bigram in x])

# %%
mous_words
# Out:
#             Word           IPA           Syllables  Min_Freq_Count  \
# 0           toen          tˈun                 tun           177.0
# 1             de           dˈə                  də        208410.0
# 2      barkeeper    bˈɑrkeːpər     bɑr - keː - pər          1201.0
# 3            die           dˈi                  di        441857.0
# 4      irritante   ˌɪɾritˈɑntə  ɪɾ - ri - tɑn - tə             8.0
# ...          ...           ...                 ...             ...
# 1937       blije        blˈɛɪə            blɛɪ - ə          1796.0
# 1938    jongeren      jˈɔŋərən       jɔŋ - ə - rən          6659.0
# 1939      intens       ˈɪntəns           ɪn - təns           575.0
# 1940     plezier      pleːzˈir          pleː - zir          1573.0
# 1941  woonplaats  ʋˈoːnplˌaːts       ʋoːn - plaːts          2198.0
#
#       Max_Freq_Count  Mean_Freq_Count                               Bigrams  \
# 0              177.0     1.770000e+02                          [to, oe, en]
# 1           208410.0     2.084100e+05                                  [de]
# 2            22550.0     1.399933e+04      [ba, ar, rk, ke, ee, ep, pe, er]
# 3           441857.0     4.418570e+05                              [di, ie]
# 4           995799.0     2.623075e+05      [ir, rr, ri, it, ta, an, nt, te]
# ...              ...              ...                                   ...
# 1937       2281166.0     1.141481e+06                      [bl, li, ij, je]
# 1938       2281166.0     7.780040e+05          [jo, on, ng, ge, er, re, en]
# 1939        214096.0     1.073355e+05                  [in, nt, te, en, ns]
# 1940          6109.0     3.841000e+03              [pl, le, ez, zi, ie, er]
# 1941         14293.0     8.245500e+03  [wo, oo, on, np, pl, la, aa, at, ts]
#
#                                Bigram Occurrence Counts
# 0                      [2236591.0, 837795.0, 8542439.0]
# 1                                           [2559661.0]
# 2     [584273.0, 1754491.0, 2174749.0, 3143026.0, 94...
# 3                                [1050254.0, 2076673.0]
# 4     [2884214.0, 200692.0, 1787712.0, 333345.0, 892...
# ...                                                 ...
# 1937         [152155.0, 3369152.0, 1639122.0, 913788.0]
# 1938  [866375.0, 2451854.0, 2927082.0, 3692145.0, 67...
# 1939  [2264626.0, 1477178.0, 3522714.0, 8542439.0, 6...
# 1940  [97171.0, 4397946.0, 100963.0, 123482.0, 20766...
# 1941  [933919.0, 3901750.0, 2451854.0, 16967.0, 9717...
#
# [1942 rows x 8 columns]

# %%
mous_words['Zipf'] = mous_words['Word'].apply(lambda x: subtlex_v2.loc[subtlex_v2['Word'] == x, 'Zipf'].values[0] if x in subtlex_v2['Word'].values else np.nan)
mous_words['FREQcount'] = mous_words['Word'].apply(lambda x: (subtlex_v2.loc[subtlex_v2['Word'] == x, 'FREQcount'].values[0]) if x in subtlex_v2['Word'].values else np.nan)
mous_words['Lg10WF'] = mous_words['FREQcount'].apply(lambda x: np.log10(x) if x > 0 else 0)
mous_words.to_csv('/home/neel/Desktop/MOUS_hierarchical-representations/mous_words_IPA_syllable_bigram_frequencies.csv', index = False)
mous_words
# Out:
#             Word           IPA           Syllables  Min_Freq_Count  \
# 0           toen          tˈun                 tun           177.0
# 1             de           dˈə                  də        208410.0
# 2      barkeeper    bˈɑrkeːpər     bɑr - keː - pər          1201.0
# 3            die           dˈi                  di        441857.0
# 4      irritante   ˌɪɾritˈɑntə  ɪɾ - ri - tɑn - tə             8.0
# ...          ...           ...                 ...             ...
# 1937       blije        blˈɛɪə            blɛɪ - ə          1796.0
# 1938    jongeren      jˈɔŋərən       jɔŋ - ə - rən          6659.0
# 1939      intens       ˈɪntəns           ɪn - təns           575.0
# 1940     plezier      pleːzˈir          pleː - zir          1573.0
# 1941  woonplaats  ʋˈoːnplˌaːts       ʋoːn - plaːts          2198.0
#
#       Max_Freq_Count  Mean_Freq_Count                               Bigrams  \
# 0              177.0     1.770000e+02                          [to, oe, en]
# 1           208410.0     2.084100e+05                                  [de]
# 2            22550.0     1.399933e+04      [ba, ar, rk, ke, ee, ep, pe, er]
# 3           441857.0     4.418570e+05                              [di, ie]
# 4           995799.0     2.623075e+05      [ir, rr, ri, it, ta, an, nt, te]
# ...              ...              ...                                   ...
# 1937       2281166.0     1.141481e+06                      [bl, li, ij, je]
# 1938       2281166.0     7.780040e+05          [jo, on, ng, ge, er, re, en]
# 1939        214096.0     1.073355e+05                  [in, nt, te, en, ns]
# 1940          6109.0     3.841000e+03              [pl, le, ez, zi, ie, er]
# 1941         14293.0     8.245500e+03  [wo, oo, on, np, pl, la, aa, at, ts]
#
#                                Bigram Occurrence Counts      Zipf  FREQcount  \
# 0                      [2236591.0, 837795.0, 8542439.0]  6.032333    47514.0
# 1                                           [2559661.0]  7.381291  1061177.0
# 2     [584273.0, 1754491.0, 2174749.0, 3143026.0, 94...  3.622674      184.0
# 3                                [1050254.0, 2076673.0]  6.853871   315041.0
# 4     [2884214.0, 200692.0, 1787712.0, 333345.0, 892...  3.284921       84.0
# ...                                                 ...       ...        ...
# 1937         [152155.0, 3369152.0, 1639122.0, 913788.0]  3.485836      134.0
# 1938  [866375.0, 2451854.0, 2927082.0, 3692145.0, 67...  3.965097      406.0
# 1939  [2264626.0, 1477178.0, 3522714.0, 8542439.0, 6...  3.778748      264.0
# 1940  [97171.0, 4397946.0, 100963.0, 123482.0, 20766...  5.093966     5475.0
# 1941  [933919.0, 3901750.0, 2451854.0, 16967.0, 9717...  3.241993       76.0
#
#         Lg10WF
# 0     4.676822
# 1     6.025788
# 2     2.264818
# 3     5.498367
# 4     1.924279
# ...        ...
# 1937  2.127105
# 1938  2.608526
# 1939  2.421604
# 1940  3.738384
# 1941  1.880814
#
# [1942 rows x 11 columns]

# %% [markdown]
# Data summary.
#
# `1942` unique words in the MOUS study.
#
#     `X` have syllable parcellations
#
#     `Y` have bigram parcellations
#
#     `4` have apostrophes (see above)
#
#
# `A` unique words in SUBTLEX, `B` unique words in CELEX
#
#     `C` (overlap) have syllable parcellations from CELEX (matters for syllable frequency calculations)

# %%
new_df

# %%
#find number of rows in mous_words that are non-Nan in 'Syllables'
#return X_words, a dataframe of all words in mous_words that have syllables
#return missing_words, a dataframe of all words in mous_words that do not have syllables
X_words = mous_words.dropna(subset = ['Syllables'])
X = mous_words['Syllables'].count()

# %%
X_words

# %%
missing_words = mous_words[mous_words['Syllables'].isnull()]

# %%
missing_words

# %%
X_words

# %%
#Find number of rows in mous_words that are non-Nan in 'Bigrams'
Y = mous_words['Bigrams'].count()
Y

# %%
A = subtlex_v2['Word'].count()
A

# %%
B = celex_syllables['Head'].count()
B

# %%
C = new_df['Zipf'].count()
C

# %% [markdown]
# International Phonetic Alphabet (IPA) transcriptions.

# %%
subtlex_words = list(subtlex['Word'])

# %%
subtlex_words
# Out:
# ['ik',
#  'je',
#  'het',
#  'de',
#  'dat',
#  'is',
#  'niet',
#  'een',
#  'en',
#  'wat',
#  'van',
#  'we',
#  'ze',
#  'hij',
#  'in',
#  'maar',
#  'er',
#  'op',
#  'zijn',
#  'te',
#  'me',
#  'die',
#  'heb',
#  'met',
#  'voor',
#  'als',
#  'u',
#  'ben',
#  'was',
#  'dit',
#  'hier',
#  'jij',
#  'naar',
#  'om',
#  'mijn',
#  'weet',
#  'dan',
#  'wel',
#  'kan',
#  'nog',
#  'wil',
#  'geen',
#  'moet',
#  'zo',
#  'aan',
#  'hem',
#  'heeft',
#  'goed',
#  'hebben',
#  'ja',
#  'hoe',
#  'waar',
#  'nu',
#  'nee',
#  'haar',
#  'ga',
#  "'t",
#  'bent',
#  'uit',
#  'ook',
#  'over',
#  'doen',
#  'gaan',
#  'kom',
#  'mij',
#  'daar',
#  'zou',
#  'bij',
#  'al',
#  'of',
#  'jullie',
#  'ons',
#  'gaat',
#  'iets',
#  'hebt',
#  'zal',
#  'waarom',
#  "m'n",
#  'had',
#  "'n",
#  'meer',
#  'laat',
#  'doe',
#  'wie',
#  'moeten',
#  'deze',
#  'alles',
#  'kunnen',
#  'jou',
#  'toch',
#  'echt',
#  'denk',
#  'zien',
#  'weg',
#  'nou',
#  'alleen',
#  'nooit',
#  'door',
#  'mee',
#  'dus',
#  'man',
#  'even',
#  'eens',
#  'terug',
#  'komt',
#  'misschien',
#  'laten',
#  'niets',
#  'zei',
#  'iemand',
#  'hou',
#  'oké',
#  'veel',
#  'komen',
#  'weer',
#  'tot',
#  'zeg',
#  'uw',
#  'mensen',
#  'toen',
#  'zeggen',
#  'worden',
#  'onze',
#  'zit',
#  "z'n",
#  'mag',
#  'kijk',
#  'leven',
#  'heel',
#  'nodig',
#  'tegen',
#  'wordt',
#  'gewoon',
#  'twee',
#  'net',
#  'dood',
#  'altijd',
#  'weten',
#  'wij',
#  'maken',
#  'tijd',
#  'gedaan',
#  'af',
#  'omdat',
#  'geef',
#  'zeker',
#  'zie',
#  'dag',
#  'doet',
#  'wacht',
#  'niks',
#  'kunt',
#  'vrouw',
#  'huis',
#  'allemaal',
#  'vader',
#  'geld',
#  'dacht',
#  'anders',
#  'wilt',
#  'dank',
#  'jaar',
#  'hun',
#  'zij',
#  'willen',
#  'erg',
#  'zitten',
#  'hé',
#  'keer',
#  'jouw',
#  'zoals',
#  'wilde',
#  'niemand',
#  'iedereen',
#  'zich',
#  'gezien',
#  'vind',
#  'beter',
#  'werk',
#  'binnen',
#  'bedankt',
#  'spijt',
#  'vast',
#  'neem',
#  'andere',
#  'staat',
#  'moeder',
#  'zullen',
#  'waren',
#  'maak',
#  'praten',
#  'één',
#  "'m",
#  'kon',
#  'mooi',
#  'hele',
#  'genoeg',
#  'vinden',
#  'lang',
#  'leuk',
#  'wist',
#  'na',
#  'graag',
#  'toe',
#  'helpen',
#  'zegt',
#  'elkaar',
#  'ziet',
#  'blijf',
#  'natuurlijk',
#  'god',
#  'klaar',
#  'bedoel',
#  'hallo',
#  'sorry',
#  'helemaal',
#  'maakt',
#  'gek',
#  'alle',
#  'luister',
#  'drie',
#  'geweest',
#  'meneer',
#  'werd',
#  'blijven',
#  'zonder',
#  'hoor',
#  'dingen',
#  'aan_het',
#  'ging',
#  'houden',
#  'alsjeblieft',
#  'krijgen',
#  'kijken',
#  'vriend',
#  'grote',
#  'idee',
#  'kwam',
#  'bang',
#  'steeds',
#  'geven',
#  'kinderen',
#  'achter',
#  'eerste',
#  'naam',
#  "zo'n",
#  'vertellen',
#  'goede',
#  'ooit',
#  'moest',
#  'snel',
#  'onder',
#  'zag',
#  'wanneer',
#  'auto',
#  'ie',
#  'beetje',
#  'eten',
#  'vragen',
#  'gebeurd',
#  'zelf',
#  'vraag',
#  'jongen',
#  'paar',
#  'ken',
#  'deed',
#  'kun',
#  'o',
#  'lijkt',
#  'verdomme',
#  'morgen',
#  'staan',
#  'zorgen',
#  'want',
#  'nieuwe',
#  'gezegd',
#  'thuis',
#  'laatste',
#  'heen',
#  'geloof',
#  'geweldig',
#  'wereld',
#  'nemen',
#  'hadden',
#  'zelfs',
#  'jongens',
#  'meisje',
#  'mannen',
#  'denken',
#  'enige',
#  'vertel',
#  'denkt',
#  'krijg',
#  'samen',
#  'vandaag',
#  'hoop',
#  'halen',
#  'buiten',
#  'wou',
#  'eerst',
#  'eigen',
#  'rustig',
#  'horen',
#  'soms',
#  'uur',
#  'zoon',
#  'politie',
#  'houdt',
#  'probleem',
#  'zat',
#  'heet',
#  'gevonden',
#  'open',
#  'vermoord',
#  'bijna',
#  'kind',
#  'vrienden',
#  'geeft',
#  'zouden',
#  'gelijk',
#  'geleden',
#  'hen',
#  'gebeurt',
#  'oh',
#  'elke',
#  'pas',
#  'krijgt',
#  'precies',
#  'begrijp',
#  'wachten',
#  'verder',
#  'hè',
#  'voel',
#  'vanavond',
#  'gehad',
#  'zet',
#  'alsof',
#  'pak',
#  'kant',
#  'eigenlijk',
#  'bel',
#  'volgens',
#  'werken',
#  'best',
#  'beste',
#  'daarom',
#  'familie',
#  'haal',
#  'stop',
#  'vindt',
#  'vroeg',
#  'gehoord',
#  'probeer',
#  'mr',
#  'dagen',
#  'eruit',
#  'volgende',
#  'word',
#  'hoeveel',
#  'ding',
#  'schiet',
#  'vijf',
#  'spreken',
#  'help',
#  'gemaakt',
#  'blij',
#  'ligt',
#  'prima',
#  'lekker',
#  'kamer',
#  'hoofd',
#  'oude',
#  'zoeken',
#  'stad',
#  'ben.',
#  'werkt',
#  'vond',
#  'geloven',
#  'kleine',
#  'slecht',
#  'pijn',
#  'jezelf',
#  'blijft',
#  'kans',
#  'in_orde',
#  'schat',
#  'ogen',
#  'niet_eens',
#  'welke',
#  'verteld',
#  'manier',
#  'ergens',
#  'mooie',
#  'moment',
#  'kent',
#  'breng',
#  'tussen',
#  'brengen',
#  "'s",
#  'spelen',
#  'deur',
#  'school',
#  'minuten',
#  'vrouwen',
#  'broer',
#  'boven',
#  'water',
#  'dokter',
#  'land',
#  'aan_de_hand',
#  'vier',
#  'praat',
#  'bed',
#  'hulp',
#  'zaak',
#  'klopt',
#  'groot',
#  'juist',
#  'week',
#  'dollar',
#  'sta',
#  'zoveel',
#  'wees',
#  'vrij',
#  'problemen',
#  'later',
#  'vergeten',
#  'vooruit',
#  'kop',
#  'bellen',
#  'hoeft',
#  'echte',
#  'proberen',
#  'betekent',
#  'papa',
#  'soort',
#  'lopen',
#  'snap',
#  'mis',
#  'zult',
#  'dochter',
#  'zorg',
#  'meteen',
#  'doden',
#  'ervan',
#  'beginnen',
#  'gebruiken',
#  'stel',
#  'handen',
#  'mevrouw',
#  'plaats',
#  'leren',
#  'klootzak',
#  'alstublieft',
#  'slapen',
#  'zoiets',
#  'liefde',
#  'vol',
#  'moeilijk',
#  'druk',
#  'tien',
#  'mama',
#  'voorbij',
#  'gekomen',
#  'gelukkig',
#  'nacht',
#  'verhaal',
#  'nummer',
#  'zodat',
#  'wakker',
#  'mogen',
#  'hand',
#  'zes',
#  'vergeet',
#  'zoek',
#  'gebeuren',
#  'sinds',
#  'fijn',
#  'voordat',
#  'hoort',
#  'bezig',
#  'hart',
#  'klein',
#  'vermoorden',
#  'liggen',
#  'stoppen',
#  'straks',
#  'hetzelfde',
#  'drinken',
#  'begin',
#  'aardig',
#  'gaf',
#  'eerder',
#  'ander',
#  'vent',
#  'waarheid',
#  'neer',
#  'beneden',
#  'agent',
#  'zaken',
#  'bloed',
#  'los',
#  'gezicht',
#  'oud',
#  'dicht',
#  'wat_voor',
#  'hoorde',
#  'vallen',
#  'avond',
#  'eraan',
#  'vaak',
#  'oorlog',
#  'nieuws',
#  'hoi',
#  'schuld',
#  'plek',
#  'kennen',
#  'begrepen',
#  'stuk',
#  'sterven',
#  'rest',
#  'buurt',
#  'veilig',
#  'mogelijk',
#  'film',
#  'maanden',
#  'vriendin',
#  'redden',
#  'terwijl',
#  'zin',
#  'rond',
#  'ouders',
#  'eerlijk',
#  'inderdaad',
#  'liever',
#  'overal',
#  'anderen',
#  'duidelijk',
#  'langs',
#  'belangrijk',
#  'kreeg',
#  'liet',
#  'hond',
#  'voelt',
#  'waarschijnlijk',
#  'heren',
#  'jaren',
#  'stond',
#  'baas',
#  'geluk',
#  'mond',
#  'vandaan',
#  'fout',
#  'klinkt',
#  'per',
#  'reden',
#  'ermee',
#  'mezelf',
#  'betalen',
#  'welkom',
#  'stil',
#  'hard',
#  'recht',
#  'prachtig',
#  'baan',
#  'houd',
#  'erop',
#  'kwaad',
#  'kapitein',
#  'telefoon',
#  'mam',
#  'pa',
#  'neemt',
#  'gegeven',
#  'al.',
#  'zetten',
#  'valt',
#  'baby',
#  'haat',
#  'dezelfde',
#  'boek',
#  'hield',
#  'trouwen',
#  'eén',
#  'rijden',
#  'zeer',
#  'hoezo',
#  'weken',
#  'lichaam',
#  'geworden',
#  'voorzichtig',
#  'jack',
#  'kwijt',
#  'daarna',
#  'nergens',
#  'erin',
#  'mens',
#  'vanaf',
#  'plan',
#  'elk',
#  'deel',
#  'moord',
#  'noemen',
#  'vertrouwen',
#  'wapen',
#  'pakken',
#  'antwoord',
#  'kerel',
#  'schatje',
#  'niet_alleen',
#  'koning',
#  'gebeld',
#  'ontmoet',
#  'jezus',
#  'geval',
#  'loopt',
#  'tijdens',
#  'nogal',
#  'meer_dan',
#  'allebei',
#  'lieverd',
#  'getrouwd',
#  'koffie',
#  'meisjes',
#  'naartoe',
#  'veranderen',
#  'miljoen',
#  'dr.',
#  'schieten',
#  'dames',
#  'gisteren',
#  'ver',
#  'zus',
#  'sir',
#  'kopen',
#  'erbij',
#  'maakte',
#  'tweede',
#  'ziek',
#  'woord',
#  'president',
#  'leg',
#  'grappig',
#  'ziens',
#  'gevoel',
#  'gebruikt',
#  'verloren',
#  'ontmoeten',
#  'vreemd',
#  'stap',
#  'vechten',
#  'trek',
#  'plezier',
#  'daarmee',
#  't.',
#  'vroeger',
#  'kantoor',
#  'goeie',
#  'begint',
#  'fantastisch',
#  'ervoor',
#  'dan_ook',
#  'verwacht',
#  'zomaar',
#  'meen',
#  'gegaan',
#  'bedoelt',
#  'pardon',
#  'minder',
#  '1',
#  'normaal',
#  'vertelde',
#  'nieuw',
#  'zichzelf',
#  't',
#  'slechte',
#  'foto',
#  'pap',
#  'leeft',
#  'loop',
#  'voelen',
#  'john',
#  'idioot',
#  'hemel',
#  'winnen',
#  'lk',
#  'eindelijk',
#  'nam',
#  'eet',
#  'men',
#  'stuur',
#  'mrs',
#  'verkeerd',
#  'val',
#  'in_deze',
#  'schip',
#  'ls',
#  'enkele',
#  'meid',
#  'team',
#  '2',
#  'gevraagd',
#  'lief',
#  'gesproken',
#  'waard',
#  'enkel',
#  'beloof',
#  'woorden',
#  'einde',
#  'slaap',
#  'jawel',
#  'hierheen',
#  'new_york',
#  'vreselijk',
#  'met_rust',
#  'begrijpen',
#  'slim',
#  'trots',
#  'de_tijd',
#  'onzin',
#  'acht',
#  'gang',
#  'weinig',
#  'spullen',
#  'gekregen',
#  'grond',
#  'ziekenhuis',
#  'onderzoek',
#  'wapens',
#  'droom',
#  'oom',
#  'herinner',
#  'brengt',
#  'nietwaar',
#  'leger',
#  'let',
#  'lezen',
#  'veranderd',
#  'wonen',
#  'muziek',
#  'verliefd',
#  'omhoog',
#  'begon',
#  'stellen',
#  'boos',
#  'of_zo',
#  'gebruik',
#  'noem',
#  'konden',
#  'eentje',
#  'gevangenis',
#  'kleren',
#  'half',
#  'frank',
#  'werden',
#  'informatie',
#  'stomme',
#  'zwarte',
#  'perfect',
#  'langer',
#  'heer',
#  'stom',
#  'succes',
#  'licht',
#  'zeven',
#  'hoef',
#  'toekomst',
#  'makkelijk',
#  'gingen',
#  'vraagt',
#  'mocht',
#  'dansen',
#  'advocaat',
#  'lukt',
#  'pistool',
#  'opnieuw',
#  'begrijpt',
#  'tenminste',
#  'wilden',
#  'woont',
#  'bewijs',
#  'geheim',
#  '20',
#  'kwamen',
#  'verlaten',
#  'sam',
#  'ongeluk',
#  'vertrekken',
#  'probeerde',
#  'vuur',
#  'straat',
#  'seks',
#  'aarde',
#  'behalve',
#  'charlie',
#  'luisteren',
#  'spreek',
#  'kracht',
#  "foto's",
#  'volgen',
#  'wegwezen',
#  'gebeurde',
#  'goedemorgen',
#  'feest',
#  'beschermen',
#  'afspraak',
#  'ene',
#  'erover',
#  'gestolen',
#  'zak',
#  'verliezen',
#  'kijkt',
#  'schrijven',
#  'absoluut',
#  'afgelopen',
#  'liefje',
#  'koud',
#  'gedood',
#  'lijken',
#  'boot',
#  'genomen',
#  'leek',
#  'trouwens',
#  'sterk',
#  'spel',
#  'ieder',
#  '$',
#  'lieve',
#  'geest',
#  'shit',
#  'gered',
#  'juiste',
#  'slaan',
#  'persoon',
#  'serieus',
#  'moordenaar',
#  'sommige',
#  'maand',
#  'helpt',
#  "da's",
#  'schelen',
#  'probeert',
#  'naast',
#  'degene',
#  'voelde',
#  'te_pakken',
#  'bestaat',
#  'dienst',
#  'sturen',
#  'contact',
#  'honger',
#  'welk',
#  'gevaarlijk',
#  'jammer',
#  '10',
#  'bank',
#  'verkeerde',
#  'jong',
#  'gevaar',
#  'verdomde',
#  'begonnen',
#  'ongeveer',
#  'verkopen',
#  'reis',
#  'grootste',
#  'op_zoek',
#  'lange',
#  'erger',
#  'moe',
#  'vliegtuig',
#  'bekend',
#  'vliegen',
#  'generaal',
#  'the',
#  'gedacht',
#  'arme',
#  'lucht',
#  'bewijzen',
#  'zolang',
#  'lachen',
#  'leuke',
#  'hotel',
#  'voorstellen',
#  'geleerd',
#  'excuseer',
#  'moesten',
#  'betaald',
#  'slechts',
#  'via',
#  'rot',
#  'lag',
#  'speelt',
#  'vorige',
#  'prijs',
#  'stem',
#  'vooral',
#  'schuldig',
#  'viel',
#  'lul',
#  'geboren',
#  'zodra',
#  'vertrouw',
#  'missen',
#  'raar',
#  'rij',
#  'tv',
#  'iedere',
#  'vanwege',
#  'hel',
#  'macht',
#  'regels',
#  'raak',
#  'paard',
#  'geraakt',
#  'tafel',
#  'kapot',
#  'sla',
#  'george',
#  'eind',
#  'he',
#  'drugs',
#  'raad',
#  'm.',
#  'van_plan',
#  'dragen',
#  'kende',
#  'dame',
#  'gelooft',
#  'ziel',
#  'gefeliciteerd',
#  'geprobeerd',
#  '3',
#  'trekken',
#  'amerika',
#  'werkte',
#  'kolonel',
#  'tom',
#  'zwaar',
#  'rug',
#  'gisteravond',
#  'sleutel',
#  'bal',
#  'wet',
#  'kost',
#  'duurt',
#  'huwelijk',
#  'gezin',
#  'gebracht',
#  'kaart',
#  'raken',
#  'volg',
#  'kerk',
#  'zweer',
#  '5',
#  'band',
#  'arm',
#  'rijk',
#  'komaan',
#  'het_beste',
#  'zul',
#  'joe',
#  'belde',
#  'jonge',
#  'daarvoor',
#  'totdat',
#  'grapje',
#  'namen',
#  'tuurlijk',
#  'dromen',
#  'wagen',
#  'dom',
#  'vertelt',
#  'geweldige',
#  'doel',
#  'regel',
#  'ruimte',
#  'stierf',
#  'tenzij',
#  'zover',
#  'ter',
#  'meter',
#  'david',
#  'harry',
#  'dronken',
#  'zoekt',
#  'derde',
#  'herinneren',
#  'teken',
#  'te_weten',
#  'relatie',
#  'gedachten',
#  'rust',
#  'ouwe',
#  'gestuurd',
#  'groep',
#  'nadat',
#  'kwalijk',
#  'eer',
#  'gemist',
#  'zeiden',
#  ...]

# %%
# Import the function from eSpeakNG_IPA.py
from eSpeakNG_IPA import get_phonetic_transcriptions_parallel

# Get the list of words from your DataFrame
words = list(mous_words['Word'])

# Call the function to process all words in parallel
ipa_transcriptions = get_phonetic_transcriptions_parallel(words, max_workers=8)

# Convert the result to a DataFrame
MOUS_IPA_transcriptions = pd.DataFrame(list(ipa_transcriptions.items()), columns=['Word', 'IPA'])

# %%
import importlib
import syllabify_ipa_nl

# Reload the module
importlib.reload(syllabify_ipa_nl)

# Re-import the specific function
from syllabify_ipa_nl import syllabify_ipa

# %%
MOUS_IPA_transcriptions = pd.read_csv('/home/neel/Desktop/MOUS_hierarchical-representations/MOUS_IPA_transcriptions.csv')

# %%
#MOUS_IPA_transcriptions['Syllables'] = MOUS_IPA_transcriptions['IPA'].apply(lambda x: syllabify_ipa(x))

# %%
# Set display options to show more rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the DataFrame
print(MOUS_IPA_transcriptions)
# Out:
#                 Word                 IPA                      Syllables
# 0               toen                tˈun                            tun
# 1                die                 dˈi                             di
# 2                 de                 dˈə                             də
# 3          barkeeper          bˈɑrkeːpər                bɑr - keː - pər
# 4          irritante         ˌɪɾritˈɑntə             ɪɾ - ri - tɑn - tə
# 5           bediende            bədˈində                  bə - din - də
# 6            wegliep            ʋˈɛɣlˌip                      ʋɛ - ɣlip
# 7              manke              mˈɑŋkə                       mɑŋ - kə
# 8             gingen              ɣˈɪŋən                       ɣɪŋ - ən
# 9              klant              klˈɑnt                          klɑnt
# 10         dronkaard          drˈɔŋkaːrt                   drɔŋ - kaːrt
# 11              open              ˈoːpən                       oː - pən
# 12            deuren             dˈøːrən                      døː - rən
# 13          betaalde           bətˈaːldə                 bə - taːl - də
# 14              viel                vˈil                            vil
# 15              kruk               krˈɵk                           krɵk
# 16            lachte              lˈɑxtə                       lɑx - tə
# 17            rector             rˈɛktɔr                      rɛk - tɔr
# 18                om                 ˈɔm                             ɔm
# 19            stoere              stˈurə                       stu - rə
# 20             puber              pˈybər                       py - bər
# 21           strafte            strˈɑftə                     strɑf - tə
# 22               was                ʋˈɑs                            ʋɑs
# 23               erg                ˈɛrx                            ɛrx
# 24        onredelijk         ɔnrˈeːdələk            ɔn - reː - də - lək
# 25          inbreker         ˈɪnbrˌeːkər                ɪn - breː - kər
# 26         gekrenkte          ɣˈɛkrɛŋktə                ɣɛ - krɛŋk - tə
# 27           smeekte            smˈeːktə                     smeːk - tə
# 28           pastoor            pɑstˈoːr                     pɑ - stoːr
# 29               ten                tˈɛn                            tɛn
# 30            vorige            vˈoːrəɣə                  voː - rə - ɣə
# 31              raad               rˈaːt                           raːt
# 32             einde              ˈɛɪndə                    ɛ - ɪn - də
# 33            bruine             brˈœynə                      brœy - nə
# 34         assistent          ˌɑsɪstˈɛnt                 ɑ - sɪ - stɛnt
# 35              week               ʋˈeːk                           ʋeːk
# 36            tanden             tˈɑndən                      tɑn - dən
# 37             kreeg              krˈeːx                          kreːx
# 38           maandag            mˈaːndɑx                     maːn - dɑx
# 39           uitslag           ˈœytslˌɑx                     œyt - slɑx
# 40        behandelde         bəhˈɑndəldə            bəh - ɑn - dəl - də
# 41            pokken              pˈɔkən                       pɔ - kən
# 42           medicus          mˈeːdikˌɵs                 meː - di - kɵs
# 43           vreemde            vrˈeːmdə                     vreːm - də
# 44            laatst             lˈaːtst                         laːtst
# 45              zelf               zˈɛlf                           zɛlf
# 46        psychiater        psˈɪxiˌaːtər            psɪx - i - aː - tər
# 47         gevreesde          ɣəvrˈeːzdə                ɣə - vreːz - də
# 48              zijn               zˈɛɪn                        zɛ - ɪn
# 49        verslaafde         vərslˈaːvdə               vər - slaːv - də
# 50                is                 ˈɪs                             ɪs
# 51           ontslag            ɔntslˈɑx                     ɔnt - slɑx
# 52        overtreder      ˌoːvərtrˈeːdər          oː - vər - treː - dər
# 53            smeris            smˈɪːrɪs                     smɪː - rɪs
# 54         ontvlucht           ɔntvlˈɵxt                    ɔnt - vlɵxt
# 55         kronkelig          krˈɔŋkələx                krɔŋ - kə - ləx
# 56               een                ˈeːn                            eːn
# 57          ingerend          ˈɪnɣərˌɛnt                 ɪn - ɣə - rɛnt
# 58            paadje             pˈaːtjə                      paːt - jə
# 59               het                hˈət                            hət
# 60         eigenaars         ˈɛɪɣənˌaːrs             ɛ - ɪ - ɣə - naːrs
# 61          landgoed           lˈɑndɣˌut                     lɑnd - ɣut
# 62               van                vˈɑn                            vɑn
# 63         bezoekers           bəzˈukərs                 bə - zu - kərs
# 64         honderden          hˈɔndɛrdən                hɔn - dɛr - dən
# 65          gisteren           ɣˈɪstərən                 ɣɪ - stə - rən
# 66        rondleiden         rˈɔndlɛɪdən            rɔnd - lɛ - ɪ - dən
# 67          filmster           fˈɪlmstər                    fɪlm - stər
# 68             trots              trˈɔts                          trɔts
# 69        beschermde          bəsxˈɛrmdə                bə - sxɛrm - də
# 70               had                hˈɑt                            hɑt
# 71             brede             brˈeːdə                      breː - də
# 72         bodyguard        bˈoːdiɣˌyɑrt            boː - di - ɣy - ɑrt
# 73             vrije              vrˈɛɪə                    vrɛ - ɪ - ə
# 74            morgen             mˈɔrɣən                      mɔr - ɣən
# 75            krijgt             krˈɛɪxt                      krɛ - ɪxt
# 76               dag                dˈɑx                            dɑx
# 77          beroemde            bərˈumdə                  bə - rum - də
# 78              ober              ˈoːbər                       oː - bər
# 79         president        prˌeːzidˈɛnt               preː - zi - dɛnt
# 80         beledigde         bəlˈeːdɪɣdə            bə - leː - dɪɣ - də
# 81           bandage           bɑndˈaːʒə                 bɑn - daː - ʒə
# 82             eerst              ˈɪːrst                          ɪːrst
# 83             vieze               vˈizə                        vi - zə
# 84              arts               ˈɑrts                           ɑrts
# 85           plastic            plˈɑstɪk                     plɑ - stɪk
# 86       verschoonde         vərsxˈoːndə               vər - sxoːn - də
# 87              trok               trˈɔk                           trɔk
# 88      handschoenen         hˈɑndsxunən               hɑnd - sxu - nən
# 89               met                mˈɛt                            mɛt
# 90               aan                ˈaːn                            aːn
# 91         sportarts         spˈɔrtˌɑrts                   spɔr - tɑrts
# 92        gescheurde          ɣəsxˈøːrdə                ɣə - sxøːr - də
# 93         adviseert          ˌɑdvizˈɪrt                 ɑd - vi - zɪrt
# 94             pezen             pˈeːzən                      peː - zən
# 95               oma              ˈoːmaː                       oː - maː
# 96          hockeyer           hˈɔkəˌiər               hɔ - kə - i - ər
# 97          verstand           vərstˈɑnt                    vər - stɑnt
# 98                er                 ˈər                             ər
# 99             heeft              hˈeːft                          heːft
# 100             veel               vˈeːl                           veːl
# 101            moest               mˈust                           must
# 102     verpleegster       vərplˈeːxstər             vər - pleːx - stər
# 103         gebroken          ɣəbrˈoːkən                ɣə - broː - kən
# 104           bekken              bˈɛkən                       bɛ - kən
# 105      raadpleegde        rˈaːdpleːɣdə              raːd - pleːɣ - də
# 106           huilen             hˈœylən                      hœy - lən
# 107       alcoholist      ˌɑlkoːhoːlˈɪst          ɑl - koːh - oː - lɪst
# 108             weer               ʋˈɪːr                           ʋɪːr
# 109          bekende            bəkˈɛndə                  bə - kɛn - də
# 110       psycholoog        psˈɪxoːlˌoːx               psɪx - oː - loːx
# 111         scholier            sxoːlˈir                     sxoː - lir
# 112          meester           mˈeːstˌɛr                     meː - stɛr
# 113         terugval          tərˈɵxvˌɑl                 tə - rɵx - vɑl
# 114         treitert           trˈɛɪtərt                 trɛ - ɪ - tərt
# 115           alweer              ɑlʋˈɪr                       ɑl - ʋɪr
# 116            stoel               stˈul                           stul
# 117         punaises          pˌynɑjzˈɛs                 py - nɑj - zɛs
# 118           gelegd             ɣəlˈɛxt                      ɣə - lɛxt
# 119           jochem              jˈɔxəm                       jɔx - əm
# 120               op                 ˈɔp                             ɔp
# 121               te                 tˈə                             tə
# 122           altijd             ˈɑltɛɪt                   ɑl - tɛ - ɪt
# 123          tijdens            tˈɛɪdəns                  tɛ - ɪ - dəns
# 124        basketbal         bˈɑskɛtbˌɑl                bɑ - skɛt - bɑl
# 125             hoog               hˈoːx                           hoːx
# 126          springt             sprˈɪŋt                         sprɪŋt
# 127          bezeerd            bəzˈɪːrt                     bə - zɪːrt
# 128       agressieve          ˌɑɣrɛsˈivə              ɑ - ɣrɛ - si - və
# 129            enkel              ˈɛŋkəl                       ɛŋ - kəl
# 130       arresteert         ˌɑɾrɛstˈɪrt                ɑɾ - rɛ - stɪrt
# 131       politieman       poːlˈitsimˌɑn           poː - lit - si - mɑn
# 132           kraker            krˈaːkər                     kraː - kər
# 133       hardhandig         hɑrdhˈɑndəx               hɑrdh - ɑn - dəx
# 134             werk               ʋˈɛrk                           ʋɛrk
# 135             gaat               ɣˈaːt                           ɣaːt
# 136           staker            stˈaːkər                     staː - kər
# 137         angstige            ˈɑŋstəɣə                  ɑŋ - stə - ɣə
# 138         bekogelt          bəkˈoːɣəlt                bə - koː - ɣəlt
# 139              ver                vˈɛr                            vɛr
# 140            dames             dˈaːməs                      daː - məs
# 141       interviewt         ˌɪntərvˈiwt                ɪn - tər - viwt
# 142       journalist        ʒˌurnaːlˈɪst               ʒur - naː - lɪst
# 143      tuberculose      tˈybərkˌyloːsə       ty - bər - ky - loː - sə
# 144           zuster             zˈɵstər                      zɵ - stər
# 145              wil                ʋˈɪl                            ʋɪl
# 146       bondscoach         bˈɔndskoːtʃ                  bɔnd - skoːtʃ
# 147            weten             ʋˈeːtən                      ʋeː - tən
# 148         lijdende           lˈɛɪdəndə              lɛ - ɪ - dən - də
# 149             wast               ʋˈɑst                           ʋɑst
# 150         bejaarde           bəjˈaːrdə                 bə - jaːr - də
# 151     enthousiaste         ˌɛntuʒˈɑstə             ɛn - tu - ʒɑ - stə
# 152         zorgzaam           zˈɔrɣzaːm                    zɔrɣ - zaːm
# 153     vrijwilliger        vrɛɪʋˈɪləɣər        vrɛ - ɪ - ʋɪ - lə - ɣər
# 154       goochelaar         ɣˈoːxəlˌaːr                ɣoːx - ə - laːr
# 155          publiek             pɵblˈik                      pɵ - blik
# 156        geduldige          ɣədˈɵldəɣə             ɣə - dɵl - də - ɣə
# 157       instrueert         ˈɪnstryˌɪrt                ɪn - stry - ɪrt
# 158              uit                ˈœyt                            œyt
# 159             baby              bˈeːbi                       beː - bi
# 160            doopt              dˈoːpt                          doːpt
# 161      onduidelijk         ɔndˈœydələk            ɔn - dœy - də - lək
# 162          dominee          dˌoːminˈeː                 doː - mi - neː
# 163           begint             bəɣˈɪnt                      bə - ɣɪnt
# 164          spreken           sprˈeːkən                    spreː - kən
# 165       voorganger          vˈɔːrɣɑŋər                vɔːr - ɣɑŋ - ər
# 166         snoezige            snˈuzəɣə                  snu - zə - ɣə
# 167         kleintje           klˈɛɪntʲə                 klɛ - ɪntʲ - ə
# 168           stevig            stˈeːvəx                     steː - vəx
# 169            houdt               hˈʌʊt                           hʌʊt
# 170             haar               hˈaːr                           haːr
# 171             vast               vˈɑst                           vɑst
# 172         boterham         bˈoːtərhˌɑm                boː - tərh - ɑm
# 173           meisje             mˈɛɪsjə                   mɛ - ɪs - jə
# 174              dat                dˈɑt                            dɑt
# 175        pindakaas        pˌɪndaːkˈaːs               pɪn - daː - kaːs
# 176           zonder             zˈɔndər                      zɔn - dər
# 177          dochter             dˈɔxtər                      dɔx - tər
# 178          verwend            vərʋˈɛnt                     vər - ʋɛnt
# 179           schone             sxˈoːnə                      sxoː - nə
# 180           robert            rˈoːbɛrt                     roː - bɛrt
# 181         huwelijk            hˈywələk                  hyw - ə - lək
# 182              jan                jˈɑn                            jɑn
# 183           slikte             slˈɪktə                      slɪk - tə
# 184            vroeg               vrˈux                           vrux
# 185         opspoort           ˈɔpspɔːrt                    ɔp - spɔːrt
# 186        detective        dˈeːtɛktˌivə            deː - tɛk - ti - və
# 187       criminelen       krˌiminˈeːlən           kri - mi - neː - lən
# 188            vette               vˈɛtə                        vɛ - tə
# 189            staat              stˈaːt                          staːt
# 190        speurhond          spˈøːrhɔnt                   spøːrh - ɔnt
# 191         beloning           bəlˈoːnɪŋ                 bə - loː - nɪŋ
# 192            drugs              drˈɵxs                          drɵxs
# 193         illegale          ˌɪləɣˈaːlə              ɪ - lə - ɣaː - lə
# 194           koekje              kˈukjə                       kuk - jə
# 195            trage             trˈaːʒə                      traː - ʒə
# 196         afschudt            ˈɑfsxˌɵt                      ɑf - sxɵt
# 197     gedetineerde      ɣədˌeːtinˈɪrdə       ɣə - deː - ti - nɪr - də
# 198             hulp               hˈɵlp                           hɵlp
# 199          vandaag            vɑndˈaːx                     vɑn - daːx
# 200          bewaker           bəʋˈaːkər                 bə - ʋaː - kər
# 201          laatste            lˈaːtstə                     laːt - stə
# 202       handlanger          hˈɑndlɑŋər                hɑnd - lɑŋ - ər
# 203       examinator     ˌɛksaːminˈaːtɔr      ɛk - saː - mi - naː - tɔr
# 204        kandidaat         kˌɑndidˈaːt                kɑn - di - daːt
# 205        overtuigt        ˌoːvərtˈœyxt               oː - vər - tœyxt
# 206            spits              spˈɪts                          spɪts
# 207       imponerend      ˌɪmpoːnˈɪːrənt          ɪm - poː - nɪː - rənt
# 208         opstelde           ˈɔpstɛldə                 ɔp - stɛl - də
# 209         cruciale           krˈyʃaːlə                 kry - ʃaː - lə
# 210          trainer            trˈeːnər                     treː - nər
# 211         training            trˈeːnɪŋ                     treː - nɪŋ
# 212             wist               ʋˈɪst                           ʋɪst
# 213      gevaarlijke         ɣəvˈaːrləkə            ɣə - vaːr - lə - kə
# 214           gemist             ɣəmˈɪst                      ɣə - mɪst
# 215     slachtoffers         slˈɑxtɔfərs               slɑx - tɔ - fərs
# 216          niemand             nˈimɑnt                      ni - mɑnt
# 217          tornado          tɔrnˈaːdoː                tɔr - naː - doː
# 218         ontstond           ɔntstˈɔnt                    ɔnt - stɔnt
# 219            eisen              ˈɛɪzən                    ɛ - ɪ - zən
# 220           dieven              dˈivən                       di - vən
# 221              zou                zˈʌʊ                            zʌʊ
# 222        ontsnapte          ɔntsnˈɑptə                ɔnt - snɑp - tə
# 223         employee         ˌɛmploːiˈeː             ɛm - ploː - i - eː
# 224       beschrijft          bəsxrˈɛɪft                bəsx - rɛ - ɪft
# 225            wrede             vrˈeːdə                      vreː - də
# 226        onderdaan         ˈɔndərdˌaːn                ɔn - dər - daːn
# 227       nauwkeurig          nʌʊkˈøːrəx                nʌʊ - køː - rəx
# 228          beveelt            bəvˈeːlt                     bə - veːlt
# 229             boos               bˈoːs                           boːs
# 230            derde              dˈɛrdə                       dɛr - də
# 231            getal              ɣətˈɑl                       ɣə - tɑl
# 232       oplettende         ˈɔplˌɛtəndə             ɔ - plɛ - tən - də
# 233       toehoorder         tˈuhˌɔːrdər                tuh - ɔːr - dər
# 234       signaleert         sˌɪɲaːlˈɪrt                sɪɲ - aː - lɪrt
# 235              zes                zˈɛs                            zɛs
# 236             mijn               mˈɛɪn                        mɛ - ɪn
# 237         vriendin            vrˈindɪn                     vrin - dɪn
# 238              gek                ɣˈɛk                            ɣɛk
# 239          jongens             jˈɔŋəns                      jɔŋ - əns
# 240             mona             mˈoːnaː                      moː - naː
# 241          gemixte           ɣəmˈɪkstə                 ɣə - mɪk - stə
# 242         drankjes           drˈɑŋkjəs                    drɑŋk - jəs
# 243            kopen             kˈoːpən                      koː - pən
# 244         aannemer         ˈaːnnˌeːmər                aːn - neː - mər
# 245             voor               vˈɔːr                           vɔːr
# 246          bewoner           bəʋˈoːnər                 bə - ʋoː - nər
# 247           humeur             hymˈøːr                      hy - møːr
# 248         vrouwtje            vrˈʌʊtʲə                     vrʌʊtʲ - ə
# 249         verlaten          vərlˈaːtən                vər - laː - tən
# 250             goed                ɣˈut                            ɣut
# 251           matste             mˈɑtstə                      mɑt - stə
# 252           poezen              pˈuzən                       pu - zən
# 253            buren              bˈyrən                       by - rən
# 254            ruzie               ryzˈi                        ry - zi
# 255          opvangt             ˈɔpvɑŋt                      ɔp - vɑŋt
# 256        populaire        pˌoːpylˈɛːrə            poː - py - lɛː - rə
# 257         jongeman           jˈɔŋəmˌɑn                  jɔŋ - ə - mɑn
# 258          onlangs             ɔnlˈɑŋs                      ɔn - lɑŋs
# 259              gaf                ɣˈɑf                            ɣɑf
# 260          portier             pɔrtˈir                      pɔr - tir
# 261           sterke             stˈɛrkə                      stɛr - kə
# 262            feest              fˈeːst                          feːst
# 263            beren             bˈɪːrən                      bɪː - rən
# 264            groot              ɣrˈoːt                          ɣroːt
# 265        betoverde         bətˈoːvərdə            bə - toː - vər - də
# 266           knappe              knˈɑpə                       knɑ - pə
# 267         inhuurde           ˈɪnhˌyrdə                  ɪnh - yr - də
# 268            elfje              ˈɛlfjə                       ɛlf - jə
# 269         schilder            sxˈɪldər                     sxɪl - dər
# 270          prinses            prɪnsˈɛs                     prɪn - sɛs
# 271           tekent            tˈeːkənt                     teː - kənt
# 272              pap                pˈɑp                            pɑp
# 273      vriendelijk          vrˈindələk                vrin - də - lək
# 274           kokkin              kˈɔkɪn                       kɔ - kɪn
# 275            onder              ˈɔndər                       ɔn - dər
# 276              zit                zˈɪt                            zɪt
# 277          dakloze           dˈɑkloːzə                 dɑ - kloː - zə
# 278             verf               vˈɛrf                           vɛrf
# 279             geen               ɣˈeːn                           ɣeːn
# 280          burgers            bˈɵrɣərs                     bɵr - ɣərs
# 281            kookt              kˈoːkt                          koːkt
# 282              zin                zˈɪn                            zɪn
# 283             meer               mˈɪːr                           mɪːr
# 284            warme              ʋˈɑrmə                       ʋɑr - mə
# 285           dekens            dˈeːkəns                     deː - kəns
# 286             nora             nˈoːraː                      noː - raː
# 287             arme               ˈɑrmə                        ɑr - mə
# 288           mensen             mˈɛnsən                      mɛn - sən
# 289            weeft              ʋˈeːft                          ʋeːft
# 290         schutter             sxˈɵtər                      sxɵ - tər
# 291         gelukkig            ɣəlˈɵkəx                  ɣə - lɵ - kəx
# 292     gewelddadige       ɣəʋɛldˈaːdəɣə       ɣə - ʋɛl - daː - də - ɣə
# 293           doodde              dˈoːdə                       doː - də
# 294           jullie               jɵlˈi                        jɵ - li
# 295        directeur         dˌirɛktˈøːr                di - rɛk - tøːr
# 296           ruiter             rˈœytər                      rœy - tər
# 297               al                 ˈɑl                             ɑl
# 298           eerder             ˈɪːrdər                      ɪːr - dər
# 299          geweest            ɣəʋˈeːst                     ɣə - ʋeːst
# 300         geliefde            ɣəlˈivdə                  ɣə - liv - də
# 301          paarden            pˈaːrdən                     paːr - dən
# 302      veroordeeld        vərˈɔːrdeːlt              və - rɔːr - deːlt
# 303         streelde           strˈeːldə                    streːl - də
# 304          winnaar             ʋˈɪnaːr                      ʋɪ - naːr
# 305         raadsman           rˈaːdsmɑn                    raːd - smɑn
# 306         geworden           ɣəʋˈɔrdən                 ɣə - ʋɔr - dən
# 307         bijstond          bˈɛɪstˌɔnt                 bɛ - ɪ - stɔnt
# 308       delinquent       dˌeːlɪnkvˈɛnt              deː - lɪnk - vɛnt
# 309            radio           rˈaːdiˌoː                  raː - di - oː
# 310          peuters            pˈøːtərs                     pøː - tərs
# 311       opgesloten       ˈɔpɣəslˌoːtən           ɔp - ɣə - sloː - tən
# 312           ouders             ˈʌʊdərs                      ʌʊ - dərs
# 313        alarmeren       ˌaːlɑrmˈɪːrən           aː - lɑr - mɪː - rən
# 314               in                 ˈɪn                             ɪn
# 315         dochters            dˈɔxtərs                     dɔx - tərs
# 316           paniek             paːnˈik                      paː - nik
# 317        bevrijden          bəvrˈɛɪdən             bə - vrɛ - ɪ - dən
# 318             huis               hˈœys                           hœys
# 319             naar               nˈaːr                           naːr
# 320        opgelucht          ˈɔpɣəlˌɵxt                 ɔp - ɣə - lɵxt
# 321            joost              jˈoːst                          joːst
# 322        kidnapper           kˈɪdnɑpər                 kɪd - nɑ - pər
# 323           grijpt             ɣrˈɛɪpt                      ɣrɛ - ɪpt
# 324            bange               bˈɑŋə                        bɑŋ - ə
# 325       directrice        dˌirɛktrˈisə            di - rɛk - tri - sə
# 326         ontglipt           ɔntɣlˈɪpt                    ɔnt - ɣlɪpt
# 327            bazin             bˈaːzɪn                      baː - zɪn
# 328             bang                bˈɑŋ                            bɑŋ
# 329            kraag              krˈaːx                          kraːx
# 330             rent               rˈɛnt                           rɛnt
# 331        diplomaat        dˌɪploːmˈaːt               dɪ - ploː - maːt
# 332           starre             stˈɑɾrə                      stɑɾ - rə
# 333       boswachter          bˈɔsʋɑxtər                bɔs - ʋɑx - tər
# 334             deur               dˈøːr                           døːr
# 335         nuchtere            nˈɵxtərə                  nɵx - tə - rə
# 336        opzichter          ˈɔpzˌɪxtər                 ɔp - zɪx - tər
# 337        onaardige          ɔnˈaːrdəɣə             ɔ - naːr - də - ɣə
# 338              man                mˈɑn                            mɑn
# 339          uitbuit           ˈœytbˌœyt                     œyt - bœyt
# 340        werknemer        ʋˈɛrknˌeːmər               ʋɛrk - neː - mər
# 341          strenge             strˈɛŋə                      strɛŋ - ə
# 342      gehoorzaamt        ɣəhˈɔːrzaːmt              ɣəh - ɔːr - zaːmt
# 343        gespannen           ɣəspˈɑnən                 ɣə - spɑ - nən
# 344            kwijt              kʋˈɛɪt                       kʋɛ - ɪt
# 345            raken             rˈaːkən                      raː - kən
# 346              hun                hˈɵn                            hɵn
# 347             fans               fˈɑns                           fɑns
# 348             baan               bˈaːn                           baːn
# 349          bowlers            bˈɔʋlərs                     bɔʋ - lərs
# 350           willen              ʋˈɪlən                       ʋɪ - lən
# 351           winnen              ʋˈɪnən                       ʋɪ - nən
# 352               ik                 ˈɪk                             ɪk
# 353      sporthelden       spˈɔrthˌɛldən              spɔrth - ɛl - dən
# 354      aanmoedigen        ˈaːnmˌudəɣən            aːn - mu - də - ɣən
# 355            sprak              sprˈɑk                          sprɑk
# 356           scheve             sxˈeːvə                      sxeː - və
# 357              nog                nˈɔx                            nɔx
# 358           torens            tˈoːrəns                     toː - rəns
# 359             hans               hˈɑns                           hɑns
# 360            hielp               hˈilp                           hilp
# 361        ontworpen          ɔntʋˈɔrpən                ɔnt - ʋɔr - pən
# 362     hulpverlener     hˈɵlpvərlˌeːnər         hɵlp - vər - leː - nər
# 363          bereden           bərˈeːdən                 bə - reː - dən
# 364              zag                zˈɑx                            zɑx
# 365          zwerver            zʋˈɛrvər                     zʋɛr - vər
# 366          politie           poːlˈitsi                 poː - lit - si
# 367            rende              rˈɛndə                       rɛn - də
# 368              hij                hˈɛɪ                         hɛ - ɪ
# 369            zieke               zˈikə                        zi - kə
# 370              weg                ʋˈɛx                            ʋɛx
# 371      heilsoldaat       hˌɛɪlsɔldˈaːt           hɛ - ɪl - sɔl - daːt
# 372            kamer             kˈaːmər                      kaː - mər
# 373       huisvestte          hˈœysfɛstə                hœy - sfɛ - stə
# 374       grootvader        ɣrˈoːtvaːdər              ɣroːt - vaː - dər
# 375       binnenkwam         bˈɪnənkʋˌɑm                bɪ - nənk - ʋɑm
# 376         deugniet            døːɣnˈit                     døːɣ - nit
# 377          slinkse            slˈɪŋksə                     slɪŋk - sə
# 378           schrok              sxrˈɔk                          sxrɔk
# 379          doorhad            dˈɔːrhɑt                     dɔːrh - ɑt
# 380             zich                zˈɪx                            zɪx
# 381         bedrogen          bədrˈoːɣən                bə - droː - ɣən
# 382         goedkope           ɣudkˈoːpə                 ɣud - koː - pə
# 383           voelde              vˈuldə                       vul - də
# 384           bordes             bɔrdˈɛs                      bɔr - dɛs
# 385        achterste           ˈɑxtərstə                 ɑx - tər - stə
# 386       repareerde       rˌeːpaːrˈɪrdə           reː - paː - rɪr - də
# 387         beunhaas           bøːnhˈaːs                    bøːnh - aːs
# 388           judoka           jydˈoːkaː                 jy - doː - kaː
# 389            dwaze             dʋˈaːzə                      dʋaː - zə
# 390           houden             hˈʌʊdən                      hʌʊ - dən
# 391          belager           bəlˈaːɣər                 bə - laː - ɣər
# 392             niet                nˈit                            nit
# 393          vloerde             vlˈurdə                      vlur - də
# 394        misleidde           mɪslˈɛɪdə              mɪ - slɛ - ɪ - də
# 395          simpele            sˈɪmpələ                  sɪm - pə - lə
# 396        bedrieger           bədrˈiɣər                 bə - dri - ɣər
# 397         schuldig            sxˈɵldəx                     sxɵl - dəx
# 398            tante              tˈɑntə                       tɑn - tə
# 399         taxateur        tˌɑksaːtˈøːr               tɑk - saː - tøːr
# 400            agaat             aːɣˈaːt                      aː - ɣaːt
# 401              won                ʋˈɔn                            ʋɔn
# 402        wedstrijd          ʋˈɛtstrɛɪt                ʋɛt - strɛ - ɪt
# 403           pieren              pˈirən                       pi - rən
# 404         gebruikt           ɣəbrˈœykt                    ɣə - brœykt
# 405           haagse             hˈaːxsə                      haːx - sə
# 406          bordeel            bɔrdˈeːl                     bɔr - deːl
# 407           gladde              ɣlˈɑdə                       ɣlɑ - də
# 408      naaktlopers       nˈaːktloːpərs             naːkt - loː - pərs
# 409           hebben              hˈɛbən                       hɛ - bən
# 410         vermaken          vərmˈaːkən                vər - maː - kən
# 411        ontwerper          ɔntʋˈɛrpər                ɔnt - ʋɛr - pər
# 412          kleding            klˈeːdɪŋ                     kleː - dɪŋ
# 413             koud               kˈʌʊt                           kʌʊt
# 414         koningin          kˌoːnɪɣˈɪn                 koː - nɪ - ɣɪn
# 415         verkoopt           vərkˈoːpt                    vər - koːpt
# 416         creatief         krˌeːaːtˈif                kreː - aː - tif
# 417          etaleur         ˌeːtaːlˈøːr                eː - taː - løːr
# 418            stond              stˈɔnt                          stɔnt
# 419           paspop             pˈɑspɔp                      pɑ - spɔp
# 420              mee                mˈeː                            meː
# 421             gang                ɣˈɑŋ                            ɣɑŋ
# 422              nam                nˈɑm                            nɑm
# 423         fransien            frɑnsˈin                     frɑn - sin
# 424          duurste             dˈyrstə                      dyr - stə
# 425          trompet            trɔmpˈɛt                     trɔm - pɛt
# 426           genoeg              ɣənˈux                       ɣə - nux
# 427           kapper              kˈɑpər                       kɑ - pər
# 428           drukke              drˈɵkə                       drɵ - kə
# 429         uitkiest           ˈœytkˌist                     œyt - kist
# 430             geld               ɣˈɛlt                           ɣɛlt
# 431       teamleider         tˈiːmlɛɪdər            tiːm - lɛ - ɪ - dər
# 432         ervaring           ɛrvˈaːrɪŋ                 ɛr - vaː - rɪŋ
# 433             joke              jˈoːkə                       joː - kə
# 434         bijknipt          bˈɛɪknˌɪpt                 bɛ - ɪk - nɪpt
# 435       tamboerijn         tˌɑmburˈɛɪn             tɑm - bu - rɛ - ɪn
# 436          spaanse            spˈaːnsə                     spaːn - sə
# 437       eenvoudige         eːnvˈʌʊdəɣə            eːn - vʌʊ - də - ɣə
# 438          vooraan           vˈɔːrˌaːn                     vɔː - raːn
# 439           boerin              bˈurɪn                       bu - rɪn
# 440           liefst              lˈifst                          lifst
# 441            hield               hˈilt                           hilt
# 442           speelt             spˈeːlt                         speːlt
# 443      serveerster        sˈɛrvɪːrstər              sɛr - vɪːr - stər
# 444           werden             ʋˈɛrdən                      ʋɛr - dən
# 445       behulpzame        bəhˈɵlpzaːmə           bəh - ɵlp - zaː - mə
# 446           winkel             ʋˈɪŋkəl                      ʋɪŋ - kəl
# 447           netjes             nˈɛtʲəs                      nɛtʲ - əs
# 448            hippe               hˈɪpə                        hɪ - pə
# 449          brillen             brˈɪlən                      brɪ - lən
# 450       behoorlijk          bəhˈoːrlək                bəh - oːr - lək
# 451         verkocht            vərkˈɔxt                     vər - kɔxt
# 452        diafragma        dˌiɑfrˈɑɣmaː            di - ɑ - frɑɣ - maː
# 453           stugge              stˈɵɣə                       stɵ - ɣə
# 454        buikholte          bˈœykhɔltə                bœykh - ɔl - tə
# 455       borstholte          bˈɔrstɔltə                bɔr - stɔl - tə
# 456               en                 ˈɛn                             ɛn
# 457             neem               nˈeːm                           neːm
# 458          scheidt              sxˈɛɪt                       sxɛ - ɪt
# 459       belangrijk          bəlˈɑŋrɛɪk             bə - lɑŋ - rɛ - ɪk
# 460           kleine             klˈɛɪnə                   klɛ - ɪ - nə
# 461             boer                bˈur                            bur
# 462          serieus         sˌɪːrijˈøːs                sɪː - ri - jøːs
# 463         biggetje            bˈɪɣɛtʲə                  bɪ - ɣɛtʲ - ə
# 464            voert               vˈurt                           vurt
# 465            kwade             kʋˈaːdə                      kʋaː - də
# 466          richard             rˈɪxɑrt                      rɪx - ɑrt
# 467           haatte              hˈaːtə                       haː - tə
# 468           dieren              dˈirən                       di - rən
# 469           oudere             ˈʌʊdərə                   ʌʊ - də - rə
# 470        verzorgde          vərzˈɔrɣdə                vər - zɔrɣ - də
# 471             ging                ɣˈɪŋ                            ɣɪŋ
# 472          zielige             zˈiləɣə                   zi - lə - ɣə
# 473              hen                hˈɛn                            hɛn
# 474         tandarts           tˈɑndɑrts                    tɑn - dɑrts
# 475       verzamelen        vərzˈaːmələn           vər - zaː - mə - lən
# 476          heftige            hˈɛftəɣə                  hɛf - tə - ɣə
# 477         bangerik          bˈɑŋɪːrˌɪk                 bɑŋ - ɪː - rɪk
# 478      inschakelde       ˈɪnsxˌaːkəldə           ɪn - sxaː - kəl - də
# 479             pijn               pˈɛɪn                        pɛ - ɪn
# 480            maand              mˈaːnt                          maːnt
# 481        afgelopen        ˈɑfɣəlˌoːpən            ɑf - ɣə - loː - pən
# 482          buurman             bˈyrmɑn                      byr - mɑn
# 483     complicaties     kˌɔmplikˈaːtsis         kɔm - pli - kaːt - sis
# 484             vele              vˈeːlə                       veː - lə
# 485        paragnost        pˈaːrɑɣnˌɔst               paː - rɑɣ - nɔst
# 486          gewonde            ɣəʋˈɔndə                  ɣə - ʋɔn - də
# 487              zus                zˈɵs                            zɵs
# 488         psychose           psɪxˈoːsə                 psɪx - oː - sə
# 489            beter             bˈeːtər                      beː - tər
# 490             keek               kˈeːk                           keːk
# 491            broer               brˈur                           brur
# 492            grote             ɣrˈoːtə                      ɣroː - tə
# 493        gebruikte          ɣəbrˈœyktə                ɣə - brœyk - tə
# 494          ervaren           ɛrvˈaːrən                 ɛr - vaː - rən
# 495           takken              tˈɑkən                       tɑ - kən
# 496             vuur                vˈyr                            vyr
# 497            agent             aːɣˈɛnt                      aː - ɣɛnt
# 498             daar               dˈaːr                           daːr
# 499          toerist            tˈurˌɪst                      tu - rɪst
# 500            gered              ɣərˈɛt                       ɣə - rɛt
# 501           kopers            kˈoːpərs                     koː - pərs
# 502           nieuwe               nˈiwə                        niw - ə
# 503             liep                lˈip                            lip
# 504        makelaars        mˈaːkəlˌaːrs               maː - kə - laːrs
# 505         eigenaar          ˈɛɪɣənˌaːr              ɛ - ɪ - ɣə - naːr
# 506          gehaaid            ɣəhˈaːjt                     ɣəh - aːjt
# 507          gemaakt            ɣəmˈaːkt                     ɣə - maːkt
# 508            gerst              ɣˈɛrst                          ɣɛrst
# 509           lekker              lˈɛkər                       lɛ - kər
# 510          biertje             bˈirtʲə                      birtʲ - ə
# 511           eerste             ˈɪːrstə                      ɪːr - stə
# 512        knipoogde          knˈipoːɣdə                kni - poːɣ - də
# 513          ontving             ɔntvˈɪŋ                      ɔnt - vɪŋ
# 514            verse             vərsˈeː                      vər - seː
# 515              jam                jˈɑm                            jɑm
# 516           bramen            brˈaːmən                     braː - mən
# 517        heerlijke           hˈɪːrləkə                 hɪːr - lə - kə
# 518            maakt              mˈaːkt                          maːkt
# 519        verhuizen          vərhˈœyzən                vərh - œy - zən
# 520            jonge               jˈɔŋə                        jɔŋ - ə
# 521             dief                dˈif                            dif
# 522         gestolen          ɣəstˈoːlən                ɣə - stoː - lən
# 523         vluchtte             vlˈɵxtə                      vlɵx - tə
# 524         telefoon         tˌeːləfˈoːn                teː - lə - foːn
# 525         verkoper          vərkˈoːpər                vər - koː - pər
# 526         paspoort           pˈɑspɔːrt                    pɑ - spɔːrt
# 527        verdiende           vərdˈində                 vər - din - də
# 528          moderne           mˈoːdɛrnə                 moː - dɛr - nə
# 529         aanprees          ˈaːnprˌeːs                    aːn - preːs
# 530        orthopeed         ˌɔrtoːpˈeːt                ɔr - toː - peːt
# 531        behandelt          bəhˈɑndəlt                bəh - ɑn - dəlt
# 532         blessure            blɛsˈyrə                  blɛ - sy - rə
# 533            benul              bənˈɵl                       bə - nɵl
# 534            geeft              ɣˈeːft                          ɣeːft
# 535           weinig             ʋˈɛɪnəx                   ʋɛ - ɪ - nəx
# 536     secretaresse      sˈɛkrətˌaːrɛsə       sɛ - krə - taː - rɛ - sə
# 537         advocaat         ˌɑdvoːkˈaːt                ɑd - voː - kaːt
# 538       mannelijke           mˈɑnələkə              mɑ - nə - lə - kə
# 539          beambte            bəˈɑmbtə                  bə - ɑmb - tə
# 540            wijze              ʋˈɛɪzə                    ʋɛ - ɪ - zə
# 541            brief               brˈif                           brif
# 542             oude               ˈʌʊdə                        ʌʊ - də
# 543           dromen            drˈoːmən                     droː - mən
# 544           ieders              ˈidərs                       i - dərs
# 545             komt               kˈɔmt                           kɔmt
# 546          aardige            ˈaːrdəɣə                  aːr - də - ɣə
# 547          uitlegt           ˈœytlˌɛxt                     œyt - lɛxt
# 548           docent            doːsˈɛnt                     doː - sɛnt
# 549           zijden             zˈɛɪdən                   zɛ - ɪ - dən
# 550           groene              ɣrˈunə                       ɣru - nə
# 551       onderwijst        ˈɔndərʋˌɛɪst            ɔn - dər - ʋɛ - ɪst
# 552           pyjama           pijˈaːmaː                 pi - jaː - maː
# 553              mag                mˈɑx                            mɑx
# 554             kast               kˈɑst                           kɑst
# 555             ligt               lˈɪxt                           lɪxt
# 556          nichtje             nˈɪxtʲə                      nɪxtʲ - ə
# 557               je                 jˈə                             jə
# 558            lenen             lˈeːnən                      leː - nən
# 559              dit                dˈɪt                            dɪt
# 560            mooie              mˈoːjə                       moː - jə
# 561          jaloers            jaːlˈurs                     jaː - lurs
# 562           alleen              ɑlˈeːn                       ɑ - leːn
# 563            wilde              ʋˈɪldə                       ʋɪl - də
# 564          potlood            pɔtlˈoːt                     pɔt - loːt
# 565              ook                ˈoːk                            oːk
# 566            echte               ˈɛxtə                        ɛx - tə
# 567         pitbulls            pˈɪtbɵls                     pɪt - bɵls
# 568           honden             hˈɔndən                      hɔn - dən
# 569            taaie              tˈaːjə                       taː - jə
# 570            mogen             mˈoːɣən                      moː - ɣən
# 571           plekje             plˈɛkjə                      plɛk - jə
# 572              rij                rˈɛɪ                         rɛ - ɪ
# 573           hondje             hˈɔntjə                      hɔnt - jə
# 574            dikke               dˈɪkə                        dɪ - kə
# 575          doorzet            dˈɔːrzɛt                     dɔːr - zɛt
# 576           duiven             dˈœyvən                      dœy - vən
# 577          opjaagt            ˈɔpjaːxt                     ɔp - jaːxt
# 578             door               dˈoːr                           doːr
# 579             wild               ʋˈɪlt                           ʋɪlt
# 580             heel               hˈeːl                           heːl
# 581          scherpe             sxˈɛrpə                      sxɛr - pə
# 582          bochten             bˈɔxtən                      bɔx - tən
# 583      griekenland        ɣrˈikənlˌɑnt               ɣri - kən - lɑnt
# 584        voorkomen        vˈɔːrkˌoːmən               vɔːr - koː - mən
# 585       ongelukken         ˈɔnɣəlˌɵkən             ɔn - ɣə - lɵ - kən
# 586            vrouw               vrˈʌʊ                           vrʌʊ
# 587       tekeningen        tˈeːkənˌɪŋən            teː - kə - nɪŋ - ən
# 588         gebeuren           ɣəbˈøːrən                 ɣə - bøː - rən
# 589            vanaf              vɑnˈɑf                       vɑ - nɑf
# 590        prachtige           prˈɑxtəɣə                 prɑx - tə - ɣə
# 591    kunstacademie   kˌɵnstaːkˌaːdəmˈi     kɵn - staː - kaː - də - mi
# 592          dinsdag            dˈɪnzdɑx                     dɪnz - dɑx
# 593         verbaasd           vərbˈaːst                    vər - baːst
# 594           moeder              mˈudər                       mu - dər
# 595       biscuitjes         bˈɪskœytʲəs               bɪ - skœytʲ - əs
# 596            sonja              sˈɔɲaː                       sɔɲ - aː
# 597       prullenbak         prˈɵlənbˌɑk                prɵ - lən - bɑk
# 598          peetoom            peːtˈoːm                     peː - toːm
# 599          overige           ˈoːvərəɣə              oː - və - rə - ɣə
# 600           gooide             ɣˈoːjdə                      ɣoːj - də
# 601          snelste            snˈɛlstə                     snɛl - stə
# 602           naakte             nˈaːktə                      naːk - tə
# 603     politieagent    poːlˈitsiaːɣˌɛnt     poː - lit - si - aː - ɣɛnt
# 604     gearresteerd       ɣəˌɑɾrɛstˈɪrt           ɣə - ɑɾ - rɛ - stɪrt
# 605        ballerina        bˌɑlɪːrˈinaː            bɑ - lɪː - ri - naː
# 606        vermoeide           vərmˈujdə                 vər - muj - də
# 607            extra            ˈɛkstraː                     ɛk - straː
# 608         reporter          rˈeːpɔrtər                reː - pɔr - tər
# 609         kansloos           kˈɑnsloːs                    kɑn - sloːs
# 610           vraagt             vrˈaːxt                         vraːxt
# 611        wachtende           ʋˈɑxtəndə                 ʋɑx - tən - də
# 612      beroemdheid         bərˈumdhɛɪt               bə - rum - dhɛɪt
# 613        wegstuurt          ʋˈɛxstˌyrt                    ʋɛx - styrt
# 614            woord              ʋˈɔːrt                          ʋɔːrt
# 615          zonnige             zˈɔnəɣə                   zɔ - nə - ɣə
# 616            staan              stˈaːn                          staːn
# 617            clown              klˈɔwn                          klɔwn
# 618           terras             tˈɛɾrɑs                      tɛɾ - rɑs
# 619             auto              ˈʌʊtoː                       ʌʊ - toː
# 620         passende            pˈɑsəndə                  pɑ - sən - də
# 621            wraak              vrˈaːk                          vraːk
# 622         trekhaak           trɛkhˈaːk                    trɛkh - aːk
# 623        propellor         prˈoːpɛlˌɔr                proː - pɛ - lɔr
# 624             rood               rˈoːt                           roːt
# 625       mechanicus        mɛxˈaːnikˌɵs            mɛx - aː - ni - kɵs
# 626          besteld            bəstˈɛlt                     bə - stɛlt
# 627          pukkels             pˈɵkəls                      pɵ - kəls
# 628              juf                jˈɵf                            jɵf
# 629        ontstoken         ɔntstˈoːkən               ɔnt - stoː - kən
# 630          gammele             ɣˈɑmələ                   ɣɑ - mə - lə
# 631             last               lˈɑst                           lɑst
# 632         verzorgt           vərzˈɔrxt                    vər - zɔrxt
# 633         berispte           bərˈɪsptə                 bə - rɪsp - tə
# 634         jongetje            jˈɔŋɛtʲə                  jɔŋ - ɛtʲ - ə
# 635         drukknop            drˈɵknɔp                     drɵk - nɔp
# 636       overvaller        ˌoːvərvˈɑlər            oː - vər - vɑ - lər
# 637         indrukte          ˈɪndrˌɵktə                 ɪn - drɵk - tə
# 638             stal               stˈɑl                           stɑl
# 639        verbaasde          vərbˈaːzdə                vər - baːz - də
# 640             alle                ˈɑlə                         ɑ - lə
# 641    kostbaarheden    kˈɔstbaːrhˌeːdən        kɔst - baːrh - eː - dən
# 642          belegde            bəlˈɛɣdə                  bə - lɛɣ - də
# 643         bolletje            bˈɔlɛtʲə                  bɔ - lɛtʲ - ə
# 644             vers               vˈɛrs                           vɛrs
# 645         margriet            mɑrɣrˈit                     mɑr - ɣrit
# 646         aanrecht           ˈaːnrˌɛxt                     aːn - rɛxt
# 647              dan                dˈɑn                            dɑn
# 648              zij                zˈɛɪ                         zɛ - ɪ
# 649         schreeuw              sxrˈeʊ                          sxreʊ
# 650          periode         pˌɪːriˈoːdə             pɪː - ri - oː - də
# 651         vakantie          vaːkˈɑntsi                vaː - kɑnt - si
# 652          barbaar            bˈɑrbaːr                     bɑr - baːr
# 653              zat                zˈɑt                            zɑt
# 654          groente             ɣrˈuntə                      ɣrun - tə
# 655          protest           prˈoːtɛst                    proː - tɛst
# 656           vroege              vrˈuɣə                       vru - ɣə
# 657        uitbracht          ˈœytbrˌɑxt                    œyt - brɑxt
# 658          collega           kɔlˈeːɣaː                 kɔ - leː - ɣaː
# 659           dienst              dˈinst                          dinst
# 660        ingedeeld         ˈɪnɣədˌeːlt                ɪn - ɣə - deːlt
# 661          plantje            plˈɑntʲə                     plɑntʲ - ə
# 662              hap                hˈɑp                            hɑp
# 663            nodig             nˈoːdəx                      noː - dəx
# 664          venster            vˈɛnstər                     vɛn - stər
# ...
# 1720   toneelbouwers     tˈoːneːlbˌʌʊərs         toː - neːl - bʌʊ - ərs
# 1721          zolder             zˈɔldər                      zɔl - dər
# 1722        tevreden          təvrˈeːdən                tə - vreː - dən
# 1723           decor             dˈeːkɔr                      deː - kɔr
# 1724         bewaard            bəʋˈaːrt                     bə - ʋaːrt
# 1725       zestiende           zˈɛstində                 zɛ - stin - də
# 1726         brommer             brˈɔmər                      brɔ - mər
# 1727         snelweg            snˈɛlʋɛx                     snɛl - ʋɛx
# 1728            helm               hˈɛlm                           hɛlm
# 1729            stil               stˈɪl                           stɪl
# 1730       brandstof          brˈɑndstɔf                   brɑnd - stɔf
# 1731            tank               tˈɑŋk                           tɑŋk
# 1732          hadden              hˈɑdən                       hɑ - dən
# 1733          moeite              mˈujtə                       muj - tə
# 1734          tentje             tˈɛntʲə                      tɛntʲ - ə
# 1735           storm              stˈɔrm                          stɔrm
# 1736        opzetten            ˈɔpzɛtən                  ɔp - zɛ - tən
# 1737           geven             ɣˈeːvən                      ɣeː - vən
# 1738         rustige            rˈɵstəɣə                  rɵ - stə - ɣə
# 1739             les                lˈɛs                            lɛs
# 1740          klopte             klˈɔptə                      klɔp - tə
# 1741           tabak             tˈaːbɑk                      taː - bɑk
# 1742            klas               klˈɑs                           klɑs
# 1743           asbak              ˈɑzbɑk                       ɑz - bɑk
# 1744      vakkundige          vɑkˈɵndəɣə             vɑ - kɵn - də - ɣə
# 1745            pijp               pˈɛɪp                        pɛ - ɪp
# 1746         wortels            ʋˈɔrtəls                     ʋɔr - təls
# 1747            kies                kˈis                            kis
# 1748           mocht               mˈɔxt                           mɔxt
# 1749       vliegreis           vlˈiɣrɛɪs                 vli - ɣrɛ - ɪs
# 1750         cockpit             kˈɔkpɪt                      kɔk - pɪt
# 1751          kijken             kˈɛɪkən                   kɛ - ɪ - kən
# 1752            nico              nˈikoː                       ni - koː
# 1753         mobiele            moːbˈilə                  moː - bi - lə
# 1754          iedere              ˈidərə                    i - də - rə
# 1755      overdracht        ˌoːvərdrˈɑxt               oː - vər - drɑxt
# 1756       donderdag         dˈɔndərdˌɑx                dɔn - dər - dɑx
# 1757          steeds             stˈeːts                         steːts
# 1758          bokser             bˈɔksər                      bɔk - sər
# 1759           lange               lˈɑŋə                        lɑŋ - ə
# 1760      ochtendmis         ˈɔxtəndmˌɪs                ɔx - tənd - mɪs
# 1761            woog               ʋˈoːx                           ʋoːx
# 1762        negentig          nˈeːɣəntəx                neː - ɣən - təx
# 1763          schoon              sxˈoːn                          sxoːn
# 1764            haak               hˈaːk                           haːk
# 1765            kilo              kˈiloː                       ki - loː
# 1766        beroving           bərˈoːvɪŋ                 bə - roː - vɪŋ
# 1767      vastgelegd        vˈɑstɣəlˌɛxt               vɑst - ɣə - lɛxt
# 1768           brute              brˈytə                       bry - tə
# 1769          camera          kˈaːmərˌaː                 kaː - mə - raː
# 1770          ingang             ˈɪnɣˌɑŋ                       ɪn - ɣɑŋ
# 1771           boven             bˈoːvən                      boː - vən
# 1772     stationshal       stˈaːʃɔnshˌɑl              staː - ʃɔnsh - ɑl
# 1773          midden              mˈɪdən                       mɪ - dən
# 1774          poster             pˈɔstər                      pɔ - stər
# 1775           winst              ʋˈɪnst                          ʋɪnst
# 1776           hangt               hˈɑŋt                           hɑŋt
# 1777       producten         prˈoːdɵktən               proː - dɵk - tən
# 1778        zilveren           zˈɪlvərən                 zɪl - və - rən
# 1779           lijst              lˈɛɪst                       lɛ - ɪst
# 1780         tribune            trˈibynə                  tri - by - nə
# 1781   basketballers      bˈɑskɛtbˌɑlərs          bɑ - skɛt - bɑ - lərs
# 1782        begeleid           bəɣəlˈɛɪt              bə - ɣə - lɛ - ɪt
# 1783           coach              kˈoːtʃ                          koːtʃ
# 1784          rechte              rˈɛxtə                       rɛx - tə
# 1785           vader             vˈaːdər                      vaː - dər
# 1786       avondeten       ˌaːvɔndˈeːtən           aː - vɔn - deː - tən
# 1787     waarzegster        ʋˈaːrzɛxstər              ʋaːr - zɛx - stər
# 1788          atleet             ɑtlˈeːt                      ɑt - leːt
# 1789     bijgelovige      bˈɛɪɣəlˌoːvəɣə    bɛ - ɪ - ɣə - loː - və - ɣə
# 1790     beschuldigd         bəsxˈɵldɪxt               bə - sxɵl - dɪxt
# 1791          glazen            ɣlˈaːzən                     ɣlaː - zən
# 1792             bol                bˈɔl                            bɔl
# 1793         gebruik            ɣəbrˈœyk                     ɣə - brœyk
# 1794          doping             dˈoːpɪŋ                      doː - pɪŋ
# 1795       duitsland          dˈœytslɑnt                   dœyt - slɑnt
# 1796            vlak               vlˈɑk                           vlɑk
# 1797           schat               sxˈɑt                           sxɑt
# 1798         gehaald            ɣəhˈaːlt                     ɣəh - aːlt
# 1799           dader             dˈaːdər                      daː - dər
# 1800        zeebodem         zˈeːbˌoːdəm                zeː - boː - dəm
# 1801         bewaart            bəʋˈaːrt                     bə - ʋaːrt
# 1802    goudvoorraad      ɣˌʌʊdvɔːɾrˈaːt             ɣʌʊd - vɔːɾ - raːt
# 1803           kluis              klˈœys                          klœys
# 1804           grond              ɣrˈɔnt                          ɣrɔnt
# 1805             eet                ˈeːt                            eːt
# 1806         meestal           mˈeːstˌɑl                     meː - stɑl
# 1807      aanleiding         ˈaːnlˌɛɪdɪŋ             aːn - lɛ - ɪ - dɪŋ
# 1808           gezin              ɣəzˈɪn                       ɣə - zɪn
# 1809         melding             mˈɛldɪŋ                      mɛl - dɪŋ
# 1810        anonieme         ˌaːnoːnˈimə             aː - noː - ni - mə
# 1811             tip                tˈɪp                            tɪp
# 1812       fanatieke        fˌaːnaːtˈikə            faː - naː - ti - kə
# 1813            bram               brˈɑm                           brɑm
# 1814         blunder            blˈɵndər                     blɵn - dər
# 1815          zakken              zˈɑkən                       zɑ - kən
# 1816    gistermiddag       ɣˈɪstərmˌɪdɑx           ɣɪ - stər - mɪ - dɑx
# 1817       berisping           bərˈɪspɪŋ                 bə - rɪ - spɪŋ
# 1818             ivo               ˈivoː                        i - voː
# 1819         slechte             slˈɛxtə                      slɛx - tə
# 1820            baas               bˈaːs                           baːs
# 1821             ria               rˈiaː                        ri - aː
# 1822          advies              ɑdvˈis                       ɑd - vis
# 1823       avonduren        ˌaːvɔndˈyrən            aː - vɔn - dy - rən
# 1824       tennissen            tˈɛnɪsən                  tɛ - nɪ - sən
# 1825          chique                ʃˈik                            ʃik
# 1826          zonnen              zˈɔnən                       zɔ - nən
# 1827            mooi               mˈoːj                           moːj
# 1828            goot               ɣˈoːt                           ɣoːt
# 1829        dineetje           dˈineːtʲə                 di - neːtʲ - ə
# 1830         kristal            krˈɪstɑl                     krɪ - stɑl
# 1831           karaf             kˈaːrɑf                      kaː - rɑf
# 1832          breken            brˈeːkən                     breː - kən
# 1833            inge                ˈɪŋə                         ɪŋ - ə
# 1834          berouw              bərˈʌʊ                       bə - rʌʊ
# 1835         toonden            tˈoːndən                     toːn - dən
# 1836            vaas               vˈaːs                           vaːs
# 1837         antieke             ɑntˈikə                   ɑn - ti - kə
# 1838         gewerkt            ɣəʋˈɛrkt                     ɣə - ʋɛrkt
# 1839          iemand              ˈimɑnt                       i - mɑnt
# 1840      voltallige          vɔltˈɑləɣə             vɔl - tɑ - lə - ɣə
# 1841       eindhoven         ɛɪndhˈoːvən            ɛ - ɪndh - oː - vən
# 1842            luuk                lˈyk                            lyk
# 1843       ontslagen         ɔntslˈaːɣən               ɔnt - slaː - ɣən
# 1844         startte             stˈɑrtə                      stɑr - tə
# 1845      voorzitter          vˈɔːrzɪtər                vɔːr - zɪ - tər
# 1846            wind               ʋˈɪnt                           ʋɪnt
# 1847          wegens            ʋˈeːɣəns                     ʋeː - ɣəns
# 1848           dorre              dˈɔɾrə                       dɔɾ - rə
# 1849        bladeren          blˈaːdərən                blaː - də - rən
# 1850       wangedrag         ʋˈɑŋɣədrˌɑx                ʋɑŋ - ɣə - drɑx
# 1851        arbeider           ˈɑrbɛɪdər              ɑr - bɛ - ɪ - dər
# 1852        afgerond          ˈɑfɣərˌɔnt                 ɑf - ɣə - rɔnt
# 1853      inspanning          ˈɪnspˌɑnɪŋ                 ɪn - spɑ - nɪŋ
# 1854          bellen              bˈɛlən                       bɛ - lən
# 1855            taxi              tˈɑksi                       tɑk - si
# 1856          afloop            ˈɑflˌoːp                      ɑ - floːp
# 1857           zoekt               zˈukt                           zukt
# 1858       arrogante        ˌɑɾroːɣˈɑntə            ɑɾ - roː - ɣɑn - tə
# 1859      werknemers       ʋˈɛrknˌeːmərs              ʋɛrk - neː - mərs
# 1860         contact            kˈɔntɑkt                     kɔn - tɑkt
# 1861           verre               vˈɛrə                        vɛ - rə
# 1862          reizen             rˈɛɪzən                   rɛ - ɪ - zən
# 1863       vliegende           vlˈiɣəndə                 vli - ɣən - də
# 1864        wellicht             ʋˈɛlɪxt                      ʋɛ - lɪxt
# 1865       toespraak          tˈusprˌaːk                    tu - spraːk
# 1866       toenemend         tˈunˌeːmənt                tu - neː - mənt
# 1867         schotel            sxˈoːtəl                     sxoː - təl
# 1868      commentaar          kɔmˈɛntaːr                kɔ - mɛn - taːr
# 1869      vandalisme        vɑndaːlˈɪsmə           vɑn - daː - lɪ - smə
# 1870         leveren           lˈeːvərən                 leː - və - rən
# 1871         spelend           spˈeːlənt                    speː - lənt
# 1872       studenten          stydˈɛntən                sty - dɛn - tən
# 1873          liepen              lˈipən                       li - pən
# 1874        trommels            trˈɔməls                     trɔ - məls
# 1875         vrolijk            vrˈoːlək                     vroː - lək
# 1876          school              sxˈoːl                          sxoːl
# 1877      vertrokken          vərtrˈɔkən                vər - trɔ - kən
# 1878          paarse             pˈaːrsə                      paːr - sə
# 1879           omdat              ˈɔmdɑt                       ɔm - dɑt
# 1880            zeer               zˈɪːr                           zɪːr
# 1881           pauze              pˈʌʊzə                       pʌʊ - zə
# 1882        soldaten          sɔldˈaːtən                sɔl - daː - tən
# 1883       onbeleefd          ɔnbəlˈeːft                ɔn - bə - leːft
# 1884          gebukt             ɣəbˈɵkt                      ɣə - bɵkt
# 1885          touwen              tˈʌʊən                       tʌʊ - ən
# 1886      scholieren          sxoːlˈirən                sxoː - li - rən
# 1887         kantine            kɑntˈinə                  kɑn - ti - nə
# 1888      schooljaar          sxˈoːljaːr                   sxoːl - jaːr
# 1889         logeren          loːʒˈɪːrən                loː - ʒɪː - rən
# 1890          dropje             drˈɔpjə                      drɔp - jə
# 1891            hand               hˈɑnt                           hɑnt
# 1892          zusjes             zˈɵsjəs                      zɵs - jəs
# 1893         lekkers             lˈɛkərs                      lɛ - kərs
# 1894     vrijstaande        vrˈɛɪstaːndə           vrɛ - ɪ - staːn - də
# 1895       boerderij          bˌurdərˈɛɪ              bur - də - rɛ - ɪ
# 1896      achtertuin         ˈɑxtərtˌœyn                ɑx - tər - tœyn
# 1897          royale          rˈoːiˌaːlə              roː - i - aː - lə
# 1898           wonen              ʋˈɔnən                       ʋɔ - nən
# 1899       kennissen            kˈɛnɪsən                  kɛ - nɪ - sən
# 1900        lekkages           lɛkˈaːʒəs                 lɛ - kaː - ʒəs
# 1901       schoonzus           sxˈoːnzɵs                    sxoːn - zɵs
# 1902     voornaamste        vˈɔːrnaːmstə              vɔːr - naːm - stə
# 1903      loodgieter          loːdɣˈitər                loːd - ɣi - tər
# 1904       verhelpen          vərhˈɛlpən                vərh - ɛl - pən
# 1905           vrome             vrˈoːmə                      vroː - mə
# 1906       onderzoek          ˈɔndərzˌuk                 ɔn - dər - zuk
# 1907             kun                kˈɵn                            kɵn
# 1908      publicatie       pˌɵblikˈaːtsi           pɵ - bli - kaːt - si
# 1909      raadplegen        raːdplˈeːɣən              raːd - pleː - ɣən
# 1910          jungle              jˈɵŋlə                       jɵŋ - lə
# 1911           groep               ɣrˈup                           ɣrup
# 1912            reis               rˈɛɪs                        rɛ - ɪs
# 1913         moeders             mˈudərs                      mu - dərs
# 1914           hotel             hoːtˈɛl                      hoː - tɛl
# 1915            apen              ˈaːpən                       aː - pən
# 1916           beest              bˈeːst                          beːst
# 1917            zaal               zˈaːl                           zaːl
# 1918          vieren              vˈirən                       vi - rən
# 1919       overstuur         ˌoːvərstˈyr                oː - vər - styr
# 1920        bereiken           bərˈɛɪkən              bə - rɛ - ɪ - kən
# 1921           tocht               tˈɔxt                           tɔxt
# 1922          bergen             bˈɛrɣən                      bɛr - ɣən
# 1923            mede              mˈeːdə                       meː - də
# 1924      wandelaars        ʋˈɑndəlˌaːrs               ʋɑn - də - laːrs
# 1925         camping             kˈɑmpɪŋ                      kɑm - pɪŋ
# 1926     uitstekende      ˈœytstˌeːkəndə          œyt - steː - kən - də
# 1927     organisatie     ˌɔrɣaːnizˈaːtsi      ɔr - ɣaː - ni - zaːt - si
# 1928         dankzij            dɑŋkzˈɛɪ                  dɑŋk - zɛ - ɪ
# 1929      arriveerde         ˌɑɾrivˈɪrdə             ɑɾ - ri - vɪr - də
# 1930     schreeuwden           sxrˈeʊdən                    sxreʊ - dən
# 1931        dictator          dɪktˈaːtɔr                dɪk - taː - tɔr
# 1932    elektronisch      ˌeːlɛktrˈoːnis          eː - lɛk - troː - nis
# 1933          leuzen             lˈøːzən                      løː - zən
# 1934         drogist           droːɣˈɪst                    droː - ɣɪst
# 1935         klanten            klˈɑntən                     klɑn - tən
# 1936           blije              blˈɛɪə                    blɛ - ɪ - ə
# 1937         betalen           bətˈaːlən                 bə - taː - lən
# 1938          intens             ˈɪntəns                      ɪn - təns
# 1939        jongeren            jˈɔŋərən                  jɔŋ - ə - rən
# 1940         plezier            pleːzˈir                     pleː - zir
# 1941      woonplaats        ʋˈoːnplˌaːts                  ʋoːn - plaːts

# %%
# MOUS_IPA_transcriptions.to_csv('/home/neel/Desktop/MOUS_hierarchical-representations/MOUS_IPA_transcriptions.csv', index = False)

# %%
# Display the resulting DataFrame
MOUS_IPA_transcriptions
# Out:
#                 Word                 IPA                      Syllables
# 0               toen                tˈun                            tun
# 1                die                 dˈi                             di
# 2                 de                 dˈə                             də
# 3          barkeeper          bˈɑrkeːpər                bɑr - keː - pər
# 4          irritante         ˌɪɾritˈɑntə             ɪɾ - ri - tɑn - tə
# 5           bediende            bədˈində                  bə - din - də
# 6            wegliep            ʋˈɛɣlˌip                      ʋɛ - ɣlip
# 7              manke              mˈɑŋkə                       mɑŋ - kə
# 8             gingen              ɣˈɪŋən                       ɣɪŋ - ən
# 9              klant              klˈɑnt                          klɑnt
# 10         dronkaard          drˈɔŋkaːrt                   drɔŋ - kaːrt
# 11              open              ˈoːpən                       oː - pən
# 12            deuren             dˈøːrən                      døː - rən
# 13          betaalde           bətˈaːldə                 bə - taːl - də
# 14              viel                vˈil                            vil
# 15              kruk               krˈɵk                           krɵk
# 16            lachte              lˈɑxtə                       lɑx - tə
# 17            rector             rˈɛktɔr                      rɛk - tɔr
# 18                om                 ˈɔm                             ɔm
# 19            stoere              stˈurə                       stu - rə
# 20             puber              pˈybər                       py - bər
# 21           strafte            strˈɑftə                     strɑf - tə
# 22               was                ʋˈɑs                            ʋɑs
# 23               erg                ˈɛrx                            ɛrx
# 24        onredelijk         ɔnrˈeːdələk            ɔn - reː - də - lək
# 25          inbreker         ˈɪnbrˌeːkər                ɪn - breː - kər
# 26         gekrenkte          ɣˈɛkrɛŋktə                ɣɛ - krɛŋk - tə
# 27           smeekte            smˈeːktə                     smeːk - tə
# 28           pastoor            pɑstˈoːr                     pɑ - stoːr
# 29               ten                tˈɛn                            tɛn
# 30            vorige            vˈoːrəɣə                  voː - rə - ɣə
# 31              raad               rˈaːt                           raːt
# 32             einde              ˈɛɪndə                    ɛ - ɪn - də
# 33            bruine             brˈœynə                      brœy - nə
# 34         assistent          ˌɑsɪstˈɛnt                 ɑ - sɪ - stɛnt
# 35              week               ʋˈeːk                           ʋeːk
# 36            tanden             tˈɑndən                      tɑn - dən
# 37             kreeg              krˈeːx                          kreːx
# 38           maandag            mˈaːndɑx                     maːn - dɑx
# 39           uitslag           ˈœytslˌɑx                     œyt - slɑx
# 40        behandelde         bəhˈɑndəldə            bəh - ɑn - dəl - də
# 41            pokken              pˈɔkən                       pɔ - kən
# 42           medicus          mˈeːdikˌɵs                 meː - di - kɵs
# 43           vreemde            vrˈeːmdə                     vreːm - də
# 44            laatst             lˈaːtst                         laːtst
# 45              zelf               zˈɛlf                           zɛlf
# 46        psychiater        psˈɪxiˌaːtər            psɪx - i - aː - tər
# 47         gevreesde          ɣəvrˈeːzdə                ɣə - vreːz - də
# 48              zijn               zˈɛɪn                        zɛ - ɪn
# 49        verslaafde         vərslˈaːvdə               vər - slaːv - də
# 50                is                 ˈɪs                             ɪs
# 51           ontslag            ɔntslˈɑx                     ɔnt - slɑx
# 52        overtreder      ˌoːvərtrˈeːdər          oː - vər - treː - dər
# 53            smeris            smˈɪːrɪs                     smɪː - rɪs
# 54         ontvlucht           ɔntvlˈɵxt                    ɔnt - vlɵxt
# 55         kronkelig          krˈɔŋkələx                krɔŋ - kə - ləx
# 56               een                ˈeːn                            eːn
# 57          ingerend          ˈɪnɣərˌɛnt                 ɪn - ɣə - rɛnt
# 58            paadje             pˈaːtjə                      paːt - jə
# 59               het                hˈət                            hət
# 60         eigenaars         ˈɛɪɣənˌaːrs             ɛ - ɪ - ɣə - naːrs
# 61          landgoed           lˈɑndɣˌut                     lɑnd - ɣut
# 62               van                vˈɑn                            vɑn
# 63         bezoekers           bəzˈukərs                 bə - zu - kərs
# 64         honderden          hˈɔndɛrdən                hɔn - dɛr - dən
# 65          gisteren           ɣˈɪstərən                 ɣɪ - stə - rən
# 66        rondleiden         rˈɔndlɛɪdən            rɔnd - lɛ - ɪ - dən
# 67          filmster           fˈɪlmstər                    fɪlm - stər
# 68             trots              trˈɔts                          trɔts
# 69        beschermde          bəsxˈɛrmdə                bə - sxɛrm - də
# 70               had                hˈɑt                            hɑt
# 71             brede             brˈeːdə                      breː - də
# 72         bodyguard        bˈoːdiɣˌyɑrt            boː - di - ɣy - ɑrt
# 73             vrije              vrˈɛɪə                    vrɛ - ɪ - ə
# 74            morgen             mˈɔrɣən                      mɔr - ɣən
# 75            krijgt             krˈɛɪxt                      krɛ - ɪxt
# 76               dag                dˈɑx                            dɑx
# 77          beroemde            bərˈumdə                  bə - rum - də
# 78              ober              ˈoːbər                       oː - bər
# 79         president        prˌeːzidˈɛnt               preː - zi - dɛnt
# 80         beledigde         bəlˈeːdɪɣdə            bə - leː - dɪɣ - də
# 81           bandage           bɑndˈaːʒə                 bɑn - daː - ʒə
# 82             eerst              ˈɪːrst                          ɪːrst
# 83             vieze               vˈizə                        vi - zə
# 84              arts               ˈɑrts                           ɑrts
# 85           plastic            plˈɑstɪk                     plɑ - stɪk
# 86       verschoonde         vərsxˈoːndə               vər - sxoːn - də
# 87              trok               trˈɔk                           trɔk
# 88      handschoenen         hˈɑndsxunən               hɑnd - sxu - nən
# 89               met                mˈɛt                            mɛt
# 90               aan                ˈaːn                            aːn
# 91         sportarts         spˈɔrtˌɑrts                   spɔr - tɑrts
# 92        gescheurde          ɣəsxˈøːrdə                ɣə - sxøːr - də
# 93         adviseert          ˌɑdvizˈɪrt                 ɑd - vi - zɪrt
# 94             pezen             pˈeːzən                      peː - zən
# 95               oma              ˈoːmaː                       oː - maː
# 96          hockeyer           hˈɔkəˌiər               hɔ - kə - i - ər
# 97          verstand           vərstˈɑnt                    vər - stɑnt
# 98                er                 ˈər                             ər
# 99             heeft              hˈeːft                          heːft
# 100             veel               vˈeːl                           veːl
# 101            moest               mˈust                           must
# 102     verpleegster       vərplˈeːxstər             vər - pleːx - stər
# 103         gebroken          ɣəbrˈoːkən                ɣə - broː - kən
# 104           bekken              bˈɛkən                       bɛ - kən
# 105      raadpleegde        rˈaːdpleːɣdə              raːd - pleːɣ - də
# 106           huilen             hˈœylən                      hœy - lən
# 107       alcoholist      ˌɑlkoːhoːlˈɪst          ɑl - koːh - oː - lɪst
# 108             weer               ʋˈɪːr                           ʋɪːr
# 109          bekende            bəkˈɛndə                  bə - kɛn - də
# 110       psycholoog        psˈɪxoːlˌoːx               psɪx - oː - loːx
# 111         scholier            sxoːlˈir                     sxoː - lir
# 112          meester           mˈeːstˌɛr                     meː - stɛr
# 113         terugval          tərˈɵxvˌɑl                 tə - rɵx - vɑl
# 114         treitert           trˈɛɪtərt                 trɛ - ɪ - tərt
# 115           alweer              ɑlʋˈɪr                       ɑl - ʋɪr
# 116            stoel               stˈul                           stul
# 117         punaises          pˌynɑjzˈɛs                 py - nɑj - zɛs
# 118           gelegd             ɣəlˈɛxt                      ɣə - lɛxt
# 119           jochem              jˈɔxəm                       jɔx - əm
# 120               op                 ˈɔp                             ɔp
# 121               te                 tˈə                             tə
# 122           altijd             ˈɑltɛɪt                   ɑl - tɛ - ɪt
# 123          tijdens            tˈɛɪdəns                  tɛ - ɪ - dəns
# 124        basketbal         bˈɑskɛtbˌɑl                bɑ - skɛt - bɑl
# 125             hoog               hˈoːx                           hoːx
# 126          springt             sprˈɪŋt                         sprɪŋt
# 127          bezeerd            bəzˈɪːrt                     bə - zɪːrt
# 128       agressieve          ˌɑɣrɛsˈivə              ɑ - ɣrɛ - si - və
# 129            enkel              ˈɛŋkəl                       ɛŋ - kəl
# 130       arresteert         ˌɑɾrɛstˈɪrt                ɑɾ - rɛ - stɪrt
# 131       politieman       poːlˈitsimˌɑn           poː - lit - si - mɑn
# 132           kraker            krˈaːkər                     kraː - kər
# 133       hardhandig         hɑrdhˈɑndəx               hɑrdh - ɑn - dəx
# 134             werk               ʋˈɛrk                           ʋɛrk
# 135             gaat               ɣˈaːt                           ɣaːt
# 136           staker            stˈaːkər                     staː - kər
# 137         angstige            ˈɑŋstəɣə                  ɑŋ - stə - ɣə
# 138         bekogelt          bəkˈoːɣəlt                bə - koː - ɣəlt
# 139              ver                vˈɛr                            vɛr
# 140            dames             dˈaːməs                      daː - məs
# 141       interviewt         ˌɪntərvˈiwt                ɪn - tər - viwt
# 142       journalist        ʒˌurnaːlˈɪst               ʒur - naː - lɪst
# 143      tuberculose      tˈybərkˌyloːsə       ty - bər - ky - loː - sə
# 144           zuster             zˈɵstər                      zɵ - stər
# 145              wil                ʋˈɪl                            ʋɪl
# 146       bondscoach         bˈɔndskoːtʃ                  bɔnd - skoːtʃ
# 147            weten             ʋˈeːtən                      ʋeː - tən
# 148         lijdende           lˈɛɪdəndə              lɛ - ɪ - dən - də
# 149             wast               ʋˈɑst                           ʋɑst
# 150         bejaarde           bəjˈaːrdə                 bə - jaːr - də
# 151     enthousiaste         ˌɛntuʒˈɑstə             ɛn - tu - ʒɑ - stə
# 152         zorgzaam           zˈɔrɣzaːm                    zɔrɣ - zaːm
# 153     vrijwilliger        vrɛɪʋˈɪləɣər        vrɛ - ɪ - ʋɪ - lə - ɣər
# 154       goochelaar         ɣˈoːxəlˌaːr                ɣoːx - ə - laːr
# 155          publiek             pɵblˈik                      pɵ - blik
# 156        geduldige          ɣədˈɵldəɣə             ɣə - dɵl - də - ɣə
# 157       instrueert         ˈɪnstryˌɪrt                ɪn - stry - ɪrt
# 158              uit                ˈœyt                            œyt
# 159             baby              bˈeːbi                       beː - bi
# 160            doopt              dˈoːpt                          doːpt
# 161      onduidelijk         ɔndˈœydələk            ɔn - dœy - də - lək
# 162          dominee          dˌoːminˈeː                 doː - mi - neː
# 163           begint             bəɣˈɪnt                      bə - ɣɪnt
# 164          spreken           sprˈeːkən                    spreː - kən
# 165       voorganger          vˈɔːrɣɑŋər                vɔːr - ɣɑŋ - ər
# 166         snoezige            snˈuzəɣə                  snu - zə - ɣə
# 167         kleintje           klˈɛɪntʲə                 klɛ - ɪntʲ - ə
# 168           stevig            stˈeːvəx                     steː - vəx
# 169            houdt               hˈʌʊt                           hʌʊt
# 170             haar               hˈaːr                           haːr
# 171             vast               vˈɑst                           vɑst
# 172         boterham         bˈoːtərhˌɑm                boː - tərh - ɑm
# 173           meisje             mˈɛɪsjə                   mɛ - ɪs - jə
# 174              dat                dˈɑt                            dɑt
# 175        pindakaas        pˌɪndaːkˈaːs               pɪn - daː - kaːs
# 176           zonder             zˈɔndər                      zɔn - dər
# 177          dochter             dˈɔxtər                      dɔx - tər
# 178          verwend            vərʋˈɛnt                     vər - ʋɛnt
# 179           schone             sxˈoːnə                      sxoː - nə
# 180           robert            rˈoːbɛrt                     roː - bɛrt
# 181         huwelijk            hˈywələk                  hyw - ə - lək
# 182              jan                jˈɑn                            jɑn
# 183           slikte             slˈɪktə                      slɪk - tə
# 184            vroeg               vrˈux                           vrux
# 185         opspoort           ˈɔpspɔːrt                    ɔp - spɔːrt
# 186        detective        dˈeːtɛktˌivə            deː - tɛk - ti - və
# 187       criminelen       krˌiminˈeːlən           kri - mi - neː - lən
# 188            vette               vˈɛtə                        vɛ - tə
# 189            staat              stˈaːt                          staːt
# 190        speurhond          spˈøːrhɔnt                   spøːrh - ɔnt
# 191         beloning           bəlˈoːnɪŋ                 bə - loː - nɪŋ
# 192            drugs              drˈɵxs                          drɵxs
# 193         illegale          ˌɪləɣˈaːlə              ɪ - lə - ɣaː - lə
# 194           koekje              kˈukjə                       kuk - jə
# 195            trage             trˈaːʒə                      traː - ʒə
# 196         afschudt            ˈɑfsxˌɵt                      ɑf - sxɵt
# 197     gedetineerde      ɣədˌeːtinˈɪrdə       ɣə - deː - ti - nɪr - də
# 198             hulp               hˈɵlp                           hɵlp
# 199          vandaag            vɑndˈaːx                     vɑn - daːx
# 200          bewaker           bəʋˈaːkər                 bə - ʋaː - kər
# 201          laatste            lˈaːtstə                     laːt - stə
# 202       handlanger          hˈɑndlɑŋər                hɑnd - lɑŋ - ər
# 203       examinator     ˌɛksaːminˈaːtɔr      ɛk - saː - mi - naː - tɔr
# 204        kandidaat         kˌɑndidˈaːt                kɑn - di - daːt
# 205        overtuigt        ˌoːvərtˈœyxt               oː - vər - tœyxt
# 206            spits              spˈɪts                          spɪts
# 207       imponerend      ˌɪmpoːnˈɪːrənt          ɪm - poː - nɪː - rənt
# 208         opstelde           ˈɔpstɛldə                 ɔp - stɛl - də
# 209         cruciale           krˈyʃaːlə                 kry - ʃaː - lə
# 210          trainer            trˈeːnər                     treː - nər
# 211         training            trˈeːnɪŋ                     treː - nɪŋ
# 212             wist               ʋˈɪst                           ʋɪst
# 213      gevaarlijke         ɣəvˈaːrləkə            ɣə - vaːr - lə - kə
# 214           gemist             ɣəmˈɪst                      ɣə - mɪst
# 215     slachtoffers         slˈɑxtɔfərs               slɑx - tɔ - fərs
# 216          niemand             nˈimɑnt                      ni - mɑnt
# 217          tornado          tɔrnˈaːdoː                tɔr - naː - doː
# 218         ontstond           ɔntstˈɔnt                    ɔnt - stɔnt
# 219            eisen              ˈɛɪzən                    ɛ - ɪ - zən
# 220           dieven              dˈivən                       di - vən
# 221              zou                zˈʌʊ                            zʌʊ
# 222        ontsnapte          ɔntsnˈɑptə                ɔnt - snɑp - tə
# 223         employee         ˌɛmploːiˈeː             ɛm - ploː - i - eː
# 224       beschrijft          bəsxrˈɛɪft                bəsx - rɛ - ɪft
# 225            wrede             vrˈeːdə                      vreː - də
# 226        onderdaan         ˈɔndərdˌaːn                ɔn - dər - daːn
# 227       nauwkeurig          nʌʊkˈøːrəx                nʌʊ - køː - rəx
# 228          beveelt            bəvˈeːlt                     bə - veːlt
# 229             boos               bˈoːs                           boːs
# 230            derde              dˈɛrdə                       dɛr - də
# 231            getal              ɣətˈɑl                       ɣə - tɑl
# 232       oplettende         ˈɔplˌɛtəndə             ɔ - plɛ - tən - də
# 233       toehoorder         tˈuhˌɔːrdər                tuh - ɔːr - dər
# 234       signaleert         sˌɪɲaːlˈɪrt                sɪɲ - aː - lɪrt
# 235              zes                zˈɛs                            zɛs
# 236             mijn               mˈɛɪn                        mɛ - ɪn
# 237         vriendin            vrˈindɪn                     vrin - dɪn
# 238              gek                ɣˈɛk                            ɣɛk
# 239          jongens             jˈɔŋəns                      jɔŋ - əns
# 240             mona             mˈoːnaː                      moː - naː
# 241          gemixte           ɣəmˈɪkstə                 ɣə - mɪk - stə
# 242         drankjes           drˈɑŋkjəs                    drɑŋk - jəs
# 243            kopen             kˈoːpən                      koː - pən
# 244         aannemer         ˈaːnnˌeːmər                aːn - neː - mər
# 245             voor               vˈɔːr                           vɔːr
# 246          bewoner           bəʋˈoːnər                 bə - ʋoː - nər
# 247           humeur             hymˈøːr                      hy - møːr
# 248         vrouwtje            vrˈʌʊtʲə                     vrʌʊtʲ - ə
# 249         verlaten          vərlˈaːtən                vər - laː - tən
# 250             goed                ɣˈut                            ɣut
# 251           matste             mˈɑtstə                      mɑt - stə
# 252           poezen              pˈuzən                       pu - zən
# 253            buren              bˈyrən                       by - rən
# 254            ruzie               ryzˈi                        ry - zi
# 255          opvangt             ˈɔpvɑŋt                      ɔp - vɑŋt
# 256        populaire        pˌoːpylˈɛːrə            poː - py - lɛː - rə
# 257         jongeman           jˈɔŋəmˌɑn                  jɔŋ - ə - mɑn
# 258          onlangs             ɔnlˈɑŋs                      ɔn - lɑŋs
# 259              gaf                ɣˈɑf                            ɣɑf
# 260          portier             pɔrtˈir                      pɔr - tir
# 261           sterke             stˈɛrkə                      stɛr - kə
# 262            feest              fˈeːst                          feːst
# 263            beren             bˈɪːrən                      bɪː - rən
# 264            groot              ɣrˈoːt                          ɣroːt
# 265        betoverde         bətˈoːvərdə            bə - toː - vər - də
# 266           knappe              knˈɑpə                       knɑ - pə
# 267         inhuurde           ˈɪnhˌyrdə                  ɪnh - yr - də
# 268            elfje              ˈɛlfjə                       ɛlf - jə
# 269         schilder            sxˈɪldər                     sxɪl - dər
# 270          prinses            prɪnsˈɛs                     prɪn - sɛs
# 271           tekent            tˈeːkənt                     teː - kənt
# 272              pap                pˈɑp                            pɑp
# 273      vriendelijk          vrˈindələk                vrin - də - lək
# 274           kokkin              kˈɔkɪn                       kɔ - kɪn
# 275            onder              ˈɔndər                       ɔn - dər
# 276              zit                zˈɪt                            zɪt
# 277          dakloze           dˈɑkloːzə                 dɑ - kloː - zə
# 278             verf               vˈɛrf                           vɛrf
# 279             geen               ɣˈeːn                           ɣeːn
# 280          burgers            bˈɵrɣərs                     bɵr - ɣərs
# 281            kookt              kˈoːkt                          koːkt
# 282              zin                zˈɪn                            zɪn
# 283             meer               mˈɪːr                           mɪːr
# 284            warme              ʋˈɑrmə                       ʋɑr - mə
# 285           dekens            dˈeːkəns                     deː - kəns
# 286             nora             nˈoːraː                      noː - raː
# 287             arme               ˈɑrmə                        ɑr - mə
# 288           mensen             mˈɛnsən                      mɛn - sən
# 289            weeft              ʋˈeːft                          ʋeːft
# 290         schutter             sxˈɵtər                      sxɵ - tər
# 291         gelukkig            ɣəlˈɵkəx                  ɣə - lɵ - kəx
# 292     gewelddadige       ɣəʋɛldˈaːdəɣə       ɣə - ʋɛl - daː - də - ɣə
# 293           doodde              dˈoːdə                       doː - də
# 294           jullie               jɵlˈi                        jɵ - li
# 295        directeur         dˌirɛktˈøːr                di - rɛk - tøːr
# 296           ruiter             rˈœytər                      rœy - tər
# 297               al                 ˈɑl                             ɑl
# 298           eerder             ˈɪːrdər                      ɪːr - dər
# 299          geweest            ɣəʋˈeːst                     ɣə - ʋeːst
# 300         geliefde            ɣəlˈivdə                  ɣə - liv - də
# 301          paarden            pˈaːrdən                     paːr - dən
# 302      veroordeeld        vərˈɔːrdeːlt              və - rɔːr - deːlt
# 303         streelde           strˈeːldə                    streːl - də
# 304          winnaar             ʋˈɪnaːr                      ʋɪ - naːr
# 305         raadsman           rˈaːdsmɑn                    raːd - smɑn
# 306         geworden           ɣəʋˈɔrdən                 ɣə - ʋɔr - dən
# 307         bijstond          bˈɛɪstˌɔnt                 bɛ - ɪ - stɔnt
# 308       delinquent       dˌeːlɪnkvˈɛnt              deː - lɪnk - vɛnt
# 309            radio           rˈaːdiˌoː                  raː - di - oː
# 310          peuters            pˈøːtərs                     pøː - tərs
# 311       opgesloten       ˈɔpɣəslˌoːtən           ɔp - ɣə - sloː - tən
# 312           ouders             ˈʌʊdərs                      ʌʊ - dərs
# 313        alarmeren       ˌaːlɑrmˈɪːrən           aː - lɑr - mɪː - rən
# 314               in                 ˈɪn                             ɪn
# 315         dochters            dˈɔxtərs                     dɔx - tərs
# 316           paniek             paːnˈik                      paː - nik
# 317        bevrijden          bəvrˈɛɪdən             bə - vrɛ - ɪ - dən
# 318             huis               hˈœys                           hœys
# 319             naar               nˈaːr                           naːr
# 320        opgelucht          ˈɔpɣəlˌɵxt                 ɔp - ɣə - lɵxt
# 321            joost              jˈoːst                          joːst
# 322        kidnapper           kˈɪdnɑpər                 kɪd - nɑ - pər
# 323           grijpt             ɣrˈɛɪpt                      ɣrɛ - ɪpt
# 324            bange               bˈɑŋə                        bɑŋ - ə
# 325       directrice        dˌirɛktrˈisə            di - rɛk - tri - sə
# 326         ontglipt           ɔntɣlˈɪpt                    ɔnt - ɣlɪpt
# 327            bazin             bˈaːzɪn                      baː - zɪn
# 328             bang                bˈɑŋ                            bɑŋ
# 329            kraag              krˈaːx                          kraːx
# 330             rent               rˈɛnt                           rɛnt
# 331        diplomaat        dˌɪploːmˈaːt               dɪ - ploː - maːt
# 332           starre             stˈɑɾrə                      stɑɾ - rə
# 333       boswachter          bˈɔsʋɑxtər                bɔs - ʋɑx - tər
# 334             deur               dˈøːr                           døːr
# 335         nuchtere            nˈɵxtərə                  nɵx - tə - rə
# 336        opzichter          ˈɔpzˌɪxtər                 ɔp - zɪx - tər
# 337        onaardige          ɔnˈaːrdəɣə             ɔ - naːr - də - ɣə
# 338              man                mˈɑn                            mɑn
# 339          uitbuit           ˈœytbˌœyt                     œyt - bœyt
# 340        werknemer        ʋˈɛrknˌeːmər               ʋɛrk - neː - mər
# 341          strenge             strˈɛŋə                      strɛŋ - ə
# 342      gehoorzaamt        ɣəhˈɔːrzaːmt              ɣəh - ɔːr - zaːmt
# 343        gespannen           ɣəspˈɑnən                 ɣə - spɑ - nən
# 344            kwijt              kʋˈɛɪt                       kʋɛ - ɪt
# 345            raken             rˈaːkən                      raː - kən
# 346              hun                hˈɵn                            hɵn
# 347             fans               fˈɑns                           fɑns
# 348             baan               bˈaːn                           baːn
# 349          bowlers            bˈɔʋlərs                     bɔʋ - lərs
# 350           willen              ʋˈɪlən                       ʋɪ - lən
# 351           winnen              ʋˈɪnən                       ʋɪ - nən
# 352               ik                 ˈɪk                             ɪk
# 353      sporthelden       spˈɔrthˌɛldən              spɔrth - ɛl - dən
# 354      aanmoedigen        ˈaːnmˌudəɣən            aːn - mu - də - ɣən
# 355            sprak              sprˈɑk                          sprɑk
# 356           scheve             sxˈeːvə                      sxeː - və
# 357              nog                nˈɔx                            nɔx
# 358           torens            tˈoːrəns                     toː - rəns
# 359             hans               hˈɑns                           hɑns
# 360            hielp               hˈilp                           hilp
# 361        ontworpen          ɔntʋˈɔrpən                ɔnt - ʋɔr - pən
# 362     hulpverlener     hˈɵlpvərlˌeːnər         hɵlp - vər - leː - nər
# 363          bereden           bərˈeːdən                 bə - reː - dən
# 364              zag                zˈɑx                            zɑx
# 365          zwerver            zʋˈɛrvər                     zʋɛr - vər
# 366          politie           poːlˈitsi                 poː - lit - si
# 367            rende              rˈɛndə                       rɛn - də
# 368              hij                hˈɛɪ                         hɛ - ɪ
# 369            zieke               zˈikə                        zi - kə
# 370              weg                ʋˈɛx                            ʋɛx
# 371      heilsoldaat       hˌɛɪlsɔldˈaːt           hɛ - ɪl - sɔl - daːt
# 372            kamer             kˈaːmər                      kaː - mər
# 373       huisvestte          hˈœysfɛstə                hœy - sfɛ - stə
# 374       grootvader        ɣrˈoːtvaːdər              ɣroːt - vaː - dər
# 375       binnenkwam         bˈɪnənkʋˌɑm                bɪ - nənk - ʋɑm
# 376         deugniet            døːɣnˈit                     døːɣ - nit
# 377          slinkse            slˈɪŋksə                     slɪŋk - sə
# 378           schrok              sxrˈɔk                          sxrɔk
# 379          doorhad            dˈɔːrhɑt                     dɔːrh - ɑt
# 380             zich                zˈɪx                            zɪx
# 381         bedrogen          bədrˈoːɣən                bə - droː - ɣən
# 382         goedkope           ɣudkˈoːpə                 ɣud - koː - pə
# 383           voelde              vˈuldə                       vul - də
# 384           bordes             bɔrdˈɛs                      bɔr - dɛs
# 385        achterste           ˈɑxtərstə                 ɑx - tər - stə
# 386       repareerde       rˌeːpaːrˈɪrdə           reː - paː - rɪr - də
# 387         beunhaas           bøːnhˈaːs                    bøːnh - aːs
# 388           judoka           jydˈoːkaː                 jy - doː - kaː
# 389            dwaze             dʋˈaːzə                      dʋaː - zə
# 390           houden             hˈʌʊdən                      hʌʊ - dən
# 391          belager           bəlˈaːɣər                 bə - laː - ɣər
# 392             niet                nˈit                            nit
# 393          vloerde             vlˈurdə                      vlur - də
# 394        misleidde           mɪslˈɛɪdə              mɪ - slɛ - ɪ - də
# 395          simpele            sˈɪmpələ                  sɪm - pə - lə
# 396        bedrieger           bədrˈiɣər                 bə - dri - ɣər
# 397         schuldig            sxˈɵldəx                     sxɵl - dəx
# 398            tante              tˈɑntə                       tɑn - tə
# 399         taxateur        tˌɑksaːtˈøːr               tɑk - saː - tøːr
# 400            agaat             aːɣˈaːt                      aː - ɣaːt
# 401              won                ʋˈɔn                            ʋɔn
# 402        wedstrijd          ʋˈɛtstrɛɪt                ʋɛt - strɛ - ɪt
# 403           pieren              pˈirən                       pi - rən
# 404         gebruikt           ɣəbrˈœykt                    ɣə - brœykt
# 405           haagse             hˈaːxsə                      haːx - sə
# 406          bordeel            bɔrdˈeːl                     bɔr - deːl
# 407           gladde              ɣlˈɑdə                       ɣlɑ - də
# 408      naaktlopers       nˈaːktloːpərs             naːkt - loː - pərs
# 409           hebben              hˈɛbən                       hɛ - bən
# 410         vermaken          vərmˈaːkən                vər - maː - kən
# 411        ontwerper          ɔntʋˈɛrpər                ɔnt - ʋɛr - pər
# 412          kleding            klˈeːdɪŋ                     kleː - dɪŋ
# 413             koud               kˈʌʊt                           kʌʊt
# 414         koningin          kˌoːnɪɣˈɪn                 koː - nɪ - ɣɪn
# 415         verkoopt           vərkˈoːpt                    vər - koːpt
# 416         creatief         krˌeːaːtˈif                kreː - aː - tif
# 417          etaleur         ˌeːtaːlˈøːr                eː - taː - løːr
# 418            stond              stˈɔnt                          stɔnt
# 419           paspop             pˈɑspɔp                      pɑ - spɔp
# 420              mee                mˈeː                            meː
# 421             gang                ɣˈɑŋ                            ɣɑŋ
# 422              nam                nˈɑm                            nɑm
# 423         fransien            frɑnsˈin                     frɑn - sin
# 424          duurste             dˈyrstə                      dyr - stə
# 425          trompet            trɔmpˈɛt                     trɔm - pɛt
# 426           genoeg              ɣənˈux                       ɣə - nux
# 427           kapper              kˈɑpər                       kɑ - pər
# 428           drukke              drˈɵkə                       drɵ - kə
# 429         uitkiest           ˈœytkˌist                     œyt - kist
# 430             geld               ɣˈɛlt                           ɣɛlt
# 431       teamleider         tˈiːmlɛɪdər            tiːm - lɛ - ɪ - dər
# 432         ervaring           ɛrvˈaːrɪŋ                 ɛr - vaː - rɪŋ
# 433             joke              jˈoːkə                       joː - kə
# 434         bijknipt          bˈɛɪknˌɪpt                 bɛ - ɪk - nɪpt
# 435       tamboerijn         tˌɑmburˈɛɪn             tɑm - bu - rɛ - ɪn
# 436          spaanse            spˈaːnsə                     spaːn - sə
# 437       eenvoudige         eːnvˈʌʊdəɣə            eːn - vʌʊ - də - ɣə
# 438          vooraan           vˈɔːrˌaːn                     vɔː - raːn
# 439           boerin              bˈurɪn                       bu - rɪn
# 440           liefst              lˈifst                          lifst
# 441            hield               hˈilt                           hilt
# 442           speelt             spˈeːlt                         speːlt
# 443      serveerster        sˈɛrvɪːrstər              sɛr - vɪːr - stər
# 444           werden             ʋˈɛrdən                      ʋɛr - dən
# 445       behulpzame        bəhˈɵlpzaːmə           bəh - ɵlp - zaː - mə
# 446           winkel             ʋˈɪŋkəl                      ʋɪŋ - kəl
# 447           netjes             nˈɛtʲəs                      nɛtʲ - əs
# 448            hippe               hˈɪpə                        hɪ - pə
# 449          brillen             brˈɪlən                      brɪ - lən
# 450       behoorlijk          bəhˈoːrlək                bəh - oːr - lək
# 451         verkocht            vərkˈɔxt                     vər - kɔxt
# 452        diafragma        dˌiɑfrˈɑɣmaː            di - ɑ - frɑɣ - maː
# 453           stugge              stˈɵɣə                       stɵ - ɣə
# 454        buikholte          bˈœykhɔltə                bœykh - ɔl - tə
# 455       borstholte          bˈɔrstɔltə                bɔr - stɔl - tə
# 456               en                 ˈɛn                             ɛn
# 457             neem               nˈeːm                           neːm
# 458          scheidt              sxˈɛɪt                       sxɛ - ɪt
# 459       belangrijk          bəlˈɑŋrɛɪk             bə - lɑŋ - rɛ - ɪk
# 460           kleine             klˈɛɪnə                   klɛ - ɪ - nə
# 461             boer                bˈur                            bur
# 462          serieus         sˌɪːrijˈøːs                sɪː - ri - jøːs
# 463         biggetje            bˈɪɣɛtʲə                  bɪ - ɣɛtʲ - ə
# 464            voert               vˈurt                           vurt
# 465            kwade             kʋˈaːdə                      kʋaː - də
# 466          richard             rˈɪxɑrt                      rɪx - ɑrt
# 467           haatte              hˈaːtə                       haː - tə
# 468           dieren              dˈirən                       di - rən
# 469           oudere             ˈʌʊdərə                   ʌʊ - də - rə
# 470        verzorgde          vərzˈɔrɣdə                vər - zɔrɣ - də
# 471             ging                ɣˈɪŋ                            ɣɪŋ
# 472          zielige             zˈiləɣə                   zi - lə - ɣə
# 473              hen                hˈɛn                            hɛn
# 474         tandarts           tˈɑndɑrts                    tɑn - dɑrts
# 475       verzamelen        vərzˈaːmələn           vər - zaː - mə - lən
# 476          heftige            hˈɛftəɣə                  hɛf - tə - ɣə
# 477         bangerik          bˈɑŋɪːrˌɪk                 bɑŋ - ɪː - rɪk
# 478      inschakelde       ˈɪnsxˌaːkəldə           ɪn - sxaː - kəl - də
# 479             pijn               pˈɛɪn                        pɛ - ɪn
# 480            maand              mˈaːnt                          maːnt
# 481        afgelopen        ˈɑfɣəlˌoːpən            ɑf - ɣə - loː - pən
# 482          buurman             bˈyrmɑn                      byr - mɑn
# 483     complicaties     kˌɔmplikˈaːtsis         kɔm - pli - kaːt - sis
# 484             vele              vˈeːlə                       veː - lə
# 485        paragnost        pˈaːrɑɣnˌɔst               paː - rɑɣ - nɔst
# 486          gewonde            ɣəʋˈɔndə                  ɣə - ʋɔn - də
# 487              zus                zˈɵs                            zɵs
# 488         psychose           psɪxˈoːsə                 psɪx - oː - sə
# 489            beter             bˈeːtər                      beː - tər
# 490             keek               kˈeːk                           keːk
# 491            broer               brˈur                           brur
# 492            grote             ɣrˈoːtə                      ɣroː - tə
# 493        gebruikte          ɣəbrˈœyktə                ɣə - brœyk - tə
# 494          ervaren           ɛrvˈaːrən                 ɛr - vaː - rən
# 495           takken              tˈɑkən                       tɑ - kən
# 496             vuur                vˈyr                            vyr
# 497            agent             aːɣˈɛnt                      aː - ɣɛnt
# 498             daar               dˈaːr                           daːr
# 499          toerist            tˈurˌɪst                      tu - rɪst
# 500            gered              ɣərˈɛt                       ɣə - rɛt
# 501           kopers            kˈoːpərs                     koː - pərs
# 502           nieuwe               nˈiwə                        niw - ə
# 503             liep                lˈip                            lip
# 504        makelaars        mˈaːkəlˌaːrs               maː - kə - laːrs
# 505         eigenaar          ˈɛɪɣənˌaːr              ɛ - ɪ - ɣə - naːr
# 506          gehaaid            ɣəhˈaːjt                     ɣəh - aːjt
# 507          gemaakt            ɣəmˈaːkt                     ɣə - maːkt
# 508            gerst              ɣˈɛrst                          ɣɛrst
# 509           lekker              lˈɛkər                       lɛ - kər
# 510          biertje             bˈirtʲə                      birtʲ - ə
# 511           eerste             ˈɪːrstə                      ɪːr - stə
# 512        knipoogde          knˈipoːɣdə                kni - poːɣ - də
# 513          ontving             ɔntvˈɪŋ                      ɔnt - vɪŋ
# 514            verse             vərsˈeː                      vər - seː
# 515              jam                jˈɑm                            jɑm
# 516           bramen            brˈaːmən                     braː - mən
# 517        heerlijke           hˈɪːrləkə                 hɪːr - lə - kə
# 518            maakt              mˈaːkt                          maːkt
# 519        verhuizen          vərhˈœyzən                vərh - œy - zən
# 520            jonge               jˈɔŋə                        jɔŋ - ə
# 521             dief                dˈif                            dif
# 522         gestolen          ɣəstˈoːlən                ɣə - stoː - lən
# 523         vluchtte             vlˈɵxtə                      vlɵx - tə
# 524         telefoon         tˌeːləfˈoːn                teː - lə - foːn
# 525         verkoper          vərkˈoːpər                vər - koː - pər
# 526         paspoort           pˈɑspɔːrt                    pɑ - spɔːrt
# 527        verdiende           vərdˈində                 vər - din - də
# 528          moderne           mˈoːdɛrnə                 moː - dɛr - nə
# 529         aanprees          ˈaːnprˌeːs                    aːn - preːs
# 530        orthopeed         ˌɔrtoːpˈeːt                ɔr - toː - peːt
# 531        behandelt          bəhˈɑndəlt                bəh - ɑn - dəlt
# 532         blessure            blɛsˈyrə                  blɛ - sy - rə
# 533            benul              bənˈɵl                       bə - nɵl
# 534            geeft              ɣˈeːft                          ɣeːft
# 535           weinig             ʋˈɛɪnəx                   ʋɛ - ɪ - nəx
# 536     secretaresse      sˈɛkrətˌaːrɛsə       sɛ - krə - taː - rɛ - sə
# 537         advocaat         ˌɑdvoːkˈaːt                ɑd - voː - kaːt
# 538       mannelijke           mˈɑnələkə              mɑ - nə - lə - kə
# 539          beambte            bəˈɑmbtə                  bə - ɑmb - tə
# 540            wijze              ʋˈɛɪzə                    ʋɛ - ɪ - zə
# 541            brief               brˈif                           brif
# 542             oude               ˈʌʊdə                        ʌʊ - də
# 543           dromen            drˈoːmən                     droː - mən
# 544           ieders              ˈidərs                       i - dərs
# 545             komt               kˈɔmt                           kɔmt
# 546          aardige            ˈaːrdəɣə                  aːr - də - ɣə
# 547          uitlegt           ˈœytlˌɛxt                     œyt - lɛxt
# 548           docent            doːsˈɛnt                     doː - sɛnt
# 549           zijden             zˈɛɪdən                   zɛ - ɪ - dən
# 550           groene              ɣrˈunə                       ɣru - nə
# 551       onderwijst        ˈɔndərʋˌɛɪst            ɔn - dər - ʋɛ - ɪst
# 552           pyjama           pijˈaːmaː                 pi - jaː - maː
# 553              mag                mˈɑx                            mɑx
# 554             kast               kˈɑst                           kɑst
# 555             ligt               lˈɪxt                           lɪxt
# 556          nichtje             nˈɪxtʲə                      nɪxtʲ - ə
# 557               je                 jˈə                             jə
# 558            lenen             lˈeːnən                      leː - nən
# 559              dit                dˈɪt                            dɪt
# 560            mooie              mˈoːjə                       moː - jə
# 561          jaloers            jaːlˈurs                     jaː - lurs
# 562           alleen              ɑlˈeːn                       ɑ - leːn
# 563            wilde              ʋˈɪldə                       ʋɪl - də
# 564          potlood            pɔtlˈoːt                     pɔt - loːt
# 565              ook                ˈoːk                            oːk
# 566            echte               ˈɛxtə                        ɛx - tə
# 567         pitbulls            pˈɪtbɵls                     pɪt - bɵls
# 568           honden             hˈɔndən                      hɔn - dən
# 569            taaie              tˈaːjə                       taː - jə
# 570            mogen             mˈoːɣən                      moː - ɣən
# 571           plekje             plˈɛkjə                      plɛk - jə
# 572              rij                rˈɛɪ                         rɛ - ɪ
# 573           hondje             hˈɔntjə                      hɔnt - jə
# 574            dikke               dˈɪkə                        dɪ - kə
# 575          doorzet            dˈɔːrzɛt                     dɔːr - zɛt
# 576           duiven             dˈœyvən                      dœy - vən
# 577          opjaagt            ˈɔpjaːxt                     ɔp - jaːxt
# 578             door               dˈoːr                           doːr
# 579             wild               ʋˈɪlt                           ʋɪlt
# 580             heel               hˈeːl                           heːl
# 581          scherpe             sxˈɛrpə                      sxɛr - pə
# 582          bochten             bˈɔxtən                      bɔx - tən
# 583      griekenland        ɣrˈikənlˌɑnt               ɣri - kən - lɑnt
# 584        voorkomen        vˈɔːrkˌoːmən               vɔːr - koː - mən
# 585       ongelukken         ˈɔnɣəlˌɵkən             ɔn - ɣə - lɵ - kən
# 586            vrouw               vrˈʌʊ                           vrʌʊ
# 587       tekeningen        tˈeːkənˌɪŋən            teː - kə - nɪŋ - ən
# 588         gebeuren           ɣəbˈøːrən                 ɣə - bøː - rən
# 589            vanaf              vɑnˈɑf                       vɑ - nɑf
# 590        prachtige           prˈɑxtəɣə                 prɑx - tə - ɣə
# 591    kunstacademie   kˌɵnstaːkˌaːdəmˈi     kɵn - staː - kaː - də - mi
# 592          dinsdag            dˈɪnzdɑx                     dɪnz - dɑx
# 593         verbaasd           vərbˈaːst                    vər - baːst
# 594           moeder              mˈudər                       mu - dər
# 595       biscuitjes         bˈɪskœytʲəs               bɪ - skœytʲ - əs
# 596            sonja              sˈɔɲaː                       sɔɲ - aː
# 597       prullenbak         prˈɵlənbˌɑk                prɵ - lən - bɑk
# 598          peetoom            peːtˈoːm                     peː - toːm
# 599          overige           ˈoːvərəɣə              oː - və - rə - ɣə
# 600           gooide             ɣˈoːjdə                      ɣoːj - də
# 601          snelste            snˈɛlstə                     snɛl - stə
# 602           naakte             nˈaːktə                      naːk - tə
# 603     politieagent    poːlˈitsiaːɣˌɛnt     poː - lit - si - aː - ɣɛnt
# 604     gearresteerd       ɣəˌɑɾrɛstˈɪrt           ɣə - ɑɾ - rɛ - stɪrt
# 605        ballerina        bˌɑlɪːrˈinaː            bɑ - lɪː - ri - naː
# 606        vermoeide           vərmˈujdə                 vər - muj - də
# 607            extra            ˈɛkstraː                     ɛk - straː
# 608         reporter          rˈeːpɔrtər                reː - pɔr - tər
# 609         kansloos           kˈɑnsloːs                    kɑn - sloːs
# 610           vraagt             vrˈaːxt                         vraːxt
# 611        wachtende           ʋˈɑxtəndə                 ʋɑx - tən - də
# 612      beroemdheid         bərˈumdhɛɪt               bə - rum - dhɛɪt
# 613        wegstuurt          ʋˈɛxstˌyrt                    ʋɛx - styrt
# 614            woord              ʋˈɔːrt                          ʋɔːrt
# 615          zonnige             zˈɔnəɣə                   zɔ - nə - ɣə
# 616            staan              stˈaːn                          staːn
# 617            clown              klˈɔwn                          klɔwn
# 618           terras             tˈɛɾrɑs                      tɛɾ - rɑs
# 619             auto              ˈʌʊtoː                       ʌʊ - toː
# 620         passende            pˈɑsəndə                  pɑ - sən - də
# 621            wraak              vrˈaːk                          vraːk
# 622         trekhaak           trɛkhˈaːk                    trɛkh - aːk
# 623        propellor         prˈoːpɛlˌɔr                proː - pɛ - lɔr
# 624             rood               rˈoːt                           roːt
# 625       mechanicus        mɛxˈaːnikˌɵs            mɛx - aː - ni - kɵs
# 626          besteld            bəstˈɛlt                     bə - stɛlt
# 627          pukkels             pˈɵkəls                      pɵ - kəls
# 628              juf                jˈɵf                            jɵf
# 629        ontstoken         ɔntstˈoːkən               ɔnt - stoː - kən
# 630          gammele             ɣˈɑmələ                   ɣɑ - mə - lə
# 631             last               lˈɑst                           lɑst
# 632         verzorgt           vərzˈɔrxt                    vər - zɔrxt
# 633         berispte           bərˈɪsptə                 bə - rɪsp - tə
# 634         jongetje            jˈɔŋɛtʲə                  jɔŋ - ɛtʲ - ə
# 635         drukknop            drˈɵknɔp                     drɵk - nɔp
# 636       overvaller        ˌoːvərvˈɑlər            oː - vər - vɑ - lər
# 637         indrukte          ˈɪndrˌɵktə                 ɪn - drɵk - tə
# 638             stal               stˈɑl                           stɑl
# 639        verbaasde          vərbˈaːzdə                vər - baːz - də
# 640             alle                ˈɑlə                         ɑ - lə
# 641    kostbaarheden    kˈɔstbaːrhˌeːdən        kɔst - baːrh - eː - dən
# 642          belegde            bəlˈɛɣdə                  bə - lɛɣ - də
# 643         bolletje            bˈɔlɛtʲə                  bɔ - lɛtʲ - ə
# 644             vers               vˈɛrs                           vɛrs
# 645         margriet            mɑrɣrˈit                     mɑr - ɣrit
# 646         aanrecht           ˈaːnrˌɛxt                     aːn - rɛxt
# 647              dan                dˈɑn                            dɑn
# 648              zij                zˈɛɪ                         zɛ - ɪ
# 649         schreeuw              sxrˈeʊ                          sxreʊ
# 650          periode         pˌɪːriˈoːdə             pɪː - ri - oː - də
# 651         vakantie          vaːkˈɑntsi                vaː - kɑnt - si
# 652          barbaar            bˈɑrbaːr                     bɑr - baːr
# 653              zat                zˈɑt                            zɑt
# 654          groente             ɣrˈuntə                      ɣrun - tə
# 655          protest           prˈoːtɛst                    proː - tɛst
# 656           vroege              vrˈuɣə                       vru - ɣə
# 657        uitbracht          ˈœytbrˌɑxt                    œyt - brɑxt
# 658          collega           kɔlˈeːɣaː                 kɔ - leː - ɣaː
# 659           dienst              dˈinst                          dinst
# 660        ingedeeld         ˈɪnɣədˌeːlt                ɪn - ɣə - deːlt
# 661          plantje            plˈɑntʲə                     plɑntʲ - ə
# 662              hap                hˈɑp                            hɑp
# 663            nodig             nˈoːdəx                      noː - dəx
# 664          venster            vˈɛnstər                     vɛn - stər
# ...
# 1720   toneelbouwers     tˈoːneːlbˌʌʊərs         toː - neːl - bʌʊ - ərs
# 1721          zolder             zˈɔldər                      zɔl - dər
# 1722        tevreden          təvrˈeːdən                tə - vreː - dən
# 1723           decor             dˈeːkɔr                      deː - kɔr
# 1724         bewaard            bəʋˈaːrt                     bə - ʋaːrt
# 1725       zestiende           zˈɛstində                 zɛ - stin - də
# 1726         brommer             brˈɔmər                      brɔ - mər
# 1727         snelweg            snˈɛlʋɛx                     snɛl - ʋɛx
# 1728            helm               hˈɛlm                           hɛlm
# 1729            stil               stˈɪl                           stɪl
# 1730       brandstof          brˈɑndstɔf                   brɑnd - stɔf
# 1731            tank               tˈɑŋk                           tɑŋk
# 1732          hadden              hˈɑdən                       hɑ - dən
# 1733          moeite              mˈujtə                       muj - tə
# 1734          tentje             tˈɛntʲə                      tɛntʲ - ə
# 1735           storm              stˈɔrm                          stɔrm
# 1736        opzetten            ˈɔpzɛtən                  ɔp - zɛ - tən
# 1737           geven             ɣˈeːvən                      ɣeː - vən
# 1738         rustige            rˈɵstəɣə                  rɵ - stə - ɣə
# 1739             les                lˈɛs                            lɛs
# 1740          klopte             klˈɔptə                      klɔp - tə
# 1741           tabak             tˈaːbɑk                      taː - bɑk
# 1742            klas               klˈɑs                           klɑs
# 1743           asbak              ˈɑzbɑk                       ɑz - bɑk
# 1744      vakkundige          vɑkˈɵndəɣə             vɑ - kɵn - də - ɣə
# 1745            pijp               pˈɛɪp                        pɛ - ɪp
# 1746         wortels            ʋˈɔrtəls                     ʋɔr - təls
# 1747            kies                kˈis                            kis
# 1748           mocht               mˈɔxt                           mɔxt
# 1749       vliegreis           vlˈiɣrɛɪs                 vli - ɣrɛ - ɪs
# 1750         cockpit             kˈɔkpɪt                      kɔk - pɪt
# 1751          kijken             kˈɛɪkən                   kɛ - ɪ - kən
# 1752            nico              nˈikoː                       ni - koː
# 1753         mobiele            moːbˈilə                  moː - bi - lə
# 1754          iedere              ˈidərə                    i - də - rə
# 1755      overdracht        ˌoːvərdrˈɑxt               oː - vər - drɑxt
# 1756       donderdag         dˈɔndərdˌɑx                dɔn - dər - dɑx
# 1757          steeds             stˈeːts                         steːts
# 1758          bokser             bˈɔksər                      bɔk - sər
# 1759           lange               lˈɑŋə                        lɑŋ - ə
# 1760      ochtendmis         ˈɔxtəndmˌɪs                ɔx - tənd - mɪs
# 1761            woog               ʋˈoːx                           ʋoːx
# 1762        negentig          nˈeːɣəntəx                neː - ɣən - təx
# 1763          schoon              sxˈoːn                          sxoːn
# 1764            haak               hˈaːk                           haːk
# 1765            kilo              kˈiloː                       ki - loː
# 1766        beroving           bərˈoːvɪŋ                 bə - roː - vɪŋ
# 1767      vastgelegd        vˈɑstɣəlˌɛxt               vɑst - ɣə - lɛxt
# 1768           brute              brˈytə                       bry - tə
# 1769          camera          kˈaːmərˌaː                 kaː - mə - raː
# 1770          ingang             ˈɪnɣˌɑŋ                       ɪn - ɣɑŋ
# 1771           boven             bˈoːvən                      boː - vən
# 1772     stationshal       stˈaːʃɔnshˌɑl              staː - ʃɔnsh - ɑl
# 1773          midden              mˈɪdən                       mɪ - dən
# 1774          poster             pˈɔstər                      pɔ - stər
# 1775           winst              ʋˈɪnst                          ʋɪnst
# 1776           hangt               hˈɑŋt                           hɑŋt
# 1777       producten         prˈoːdɵktən               proː - dɵk - tən
# 1778        zilveren           zˈɪlvərən                 zɪl - və - rən
# 1779           lijst              lˈɛɪst                       lɛ - ɪst
# 1780         tribune            trˈibynə                  tri - by - nə
# 1781   basketballers      bˈɑskɛtbˌɑlərs          bɑ - skɛt - bɑ - lərs
# 1782        begeleid           bəɣəlˈɛɪt              bə - ɣə - lɛ - ɪt
# 1783           coach              kˈoːtʃ                          koːtʃ
# 1784          rechte              rˈɛxtə                       rɛx - tə
# 1785           vader             vˈaːdər                      vaː - dər
# 1786       avondeten       ˌaːvɔndˈeːtən           aː - vɔn - deː - tən
# 1787     waarzegster        ʋˈaːrzɛxstər              ʋaːr - zɛx - stər
# 1788          atleet             ɑtlˈeːt                      ɑt - leːt
# 1789     bijgelovige      bˈɛɪɣəlˌoːvəɣə    bɛ - ɪ - ɣə - loː - və - ɣə
# 1790     beschuldigd         bəsxˈɵldɪxt               bə - sxɵl - dɪxt
# 1791          glazen            ɣlˈaːzən                     ɣlaː - zən
# 1792             bol                bˈɔl                            bɔl
# 1793         gebruik            ɣəbrˈœyk                     ɣə - brœyk
# 1794          doping             dˈoːpɪŋ                      doː - pɪŋ
# 1795       duitsland          dˈœytslɑnt                   dœyt - slɑnt
# 1796            vlak               vlˈɑk                           vlɑk
# 1797           schat               sxˈɑt                           sxɑt
# 1798         gehaald            ɣəhˈaːlt                     ɣəh - aːlt
# 1799           dader             dˈaːdər                      daː - dər
# 1800        zeebodem         zˈeːbˌoːdəm                zeː - boː - dəm
# 1801         bewaart            bəʋˈaːrt                     bə - ʋaːrt
# 1802    goudvoorraad      ɣˌʌʊdvɔːɾrˈaːt             ɣʌʊd - vɔːɾ - raːt
# 1803           kluis              klˈœys                          klœys
# 1804           grond              ɣrˈɔnt                          ɣrɔnt
# 1805             eet                ˈeːt                            eːt
# 1806         meestal           mˈeːstˌɑl                     meː - stɑl
# 1807      aanleiding         ˈaːnlˌɛɪdɪŋ             aːn - lɛ - ɪ - dɪŋ
# 1808           gezin              ɣəzˈɪn                       ɣə - zɪn
# 1809         melding             mˈɛldɪŋ                      mɛl - dɪŋ
# 1810        anonieme         ˌaːnoːnˈimə             aː - noː - ni - mə
# 1811             tip                tˈɪp                            tɪp
# 1812       fanatieke        fˌaːnaːtˈikə            faː - naː - ti - kə
# 1813            bram               brˈɑm                           brɑm
# 1814         blunder            blˈɵndər                     blɵn - dər
# 1815          zakken              zˈɑkən                       zɑ - kən
# 1816    gistermiddag       ɣˈɪstərmˌɪdɑx           ɣɪ - stər - mɪ - dɑx
# 1817       berisping           bərˈɪspɪŋ                 bə - rɪ - spɪŋ
# 1818             ivo               ˈivoː                        i - voː
# 1819         slechte             slˈɛxtə                      slɛx - tə
# 1820            baas               bˈaːs                           baːs
# 1821             ria               rˈiaː                        ri - aː
# 1822          advies              ɑdvˈis                       ɑd - vis
# 1823       avonduren        ˌaːvɔndˈyrən            aː - vɔn - dy - rən
# 1824       tennissen            tˈɛnɪsən                  tɛ - nɪ - sən
# 1825          chique                ʃˈik                            ʃik
# 1826          zonnen              zˈɔnən                       zɔ - nən
# 1827            mooi               mˈoːj                           moːj
# 1828            goot               ɣˈoːt                           ɣoːt
# 1829        dineetje           dˈineːtʲə                 di - neːtʲ - ə
# 1830         kristal            krˈɪstɑl                     krɪ - stɑl
# 1831           karaf             kˈaːrɑf                      kaː - rɑf
# 1832          breken            brˈeːkən                     breː - kən
# 1833            inge                ˈɪŋə                         ɪŋ - ə
# 1834          berouw              bərˈʌʊ                       bə - rʌʊ
# 1835         toonden            tˈoːndən                     toːn - dən
# 1836            vaas               vˈaːs                           vaːs
# 1837         antieke             ɑntˈikə                   ɑn - ti - kə
# 1838         gewerkt            ɣəʋˈɛrkt                     ɣə - ʋɛrkt
# 1839          iemand              ˈimɑnt                       i - mɑnt
# 1840      voltallige          vɔltˈɑləɣə             vɔl - tɑ - lə - ɣə
# 1841       eindhoven         ɛɪndhˈoːvən            ɛ - ɪndh - oː - vən
# 1842            luuk                lˈyk                            lyk
# 1843       ontslagen         ɔntslˈaːɣən               ɔnt - slaː - ɣən
# 1844         startte             stˈɑrtə                      stɑr - tə
# 1845      voorzitter          vˈɔːrzɪtər                vɔːr - zɪ - tər
# 1846            wind               ʋˈɪnt                           ʋɪnt
# 1847          wegens            ʋˈeːɣəns                     ʋeː - ɣəns
# 1848           dorre              dˈɔɾrə                       dɔɾ - rə
# 1849        bladeren          blˈaːdərən                blaː - də - rən
# 1850       wangedrag         ʋˈɑŋɣədrˌɑx                ʋɑŋ - ɣə - drɑx
# 1851        arbeider           ˈɑrbɛɪdər              ɑr - bɛ - ɪ - dər
# 1852        afgerond          ˈɑfɣərˌɔnt                 ɑf - ɣə - rɔnt
# 1853      inspanning          ˈɪnspˌɑnɪŋ                 ɪn - spɑ - nɪŋ
# 1854          bellen              bˈɛlən                       bɛ - lən
# 1855            taxi              tˈɑksi                       tɑk - si
# 1856          afloop            ˈɑflˌoːp                      ɑ - floːp
# 1857           zoekt               zˈukt                           zukt
# 1858       arrogante        ˌɑɾroːɣˈɑntə            ɑɾ - roː - ɣɑn - tə
# 1859      werknemers       ʋˈɛrknˌeːmərs              ʋɛrk - neː - mərs
# 1860         contact            kˈɔntɑkt                     kɔn - tɑkt
# 1861           verre               vˈɛrə                        vɛ - rə
# 1862          reizen             rˈɛɪzən                   rɛ - ɪ - zən
# 1863       vliegende           vlˈiɣəndə                 vli - ɣən - də
# 1864        wellicht             ʋˈɛlɪxt                      ʋɛ - lɪxt
# 1865       toespraak          tˈusprˌaːk                    tu - spraːk
# 1866       toenemend         tˈunˌeːmənt                tu - neː - mənt
# 1867         schotel            sxˈoːtəl                     sxoː - təl
# 1868      commentaar          kɔmˈɛntaːr                kɔ - mɛn - taːr
# 1869      vandalisme        vɑndaːlˈɪsmə           vɑn - daː - lɪ - smə
# 1870         leveren           lˈeːvərən                 leː - və - rən
# 1871         spelend           spˈeːlənt                    speː - lənt
# 1872       studenten          stydˈɛntən                sty - dɛn - tən
# 1873          liepen              lˈipən                       li - pən
# 1874        trommels            trˈɔməls                     trɔ - məls
# 1875         vrolijk            vrˈoːlək                     vroː - lək
# 1876          school              sxˈoːl                          sxoːl
# 1877      vertrokken          vərtrˈɔkən                vər - trɔ - kən
# 1878          paarse             pˈaːrsə                      paːr - sə
# 1879           omdat              ˈɔmdɑt                       ɔm - dɑt
# 1880            zeer               zˈɪːr                           zɪːr
# 1881           pauze              pˈʌʊzə                       pʌʊ - zə
# 1882        soldaten          sɔldˈaːtən                sɔl - daː - tən
# 1883       onbeleefd          ɔnbəlˈeːft                ɔn - bə - leːft
# 1884          gebukt             ɣəbˈɵkt                      ɣə - bɵkt
# 1885          touwen              tˈʌʊən                       tʌʊ - ən
# 1886      scholieren          sxoːlˈirən                sxoː - li - rən
# 1887         kantine            kɑntˈinə                  kɑn - ti - nə
# 1888      schooljaar          sxˈoːljaːr                   sxoːl - jaːr
# 1889         logeren          loːʒˈɪːrən                loː - ʒɪː - rən
# 1890          dropje             drˈɔpjə                      drɔp - jə
# 1891            hand               hˈɑnt                           hɑnt
# 1892          zusjes             zˈɵsjəs                      zɵs - jəs
# 1893         lekkers             lˈɛkərs                      lɛ - kərs
# 1894     vrijstaande        vrˈɛɪstaːndə           vrɛ - ɪ - staːn - də
# 1895       boerderij          bˌurdərˈɛɪ              bur - də - rɛ - ɪ
# 1896      achtertuin         ˈɑxtərtˌœyn                ɑx - tər - tœyn
# 1897          royale          rˈoːiˌaːlə              roː - i - aː - lə
# 1898           wonen              ʋˈɔnən                       ʋɔ - nən
# 1899       kennissen            kˈɛnɪsən                  kɛ - nɪ - sən
# 1900        lekkages           lɛkˈaːʒəs                 lɛ - kaː - ʒəs
# 1901       schoonzus           sxˈoːnzɵs                    sxoːn - zɵs
# 1902     voornaamste        vˈɔːrnaːmstə              vɔːr - naːm - stə
# 1903      loodgieter          loːdɣˈitər                loːd - ɣi - tər
# 1904       verhelpen          vərhˈɛlpən                vərh - ɛl - pən
# 1905           vrome             vrˈoːmə                      vroː - mə
# 1906       onderzoek          ˈɔndərzˌuk                 ɔn - dər - zuk
# 1907             kun                kˈɵn                            kɵn
# 1908      publicatie       pˌɵblikˈaːtsi           pɵ - bli - kaːt - si
# 1909      raadplegen        raːdplˈeːɣən              raːd - pleː - ɣən
# 1910          jungle              jˈɵŋlə                       jɵŋ - lə
# 1911           groep               ɣrˈup                           ɣrup
# 1912            reis               rˈɛɪs                        rɛ - ɪs
# 1913         moeders             mˈudərs                      mu - dərs
# 1914           hotel             hoːtˈɛl                      hoː - tɛl
# 1915            apen              ˈaːpən                       aː - pən
# 1916           beest              bˈeːst                          beːst
# 1917            zaal               zˈaːl                           zaːl
# 1918          vieren              vˈirən                       vi - rən
# 1919       overstuur         ˌoːvərstˈyr                oː - vər - styr
# 1920        bereiken           bərˈɛɪkən              bə - rɛ - ɪ - kən
# 1921           tocht               tˈɔxt                           tɔxt
# 1922          bergen             bˈɛrɣən                      bɛr - ɣən
# 1923            mede              mˈeːdə                       meː - də
# 1924      wandelaars        ʋˈɑndəlˌaːrs               ʋɑn - də - laːrs
# 1925         camping             kˈɑmpɪŋ                      kɑm - pɪŋ
# 1926     uitstekende      ˈœytstˌeːkəndə          œyt - steː - kən - də
# 1927     organisatie     ˌɔrɣaːnizˈaːtsi      ɔr - ɣaː - ni - zaːt - si
# 1928         dankzij            dɑŋkzˈɛɪ                  dɑŋk - zɛ - ɪ
# 1929      arriveerde         ˌɑɾrivˈɪrdə             ɑɾ - ri - vɪr - də
# 1930     schreeuwden           sxrˈeʊdən                    sxreʊ - dən
# 1931        dictator          dɪktˈaːtɔr                dɪk - taː - tɔr
# 1932    elektronisch      ˌeːlɛktrˈoːnis          eː - lɛk - troː - nis
# 1933          leuzen             lˈøːzən                      løː - zən
# 1934         drogist           droːɣˈɪst                    droː - ɣɪst
# 1935         klanten            klˈɑntən                     klɑn - tən
# 1936           blije              blˈɛɪə                    blɛ - ɪ - ə
# 1937         betalen           bətˈaːlən                 bə - taː - lən
# 1938          intens             ˈɪntəns                      ɪn - təns
# 1939        jongeren            jˈɔŋərən                  jɔŋ - ə - rən
# 1940         plezier            pleːzˈir                     pleː - zir
# 1941      woonplaats        ʋˈoːnplˌaːts                  ʋoːn - plaːts

# %%
#MOUS_IPA_transcriptions.to_csv('/home/neel/Desktop/MOUS_hierarchical-representations/MOUS_IPA_transcriptions.csv', index = False)
MOUS_IPA_transcriptions = pd.read_csv('/home/neel/Desktop/MOUS_hierarchical-representations/MOUS_IPA_transcriptions.csv')

# %%
# Split each word's syllables into a list, handling non-string values
syllables_list = MOUS_IPA_transcriptions['Syllables'].apply(lambda x: x.split(' - ') if isinstance(x, str) else []).tolist()

# Flatten the list of lists
flattened_syllables = [syllable for sublist in syllables_list for syllable in sublist]

# Get unique syllables
unique_syllables = list(set(flattened_syllables))

print(unique_syllables)
# Out:
# ['kɔmt', 'jɵ', 'fɑns', 'raːs', 'trɔm', 'daːr', 'stɛlt', 'sproːk', 'kəl', 'ɣeː', 'bœyk', 'hɔ', 'ɑɾ', 'sfɔ', 'pri', 'keːs', 'klɑs', 'ɣut', 'vi', 'ni', 'hoː', 'nɔr', 'vɔː', 'ɣru', 'tə', 'rɛx', 'kəls', 'blʌʊ', 'hɵlp', 'ʋɔŋ', 'ɣɪŋ', 'proː', 'pu', 'naː', 'ʋɔ', 'mɪn', 'skɵ', 'bøː', 'nɪŋ', 'bɔs', 'zaːl', 'ʋɛrt', 'ʋɛr', 'jɔx', 'peːt', 'trɔk', 'lɑp', 'lɪːrt', 'bəsx', 'ʋix', 'neːn', 'dəl', 'lɔr', 'løːr', 'spaːr', 'sxɛrm', 'kɪd', 'lɛk', 'ɪst', 'dɔːr', 'dɪxt', 'kaːrt', 'lɪx', 'tɔp', 'koːh', 'zɛl', 'pɛn', 'dun', 'zən', 'vɔːɾ', 'dərs', 'droː', 'sɑn', 'floːp', 'føːr', 'dəx', 'səm', 'maːl', 'rin', 'lin', 'strɑn', 'kɛst', 'ʋɔːrt', 'haːlt', 'kɔːrts', 'vaː', 'ɑxt', 'ɪs(nl)', 'lɪst', 'bɔk', 'ɛtʲ', 'hɛf', 'stɑnt', 'lyk', 'baːn', 'ɛm', 'bɑŋ', 'taːl', 'hɑl', 'nɪk', 'slɑx', 'məls', 'blaː', 'bə', 'pleː', 'ɛx', 'naːk', 'ɣrɛ', 'zʋɛr', 'leːst', 'ɑk', 'brɔ', 'sɛs', 'pɛt', 'stoːr', 'stɔnt', 'ɣlɪ', 'bəh', 'psɪx', 'ɣud', 'flɛs', 'pɑ', 'sxaː', 'klœys', 'ɣɛnt', 'tɑn', 'aːr', 'putst', 'prɔ', 'nɛt', 'must', 'dɑrts', 'ɣʌʊd', 'treː', 'troː', 'spi', 'ɔr', 'tif', 'ɣʌʊ', 'bruk', 'spɔrth', 'pɔt', 'təx', 'trɑt', 'virt', 'lɪnk', 'kɔmst', 'ɛlf', 'sən', 'ɣəsx', 'styr', 'smɑn', 'lək', 'tɑrts', 'tri', 'brurtʲ', 'dʋɛrx', 'kɪ', 'poːtʲ', 'ɣɪn', 'oːm', 'hœyl', 'baːr', 'øː', 'tɔx', 'zɛt', 'ʋeːs', 'kir', 'hɔːr', 'køː', 'lɪxt', 'sy', 'stɛmt', 'rɪst', 'vrøːɣ', 'kən', 'krɵ', 'sin', 'tɑkt', 'vrʌʊtʲ', 'rɛn', 'ʒə', 'dɛf', 'ɑt', 'brœykt', 'brur', 'nənk', 'mɵ', 'spraːk', 'pɑrk', 'pə', 'ɔns', 'laːrs', 'lən', 'pɪtʲ', 'viwt', 'sis', 'dɪk', 'vəx', 'pvdaː', 'krɵk', 'strɑf', 'tʋeː', 'ɪŋ', 'dən', 'ɣaːt', 'rum', 'bɪː', 'lɛɣ', 'mən', 'zaː', 'rɔnt', 'doː', 'seːl', 'hir', 'lɪːr', 'ɣəh', 'leːft', 'kɔk', 'stɛ', 'rɛs', 'pənt', 'hɑnd', 'nɵs', 'ɣlip', 'prɪn', 'bɪ', 'kraː', 'leːt', 'vu', 'sfɛr', 'dri', 'ɪɾ', 'roːs', 'dɛs', 'ʋɑs', 'ɪntʲ', 'rɑh', 'kʌʊ', 'stɑr', 'mɛ', 'sxrɪ', 'strœy', 'frœyt', 'taːr', 'ɔn', 'ɛrx', 'dərt', 'maːr', 'nɑf', 'ɣɑŋ', 'loː', 'voː', 'bi', 'sxœyt', 'bɵkt', 'bɑk', 'ʋɑm', 'kɑmp', 'ɣoːx', 'loːv', 'vɛrs', 'fɛt', 'ɣaːj', 'sə', 'haːr', 'jœyx', 'dɛr', 'dɑm', 'zir', 'kni', 'bɔx', 'kraːt', 'bleːm', 'kuk', '(en)ɹ', 'ɣlɪpt', 'drɛ', 'təls', 'ʋɪt', 'pɑn', 'rɑ', 'jən', 'dul', 'bis', 'ɣraː', 'drɵk', 'dɛ', 'klɔwn', 'nɪxtʲ', 'zɪːr', 'zukt', 'ɪpt', 'ɑrt', 'dɔrp', 'dy', 'teː', 'zɔxt', 'tis', 'my', 'fən', 'dœyt', 'tɛn', 'ɣɪ', 'tɔs', 'ɑl', 'pli', 'broːt', 'rɑs', 'bɑnts', 'jaːr', 'vraː', 'ju', 'ɔːrt', 'ʃaː', 'kaːs', 'stɔrm', 'rɪn', 'toːm', 'mi', 'deːlt', 'draːjt', 'nɑxt', 'rə', 'rɪŋ', 'i', 'vurt', 'lit', 'slip', 'straːt', 'rɑf', 'zɑŋ', 'vɛ', 'vaːr', 'plɑ', 'ɣraːf', 'prœyk', 'zi', 'vleːs', 'nɪː', 'floːr', 'sloːs', 'dʋaː', 'sxɵl', 'stɔp', 'hɪːr', 'doːd', 'ʋeːft', 'smeːk', 'ɣɛ', 'zɵ', 'ru', 'oːk', 'veːɣ', 'trɛxt', 'ʒəs', 'vrɛ', 'dɔx', 'bɛr', 'koːtʃ', 'kɛp', 'zʋaː', 'hɑ', 'bli', 'naːl', 'kɑnt', 'bɛlt', 'ky', 'nits', 'sxɔlt', 'smɪː', 'nɑj', 'bɔ', 'beːst', 'ɛk', 'ɪx', 'ʋaːrt', 'reːn', 'ɣərs', 'zʋɑr', 'vaːrt', 'tʋɛ', 'tɛk', 'rʌʊ', 'ʋaːr', 'spoːr', 'zər', 'jøː', 'poːɣ', 'plux', 'ʃɑm', 'brɑm', 'trɔ', 'spreː', 'sxɔŋ', 'aːn', 'dɪ', 'drɔp', 'ɑmb', 'pis', 'ʃaːr', 'dɪɣ', 'poː', 'slaːv', 'kɛtʲ', 'zɑt', 'mɛrkt', 'bɵr', 'lɑx', 'skœytʲ', 'stɛnt', 'vlɑk', 'pɪŋ', 'vɔ', 'klɔp', 'fɪlm', 'ɣrɔnt', 'ɪs', 'zɛld', 'zɛlfs', 'ʋɛx', 'sprɪŋ', 'stɑɾ', 'hɪ', 'ɣaːn', 'eːns', 'stə', 'trœy', 'rən', 'lɑnt', 'blɛ', 'laːs', 'prɑx', 'drɵxs', 'duk', 'vrux', 'jəs', 'pɔ', 'vil', 'ʋɑx', 'mɔːr', 'speːlt', 'kaːt', 'dyr', 'ʋɔːr', 'mu', 'foː', 'ər', 'rəlt', 'rɪ', 'lərs', 'mər', 'fɑ', 'speːl', 'mɑnt', 'bur', 'lyw', 'frɔn', 'trɛkh', 'plɵk', 'mɑn', 'mɛn', 'hʌʊt', 'sxøːr', 'dɵl', 'vəl', 'drux', 'stɑn', 'zɑk', 'nɔx', 'rɪk', 'rɛxt', 'teːn', 'traː', 'zɔr', 'sɔɲ', 'nɪ', 'lɪp', 'tɑm', 'ɵlp', 'aːrt', 'ki', 'zoː', 'loːd', 'kist', 'strɛ', 'kɑr', 'ɔx', 'tøːr', 'drɵ', 'heːl', 'rɔl', 'kɛrn', 'trʌʊ', 'ən', 'zɔ', 'nʌʊ', 'lɛː', 'ɣoːj', 'sxoːn', 'lɵk', 'stry', 'ɣəlt', 'ʋoːn', 'ɑn', 'slux', 'sfɛ', 'mɔːrt', 'frœy', 'dɔr', 'ɣɛtʲ', 'its', 'tœyɣ', 'bleː', 'dɛn', 'klɑn', 'bɛ', 'hɛks', 'krɔ', 'zɔrɣ', 'ɪrt', 'mɑrkt', 'lip', 'leːs', 'rɵ', 'və', 'sɪɲ', 'dɪnz', 'vɪn', 'vɑst', 'tɪŋ', ...

# %%
subtlex
# Out:
#                 Word  FREQcount  CDcount  FREQlow  CDlow  FREQlemma  \
# 0                 ik    1744062     8054   778704   3125    1744527
# 1                 je    1600888     8060  1315051   6535    1600923
# 2                het    1068396     8066   780771   5578    1913811
# 3                 de    1061177     8070   903872   6512    1063827
# 4                dat     965424     8063   715570   6107     965431
# ...              ...        ...      ...      ...    ...        ...
# 437498       &_blake          1        1        1      1          1
# 437499      &_barbie          1        1        1      1          1
# 437500  &_bake_pizza          1        1        1      1          1
# 437501        &_bach          1        1        1      1          1
# 437502    &_atlantic          1        1        1      1          1
#
#          SUBTLEXWF      Zipf  SUBTLEXCD  Lg10CD dominant.pos  \
# 0       39883.0334  7.597064    99.8017  3.9061          VNW
# 1       36608.9449  7.559864    99.8761  3.9064          VNW
# 2       24431.9717  7.384235    99.9504  3.9067          VNW
# 3       24266.8883  7.381291   100.0000  3.9069          LID
# 4       22077.2184  7.340221    99.9133  3.9066          VNW
# ...            ...       ...        ...     ...          ...
# 437498      0.0229  1.656532     0.0124  0.3010         SPEC
# 437499      0.0229  1.656532     0.0124  0.3010         SPEC
# 437500      0.0229  1.656532     0.0124  0.3010         SPEC
# 437501      0.0229  1.656532     0.0124  0.3010         SPEC
# 437502      0.0229  1.656532     0.0124  0.3010         SPEC
#
#         dominant.pos.freq dominant.pos.lemma  dominant.pos.lemma.freq  \
# 0                 1743609                 ik                  1743944
# 1                 1600798                 je                  1600798
# 2                  735390                het                   735395
# 3                 1060098                 de                  1062748
# 4                  532576                dat                   532576
# ...                   ...                ...                      ...
# 437498                  1            &_blake                        1
# 437499                  1           &_barbie                        1
# 437500                  1       &_bake_pizza                        1
# 437501                  1             &_bach                        1
# 437502                  1         &_atlantic                        1
#
#                     all.pos             all.pos.freq  \
# 0           .VNW.SPEC.N.VZ.        .1743609.448.4.1.
# 1       .VNW.SPEC.N.BW.LID.      .1600798.72.15.2.1.
# 2       .VNW.LID.SPEC.WW.N.  .735390.332929.53.22.2.
# 3         .LID.VNW.SPEC.VZ.      .1060098.806.272.1.
# 4        .VNW.VG.SPEC.N.WW.   .532576.432794.51.2.1.
# ...                     ...                      ...
# 437498               .SPEC.                      .1.
# 437499               .SPEC.                      .1.
# 437500               .SPEC.                      .1.
# 437501               .SPEC.                      .1.
# 437502               .SPEC.                      .1.
#
#                   all.pos.lemma.freq
# 0                .1743944.448.134.1.
# 1                .1600798.72.50.2.1.
# 2       .735395.332929.53.845403.31.
# 3                .1062748.806.272.1.
# 4             .532576.432794.51.9.1.
# ...                              ...
# 437498                           .1.
# 437499                           .1.
# 437500                           .1.
# 437501                           .1.
# 437502                           .1.
#
# [437503 rows x 17 columns]

# %%
# #Pre-cleaning of the subtlex dataframe
# # # Assume subtlex is a DataFrame with a 'Word' column that may contain floats/NaNs
# # Convert all items in the 'Word' column to strings, filtering out NaN values
# subtlex['Word'] = subtlex['Word'].astype(str)
# # remove all entrys with numbers or special characters
# # subtlex = subtlex[~subtlex['Word'].str.contains(r'[0-9]')]
# # subtlex = subtlex[~subtlex['Word'].str.contains(r'[^a-zA-Z]')]
# #report how many were removed

# # Initial number of rows
# initial_count = len(subtlex)

# # Remove rows containing numbers
# subtlex = subtlex[~subtlex['Word'].str.contains(r'[0-9]')]

# # Remove rows containing non-alphabetic characters
# subtlex = subtlex[~subtlex['Word'].str.contains(r'[^a-zA-Z]')]

# # Final number of rows
# final_count = len(subtlex)

# # Number of rows removed
# removed_count = initial_count - final_count

# print(f"Number of rows removed: {removed_count}")

# # Replace 'nan' strings with an empty string or some default word like "unknown"
# subtlex['Word'].replace('nan', '', inplace=True)  # This will remove NaN-like strings

# subtlex
# Out:
# Number of rows removed: 166276
#                 Word  FREQcount  CDcount  FREQlow  CDlow  FREQlemma  \
# 0                 ik    1744062     8054   778704   3125    1744527
# 1                 je    1600888     8060  1315051   6535    1600923
# 2                het    1068396     8066   780771   5578    1913811
# 3                 de    1061177     8070   903872   6512    1063827
# 4                dat     965424     8063   715570   6107     965431
# ...              ...        ...      ...      ...    ...        ...
# 432113  aaaaaaaaaaaa          1        1        0      0          1
# 432114   aaaaaaaaaaa          1        1        0      0          1
# 432115       aaaaaaa          1        1        0      0          1
# 432116         aaaaa          1        1        0      0          1
# 432117          aaaa          1        1        0      0          1
#
#          SUBTLEXWF      Zipf  SUBTLEXCD  Lg10CD dominant.pos  \
# 0       39883.0334  7.597064    99.8017  3.9061          VNW
# 1       36608.9449  7.559864    99.8761  3.9064          VNW
# 2       24431.9717  7.384235    99.9504  3.9067          VNW
# 3       24266.8883  7.381291   100.0000  3.9069          LID
# 4       22077.2184  7.340221    99.9133  3.9066          VNW
# ...            ...       ...        ...     ...          ...
# 432113      0.0229  1.656532     0.0124  0.3010            N
# 432114      0.0229  1.656532     0.0124  0.3010         SPEC
# 432115      0.0229  1.656532     0.0124  0.3010            N
# 432116      0.0229  1.656532     0.0124  0.3010            N
# 432117      0.0229  1.656532     0.0124  0.3010            N
#
#         dominant.pos.freq dominant.pos.lemma  dominant.pos.lemma.freq  \
# 0                 1743609                 ik                  1743944
# 1                 1600798                 je                  1600798
# 2                  735390                het                   735395
# 3                 1060098                 de                  1062748
# 4                  532576                dat                   532576
# ...                   ...                ...                      ...
# 432113                  1       aaaaaaaaaaaa                        1
# 432114                  1        aaaaaaaaaaa                        1
# 432115                  1            aaaaaaa                        1
# 432116                  1              aaaaa                        1
# 432117                  1               aaaa                        1
#
#                     all.pos             all.pos.freq  \
# 0           .VNW.SPEC.N.VZ.        .1743609.448.4.1.
# 1       .VNW.SPEC.N.BW.LID.      .1600798.72.15.2.1.
# 2       .VNW.LID.SPEC.WW.N.  .735390.332929.53.22.2.
# 3         .LID.VNW.SPEC.VZ.      .1060098.806.272.1.
# 4        .VNW.VG.SPEC.N.WW.   .532576.432794.51.2.1.
# ...                     ...                      ...
# 432113                  .N.                      .1.
# 432114               .SPEC.                      .1.
# 432115                  .N.                      .1.
# 432116                  .N.                      .1.
# 432117                  .N.                      .1.
#
#                   all.pos.lemma.freq
# 0                .1743944.448.134.1.
# 1                .1600798.72.50.2.1.
# 2       .735395.332929.53.845403.31.
# 3                .1062748.806.272.1.
# 4             .532576.432794.51.9.1.
# ...                              ...
# 432113                           .1.
# 432114                           .1.
# 432115                           .1.
# 432116                           .1.
# 432117                           .1.
#
# [271227 rows x 17 columns]

# %% [markdown]
# SUBTLEX Lexical database cleaning

# %%
import re
# Load the dataset
df = subtlex

# Ensure 'Word' is a string and handle NaN values
df['Word'] = df['Word'].astype(str).fillna('').str.strip()

# Initialize the 'Status' column to 'keep' by default
df['Status'] = 'keep'

# Ensure 'CDcount' and 'FREQcount' are numeric
df['CDcount'] = pd.to_numeric(df['CDcount'], errors='coerce')
df['FREQcount'] = pd.to_numeric(df['FREQcount'], errors='coerce')

# Remove hyphens for the length check
df['Word_no_hyphen'] = df['Word'].str.replace('-', '', regex=False)

# Filter 1: Valid word pattern
valid_word_pattern = r"^[A-Za-zÀ-ÿ]+('s)?$"
mask_valid_words = df['Word'].str.match(valid_word_pattern, na=False)

# Filter 2: Word length threshold
max_word_length = 25
mask_length = df['Word_no_hyphen'].str.len() <= max_word_length

# Filter 3: Exclude entries that are solely punctuation
mask_punctuation = ~df['Word'].str.match(r'^[^\w\s]+$', na=False)

# Filter 4: Handle 'SPEC' POS
mask_spec = df['dominant.pos'] == 'SPEC'
mask_spec_alphabetic = df['Word'].str.replace('-', '', regex=False).str.isalpha()
mask_spec_keep = ~(mask_spec & ~mask_spec_alphabetic)

# Additional Filter 1: Exclude words starting with a single letter and apostrophe
mask_no_single_letter_apostrophe = ~df['Word'].str.match(r"^[A-Za-zÀ-ÿ]'[A-Za-zÀ-ÿ]+", na=False)

# Additional Filter 2: Exclude words composed of repeated characters
def is_repeated_char(word):
    return len(set(word.lower())) == 1
mask_no_repeated_chars = ~df['Word'].apply(is_repeated_char)

# **Corrected Filter**: Flag words containing triple letters
# Use flags=re.IGNORECASE in str.contains
triple_letter_pattern = r'([a-zA-ZÀ-ÿ])\1\1'
mask_triple_letters = ~df['Word'].str.contains(triple_letter_pattern, flags=re.IGNORECASE, na=False)

# Combine all masks
mask_keep = (
    mask_valid_words & mask_length & mask_punctuation &
    mask_spec_keep & mask_no_single_letter_apostrophe &
    mask_no_repeated_chars & mask_triple_letters
)

# Update the 'Status' column
df.loc[~mask_keep, 'Status'] = 'drop'

# Remove temporary columns
df.drop(['Word_no_hyphen'], axis=1, inplace=True)

# Display counts of 'keep' and 'drop' entries
print(df['Status'].value_counts())

# Display the words marked as 'drop'
dropped_words = df[df['Status'] == 'drop']
print("\nWords to Drop:")
print(dropped_words[['Word', 'Status']].head())

# Display a sample of the DataFrame
print("\nSample of the DataFrame:")
print(df.head())
# Out:
# /tmp/ipykernel_1984360/51974547.py:45: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask_triple_letters = ~df['Word'].str.contains(triple_letter_pattern, flags=re.IGNORECASE, na=False)
# Status
# keep    278061
# drop    159442
# Name: count, dtype: int64
#
# Words to Drop:
#     Word Status
# 26     u   drop
# 56    't   drop
# 77   m'n   drop
# 79    'n   drop
# 124  z'n   drop
#
# Sample of the DataFrame:
#   Word  FREQcount  CDcount  FREQlow  CDlow  FREQlemma   SUBTLEXWF      Zipf  \
# 0   ik    1744062     8054   778704   3125    1744527  39883.0334  7.597064
# 1   je    1600888     8060  1315051   6535    1600923  36608.9449  7.559864
# 2  het    1068396     8066   780771   5578    1913811  24431.9717  7.384235
# 3   de    1061177     8070   903872   6512    1063827  24266.8883  7.381291
# 4  dat     965424     8063   715570   6107     965431  22077.2184  7.340221
#
#    SUBTLEXCD  Lg10CD dominant.pos  dominant.pos.freq dominant.pos.lemma  \
# 0    99.8017  3.9061          VNW            1743609                 ik
# 1    99.8761  3.9064          VNW            1600798                 je
# 2    99.9504  3.9067          VNW             735390                het
# 3   100.0000  3.9069          LID            1060098                 de
# 4    99.9133  3.9066          VNW             532576                dat
#
#    dominant.pos.lemma.freq              all.pos             all.pos.freq  \
# 0                  1743944      .VNW.SPEC.N.VZ.        .1743609.448.4.1.
# 1                  1600798  .VNW.SPEC.N.BW.LID.      .1600798.72.15.2.1.
# 2                   735395  .VNW.LID.SPEC.WW.N.  .735390.332929.53.22.2.
# 3                  1062748    .LID.VNW.SPEC.VZ.      .1060098.806.272.1.
# 4                   532576   .VNW.VG.SPEC.N.WW.   .532576.432794.51.2.1.
#
#              all.pos.lemma.freq Status
# 0           .1743944.448.134.1.   keep
# 1           .1600798.72.50.2.1.   keep
# 2  .735395.332929.53.845403.31.   keep
# 3           .1062748.806.272.1.   keep
# 4        .532576.432794.51.9.1.   keep

# %%
# ------------------
# 1) Data Loading
# ------------------

# Example: we assume your final dataframe is already in 'df' after reading subtlex.
# If you already have 'df' prepared, skip the loading step and proceed to the filter masks.

# df = pd.read_csv('subtlex-nl.csv', delimiter='\t', encoding='utf-8')
# or
# df = subtlex  # if it's already in a variable named 'subtlex'

# ------------------
# 2) Prepare Data
# ------------------

# Convert 'Word' to string, handle NaN, strip whitespace
df['Word'] = df['Word'].astype(str).fillna('').str.strip()

# Ensure numeric columns
df['CDcount'] = pd.to_numeric(df['CDcount'], errors='coerce')
df['FREQcount'] = pd.to_numeric(df['FREQcount'], errors='coerce')

# Temporary column for length check (remove hyphens)
df['Word_no_hyphen'] = df['Word'].str.replace('-', '', regex=False)

# ------------------
# 3) Define Masks for Each Criterion
# ------------------

# Criterion 1: Valid word pattern
#   Matches words composed of Dutch letters (including diacritics), 
#   optionally ending in "'s".
valid_word_pattern = r"^[A-Za-zÀ-ÿ]+('s)?$"
mask_valid_words = df['Word'].str.match(valid_word_pattern, na=False)

# Criterion 2: Word length threshold
max_word_length = 25
mask_length = df['Word_no_hyphen'].str.len() <= max_word_length

# Criterion 3: Exclude entries that are solely punctuation
mask_punctuation = ~df['Word'].str.match(r'^[^\w\s]+$', na=False)

# Criterion 4: Handle 'SPEC' POS
#   Keep 'SPEC' words only if they're alphabetic (after removing hyphens).
mask_spec = df['dominant.pos'] == 'SPEC'
mask_spec_alphabetic = df['Word'].str.replace('-', '', regex=False).str.isalpha()
mask_spec_keep = ~(mask_spec & ~mask_spec_alphabetic)

# Criterion 5: Exclude words starting with a single letter and apostrophe
pattern_single_letter_apostrophe = r"^[A-Za-zÀ-ÿ]'[A-Za-zÀ-ÿ]+"
mask_no_single_letter_apostrophe = ~df['Word'].str.match(pattern_single_letter_apostrophe, na=False)

# Criterion 6: Exclude words composed entirely of repeated characters
def is_repeated_char(word):
    return len(set(word.lower())) == 1
mask_no_repeated_chars = ~df['Word'].apply(is_repeated_char)

# Criterion 7: Exclude words containing triple consecutive letters
triple_letter_pattern = r'([a-zA-ZÀ-ÿ])\1\1'
mask_triple_letters = ~df['Word'].str.contains(triple_letter_pattern, flags=re.IGNORECASE, na=False)

# ------------------
# 4) Count Failures for Each Criterion Separately
# ------------------

fail_valid_words = ~mask_valid_words
fail_length = ~mask_length
fail_punctuation = ~mask_punctuation
fail_spec = ~mask_spec_keep
fail_single_letter_apostrophe = ~mask_no_single_letter_apostrophe
fail_repeated_chars = ~mask_no_repeated_chars
fail_triple_letters = ~mask_triple_letters

print("Number of entries failing each criterion (independently):\n")
print(f"1) Invalid word pattern          : {fail_valid_words.sum()}")
print(f"2) Exceeding length threshold    : {fail_length.sum()}")
print(f"3) Solely punctuation            : {fail_punctuation.sum()}")
print(f"4) SPEC with non-alphabetic chars: {fail_spec.sum()}")
print(f"5) Single-letter + apostrophe    : {fail_single_letter_apostrophe.sum()}")
print(f"6) Entirely repeated characters  : {fail_repeated_chars.sum()}")
print(f"7) Triple consecutive letters    : {fail_triple_letters.sum()}")


# ------------------
# 5) (Optional) Combine All Masks for Final Keep/Drop
# ------------------

mask_keep = (
    mask_valid_words & mask_length & mask_punctuation & 
    mask_spec_keep & mask_no_single_letter_apostrophe &
    mask_no_repeated_chars & mask_triple_letters
)

df.loc[~mask_keep, 'Status'] = 'drop'
df.loc[mask_keep, 'Status'] = 'keep'

# Clean up the temporary column
df.drop(['Word_no_hyphen'], axis=1, inplace=True)

print("\n--- Final status counts ---")
print(df['Status'].value_counts())
# Out:
# /tmp/ipykernel_1984360/166648240.py:60: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask_triple_letters = ~df['Word'].str.contains(triple_letter_pattern, flags=re.IGNORECASE, na=False)
# Number of entries failing each criterion (independently):
#
# 1) Invalid word pattern          : 153807
# 2) Exceeding length threshold    : 3055
# 3) Solely punctuation            : 37
# 4) SPEC with non-alphabetic chars: 106539
# 5) Single-letter + apostrophe    : 506
# 6) Entirely repeated characters  : 173
# 7) Triple consecutive letters    : 953
#
# --- Final status counts ---
# Status
# keep    278061
# drop    159442
# Name: count, dtype: int64

# %%
#if 'Status' in df is 'drop', drop the row
df = df[df['Status'] != 'drop']
df.reset_index(drop = True, inplace = True)
df
# Out:
#             Word  FREQcount  CDcount  FREQlow  CDlow  FREQlemma   SUBTLEXWF  \
# 0             ik    1744062     8054   778704   3125    1744527  39883.0334
# 1             je    1600888     8060  1315051   6535    1600923  36608.9449
# 2            het    1068396     8066   780771   5578    1913811  24431.9717
# 3             de    1061177     8070   903872   6512    1063827  24266.8883
# 4            dat     965424     8063   715570   6107     965431  22077.2184
# ...          ...        ...      ...      ...    ...        ...         ...
# 278056    aagghh          1        1        0      0          1      0.0229
# 278057  aagezien          1        1        1      1          1      0.0229
# 278058       aaf          1        1        0      0          1      0.0229
# 278059    aada's          1        1        0      0          1      0.0229
# 278060  aachener          1        1        0      0          1      0.0229
#
#             Zipf  SUBTLEXCD  Lg10CD dominant.pos  dominant.pos.freq  \
# 0       7.597064    99.8017  3.9061          VNW            1743609
# 1       7.559864    99.8761  3.9064          VNW            1600798
# 2       7.384235    99.9504  3.9067          VNW             735390
# 3       7.381291   100.0000  3.9069          LID            1060098
# 4       7.340221    99.9133  3.9066          VNW             532576
# ...          ...        ...     ...          ...                ...
# 278056  1.656532     0.0124  0.3010            N                  1
# 278057  1.656532     0.0124  0.3010           WW                  1
# 278058  1.656532     0.0124  0.3010         SPEC                  1
# 278059  1.656532     0.0124  0.3010            N                  1
# 278060  1.656532     0.0124  0.3010         SPEC                  1
#
#        dominant.pos.lemma  dominant.pos.lemma.freq              all.pos  \
# 0                      ik                  1743944      .VNW.SPEC.N.VZ.
# 1                      je                  1600798  .VNW.SPEC.N.BW.LID.
# 2                     het                   735395  .VNW.LID.SPEC.WW.N.
# 3                      de                  1062748    .LID.VNW.SPEC.VZ.
# 4                     dat                   532576   .VNW.VG.SPEC.N.WW.
# ...                   ...                      ...                  ...
# 278056             aagghh                        1                  .N.
# 278057             aazien                        1                 .WW.
# 278058                aaf                        1               .SPEC.
# 278059               aada                        1                  .N.
# 278060           aachener                        1               .SPEC.
#
#                    all.pos.freq            all.pos.lemma.freq Status
# 0             .1743609.448.4.1.           .1743944.448.134.1.   keep
# 1           .1600798.72.15.2.1.           .1600798.72.50.2.1.   keep
# 2       .735390.332929.53.22.2.  .735395.332929.53.845403.31.   keep
# 3           .1060098.806.272.1.           .1062748.806.272.1.   keep
# 4        .532576.432794.51.2.1.        .532576.432794.51.9.1.   keep
# ...                         ...                           ...    ...
# 278056                      .1.                           .1.   keep
# 278057                      .1.                           .1.   keep
# 278058                      .1.                           .1.   keep
# 278059                      .1.                           .1.   keep
# 278060                      .1.                           .1.   keep
#
# [278061 rows x 18 columns]

# %%
df.to_excel('/home/neel/Desktop/MOUS_hierarchical-representations/subtlex_v2_cleaned_no_drop3.xlsx', index = False)

# %%
from eSpeakNG_IPA import get_phonetic_transcriptions_parallel
# Now, run the main function with a list of words
df['IPA'] = get_phonetic_transcriptions_parallel(list(df['Word']),max_workers=8)



df['Syllables'] = df['IPA'].apply(lambda x: syllabify_ipa(x))
#df.drop(columns = ['CDcount', 'FREQlow', 'CDlow','FREQlemma'], inplace = True)
#save the dataframe to a csv file
df.to_csv('/home/neel/Desktop/MOUS_hierarchical-representations/subtlex_v2_IPA_syllables_heid.csv', index = False)
df = pd.read_csv('/home/neel/Desktop/MOUS_hierarchical-representations/subtlex_v2_IPA_syllables.csv')
