# %%
import nibabel as nib
import numpy as np
from scipy.ndimage import label
import os
import csv
from pathlib import Path

# %%
def separate_clusters(tmap_path, output_dir, threshold, extent_threshold=20):
    """
    Separates non-contiguous clusters in a T-map into individual NIfTI masks,
    applying a voxel count threshold (extent threshold).

    Parameters:
        tmap_path (str): Path to the input T-map NIfTI file.
        output_dir (str): Directory to save the output NIfTI masks.
        threshold (float): Threshold value to apply to the T-map.
        extent_threshold (int): Minimum number of voxels for a cluster to be retained.

    Returns:
        tuple: (list of cluster paths, affine transformation matrix)
    """
    # Load the T-map
    tmap_img = nib.load(tmap_path)
    tmap_data = tmap_img.get_fdata()

    # Apply threshold
    thresholded_data = tmap_data > threshold

    # Label clusters
    labeled_data, num_clusters = label(thresholded_data)
    print(f"Found {num_clusters} clusters (before extent threshold).")

    # Ensure output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Save each cluster that meets the extent threshold
    cluster_paths = []
    retained_clusters = 0
    for cluster_id in range(1, num_clusters + 1):
        cluster_mask = (labeled_data == cluster_id).astype(np.int16)
        # Count the number of voxels in the cluster
        voxel_count = np.sum(cluster_mask)

        # Skip clusters that do not meet the extent threshold
        if voxel_count < extent_threshold:
            continue

        # Save the cluster mask
        cluster_img = nib.Nifti1Image(cluster_mask, affine=tmap_img.affine, header=tmap_img.header)
        output_path = os.path.join(output_dir, f"cluster_{retained_clusters + 1}.nii")
        nib.save(cluster_img, output_path)
        cluster_paths.append(output_path)
        retained_clusters += 1
        print(f"Saved cluster {retained_clusters} with {voxel_count} voxels to {output_path}")

    print(f"Retained {retained_clusters} clusters (after extent threshold).")

    # Return cluster paths and the affine matrix
    return cluster_paths, tmap_img.affine

# %%
def calculate_centroids_and_peaks(cluster_paths, tmap_path):
    """
    Calculates the centroid and peak coordinates of each cluster.

    Parameters:
        cluster_paths (list): List of paths to cluster NIfTI masks.
        tmap_path (str): Path to the original T-map NIfTI file.

    Returns:
        list: A list of dictionaries for each cluster containing centroid and peak coordinates.
    """
    # Load the T-map
    tmap_img = nib.load(tmap_path)
    tmap_data = tmap_img.get_fdata()

    results = []
    for cluster_path in cluster_paths:
        # Load the cluster mask
        cluster_img = nib.load(cluster_path)
        cluster_data = cluster_img.get_fdata()

        # Mask the T-map with the cluster mask
        weighted_data = cluster_data * tmap_data

        # Find voxel coordinates
        coords = np.array(np.nonzero(cluster_data))
        weights = weighted_data[cluster_data > 0]

        # Calculate the weighted centroid
        if weights.sum() > 0:
            centroid = np.average(coords, axis=1, weights=weights)
            # Transform centroid to world coordinates
            centroid_world = nib.affines.apply_affine(tmap_img.affine, centroid)
        else:
            centroid_world = (np.nan, np.nan, np.nan)  # In case of no weights

        # Find the peak coordinate (voxel with the highest T-statistic)
        peak_voxel_index = np.unravel_index(np.argmax(weighted_data, axis=None), cluster_data.shape)
        peak_world = nib.affines.apply_affine(tmap_img.affine, peak_voxel_index)

        # Store results
        results.append({
            "centroid": tuple(centroid_world),
            "peak": tuple(peak_world)
        })
    
    return results

# Updated to include peak T value

# %%
import csv
import os
import numpy as np
import nibabel as nib
from pathlib import Path

def save_centroid_table_and_masks(tmap, roi_output_dir, u_threshold_path, save_path):
    """
    Separates clusters, sorts them by peak T-value, renames the files, and saves a summary CSV.
    """
    
    # 1. Read Threshold
    with open(u_threshold_path, 'r') as f:
        u_threshold = float(f.read().strip())
    
    print(f"Processing T-map: {tmap}")
    print(f"Using threshold: {u_threshold}")
    
    # 2. Separate Clusters (Save initial masks)
    # Ensure roi_output_dir exists
    Path(roi_output_dir).mkdir(parents=True, exist_ok=True)
    
    cluster_paths, affine = separate_clusters(str(tmap), str(roi_output_dir), threshold=u_threshold, extent_threshold=20)
    results = calculate_centroids_and_peaks(cluster_paths, str(tmap))
    
    # 3. Calculate Stats for Sorting
    tmap_img = nib.load(tmap)
    tmap_data = tmap_img.get_fdata()
    
    for i, (cluster_path, result) in enumerate(zip(cluster_paths, results)):
        result["original_path"] = cluster_path
        
        # Get Peak T-value
        peak_voxel = np.round(nib.affines.apply_affine(np.linalg.inv(tmap_img.affine), result["peak"])).astype(int)
        if (0 <= peak_voxel[0] < tmap_data.shape[0] and
            0 <= peak_voxel[1] < tmap_data.shape[1] and
            0 <= peak_voxel[2] < tmap_data.shape[2]):
            result["peak_t_value"] = tmap_data[tuple(peak_voxel)]
        else:
            result["peak_t_value"] = float('nan')
        
        # Get Extent
        cluster_img = nib.load(cluster_path)
        cluster_data = cluster_img.get_fdata()
        result["extent"] = int(np.sum(cluster_data > 0))

    # 4. Sort and Rename
    sorted_results = sorted(results, key=lambda x: x['peak_t_value'], reverse=True)
    
    print("Renaming files to match sorted order...")
    for i, result in enumerate(sorted_results, start=1):
        result['Cluster #'] = i
        
        # Rename logic
        old_path = Path(result["original_path"])
        new_name = f"cluster_{i}_sorted.nii"
        new_path = old_path.parent / new_name
        
        if old_path.exists():
            os.rename(old_path, new_path)
            result["new_path"] = str(new_path)
            # Update the dictionary so we know the new filename
            result["file_name"] = new_name 

    # 5. Save CSV
    with open(save_path, 'w', newline='') as csvfile:
        fieldnames = ['Cluster #', 'Centroid', 'Peak', 'Peak T-value', 'Extent', 'File Name']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        
        for result in sorted_results:
            writer.writerow({
                'Cluster #': result['Cluster #'],
                'Centroid': [round(c) for c in result['centroid']],
                'Peak': [round(c) for c in result['peak']],
                'Peak T-value': round(result['peak_t_value'], 2),
                'Extent': result['extent'],
                'File Name': result.get('file_name', 'N/A')
            })
            
    # FIXED LINE: Use the T-map parent folder instead of 'second_level'
    print(f"Processing completed for {Path(tmap).parent}\n")

# %%
results_dir = Path('/home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results')

for modality in results_dir.iterdir():
    # FIXED LINE: Skip if 'modality' is actually a file (like .m scripts)
    if not modality.is_dir(): 
        continue

    for subfolder in modality.iterdir():
        if subfolder.is_dir() and subfolder.name.startswith('SPM'):
            
            # Define inputs
            u_threshold_path = str(subfolder / 'u_threshold.txt')
            tmap = str(subfolder / 'spmT_0001.nii')
            roi_out_path = subfolder / 'roi2'
            
            # Define output CSV path
            save_path = str(roi_out_path / 'cluster_centroids_sorted.csv')
            roi_output_dir = str(roi_out_path)
            
            try:
                # Check for inputs before running
                if Path(u_threshold_path).exists() and Path(tmap).exists():
                    save_centroid_table_and_masks(
                        tmap=tmap, 
                        roi_output_dir=roi_output_dir,
                        u_threshold_path=u_threshold_path,
                        save_path=save_path
                    )
            except Exception as e:
                print(f"Error in {subfolder.name}: {e}")
# Out:
# Processing T-map: /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/spmT_0001.nii
# Using threshold: 5.39
# Found 30 clusters (before extent threshold).
# Saved cluster 1 with 848 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_1.nii
# Saved cluster 2 with 373 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_2.nii
# Saved cluster 3 with 72 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_3.nii
# Saved cluster 4 with 1333 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_4.nii
# Saved cluster 5 with 2226 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_5.nii
# Saved cluster 6 with 107 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_6.nii
# Saved cluster 7 with 23 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_7.nii
# Saved cluster 8 with 29 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_8.nii
# Saved cluster 9 with 49 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_9.nii
# Saved cluster 10 with 167 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II/roi2/cluster_10.nii
# Retained 10 clusters (after extent threshold).
# Renaming files to match sorted order...
# Processing completed for /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/combined models/SPM_auditory_dur0_syll0_WF1_II
#
# Processing T-map: /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II/spmT_0001.nii
# Using threshold: 7.41
# Found 7 clusters (before extent threshold).
# Saved cluster 1 with 195 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II/roi2/cluster_1.nii
# Saved cluster 2 with 188 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II/roi2/cluster_2.nii
# Saved cluster 3 with 97 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II/roi2/cluster_3.nii
# Saved cluster 4 with 424 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II/roi2/cluster_4.nii
# Saved cluster 5 with 66 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II/roi2/cluster_5.nii
# Retained 5 clusters (after extent threshold).
# Renaming files to match sorted order...
# Processing completed for /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/BIGRAMS/SPM-V_Lg10_plus1_BG_august_II
#
# Processing T-map: /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/spmT_0001.nii
# Using threshold: 7.8933
# Found 14 clusters (before extent threshold).
# Saved cluster 1 with 745 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_1.nii
# Saved cluster 2 with 317 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_2.nii
# Saved cluster 3 with 127 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_3.nii
# Saved cluster 4 with 750 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_4.nii
# Saved cluster 5 with 26 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_5.nii
# Saved cluster 6 with 37 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_6.nii
# Saved cluster 7 with 86 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II/roi2/cluster_7.nii
# Retained 7 clusters (after extent threshold).
# Renaming files to match sorted order...
# Processing completed for /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/AUDITORY/SPM-A_II
#
# Processing T-map: /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/SYLLABLES/SPM_syllables_guslatho_Log10/spmT_0001.nii
# Using threshold: 7.89
# Found 2 clusters (before extent threshold).
# Saved cluster 1 with 870 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/SYLLABLES/SPM_syllables_guslatho_Log10/roi2/cluster_1.nii
# Saved cluster 2 with 618 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/SYLLABLES/SPM_syllables_guslatho_Log10/roi2/cluster_2.nii
# Retained 2 clusters (after extent threshold).
# Renaming files to match sorted order...
# Processing completed for /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/SYLLABLES/SPM_syllables_guslatho_Log10
#
# Processing T-map: /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II/spmT_0001.nii
# Using threshold: 7.41
# Found 8 clusters (before extent threshold).
# Saved cluster 1 with 278 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II/roi2/cluster_1.nii
# Saved cluster 2 with 94 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II/roi2/cluster_2.nii
# Saved cluster 3 with 761 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II/roi2/cluster_3.nii
# Saved cluster 4 with 444 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II/roi2/cluster_4.nii
# Saved cluster 5 with 21 voxels to /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II/roi2/cluster_5.nii
# Retained 5 clusters (after extent threshold).
# Renaming files to match sorted order...
# Processing completed for /home/lillianchang/Documents/MOUS_hierarchical-representations/SPM_Aug_2025_results/VISUAL/SPM-V_II

# %%
# spm_dir = '/home/neel/Documents/SPM_results/second_level/SPM-A_II_syllables_IPA_eSpeak_ijfix2'
# roi_output_dir = str(Path(spm_dir) / 'roi')




# if not os.path.exists(roi_output_dir):
#     os.makedirs(roi_output_dir)
# tmap = str(Path(spm_dir) / 'spmT_0001.nii')
# print(tmap)
# save_path = str(Path(roi_output_dir) / 'cluster_centroids.csv')
# print(save_path)

# %%
# tmap

# %%
# #delete all the contents of the roi_output_dir before running the code
# for file in os.listdir(roi_output_dir):
#     os.remove(os.path.join(roi_output_dir, file))
# cluster_paths, affine = separate_clusters(tmap, roi_output_dir, 5.409,extent_threshold=20)
# results = calculate_centroids_and_peaks(cluster_paths, tmap)

# %%
# # Calculate peak T-values and store results
# sorted_results = []
# for i, result in enumerate(results, start=1):
#     centroid = [round(coord) for coord in result["centroid"]]
#     peak = [round(coord) for coord in result["peak"]]
    
#     # Load the T-map to get the peak T-value
#     tmap_img = nib.load(tmap)
#     tmap_data = tmap_img.get_fdata()
    
#     # Convert the peak coordinate from world space to voxel space
#     peak_voxel = np.round(nib.affines.apply_affine(np.linalg.inv(tmap_img.affine), result["peak"])).astype(int)
    
#     # Ensure the voxel indices are within bounds
#     if (0 <= peak_voxel[0] < tmap_data.shape[0] and
#         0 <= peak_voxel[1] < tmap_data.shape[1] and
#         0 <= peak_voxel[2] < tmap_data.shape[2]):
#         peak_t_value = tmap_data[tuple(peak_voxel)]
#     else:
#         peak_t_value = float('nan')  # Out of bounds, assign NaN

#     # Calculate cluster size in voxels
#     cluster_path = cluster_paths[i - 1]
#     cluster_img = nib.load(cluster_path)
#     cluster_data = cluster_img.get_fdata()
#     cluster_size = int(np.sum(cluster_data > 0))  # Count non-zero voxels

#     sorted_results.append({
#         'Cluster #': i,
#         'Centroid': centroid,
#         'Peak': peak,
#         'Peak T-value': peak_t_value,
#         'Extent': cluster_size
#     })

# # Sort results by peak T-value in descending order
# sorted_results.sort(key=lambda x: x['Peak T-value'], reverse=True)

# # Reassign cluster numbers in order
# for i, result in enumerate(sorted_results, start=1):
#     result['Cluster #'] = i

# # Print sorted results
# for result in sorted_results:
#     print(f"Cluster {result['Cluster #']}:")
#     print(f"  Centroid = {result['Centroid']}")
#     print(f"  Peak = {result['Peak']}")
#     print(f"  Peak T-value = {round(result['Peak T-value'], 2)}")
#     print(f"  Extent = {result['Extent']} voxels")

# # Save sorted results to a CSV file
# with open(save_path, 'w', newline='') as csvfile:
#     fieldnames = ['Cluster #', 'Centroid', 'Peak', 'Peak T-value', 'Extent']
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#     writer.writeheader()
#     for result in sorted_results:
#         writer.writerow({
#             'Cluster #': result['Cluster #'],
#             'Centroid': result['Centroid'],
#             'Peak': result['Peak'],
#             'Peak T-value': round(result['Peak T-value'], 2),
#             'Extent': result['Extent']
#         })
