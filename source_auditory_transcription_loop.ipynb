# %%
import pandas as pd
from pathlib import Path
import os
import numpy as np
from source_auditory_transcription import *

# %%
source = Path('/media/neel/MOUS/MOUS/MOUS/SynologyDrive/source')
for subject in source.iterdir():
    if subject.is_dir():
        if subject.name.startswith('sub-A'):
            print(subject)
            events = str(subject / 'func' / f'{subject.name}_task-auditory_events.tsv')
            if os.path.exists(events):
               source_auditory_transcription(events)
# Out:
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1008
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1081
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1077
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2113
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2120
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2029
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2042
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2046
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1065
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2106
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2089
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1011
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1086
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2035
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-A2015
# /media/neel/MOUS/MOUS/MOUS/SynologyDrive/source/sub-V1099
# ...
