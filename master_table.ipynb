# %%
import pandas as pd
from pathlib import Path
import numpy as np
import scipy.io

# %%
subtlex_v2 = pd.read_excel('/home/neel/Desktop/sublexical_crossmodal/SUBTLEX-NL with pos and Zipf.xlsx')
subtlex_v1 = pd.read_csv('/home/neel/Desktop/sublexical_crossmodal/SUBTLEX-NL-utf8.txt',delimiter = '\t')
subtlex = subtlex_v2
subtlex
# Out:
#                 Word  FREQcount  CDcount  FREQlow  CDlow  FREQlemma  \
# 0                 ik    1744062     8054   778704   3125    1744527
# 1                 je    1600888     8060  1315051   6535    1600923
# 2                het    1068396     8066   780771   5578    1913811
# 3                 de    1061177     8070   903872   6512    1063827
# 4                dat     965424     8063   715570   6107     965431
# ...              ...        ...      ...      ...    ...        ...
# 437498       &_blake          1        1        1      1          1
# 437499      &_barbie          1        1        1      1          1
# 437500  &_bake_pizza          1        1        1      1          1
# 437501        &_bach          1        1        1      1          1
# 437502    &_atlantic          1        1        1      1          1
#
#          SUBTLEXWF      Zipf  SUBTLEXCD  Lg10CD dominant.pos  \
# 0       39883.0334  7.597064    99.8017  3.9061          VNW
# 1       36608.9449  7.559864    99.8761  3.9064          VNW
# 2       24431.9717  7.384235    99.9504  3.9067          VNW
# 3       24266.8883  7.381291   100.0000  3.9069          LID
# 4       22077.2184  7.340221    99.9133  3.9066          VNW
# ...            ...       ...        ...     ...          ...
# 437498      0.0229  1.656532     0.0124  0.3010         SPEC
# 437499      0.0229  1.656532     0.0124  0.3010         SPEC
# 437500      0.0229  1.656532     0.0124  0.3010         SPEC
# 437501      0.0229  1.656532     0.0124  0.3010         SPEC
# 437502      0.0229  1.656532     0.0124  0.3010         SPEC
#
#         dominant.pos.freq dominant.pos.lemma  dominant.pos.lemma.freq  \
# 0                 1743609                 ik                  1743944
# 1                 1600798                 je                  1600798
# 2                  735390                het                   735395
# 3                 1060098                 de                  1062748
# 4                  532576                dat                   532576
# ...                   ...                ...                      ...
# 437498                  1            &_blake                        1
# 437499                  1           &_barbie                        1
# 437500                  1       &_bake_pizza                        1
# 437501                  1             &_bach                        1
# 437502                  1         &_atlantic                        1
#
#                     all.pos             all.pos.freq  \
# 0           .VNW.SPEC.N.VZ.        .1743609.448.4.1.
# 1       .VNW.SPEC.N.BW.LID.      .1600798.72.15.2.1.
# 2       .VNW.LID.SPEC.WW.N.  .735390.332929.53.22.2.
# 3         .LID.VNW.SPEC.VZ.      .1060098.806.272.1.
# 4        .VNW.VG.SPEC.N.WW.   .532576.432794.51.2.1.
# ...                     ...                      ...
# 437498               .SPEC.                      .1.
# 437499               .SPEC.                      .1.
# 437500               .SPEC.                      .1.
# 437501               .SPEC.                      .1.
# 437502               .SPEC.                      .1.
#
#                   all.pos.lemma.freq
# 0                .1743944.448.134.1.
# 1                .1600798.72.50.2.1.
# 2       .735395.332929.53.845403.31.
# 3                .1062748.806.272.1.
# 4             .532576.432794.51.9.1.
# ...                              ...
# 437498                           .1.
# 437499                           .1.
# 437500                           .1.
# 437501                           .1.
# 437502                           .1.
#
# [437503 rows x 17 columns]

# %%
celex_syllables = pd.read_csv('/home/neel/Desktop/sublexical_crossmodal/dutch_celex_database_updated.csv')

# %%
celex_syllables
# Out:
#         n_word   IdNum       Head  phone_full  syl_num  phone_num phone_clean  \
# 0            1       1          a          'a        1          1         .a.
# 1            2       5      Aagje      'ax-j@        2          4      .axj@.
# 2            3       6       aagt        'axt        1          3       .axt.
# 3            4       7  aagtappel  'axt-A-p@l        3          7   .axtAp@l.
# 4            5       8        aai         'aj        1          2        .aj.
# ...        ...     ...        ...         ...      ...        ...         ...
# 117232  117233  124132     zygoot     zi-'Got        2          5     .ziGot.
# 117233  117234  124133     zygote   zi-'Go-t@        3          6    .ziGot@.
# 117234  117235  124134     zymase   zi-'ma-z@        3          6    .zimaz@.
# 117235  117236  124135     zymose   zi-'mo-z@        3          6    .zimoz@.
# 117236  117237  124136  zymotisch  zi-'mo-tis        3          7   .zimotis.
#
#          phone_CV syl_num_sequence phone_position_syl phone_position_syl_onc  \
# 0             .V.              .1.                .1.                    .n.
# 1          .VCCV.           .1122.             .1212.                 .ncon.
# 2           .VCC.            .111.              .123.                  .ncc.
# 3       .VCCVCVC.        .1112333.          .1231123.              .nccnonc.
# 4            .VC.             .11.               .12.                   .nc.
# ...           ...              ...                ...                    ...
# 117232    .CVCVC.          .11222.            .12123.                .ononc.
# 117233   .CVCVCV.         .112233.           .121212.               .ononon.
# 117234   .CVCVCV.         .112233.           .121212.               .ononon.
# 117235   .CVCVCV.         .112233.           .121212.               .ononon.
# 117236  .CVCVCVC.        .1122333.          .1212123.              .onononc.
#
#        phone_cluster_size phone_cluster_position stress_pattern
# 0                     .1.                    .1.            .s.
# 1                  .1111.                 .1111.           .su.
# 2                   .122.                  .112.            .s.
# 3               .1221111.              .1121111.          .suu.
# 4                    .11.                   .11.            .s.
# ...                   ...                    ...            ...
# 117232            .11111.                .11111.           .us.
# 117233           .111111.               .111111.          .usu.
# 117234           .111111.               .111111.          .usu.
# 117235           .111111.               .111111.          .usu.
# 117236          .1111111.              .1111111.          .usu.
#
# [117237 rows x 14 columns]

# %%
syllables = celex_syllables['phone_full'].apply(lambda x: x.split('-'))
syllables_unique = []
for word in syllables:
    for syl in word:
            syllables_unique.append(syl)

# %%
len(syllables_unique)
# Out:
# 396195

# %%
# #remove apostrophes from every term in syllables_unique
# syllables_unique = [syl.replace("'", "") for syl in syllables_unique]  
# #remove apostrophes from every term in celex_syllables['phone_full']
# celex_syllables['phone_full'] = celex_syllables['phone_full'].apply(lambda x: x.replace("'", ""))

# %%
celex_syllables
# Out:
#         n_word   IdNum       Head  phone_full  syl_num  phone_num phone_clean  \
# 0            1       1          a          'a        1          1         .a.
# 1            2       5      Aagje      'ax-j@        2          4      .axj@.
# 2            3       6       aagt        'axt        1          3       .axt.
# 3            4       7  aagtappel  'axt-A-p@l        3          7   .axtAp@l.
# 4            5       8        aai         'aj        1          2        .aj.
# ...        ...     ...        ...         ...      ...        ...         ...
# 117232  117233  124132     zygoot     zi-'Got        2          5     .ziGot.
# 117233  117234  124133     zygote   zi-'Go-t@        3          6    .ziGot@.
# 117234  117235  124134     zymase   zi-'ma-z@        3          6    .zimaz@.
# 117235  117236  124135     zymose   zi-'mo-z@        3          6    .zimoz@.
# 117236  117237  124136  zymotisch  zi-'mo-tis        3          7   .zimotis.
#
#          phone_CV syl_num_sequence phone_position_syl phone_position_syl_onc  \
# 0             .V.              .1.                .1.                    .n.
# 1          .VCCV.           .1122.             .1212.                 .ncon.
# 2           .VCC.            .111.              .123.                  .ncc.
# 3       .VCCVCVC.        .1112333.          .1231123.              .nccnonc.
# 4            .VC.             .11.               .12.                   .nc.
# ...           ...              ...                ...                    ...
# 117232    .CVCVC.          .11222.            .12123.                .ononc.
# 117233   .CVCVCV.         .112233.           .121212.               .ononon.
# 117234   .CVCVCV.         .112233.           .121212.               .ononon.
# 117235   .CVCVCV.         .112233.           .121212.               .ononon.
# 117236  .CVCVCVC.        .1122333.          .1212123.              .onononc.
#
#        phone_cluster_size phone_cluster_position stress_pattern
# 0                     .1.                    .1.            .s.
# 1                  .1111.                 .1111.           .su.
# 2                   .122.                  .112.            .s.
# 3               .1221111.              .1121111.          .suu.
# 4                    .11.                   .11.            .s.
# ...                   ...                    ...            ...
# 117232            .11111.                .11111.           .us.
# 117233           .111111.               .111111.          .usu.
# 117234           .111111.               .111111.          .usu.
# 117235           .111111.               .111111.          .usu.
# 117236          .1111111.              .1111111.          .usu.
#
# [117237 rows x 14 columns]

# %%
new_df = celex_syllables[['Head','phone_full']]
new_df.rename(columns = {'Head':'Word', 'phone_full':'Syllables'}, inplace = True)
#merge new_df with subtlex on 'Word' but only keep 'FREQcount' and 'Zipf' from subtlex
new_df = new_df.merge(subtlex[['Word','FREQcount']], on = 'Word', how = 'left')
new_df
# Out:
# /tmp/ipykernel_1702612/1891189283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns = {'Head':'Word', 'phone_full':'Syllables'}, inplace = True)
#              Word   Syllables  FREQcount
# 0               a          'a     1462.0
# 1           Aagje      'ax-j@        NaN
# 2            aagt        'axt        NaN
# 3       aagtappel  'axt-A-p@l        NaN
# 4             aai         'aj       31.0
# ...           ...         ...        ...
# 117232     zygoot     zi-'Got        1.0
# 117233     zygote   zi-'Go-t@        1.0
# 117234     zymase   zi-'ma-z@        NaN
# 117235     zymose   zi-'mo-z@        NaN
# 117236  zymotisch  zi-'mo-tis        NaN
#
# [117237 rows x 3 columns]

# %%
#drop rows with NaN values in FREQcount
#new_df = new_df.dropna(subset = ['FREQcount'])
#reset index
new_df = new_df.reset_index(drop = True)
new_df
# Out:
#              Word   Syllables  FREQcount
# 0               a          'a     1462.0
# 1           Aagje      'ax-j@        NaN
# 2            aagt        'axt        NaN
# 3       aagtappel  'axt-A-p@l        NaN
# 4             aai         'aj       31.0
# ...           ...         ...        ...
# 117232     zygoot     zi-'Got        1.0
# 117233     zygote   zi-'Go-t@        1.0
# 117234     zymase   zi-'ma-z@        NaN
# 117235     zymose   zi-'mo-z@        NaN
# 117236  zymotisch  zi-'mo-tis        NaN
#
# [117237 rows x 3 columns]

# %%
new_df.rename(columns ={'Syllables':'Phonetic'}, inplace = True)
new_df['Syllables'] = new_df['Phonetic'].apply(lambda x: x.split('-'))
new_df
# Out:
#              Word    Phonetic  FREQcount       Syllables
# 0               a          'a     1462.0            ['a]
# 1           Aagje      'ax-j@        NaN       ['ax, j@]
# 2            aagt        'axt        NaN          ['axt]
# 3       aagtappel  'axt-A-p@l        NaN  ['axt, A, p@l]
# 4             aai         'aj       31.0           ['aj]
# ...           ...         ...        ...             ...
# 117232     zygoot     zi-'Got        1.0      [zi, 'Got]
# 117233     zygote   zi-'Go-t@        1.0   [zi, 'Go, t@]
# 117234     zymase   zi-'ma-z@        NaN   [zi, 'ma, z@]
# 117235     zymose   zi-'mo-z@        NaN   [zi, 'mo, z@]
# 117236  zymotisch  zi-'mo-tis        NaN  [zi, 'mo, tis]
#
# [117237 rows x 4 columns]

# %%
new_df.to_csv('/home/neel/Desktop/sublexical_crossmodal/subtlex_v2_celex_intersect_phonetic_counts.csv', index = False)
#new_df.to_excel('/home/neel/Desktop/sublexical_crossmodal/subtlex_v2_celex_intersect_phonetic_counts.xlsx', index = False)

# %%
#drop duplicates in syllables_unique
syllables_unique = list(set(syllables_unique))
len(syllables_unique)
# Out:
# 13034

# %%
# Initialize a dictionary to count occurrences of each syllable
syllable_counts = {syllable: 0 for syllable in syllables_unique}
print(len(syllable_counts))
# Out:
# 13034

# %%
# Iterate through each syllable and use list comprehension to count occurrences
for syllable in syllables_unique:
    # Create a boolean mask where the syllable is present in the 'Syllables' column
    mask = new_df['Syllables'].apply(lambda x: syllable in x)
    # Sum the 'FREQcount' values where the mask is True
    syllable_counts[syllable] = new_df.loc[mask, 'FREQcount'].sum()

# Print the count of each syllable
for syllable, count in syllable_counts.items():
    print(f"Syllable: {syllable}, Count: {count}")
# Out:
# Syllable: wAn, Count: 1031.0
# Syllable: wErkt, Count: 269.0
# Syllable: g|, Count: 0.0
# Syllable: 'staks, Count: 0.0
# Syllable: 'sxrK, Count: 6636.0
# Syllable: nLs, Count: 13.0
# Syllable: kAl, Count: 970.0
# Syllable: 'h}p, Count: 644.0
# Syllable: dOx, Count: 433.0
# Syllable: 'bOr, Count: 1972.0
# Syllable: tAns, Count: 32.0
# Syllable: 'pes, Count: 16.0
# Syllable: 'hoz, Count: 0.0
# Syllable: 'vr|G, Count: 635.0
# Syllable: 'bIps, Count: 39.0
# Syllable: trIn, Count: 3.0
# Syllable: mAGd, Count: 62.0
# Syllable: bEk, Count: 166.0
# Syllable: sxrIk, Count: 39.0
# Syllable: 'mOlmt, Count: 2.0
# Syllable: stroj, Count: 0.0
# Syllable: 'lag, Count: 6.0
# Syllable: 'spIxt, Count: 0.0
# Syllable: 'pLs, Count: 2.0
# Syllable: 'pl|, Count: 72.0
# Syllable: sE, Count: 2965.0
# Syllable: 'stem, Count: 57.0
# Syllable: 'mArk, Count: 1483.0
# Syllable: 'sem, Count: 23.0
# Syllable: 'spIts, Count: 144.0
# Syllable: 'zAl, Count: 35.0
# Syllable: b|n, Count: 0.0
# Syllable: 'kwAst, Count: 78.0
# Syllable: 'zLt, Count: 393.0
# Syllable: prEd, Count: 6.0
# Syllable: sxu, Count: 44.0
# Syllable: 'sprOt, Count: 4.0
# Syllable: 'mIz, Count: 3406.0
# Syllable: G@t, Count: 28.0
# Syllable: sIx, Count: 132.0
# Syllable: 'xEr, Count: 7.0
# Syllable: 'kOG, Count: 40.0
# Syllable: 'tEnd, Count: 1.0
# Syllable: 'drEt, Count: 0.0
# Syllable: 'rap, Count: 432.0
# Syllable: 'mudz, Count: 0.0
# Syllable: SpEl, Count: 1.0
# Syllable: k@G, Count: 2.0
# Syllable: 'vlaj, Count: 8.0
# Syllable: 'lArd, Count: 0.0
# Syllable: 'slax, Count: 202.0
# Syllable: 'rA, Count: 6691.0
# Syllable: 'xrOs, Count: 15.0
# Syllable: 'spitS, Count: 542.0
# Syllable: 'lofs, Count: 31.0
# Syllable: did, Count: 1.0
# Syllable: bukt, Count: 51.0
# Syllable: 'dIN, Count: 12452.0
# Syllable: l@x, Count: 21003.0
# Syllable: 'xlas, Count: 390.0
# Syllable: r}nt, Count: 0.0
# Syllable: 'mEd, Count: 6.0
# Syllable: 'bif, Count: 327.0
# Syllable: nINs, Count: 539.0
# Syllable: pLt, Count: 15.0
# Syllable: vIgz, Count: 0.0
# Syllable: 'lurs, Count: 1900.0
# Syllable: 'krLt, Count: 144.0
# Syllable: G}nst, Count: 2.0
# Syllable: 'dr}m, Count: 160.0
# Syllable: 'trist, Count: 770.0
# Syllable: pj@z, Count: 0.0
# Syllable: pK, Count: 389.0
# Syllable: mAxts, Count: 1.0
# Syllable: 'krK, Count: 22308.0
# Syllable: 'Al, Count: 157526.0
# Syllable: 'nAk, Count: 0.0
# Syllable: bes, Count: 291.0
# Syllable: ZAs, Count: 0.0
# Syllable: 'wen, Count: 16.0
# Syllable: 'Graf, Count: 1005.0
# Syllable: 'krLd, Count: 14.0
# Syllable: 'lArm, Count: 1929.0
# Syllable: tOns, Count: 1.0
# Syllable: 'gOs, Count: 40.0
# Syllable: 'lifst, Count: 180.0
# Syllable: 'strLk, Count: 168.0
# Syllable: 'smO, Count: 382.0
# Syllable: 'stLt, Count: 50.0
# Syllable: 'vlest, Count: 0.0
# Syllable: tu, Count: 4425.0
# Syllable: 'prMw, Count: 8.0
# Syllable: 'lyw, Count: 2.0
# Syllable: t}rf, Count: 0.0
# Syllable: 'let, Count: 678.0
# Syllable: 'fL, Count: 417.0
# Syllable: 'trOn, Count: 153.0
# Syllable: plKs, Count: 12.0
# Syllable: 'vorst, Count: 0.0
# Syllable: 'platst, Count: 621.0
# Syllable: zAn, Count: 12.0
# Syllable: 'zoG, Count: 42.0
# Syllable: sxIl, Count: 1202.0
# Syllable: 'kral, Count: 52.0
# Syllable: sM, Count: 68.0
# Syllable: dIxt, Count: 299.0
# Syllable: sEd, Count: 0.0
# Syllable: 'sOmp, Count: 0.0
# Syllable: hK, Count: 159.0
# Syllable: 'trOl, Count: 83.0
# Syllable: 'zward, Count: 2.0
# Syllable: 'rEx, Count: 5684.0
# Syllable: 'jed, Count: 0.0
# Syllable: 'Ord, Count: 1.0
# Syllable: 'zAj, Count: 14.0
# Syllable: wAks, Count: 0.0
# Syllable: 'pInt, Count: 65.0
# Syllable: 'Iks, Count: 300.0
# Syllable: dwK, Count: 15.0
# Syllable: 'vj), Count: 0.0
# Syllable: brOn, Count: 249.0
# Syllable: zwu, Count: 0.0
# Syllable: 'vOs, Count: 332.0
# Syllable: 'vra, Count: 20238.0
# Syllable: 'sxruj, Count: 0.0
# Syllable: 'mEx, Count: 0.0
# Syllable: b}p, Count: 0.0
# Syllable: 'sx}rft, Count: 26.0
# Syllable: strL, Count: 5.0
# Syllable: tur, Count: 603.0
# Syllable: 'st), Count: 0.0
# Syllable: 'ful, Count: 27.0
# Syllable: n|r, Count: 8.0
# Syllable: knOt, Count: 0.0
# Syllable: GrM, Count: 0.0
# Syllable: 'sxrod, Count: 0.0
# Syllable: 'n|t, Count: 136.0
# Syllable: 'vEN, Count: 7.0
# Syllable: sy, Count: 1564.0
# Syllable: 'kog, Count: 53.0
# Syllable: 'frI, Count: 143.0
# Syllable: s}m, Count: 857.0
# Syllable: dint, Count: 20.0
# Syllable: 'krAm, Count: 3.0
# Syllable: 'se, Count: 7993.0
# Syllable: 'drKx, Count: 3.0
# Syllable: fam, Count: 2.0
# Syllable: 'vur, Count: 1909.0
# Syllable: 'strEkt, Count: 151.0
# Syllable: 'b|rs, Count: 634.0
# Syllable: spKt, Count: 7.0
# Syllable: trys, Count: 0.0
# Syllable: 'xAt, Count: 2396.0
# Syllable: 'rAxt, Count: 85.0
# Syllable: 'v}t, Count: 0.0
# Syllable: zIg, Count: 1.0
# Syllable: 'fIl, Count: 1075.0
# Syllable: 'kn}t, Count: 20.0
# Syllable: 'nert, Count: 497.0
# Syllable: 'Gon, Count: 2.0
# Syllable: 'vlEk, Count: 299.0
# Syllable: 'wElp, Count: 32.0
# Syllable: 'vOlx, Count: 608.0
# Syllable: wMt, Count: 206.0
# Syllable: 'zL, Count: 3341.0
# Syllable: sxAf, Count: 16.0
# Syllable: dyw, Count: 1049.0
# Syllable: 'klLv, Count: 0.0
# Syllable: 'nOk, Count: 37.0
# Syllable: 'vOlks, Count: 255.0
# Syllable: tEnt, Count: 120.0
# Syllable: bEl, Count: 306.0
# Syllable: 'koks, Count: 9.0
# Syllable: 'spE, Count: 3102.0
# Syllable: 'wElf, Count: 12.0
# Syllable: 'bKt, Count: 2754.0
# Syllable: l|, Count: 140.0
# Syllable: G|l, Count: 16.0
# Syllable: k@ns, Count: 1246.0
# Syllable: 'spok, Count: 760.0
# Syllable: 'bomt, Count: 0.0
# Syllable: swe, Count: 22.0
# Syllable: 'hLx, Count: 5.0
# Syllable: 'styk, Count: 7.0
# Syllable: rIks, Count: 10.0
# Syllable: Ant, Count: 3457.0
# Syllable: jOk, Count: 8.0
# Syllable: 'tS|s, Count: 191.0
# Syllable: n}t, Count: 242.0
# Syllable: 'jap, Count: 20.0
# Syllable: S@nt, Count: 0.0
# Syllable: pKt, Count: 13.0
# Syllable: 'fe, Count: 800.0
# Syllable: 'sx}x, Count: 20.0
# Syllable: 'nOst, Count: 5.0
# Syllable: 'brOks, Count: 0.0
# Syllable: 'brOnst, Count: 1.0
# Syllable: yr, Count: 453.0
# Syllable: 'hAns, Count: 330.0
# Syllable: klErk, Count: 9.0
# Syllable: dIf, Count: 20.0
# Syllable: 'ovd, Count: 0.0
# Syllable: vit, Count: 1.0
# Syllable: plMs, Count: 0.0
# Syllable: 'sIst, Count: 251.0
# Syllable: 'Ant, Count: 9525.0
# Syllable: jAnt, Count: 2744.0
# Syllable: 'stAN, Count: 101.0
# Syllable: 'dyp, Count: 0.0
# Syllable: GrAxt, Count: 0.0
# Syllable: 'mujt, Count: 268.0
# Syllable: 'hOrn, Count: 11.0
# Syllable: haf, Count: 0.0
# Syllable: 'kOt, Count: 376.0
# Syllable: ma, Count: 53566.0
# Syllable: spEn, Count: 104.0
# Syllable: 'jIxt, Count: 66.0
# Syllable: 'spr|, Count: 2.0
# Syllable: 'dOns, Count: 48.0
# Syllable: 'traxt, Count: 128.0
# Syllable: 'nK, Count: 894.0
# Syllable: st}l, Count: 3.0
# Syllable: 'br}, Count: 113.0
# Syllable: 'slKm, Count: 258.0
# Syllable: d@ns, Count: 5920.0
# Syllable: luk, Count: 0.0
# Syllable: 'bOd, Count: 3.0
# Syllable: 'z}xt, Count: 137.0
# Syllable: krMt, Count: 0.0
# Syllable: snar, Count: 0.0
# Syllable: 'hOm, Count: 5.0
# Syllable: ha, Count: 6460.0
# Syllable: 'vremd, Count: 3.0
# Syllable: 'krAp, Count: 180.0
# Syllable: d}, Count: 118.0
# Syllable: kOrps, Count: 32.0
# Syllable: tOv, Count: 0.0
# Syllable: 'stut, Count: 47.0
# Syllable: 'fIs, Count: 87.0
# Syllable: 'dyw, Count: 681.0
# Syllable: bONk, Count: 5.0
# Syllable: vuts, Count: 1.0
# Syllable: 'nort, Count: 627.0
# Syllable: 'raj, Count: 0.0
# Syllable: 'bem, Count: 8.0
# Syllable: 'mens, Count: 0.0
# Syllable: 'sxrIf, Count: 61.0
# Syllable: 'hef, Count: 49.0
# Syllable: 'zwo, Count: 414.0
# Syllable: 'tAjm, Count: 2.0
# Syllable: wrI, Count: 13.0
# Syllable: 'frLd, Count: 2.0
# Syllable: 'rLf, Count: 2.0
# Syllable: 'dwA, Count: 8.0
# Syllable: 'rats, Count: 453.0
# Syllable: dart, Count: 428.0
# Syllable: kwAns, Count: 0.0
# Syllable: 'dOrt, Count: 9.0
# Syllable: 'brOt, Count: 0.0
# Syllable: fre, Count: 291.0
# Syllable: 'mInt, Count: 91.0
# Syllable: 'lam, Count: 88.0
# Syllable: borts, Count: 0.0
# Syllable: pl)n, Count: 0.0
# Syllable: 'sxrI, Count: 3144.0
# Syllable: 'fAl, Count: 0.0
# Syllable: puk, Count: 3.0
# Syllable: 'bals, Count: 1.0
# Syllable: vINs, Count: 232.0
# Syllable: Graf, Count: 11.0
# Syllable: gAr, Count: 0.0
# Syllable: 'bemt, Count: 2.0
# Syllable: 'stots, Count: 0.0
# Syllable: bOndz, Count: 0.0
# Syllable: 'krel, Count: 20.0
# Syllable: 'sxAl, Count: 16.0
# Syllable: sEN, Count: 14.0
# Syllable: SmErts, Count: 0.0
# Syllable: stAts, Count: 0.0
# Syllable: 'skrAps, Count: 24.0
# Syllable: 'stAmpt, Count: 12.0
# Syllable: top, Count: 0.0
# Syllable: sik, Count: 291.0
# Syllable: 'namt, Count: 1360.0
# Syllable: 'rAms, Count: 0.0
# Syllable: G@l, Count: 11488.0
# Syllable: k@lt, Count: 1328.0
# Syllable: n), Count: 13.0
# Syllable: 'drLp, Count: 4.0
# Syllable: 'hax, Count: 14.0
# Syllable: 'njel, Count: 14.0
# Syllable: 'vOnt, Count: 11801.0
# Syllable: 'vErv, Count: 12.0
# Syllable: pjE, Count: 55.0
# Syllable: 'tans, Count: 1.0
# Syllable: 'rExt, Count: 11680.0
# Syllable: 'raG, Count: 0.0
# Syllable: 'dof, Count: 957.0
# Syllable: 'wEp, Count: 197.0
# Syllable: 'sef, Count: 147.0
# Syllable: 'sxot, Count: 2167.0
# Syllable: 'dANg, Count: 2060.0
# Syllable: 'kEd, Count: 37.0
# Syllable: 'fOp, Count: 13.0
# Syllable: 'pOp, Count: 1513.0
# Syllable: 'sxErm, Count: 809.0
# Syllable: 'dodz, Count: 770.0
# Syllable: brots, Count: 17.0
# Syllable: vor, Count: 41977.0
# Syllable: 'tMw, Count: 1264.0
# Syllable: 'fly, Count: 4.0
# Syllable: zu, Count: 656.0
# Syllable: 'trant, Count: 4.0
# Syllable: lIn, Count: 195.0
# Syllable: lKts, Count: 0.0
# Syllable: for, Count: 183.0
# Syllable: 'blum, Count: 692.0
# Syllable: 'slOd, Count: 1.0
# Syllable: bAn, Count: 239.0
# Syllable: 'zInz, Count: 24.0
# Syllable: zwEm, Count: 25.0
# Syllable: pIm, Count: 7.0
# Syllable: 'sxe, Count: 7187.0
# Syllable: 'rOdz, Count: 25.0
# Syllable: 'pruf, Count: 1358.0
# Syllable: 'sprek, Count: 102.0
# Syllable: 'zwErv, Count: 1.0
# Syllable: 'suns, Count: 4.0
# Syllable: krLd, Count: 0.0
# Syllable: 'xrun, Count: 1826.0
# Syllable: 'krEb, Count: 0.0
# Syllable: d@, Count: 515645.0
# Syllable: 'arz, Count: 0.0
# Syllable: 'huv, Count: 4.0
# Syllable: 'mErG, Count: 1.0
# Syllable: 'krKn, Count: 0.0
# Syllable: knak, Count: 0.0
# Syllable: vEks, Count: 0.0
# Syllable: 'fEs, Count: 217.0
# Syllable: prK, Count: 45.0
# Syllable: 'fnL, Count: 2.0
# Syllable: skrIpt, Count: 13.0
# Syllable: 'zuns, Count: 7.0
# Syllable: tyr, Count: 349.0
# Syllable: 'xap, Count: 17.0
# Syllable: 'raz, Count: 0.0
# Syllable: left, Count: 23.0
# Syllable: 'flEns, Count: 11.0
# Syllable: sprInt, Count: 3.0
# Syllable: 'klEmt, Count: 6.0
# Syllable: 'sAks, Count: 0.0
# Syllable: sx}ld, Count: 2.0
# Syllable: 'b}ps, Count: 1.0
# Syllable: frAl, Count: 0.0
# Syllable: 'rLn, Count: 22.0
# Syllable: mAns, Count: 30.0
# Syllable: tjON, Count: 0.0
# Syllable: 'pLN, Count: 0.0
# Syllable: rEm, Count: 148.0
# Syllable: xlAz, Count: 2.0
# Syllable: 'hOg, Count: 0.0
# Syllable: luj, Count: 0.0
# Syllable: 'dAms, Count: 0.0
# Syllable: 'hErn, Count: 0.0
# Syllable: 'nojt, Count: 63864.0
# Syllable: 'vr}Gd, Count: 259.0
# Syllable: 'plat, Count: 3893.0
# Syllable: 't}rk, Count: 0.0
# Syllable: 'lons, Count: 60.0
# Syllable: 'sna, Count: 103.0
# Syllable: snLt, Count: 3.0
# Syllable: 'd)r, Count: 109.0
# Syllable: xar, Count: 0.0
# Syllable: Gal, Count: 47.0
# Syllable: frO, Count: 0.0
# Syllable: 'xlo, Count: 1071.0
# Syllable: 'mLt, Count: 0.0
# Syllable: prO, Count: 54.0
# Syllable: 'pest, Count: 0.0
# Syllable: fEx, Count: 258.0
# Syllable: fEnt, Count: 5.0
# Syllable: hIr, Count: 6.0
# Syllable: 'bril, Count: 0.0
# Syllable: jAm, Count: 5.0
# Syllable: 'krev, Count: 0.0
# Syllable: sprONs, Count: 0.0
# Syllable: 'blIs, Count: 0.0
# Syllable: 'kleft, Count: 2.0
# Syllable: 'kOst, Count: 3724.0
# Syllable: 'klLz, Count: 9.0
# Syllable: d@n, Count: 27.0
# Syllable: 'pw), Count: 0.0
# Syllable: 'rAspt, Count: 1.0
# Syllable: 'vOt, Count: 117.0
# Syllable: lax, Count: 577.0
# Syllable: 'bElt, Count: 2495.0
# Syllable: skro, Count: 0.0
# Syllable: 'f|r, Count: 1303.0
# Syllable: drIN, Count: 317.0
# Syllable: flIp, Count: 1.0
# Syllable: 'lIsk, Count: 33.0
# Syllable: fes, Count: 42.0
# Syllable: 'Si, Count: 1911.0
# Syllable: 'zy, Count: 151.0
# Syllable: 'krINs, Count: 0.0
# Syllable: 'n|z, Count: 12.0
# Syllable: 'prEn, Count: 21.0
# Syllable: 'frik, Count: 406.0
# Syllable: 'knOxt, Count: 25.0
# Syllable: ZEt, Count: 12.0
# Syllable: rEkt, Count: 99.0
# Syllable: ZAr, Count: 0.0
# Syllable: d@mt, Count: 0.0
# Syllable: 'bl}s, Count: 6.0
# Syllable: sprK, Count: 14.0
# Syllable: 'brad, Count: 13.0
# Syllable: 'kApt, Count: 71.0
# Syllable: 'vrut, Count: 44.0
# Syllable: 'pOl, Count: 370.0
# Syllable: 'breks, Count: 0.0
# Syllable: 'brAt, Count: 2.0
# Syllable: 'klOm, Count: 1.0
# Syllable: GAst, Count: 115.0
# Syllable: 'hof, Count: 24.0
# Syllable: 'knKb, Count: 0.0
# Syllable: 'Glo, Count: 0.0
# Syllable: 'drAxs, Count: 74.0
# Syllable: 'bIl, Count: 202.0
# Syllable: 'hEsp, Count: 4.0
# Syllable: 'spe, Count: 11695.0
# Syllable: sx}l, Count: 1.0
# Syllable: fIn, Count: 1190.0
# Syllable: 'lAxt, Count: 0.0
# Syllable: 'xrups, Count: 100.0
# Syllable: 'G}rk, Count: 59.0
# Syllable: 'bAn, Count: 277.0
# Syllable: 'kif, Count: 0.0
# Syllable: 'GOmt, Count: 0.0
# Syllable: stir, Count: 1.0
# Syllable: 'kwInt, Count: 4.0
# Syllable: rKd, Count: 11.0
# Syllable: 'wKfs, Count: 0.0
# Syllable: '_Et, Count: 256.0
# Syllable: 'slExts, Count: 3846.0
# Syllable: 'rKs, Count: 4153.0
# Syllable: 'tAzd, Count: 101.0
# Syllable: 'bInt, Count: 2.0
# Syllable: wErf, Count: 46.0
# Syllable: flow, Count: 1.0
# Syllable: py, Count: 6080.0
# Syllable: 'to, Count: 7644.0
# Syllable: 'bArk, Count: 6.0
# Syllable: 'hL, Count: 5729.0
# Syllable: lAs, Count: 320.0
# Syllable: 'beN, Count: 0.0
# Syllable: SOk, Count: 22.0
# Syllable: lEns, Count: 49.0
# Syllable: 'fOnt, Count: 389.0
# Syllable: 'pIN, Count: 127.0
# Syllable: streks, Count: 33.0
# Syllable: 'sId, Count: 396.0
# Syllable: dAG, Count: 1157.0
# Syllable: 'skys, Count: 1043.0
# Syllable: 'pIs, Count: 432.0
# Syllable: 'nEts, Count: 7.0
# Syllable: 'end, Count: 0.0
# Syllable: fax, Count: 6.0
# Syllable: 'bAd, Count: 50.0
# Syllable: 'ZEs, Count: 16.0
# Syllable: 'pOn, Count: 158.0
# Syllable: blI, Count: 20.0
# Syllable: 'byn, Count: 72.0
# Syllable: 'tSum, Count: 0.0
# Syllable: 'wEd, Count: 110.0
# Syllable: 'vOlt, Count: 65.0
# Syllable: xir, Count: 35.0
# Syllable: 'vKt, Count: 18.0
# Syllable: flK, Count: 0.0
# Syllable: 'xlOp, Count: 0.0
# Syllable: 'tswe, Count: 1.0
# Syllable: 'kloft, Count: 5.0
# Syllable: 'dr}g, Count: 42.0
# Syllable: 'wIst, Count: 10.0
# Syllable: 'smul, Count: 236.0
# Syllable: 'bl|r, Count: 0.0
# Syllable: 'tra, Count: 3179.0
# Syllable: dorm, Count: 1.0
# Syllable: 'grep, Count: 63.0
# Syllable: 'grin, Count: 332.0
# Syllable: sxEp, Count: 3.0
# Syllable: sINz, Count: 7.0
# Syllable: 'wOk, Count: 13.0
# Syllable: 'xrubz, Count: 10.0
# Syllable: 'drKfs, Count: 222.0
# Syllable: 'blOs, Count: 14.0
# Syllable: b}d, Count: 297.0
# Syllable: 'lKd, Count: 0.0
# Syllable: tSa, Count: 286.0
# Syllable: 'bM, Count: 501.0
# Syllable: lIft, Count: 21.0
# Syllable: 'spIn, Count: 360.0
# Syllable: 'k|rt, Count: 0.0
# Syllable: 'xruN, Count: 0.0
# Syllable: spLs, Count: 0.0
# Syllable: 'smixt, Count: 10.0
# Syllable: 'sxrANk, Count: 3.0
# Syllable: 'stAts, Count: 91.0
# Syllable: krEk, Count: 0.0
# Syllable: 'klINg, Count: 0.0
# Syllable: 'slLp, Count: 235.0
# Syllable: 'hopt, Count: 11.0
# Syllable: tI, Count: 436.0
# Syllable: 'muts, Count: 110.0
# Syllable: 'hus, Count: 174.0
# Syllable: 'tIs, Count: 281.0
# Syllable: sxruft, Count: 5.0
# Syllable: 'SAs, Count: 1.0
# Syllable: fAnt, Count: 542.0
# Syllable: 'drAGz, Count: 5.0
# Syllable: 'fl}t, Count: 15.0
# Syllable: 'sxruv, Count: 11.0
# Syllable: sxKd, Count: 0.0
# Syllable: 'haj, Count: 415.0
# Syllable: skI, Count: 0.0
# Syllable: d|rs, Count: 8.0
# Syllable: t@, Count: 603753.0
# Syllable: lars, Count: 30.0
# Syllable: rLm, Count: 616.0
# Syllable: 'mEzd, Count: 1.0
# Syllable: 'pLn, Count: 847.0
# Syllable: pr}, Count: 5.0
# Syllable: 'dr}kt, Count: 402.0
# Syllable: jis, Count: 0.0
# Syllable: 'krIm, Count: 90.0
# Syllable: kur, Count: 33.0
# Syllable: 'plEnz, Count: 1.0
# Syllable: n@xst, Count: 13.0
# Syllable: 'dAj, Count: 1.0
# Syllable: 'sIm, Count: 2492.0
# Syllable: 'rAst, Count: 944.0
# Syllable: 'sn}f, Count: 56.0
# Syllable: G@N, Count: 18.0
# Syllable: 'dKg, Count: 0.0
# Syllable: rOp, Count: 2.0
# Syllable: 'kIft, Count: 1.0
# Syllable: 'wip, Count: 0.0
# Syllable: fAndz, Count: 0.0
# Syllable: 'wEb, Count: 0.0
# Syllable: h}xt, Count: 0.0
# Syllable: <, Count: 0.0
# Syllable: hM, Count: 10446.0
# Syllable: 'prim, Count: 42.0
# Syllable: 'kryt, Count: 90.0
# Syllable: 'mIk, Count: 286.0
# Syllable: 'fOz, Count: 0.0
# Syllable: 'smES, Count: 11.0
# Syllable: GEr, Count: 0.0
# Syllable: 'bLkt, Count: 3.0
# Syllable: 'SlAm, Count: 0.0
# Syllable: 'mom, Count: 1.0
# Syllable: tAj, Count: 27.0
# Syllable: pw)n, Count: 0.0
# Syllable: flAN, Count: 3.0
# Syllable: tKl, Count: 1.0
# Syllable: drAk, Count: 0.0
# Syllable: 'dIn, Count: 8082.0
# Syllable: 'kram, Count: 84.0
# Syllable: 'mErkt, Count: 788.0
# Syllable: mum, Count: 0.0
# Syllable: 'st}k, Count: 9994.0
# Syllable: kar, Count: 13.0
# Syllable: dLs, Count: 56.0
# Syllable: 'dEm, Count: 39.0
# Syllable: tKts, Count: 319.0
# Syllable: 'dif, Count: 1901.0
# Syllable: 'vEGdz, Count: 0.0
# Syllable: fAj, Count: 8.0
# Syllable: sxrO, Count: 7.0
# Syllable: 'kyr, Count: 106.0
# Syllable: zOrx, Count: 365.0
# Syllable: nMwt, Count: 34.0
# Syllable: 'S|r, Count: 1749.0
# Syllable: 'burs, Count: 12.0
# Syllable: blot, Count: 0.0
# Syllable: 'zErk, Count: 7.0
# Syllable: rAt, Count: 156.0
# Syllable: 'pAn, Count: 2723.0
# Syllable: 'vlExt, Count: 29.0
# Syllable: 'tI, Count: 1390.0
# Syllable: vOxt, Count: 3.0
# Syllable: dKs, Count: 3.0
# Syllable: 'vOr, Count: 1563.0
# Syllable: 'jut, Count: 0.0
# Syllable: 'kwar, Count: 0.0
# Syllable: 'sxav, Count: 0.0
# Syllable: 'fKt, Count: 1949.0
# Syllable: 'GlAnst, Count: 0.0
# Syllable: 'mExt, Count: 137.0
# Syllable: xef, Count: 23.0
# Syllable: p}nts, Count: 2.0
# Syllable: blar, Count: 0.0
# Syllable: 'pAN, Count: 148.0
# Syllable: pKp, Count: 173.0
# Syllable: krAs, Count: 6.0
# Syllable: 'vlEGd, Count: 0.0
# Syllable: 'sx|, Count: 527.0
# Syllable: 'krLb, Count: 1.0
# Syllable: wart, Count: 0.0
# Syllable: 'h)d, Count: 6.0
# Syllable: spyw, Count: 0.0
# Syllable: 'vard, Count: 176.0
# Syllable: brIl, Count: 1203.0
# Syllable: 'hOrt, Count: 28.0
# Syllable: knLst, Count: 0.0
# Syllable: 'pra, Count: 28286.0
# Syllable: dMw, Count: 11.0
# Syllable: 'kAst, Count: 418.0
# Syllable: 'xAns, Count: 257.0
# Syllable: 'kurs, Count: 1175.0
# Syllable: tOlk, Count: 0.0
# Syllable: flIn, Count: 12.0
# Syllable: vre, Count: 148.0
# Syllable: 'rEn, Count: 2105.0
# Syllable: klMs, Count: 55.0
# Syllable: 'xrEnz, Count: 0.0
# Syllable: vAl, Count: 8070.0
# Syllable: sxrKf, Count: 12.0
# Syllable: 'net, Count: 2126.0
# Syllable: kwad, Count: 216.0
# Syllable: 'vInd, Count: 79.0
# Syllable: lKt, Count: 418.0
# Syllable: bOr, Count: 689.0
# Syllable: 'pOlz, Count: 3.0
# Syllable: 'sxAp, Count: 0.0
# Syllable: 'sxEx, Count: 2.0
# Syllable: 'hOp, Count: 189.0
# Syllable: 'sxAm, Count: 6.0
# Syllable: 'zLlt, Count: 0.0
# Syllable: N@ns, Count: 5.0
# Syllable: 'kAkt, Count: 16.0
# Syllable: 'klEn, Count: 138.0
# Syllable: 'SrEp, Count: 2.0
# Syllable: rut, Count: 0.0
# Syllable: 'drak, Count: 745.0
# Syllable: 'prEd, Count: 4.0
# Syllable: 'w}lk, Count: 0.0
# Syllable: nik, Count: 88.0
# Syllable: b|k, Count: 0.0
# Syllable: stAj, Count: 0.0
# Syllable: 'rKt, Count: 2161.0
# Syllable: prost, Count: 0.0
# Syllable: 'krEN, Count: 950.0
# Syllable: 'lAm, Count: 511.0
# Syllable: 'GrA, Count: 1664.0
# Syllable: 'slak, Count: 5.0
# Syllable: 'spA, Count: 3802.0
# Syllable: fa, Count: 19059.0
# Syllable: 'sLt, Count: 0.0
# Syllable: leN, Count: 0.0
# Syllable: r|, Count: 27.0
# Syllable: 'xlM, Count: 0.0
# Syllable: sxAns, Count: 4.0
# Syllable: 'flInt, Count: 0.0
# Syllable: 'xnKs, Count: 0.0
# Syllable: 'pKp, Count: 728.0
# Syllable: 'mOlm, Count: 0.0
# Syllable: 'trEg, Count: 30.0
# Syllable: 'pMs, Count: 554.0
# Syllable: 'rof, Count: 187.0
# Syllable: 'sxErv, Count: 0.0
# Syllable: 'plet, Count: 1529.0
# Syllable: 'mAr, Count: 1299.0
# Syllable: 'stuts, Count: 0.0
# Syllable: 'stAf, Count: 597.0
# Syllable: dEN, Count: 2636.0
# Syllable: 'dok, Count: 205.0
# Syllable: plax, Count: 11.0
# Syllable: 'brIlt, Count: 0.0
# Syllable: 'rOkt, Count: 0.0
# Syllable: 'hon, Count: 16.0
# Syllable: 'klAp, Count: 1362.0
# Syllable: '_Em, Count: 4.0
# Syllable: frMw, Count: 2698.0
# Syllable: prim, Count: 0.0
# Syllable: xuts, Count: 0.0
# Syllable: 'kAS, Count: 47.0
# Syllable: 'xEl, Count: 550.0
# Syllable: stAf, Count: 64.0
# Syllable: xoj, Count: 7.0
# Syllable: 'Ze, Count: 681.0
# Syllable: t|r, Count: 862.0
# Syllable: dINs, Count: 668.0
# Syllable: 'bKns, Count: 0.0
# Syllable: 'mAms, Count: 196.0
# Syllable: f@l, Count: 6556.0
# Syllable: hos, Count: 3.0
# Syllable: 'bOt, Count: 973.0
# Syllable: xANz, Count: 0.0
# Syllable: spAlt, Count: 6.0
# Syllable: krik, Count: 0.0
# Syllable: 'tON, Count: 1442.0
# Syllable: 'lOdz, Count: 62.0
# Syllable: 'm}N, Count: 11.0
# Syllable: slAG, Count: 174.0
# Syllable: z@r, Count: 6173.0
# Syllable: 'norts, Count: 2.0
# Syllable: trIk, Count: 13.0
# Syllable: 'nAnt, Count: 2786.0
# Syllable: krEN, Count: 0.0
# Syllable: 'xor, Count: 130.0
# Syllable: Gats, Count: 0.0
# Syllable: xOdz, Count: 44.0
# Syllable: 'suS, Count: 0.0
# Syllable: 'hal, Count: 22291.0
# Syllable: 'gust, Count: 2.0
# Syllable: mIts, Count: 0.0
# Syllable: m@, Count: 227160.0
# Syllable: 'bErx, Count: 1682.0
# Syllable: 'dEsk, Count: 5.0
# Syllable: '}rn, Count: 52.0
# Syllable: 'rIs, Count: 551.0
# Syllable: rIn, Count: 0.0
# Syllable: pr@m, Count: 0.0
# Syllable: 'G}ld, Count: 0.0
# Syllable: klAs, Count: 80.0
# Syllable: 'drAx, Count: 2711.0
# Syllable: 'tLx, Count: 781.0
# Syllable: 'ent, Count: 393.0
# Syllable: nOp, Count: 1.0
# Syllable: 'krefts, Count: 13.0
# Syllable: 's}rt, Count: 431.0
# Syllable: vri, Count: 38.0
# Syllable: 'Gren, Count: 23.0
# Syllable: S}p, Count: 2.0
# Syllable: p@s, Count: 137.0
# Syllable: kEs, Count: 3.0
# Syllable: vIx, Count: 0.0
# Syllable: xOl, Count: 0.0
# Syllable: klAp, Count: 41.0
# Syllable: fry, Count: 0.0
# Syllable: l}x, Count: 395.0
# Syllable: 'trups, Count: 0.0
# Syllable: vort, Count: 299.0
# Syllable: 'sxref, Count: 1867.0
# Syllable: vOlk, Count: 10.0
# Syllable: kOrd, Count: 30.0
# Syllable: xlor, Count: 5.0
# Syllable: 'sxLm, Count: 190.0
# Syllable: 'vlEG, Count: 0.0
# Syllable: 'vir, Count: 14640.0
# Syllable: j|s, Count: 5.0
# Syllable: 'plEns, Count: 6.0
# Syllable: pAf, Count: 1.0
# Syllable: 'war, Count: 163067.0
# Syllable: tiz, Count: 5.0
# Syllable: 'stLd, Count: 17.0
# Syllable: vM, Count: 50.0
# Syllable: d}n, Count: 12.0
# Syllable: 'mEks, Count: 113.0
# Syllable: stIft, Count: 300.0
# Syllable: 'Ak, Count: 2443.0
# Syllable: 'krEm, Count: 8.0
# Syllable: 'spEkt, Count: 21.0
# Syllable: 'stOkt, Count: 4.0
# Syllable: trAps, Count: 1.0
# Syllable: zAx, Count: 19.0
# Syllable: 'knAkt, Count: 0.0
# Syllable: 'klam, Count: 0.0
# Syllable: p}l, Count: 145.0
# Syllable: 'sAG, Count: 4.0
# Syllable: slKm, Count: 3.0
# Syllable: m@l, Count: 14839.0
# Syllable: 'GOl, Count: 4.0
# Syllable: fest, Count: 1381.0
# Syllable: zwar, Count: 122.0
# Syllable: 'nAl, Count: 0.0
# Syllable: 'SIs, Count: 86.0
# Syllable: 'lOmp, Count: 125.0
# Syllable: 'tim, Count: 5488.0
# Syllable: 'rI, Count: 1974.0
# Syllable: 'k}t, Count: 552.0
# Syllable: 'da, Count: 23990.0
# Syllable: 'nEn, Count: 133.0
# Syllable: SAl, Count: 0.0
# Syllable: 'zId, Count: 3.0
# Syllable: 'snEr, Count: 0.0
# Syllable: 'mIks, Count: 187.0
# Syllable: 'nams, Count: 12.0
# Syllable: bOns, Count: 0.0
# Syllable: 'zer, Count: 6926.0
# Syllable: }n, Count: 31.0
# Syllable: 'sEz, Count: 0.0
# Syllable: 'lom, Count: 21.0
# Syllable: 'kInd, Count: 0.0
# Syllable: 'rur, Count: 710.0
# Syllable: 'sxLnt, Count: 0.0
# Syllable: z<, Count: 41.0
# Syllable: 'torts, Count: 60.0
# Syllable: 'fAn, Count: 26.0
# Syllable: 'its, Count: 98340.0
# Syllable: 'bart, Count: 588.0
# Syllable: 'At, Count: 124.0
# Syllable: djEs, Count: 0.0
# Syllable: bLs, Count: 178.0
# Syllable: lAj, Count: 3.0
# Syllable: 'bruk, Count: 3157.0
# Syllable: 'bAlx, Count: 1.0
# Syllable: trApt, Count: 12.0
# Syllable: 'prEz, Count: 3.0
# Syllable: 'fli, Count: 99.0
# Syllable: 'Gaft, Count: 120.0
# Syllable: 'sprONs, Count: 0.0
# Syllable: lOk, Count: 28.0
# Syllable: mEN, Count: 4.0
# Syllable: 'dil, Count: 2471.0
# Syllable: 'kl|ms, Count: 0.0
# Syllable: 'xA, Count: 397.0
# Syllable: 'spOj, Count: 3.0
# Syllable: 'sEnd, Count: 253.0
# Syllable: krEs, Count: 0.0
# Syllable: wi, Count: 568.0
# Syllable: slep, Count: 16.0
# Syllable: 'stOr, Count: 779.0
# Syllable: 'rKx, Count: 0.0
# Syllable: tLz, Count: 0.0
# Syllable: ort, Count: 217.0
# Syllable: b}, Count: 196.0
# Syllable: 'hIs, Count: 0.0
# Syllable: tAp, Count: 0.0
# Syllable: hud, Count: 5.0
# Syllable: 'dorz, Count: 0.0
# Syllable: zLm, Count: 11.0
# Syllable: 'xro, Count: 519.0
# Syllable: lEst, Count: 0.0
# Syllable: 'pap, Count: 3.0
# Syllable: wEG, Count: 16.0
# Syllable: 'mons, Count: 4.0
# Syllable: r@ld, Count: 665.0
# Syllable: 'm}nt, Count: 820.0
# Syllable: 'muj, Count: 12285.0
# Syllable: 'spAjk, Count: 200.0
# Syllable: stErk, Count: 68.0
# Syllable: 'skrEm, Count: 4.0
# Syllable: 'pLm, Count: 9.0
# Syllable: 'rLts, Count: 0.0
# Syllable: 'wAlx, Count: 219.0
# Syllable: 'sko, Count: 561.0
# Syllable: 'bErs, Count: 0.0
# Syllable: rIf, Count: 35.0
# Syllable: fAt, Count: 801.0
# Syllable: mAnt, Count: 85055.0
# Syllable: 'pfAj, Count: 18.0
# Syllable: 'nIpt, Count: 44.0
# Syllable: Ast, Count: 7.0
# Syllable: plL, Count: 38.0
# Syllable: 'blE, Count: 1.0
# Syllable: lik, Count: 5.0
# Syllable: 'kox, Count: 0.0
# Syllable: 'stOn, Count: 17.0
# Syllable: sprit, Count: 12.0
# Syllable: 'tuN, Count: 0.0
# Syllable: 'trent, Count: 516.0
# Syllable: 'tAkt, Count: 4731.0
# Syllable: 'xlO, Count: 1.0
# Syllable: kl}ks, Count: 0.0
# Syllable: fInt, Count: 17.0
# Syllable: 'SwA, Count: 0.0
# Syllable: jas, Count: 0.0
# Syllable: 'lEd, Count: 1.0
# Syllable: 'prLm, Count: 66.0
# Syllable: flAx, Count: 0.0
# Syllable: wItS, Count: 253.0
# Syllable: 'sprIts, Count: 0.0
# Syllable: Zur, Count: 1135.0
# Syllable: 'strIk, Count: 181.0
# Syllable: 'rINk, Count: 4.0
# Syllable: sm}, Count: 4.0
# Syllable: r}zd, Count: 2.0
# Syllable: 'fO, Count: 200.0
# Syllable: wOnt, Count: 359.0
# Syllable: 'drIl, Count: 43.0
# Syllable: 'wKg, Count: 0.0
# Syllable: stats, Count: 4.0
# Syllable: gAs, Count: 0.0
# Syllable: 'rEnS, Count: 494.0
# Syllable: spL, Count: 69.0
# Syllable: 'vOrzd, Count: 0.0
# Syllable: 'sEl, Count: 2418.0
# Syllable: dIGd, Count: 2167.0
# Syllable: fEk, Count: 385.0
# Syllable: mAjs, Count: 0.0
# Syllable: 'klIts, Count: 0.0
# Syllable: 'wOlf, Count: 895.0
# Syllable: horN, Count: 1.0
# Syllable: 'flINk, Count: 1730.0
# Syllable: 'plKd, Count: 2.0
# Syllable: bEd, Count: 12.0
# Syllable: 'wErk, Count: 31839.0
# Syllable: 'nalz, Count: 0.0
# Syllable: sla, Count: 825.0
# Syllable: tLm, Count: 0.0
# Syllable: 'sprak, Count: 130.0
# Syllable: En, Count: 2303.0
# Syllable: 'd}xt, Count: 20.0
# Syllable: stro, Count: 161.0
# Syllable: pl}n, Count: 4.0
# Syllable: 'plex, Count: 803.0
# Syllable: drOp, Count: 0.0
# Syllable: 'dOs, Count: 34.0
# Syllable: 'klLf, Count: 37.0
# Syllable: 'snO, Count: 107.0
# Syllable: 'fIrn, Count: 0.0
# Syllable: stAx, Count: 0.0
# Syllable: sxMw, Count: 20.0
# Syllable: 'wek, Count: 10443.0
# Syllable: jAl, Count: 0.0
# Syllable: 'wOlv, Count: 0.0
# Syllable: 'dI, Count: 22855.0
# Syllable: t}z, Count: 7.0
# Syllable: 'slav, Count: 185.0
# Syllable: vlAx, Count: 2.0
# Syllable: f@nt, Count: 491.0
# Syllable: hom, Count: 2.0
# Syllable: 'drit, Count: 1159.0
# Syllable: wEl, Count: 3394.0
# Syllable: GlAt, Count: 10.0
# Syllable: tMws, Count: 0.0
# Syllable: 'low, Count: 2.0
# Syllable: lOrt, Count: 0.0
# Syllable: dOms, Count: 11.0
# Syllable: 'ZwA, Count: 27.0
# Syllable: 'hOrs, Count: 35.0
# Syllable: mAxt, Count: 764.0
# Syllable: rAb, Count: 0.0
# Syllable: 'trEk, Count: 2373.0
# Syllable: 'plKs, Count: 114.0
# Syllable: 'kAts, Count: 0.0
# Syllable: xAm, Count: 1.0
# Syllable: 'tu, Count: 45349.0
# Syllable: 'kErf, Count: 24.0
# Syllable: 'nom, Count: 78.0
# Syllable: nun, Count: 0.0
# Syllable: 'fes, Count: 927.0
# Syllable: 'snM, Count: 19.0
# Syllable: 'sANk, Count: 12.0
# Syllable: 'blEn, Count: 0.0
# Syllable: k}p, Count: 3.0
# Syllable: 'spL, Count: 307.0
# Syllable: rAf, Count: 8.0
# Syllable: 'zIx, Count: 37065.0
# Syllable: 'kEsp, Count: 0.0
# Syllable: 'p|s, Count: 11.0
# Syllable: 'pols, Count: 28.0
# Syllable: 'GAl, Count: 14.0
# Syllable: dim, Count: 0.0
# Syllable: 'fAzd, Count: 3.0
# Syllable: 'vr|xt, Count: 43.0
# Syllable: su, Count: 3609.0
# Syllable: d@m, Count: 4185.0
# Syllable: 'bret, Count: 272.0
# Syllable: 'klEts, Count: 842.0
# Syllable: kEm, Count: 0.0
# Syllable: nort, Count: 9.0
# Syllable: xrup, Count: 289.0
# Syllable: 'l}p, Count: 1.0
# Syllable: 'Sel, Count: 2124.0
# Syllable: 'sxAn, Count: 1113.0
# Syllable: trup, Count: 9.0
# Syllable: '_Ojnt, Count: 285.0
# Syllable: 'xOr, Count: 460.0
# Syllable: dEk, Count: 213.0
# Syllable: fas, Count: 0.0
# Syllable: 'l}zd, Count: 0.0
# Syllable: Gaj, Count: 0.0
# Syllable: stil, Count: 0.0
# Syllable: sxAnst, Count: 0.0
# Syllable: GEs, Count: 26.0
# Syllable: 'mArS, Count: 38.0
# Syllable: 'Gud, Count: 6.0
# Syllable: 'vu, Count: 10009.0
# Syllable: 'ver, Count: 6307.0
# Syllable: 't}rf, Count: 24.0
# Syllable: 'j}, Count: 103953.0
# Syllable: 'ply, Count: 171.0
# Syllable: rON, Count: 6.0
# Syllable: 'xirst, Count: 5.0
# Syllable: 'dirs, Count: 0.0
# Syllable: gwe, Count: 0.0
# Syllable: farts, Count: 0.0
# Syllable: sxrew, Count: 0.0
# Syllable: r@l, Count: 7540.0
# Syllable: 'lKk, Count: 20108.0
# Syllable: skEp, Count: 8.0
# Syllable: Ser, Count: 6.0
# Syllable: 'kn}rft, Count: 9.0
# Syllable: sxEl, Count: 70.0
# Syllable: 'stanz, Count: 0.0
# Syllable: k|s, Count: 14.0
# Syllable: 'Zans, Count: 0.0
# Syllable: mAs, Count: 461.0
# Syllable: trEx, Count: 0.0
# Syllable: lAns, Count: 42.0
# Syllable: 'sprANk, Count: 36.0
# Syllable: 'did, Count: 13.0
# Syllable: 'pOz, Count: 36.0
# Syllable: 'kr}ks, Count: 9.0
# Syllable: sxOr, Count: 153.0
# Syllable: 'blAt, Count: 726.0
# Syllable: flO, Count: 3.0
# Syllable: 'nik, Count: 3585.0
# Syllable: 'rje, Count: 9.0
# Syllable: 'd}N, Count: 37.0
# Syllable: GrAp, Count: 12.0
# Syllable: GAl, Count: 5.0
# Syllable: stIl, Count: 460.0
# Syllable: 'xrax, Count: 25527.0
# Syllable: 'kry, Count: 60.0
# Syllable: 'hops, Count: 0.0
# Syllable: 'zAt, Count: 14954.0
# Syllable: vIz, Count: 0.0
# Syllable: 'Se, Count: 1983.0
# Syllable: 'stEg, Count: 0.0
# Syllable: p}ndz, Count: 0.0
# Syllable: 'slap, Count: 6852.0
# Syllable: SEnt, Count: 0.0
# Syllable: 'sAl, Count: 261.0
# Syllable: l@z, Count: 45.0
# Syllable: drajt, Count: 4.0
# Syllable: 'klov, Count: 0.0
# Syllable: 'wAlG, Count: 1.0
# Syllable: 'r}N, Count: 0.0
# Syllable: hes, Count: 0.0
# Syllable: 'kAt, Count: 2396.0
# Syllable: NEnt, Count: 45.0
# Syllable: 'st}x, Count: 55.0
# Syllable: SIm, Count: 0.0
# Syllable: 'lOz, Count: 99.0
# Syllable: flLs, Count: 18.0
# Syllable: 'wIxts, Count: 29.0
# Syllable: tr}s, Count: 3.0
# Syllable: wAnts, Count: 0.0
# Syllable: 'pOg, Count: 0.0
# Syllable: sxak, Count: 137.0
# Syllable: 'ZAnts, Count: 0.0
# Syllable: nKs, Count: 0.0
# Syllable: jiN, Count: 0.0
# Syllable: 'pl}x, Count: 48.0
# Syllable: 'vrat, Count: 14.0
# Syllable: rINks, Count: 4.0
# Syllable: 'sxM, Count: 1360.0
# Syllable: snO, Count: 4.0
# Syllable: 'im, Count: 0.0
# Syllable: nAst, Count: 1.0
# Syllable: 'spr|k, Count: 268.0
# Syllable: 'Ast, Count: 170.0
# Syllable: kry, Count: 210.0
# Syllable: tSIn, Count: 8.0
# Syllable: 'kin, Count: 15.0
# Syllable: nit, Count: 61.0
# Syllable: 'grIlt, Count: 2.0
# Syllable: 'pONk, Count: 1.0
# Syllable: vElt, Count: 277.0
# Syllable: lEp, Count: 81.0
# Syllable: NIN, Count: 337.0
# Syllable: pOn, Count: 173.0
# Syllable: 'syr, Count: 50.0
# Syllable: by, Count: 5469.0
# Syllable: 'slEN, Count: 946.0
# Syllable: xrax, Count: 22.0
# Syllable: 'fInt, Count: 0.0
# Syllable: 'tars, Count: 0.0
# Syllable: 'knIp, Count: 368.0
# Syllable: 'gOjs, Count: 0.0
# Syllable: 'zEnd, Count: 26.0
# Syllable: 'sxKl, Count: 0.0
# Syllable: wIn, Count: 501.0
# Syllable: arts, Count: 0.0
# Syllable: 'ruf, Count: 5.0
# Syllable: 'rOmp, Count: 296.0
# Syllable: 'xOlf, Count: 935.0
# Syllable: 'GOlft, Count: 8.0
# Syllable: 'hOnd, Count: 3.0
# Syllable: 'was, Count: 40.0
# Syllable: nOts, Count: 0.0
# Syllable: 'puf, Count: 45.0
# Syllable: 'zIts, Count: 0.0
# Syllable: 'brEn, Count: 377.0
# Syllable: 'krAGd, Count: 54.0
# Syllable: h}, Count: 8.0
# Syllable: prOmp, Count: 0.0
# Syllable: 'hemst, Count: 0.0
# Syllable: 'pOts, Count: 0.0
# Syllable: 'mOls, Count: 4.0
# Syllable: 'laG, Count: 5.0
# Syllable: 'GON, Count: 0.0
# Syllable: var, Count: 1977.0
# Syllable: lIxt, Count: 1365.0
# Syllable: 'wKl, Count: 7579.0
# Syllable: 'mKm, Count: 22.0
# Syllable: 'brigz, Count: 0.0
# Syllable: bInt, Count: 0.0
# Syllable: lEz, Count: 74.0
# Syllable: 'skat, Count: 0.0
# Syllable: stOl, Count: 7.0
# Syllable: ZIt, Count: 140.0
# Syllable: jEf, Count: 0.0
# Syllable: 'lAmb, Count: 0.0
# Syllable: 'wKts, Count: 5.0
# Syllable: 'drINg, Count: 24.0
# Syllable: 'sEmpt, Count: 0.0
# Syllable: El, Count: 25338.0
# Syllable: 'pErg, Count: 0.0
# Syllable: 'kAlfs, Count: 70.0
# Syllable: 'kiw, Count: 1.0
# Syllable: swu, Count: 0.0
# Syllable: 'rust, Count: 162.0
# Syllable: 'mEtS, Count: 168.0
# Syllable: puts, Count: 9.0
# Syllable: 'Ek, Count: 2690.0
# Syllable: 'pMn, Count: 0.0
# Syllable: 'strAv, Count: 652.0
# Syllable: 'bLx, Count: 40.0
# Syllable: tarn, Count: 123.0
# Syllable: kwIN, Count: 4.0
# Syllable: dar, Count: 22959.0
# Syllable: 'kirs, Count: 0.0
# Syllable: 'slop, Count: 216.0
# Syllable: 'smL, Count: 0.0
# Syllable: 'strAks, Count: 8575.0
# Syllable: bErm, Count: 3.0
# Syllable: 'strOnt, Count: 1226.0
# Syllable: N@rz, Count: 8.0
# Syllable: lEk, Count: 1417.0
# Syllable: snOr, Count: 3.0
# Syllable: lEx, Count: 647.0
# Syllable: lis, Count: 504.0
# Syllable: 'ZAs, Count: 193.0
# Syllable: to, Count: 39525.0
# Syllable: 'maG, Count: 240.0
# Syllable: xOlf, Count: 136.0
# Syllable: GrI, Count: 2.0
# Syllable: Op, Count: 14057.0
# Syllable: 'tEzd, Count: 12.0
# Syllable: 'smak, Count: 1361.0
# Syllable: 'swAx, Count: 0.0
# Syllable: sus, Count: 8.0
# Syllable: 'ek, Count: 271.0
# Syllable: stem, Count: 2.0
# Syllable: 'vojs, Count: 0.0
# Syllable: wul, Count: 2.0
# Syllable: 'blKt, Count: 148.0
# Syllable: 'bOrt, Count: 1197.0
# Syllable: wI, Count: 1396.0
# Syllable: 'rEns, Count: 3.0
# Syllable: 'kl}, Count: 176.0
# Syllable: huv, Count: 0.0
# Syllable: 'r}r, Count: 42.0
# Syllable: 'lOp, Count: 312.0
# Syllable: strok, Count: 35.0
# Syllable: 'rAns, Count: 0.0
# Syllable: l<, Count: 2.0
# Syllable: _@rs, Count: 2.0
# Syllable: d@rzd, Count: 0.0
# Syllable: warts, Count: 1267.0
# Syllable: mKns, Count: 0.0
# Syllable: flOp, Count: 0.0
# Syllable: 'IN, Count: 4116.0
# Syllable: 'vlEkt, Count: 22.0
# Syllable: 'pl), Count: 0.0
# Syllable: 'nav, Count: 0.0
# Syllable: 'sket, Count: 0.0
# Syllable: 'swis, Count: 3.0
# Syllable: 'kIt, Count: 324.0
# Syllable: fis, Count: 187.0
# Syllable: 'hKs, Count: 190.0
# Syllable: 'xElt, Count: 34895.0
# Syllable: dE, Count: 522.0
# Syllable: 'tSif, Count: 0.0
# Syllable: 'wOrm, Count: 634.0
# Syllable: 'twK, Count: 2551.0
# Syllable: 'krAs, Count: 103.0
# Syllable: 'plAnt, Count: 536.0
# Syllable: 'lovs, Count: 0.0
# Syllable: vojst, Count: 0.0
# Syllable: sEst, Count: 60.0
# Syllable: swEN, Count: 0.0
# Syllable: GAr, Count: 2.0
# Syllable: 'kOj, Count: 0.0
# Syllable: 'brLN, Count: 3.0
# Syllable: j@m, Count: 5.0
# Syllable: 'klo, Count: 1329.0
# Syllable: 'xrAz, Count: 1.0
# Syllable: 'prON, Count: 64.0
# Syllable: dAm, Count: 13.0
# Syllable: 'bez, Count: 106.0
# Syllable: 'bOrm, Count: 0.0
# Syllable: 'swit, Count: 0.0
# Syllable: 'pEkt, Count: 3231.0
# Syllable: 'wru, Count: 102.0
# Syllable: 'fl}rt, Count: 190.0
# Syllable: GOrt, Count: 0.0
# Syllable: paps, Count: 0.0
# Syllable: 'hers, Count: 0.0
# Syllable: 'plOv, Count: 0.0
# Syllable: Art, Count: 5.0
# Syllable: r@lt, Count: 18697.0
# Syllable: zun, Count: 153.0
# Syllable: 'pEk, Count: 53.0
# Syllable: 'tKd, Count: 179.0
# Syllable: 'sum, Count: 0.0
# Syllable: 'brot, Count: 2075.0
# Syllable: m@lz, Count: 12.0
# Syllable: blINk, Count: 0.0
# Syllable: klOt, Count: 0.0
# Syllable: Oms, Count: 4.0
# Syllable: 'ves, Count: 0.0
# Syllable: frik, Count: 14.0
# Syllable: bOs, Count: 37.0
# Syllable: 'det, Count: 0.0
# Syllable: 'l}s, Count: 394.0
# Syllable: 'sIs, Count: 418.0
# Syllable: spri, Count: 0.0
# Syllable: plo, Count: 697.0
# Syllable: 'dwO, Count: 743.0
# Syllable: 'kwAl, Count: 78.0
# Syllable: 'wid, Count: 0.0
# Syllable: 'spAl, Count: 14.0
# Syllable: jIms, Count: 1.0
# Syllable: zOns, Count: 1032.0
# Syllable: 'kart, Count: 1418.0
# Syllable: ZEd, Count: 0.0
# Syllable: 'fLk, Count: 7.0
# Syllable: 'tIm, Count: 0.0
# Syllable: prL, Count: 0.0
# Syllable: p@rz, Count: 0.0
# Syllable: tje, Count: 1.0
# Syllable: stOv, Count: 20.0
# Syllable: 'kOrf, Count: 19.0
# Syllable: 'strOn, Count: 1.0
# Syllable: 'krust, Count: 2.0
# Syllable: din, Count: 210.0
# Syllable: 'filt, Count: 0.0
# Syllable: 'lOf, Count: 1843.0
# Syllable: 'zAr, Count: 371.0
# Syllable: kIg, Count: 0.0
# Syllable: klet, Count: 313.0
# Syllable: dr}m, Count: 0.0
# Syllable: dr}ft, Count: 0.0
# Syllable: f}, Count: 66.0
# Syllable: flEs, Count: 150.0
# Syllable: 'sxrab, Count: 0.0
# Syllable: 'xre, Count: 103.0
# Syllable: g), Count: 6.0
# Syllable: trIl, Count: 28.0
# Syllable: 'mat, Count: 5079.0
# Syllable: trop, Count: 0.0
# Syllable: Zu, Count: 2.0
# Syllable: mOns, Count: 0.0
# Syllable: '_us, Count: 71.0
# Syllable: 'jAnd, Count: 3.0
# Syllable: 'b}d, Count: 0.0
# Syllable: 'huzd, Count: 4.0
# Syllable: 'spOns, Count: 110.0
# Syllable: 'krO, Count: 124.0
# Syllable: 'bil, Count: 1393.0
# Syllable: 'rLg, Count: 0.0
# Syllable: 'hyw, Count: 11.0
# Syllable: 'jE, Count: 147.0
# Syllable: 'GlIst, Count: 0.0
# Syllable: 'dEkt, Count: 667.0
# Syllable: 'fArm, Count: 81.0
# Syllable: pry, Count: 16.0
# Syllable: 'kl}ts, Count: 67.0
# Syllable: 'skMt, Count: 120.0
# Syllable: 'xoj, Count: 3220.0
# Syllable: kIs, Count: 0.0
# Syllable: vlE, Count: 1.0
# Syllable: fil, Count: 2.0
# Syllable: 'tot, Count: 5.0
# Syllable: GrIl, Count: 2.0
# Syllable: 'j), Count: 3.0
# Syllable: bol, Count: 21.0
# Syllable: 'wElft, Count: 1.0
# Syllable: 'xOrz, Count: 0.0
# Syllable: bO, Count: 210.0
# Syllable: 't|rs, Count: 17.0
# Syllable: 'skrE, Count: 59.0
# Syllable: 'Ses, Count: 3.0
# Syllable: 'box, Count: 445.0
# Syllable: f@m, Count: 7.0
# Syllable: hEmts, Count: 0.0
# Syllable: 'smus, Count: 191.0
# Syllable: buk, Count: 2245.0
# Syllable: 'b}ts, Count: 1.0
# Syllable: 'stAlt, Count: 1.0
# Syllable: 'SErp, Count: 30.0
# Syllable: p)r, Count: 0.0
# Syllable: 'vrin, Count: 1894.0
# Syllable: kwEs, Count: 64.0
# Syllable: 'mew, Count: 28.0
# Syllable: 'zal, Count: 681.0
# Syllable: 'tErn, Count: 97.0
# Syllable: steg, Count: 0.0
# Syllable: 'kES, Count: 382.0
# Syllable: b}s, Count: 506.0
# Syllable: 'f}l, Count: 290.0
# Syllable: Axt, Count: 276.0
# Syllable: nIN, Count: 24287.0
# Syllable: bOrG, Count: 0.0
# Syllable: 'wo, Count: 5629.0
# Syllable: rEmt, Count: 13.0
# Syllable: 'snar, Count: 35.0
# Syllable: 'ser, Count: 122.0
# Syllable: plAg, Count: 10.0
# Syllable: 'vlAk, Count: 2217.0
# Syllable: sxIk, Count: 2.0
# Syllable: 'trAp, Count: 2322.0
# Syllable: 'Sert, Count: 27.0
# Syllable: slLt, Count: 34.0
# Syllable: port, Count: 941.0
# Syllable: 'nKt, Count: 15.0
# Syllable: 'smeg, Count: 26.0
# Syllable: 'tan, Count: 251.0
# Syllable: krAt, Count: 0.0
# Syllable: 'vuG, Count: 68.0
# Syllable: 'zweb, Count: 0.0
# Syllable: 'st}r, Count: 46.0
# Syllable: 'S), Count: 124.0
# Syllable: 'stu, Count: 556.0
# Syllable: 'tarn, Count: 72.0
# Syllable: 'stri, Count: 42.0
# Syllable: 'brLkt, Count: 19.0
# Syllable: trEnt, Count: 8.0
# Syllable: 'pert, Count: 18.0
# Syllable: frax, Count: 91.0
# Syllable: 'tINk, Count: 0.0
# Syllable: 'j}t, Count: 17.0
# Syllable: rarz, Count: 0.0
# Syllable: 'sxeps, Count: 137.0
# Syllable: 'nje, Count: 10.0
# Syllable: kraft, Count: 13.0
# Syllable: Ek, Count: 5389.0
# Syllable: 'lAxs, Count: 1.0
# Syllable: pus, Count: 236.0
# Syllable: 'fik, Count: 309.0
# Syllable: hOp, Count: 0.0
# Syllable: 'st}nt, Count: 368.0
# Syllable: rimz, Count: 0.0
# Syllable: sxre, Count: 342.0
# Syllable: 'xral, Count: 220.0
# Syllable: 'kMst, Count: 79.0
# Syllable: 'b}m, Count: 113.0
# Syllable: xraf, Count: 80.0
# Syllable: lof, Count: 525.0
# Syllable: wAm, Count: 13.0
# Syllable: r|k, Count: 0.0
# Syllable: snLf, Count: 0.0
# Syllable: 'zwAN, Count: 5.0
# Syllable: 'kil, Count: 393.0
# Syllable: sAl, Count: 92.0
# Syllable: 'zwans, Count: 0.0
# Syllable: pAxt, Count: 1.0
# Syllable: 'kOzd, Count: 293.0
# Syllable: lun, Count: 75.0
# Syllable: 'dAnt, Count: 2308.0
# Syllable: pris, Count: 68.0
# Syllable: 'soN, Count: 0.0
# Syllable: w}m, Count: 0.0
# Syllable: 'sxErt, Count: 9.0
# Syllable: 'vliG, Count: 213.0
# Syllable: 'Eks, Count: 728.0
# Syllable: nid, Count: 4734.0
# Syllable: xAs, Count: 248.0
# Syllable: nIm, Count: 6.0
# Syllable: v@rz, Count: 1.0
# Syllable: wEp, Count: 0.0
# Syllable: GrKn, Count: 1.0
# Syllable: 'drANk, Count: 3489.0
# Syllable: klMn, Count: 7.0
# Syllable: darz, Count: 0.0
# Syllable: 'sid, Count: 0.0
# Syllable: 'sxir, Count: 46.0
# Syllable: trEks, Count: 0.0
# Syllable: 'stAx, Count: 58.0
# Syllable: _Ojnt, Count: 0.0
# Syllable: 'vrOn, Count: 28.0
# Syllable: N@z, Count: 1.0
# Syllable: ow, Count: 0.0
# Syllable: strIk, Count: 353.0
# Syllable: 'hOv, Count: 17.0
# Syllable: slOmp, Count: 13.0
# Syllable: 'sOms, Count: 15299.0
# Syllable: 'ir, Count: 0.0
# Syllable: 'kler, Count: 270.0
# Syllable: 'stIpt, Count: 158.0
# Syllable: 'blAk, Count: 2.0
# Syllable: 'sme, Count: 3330.0
# Syllable: 'pIls, Count: 40.0
# Syllable: sxi, Count: 4815.0
# Syllable: 'sxA, Count: 2742.0
# Syllable: stIp, Count: 475.0
# Syllable: 'G}s, Count: 472.0
# Syllable: @m, Count: 15.0
# Syllable: 'krLp, Count: 19.0
# Syllable: 'kIzd, Count: 0.0
# Syllable: fel, Count: 145.0
# Syllable: sxEnt, Count: 0.0
# Syllable: 'streks, Count: 571.0
# Syllable: 'bON, Count: 75.0
# Syllable: 'tSe, Count: 98.0
# Syllable: br}x, Count: 120.0
# Syllable: 'zug, Count: 0.0
# Syllable: 'horN, Count: 3.0
# Syllable: zEz, Count: 6.0
# Syllable: 'kag, Count: 10.0
# Syllable: 'lat, Count: 90866.0
# Syllable: dof, Count: 94.0
# Syllable: 'tipt, Count: 47.0
# Syllable: 'Snit, Count: 22.0
# Syllable: 'zKns, Count: 0.0
# Syllable: aN, Count: 213.0
# Syllable: 'et, Count: 996.0
# Syllable: 'hElp, Count: 12244.0
# Syllable: 'nirs, Count: 44.0
# Syllable: 'spreg, Count: 87.0
# Syllable: 'Kn, Count: 9383.0
# Syllable: 'brLs, Count: 7.0
# Syllable: 'G}n, Count: 110.0
# Syllable: 'log, Count: 0.0
# Syllable: k}r, Count: 31.0
# Syllable: 'ven, Count: 13.0
# Syllable: 'taf, Count: 12.0
# Syllable: 'brAz, Count: 1.0
# Syllable: 'ar, Count: 9483.0
# Syllable: 'knok, Count: 0.0
# Syllable: 'wIx, Count: 119.0
# Syllable: rEnts, Count: 0.0
# Syllable: 'h}ps, Count: 5.0
# Syllable: vI, Count: 81.0
# Syllable: 'drLl, Count: 40.0
# Syllable: 'mOrf, Count: 4.0
# Syllable: na, Count: 56112.0
# Syllable: sxErm, Count: 48.0
# Syllable: 'jK, Count: 195609.0
# Syllable: 'kwab, Count: 0.0
# Syllable: 'slExt, Count: 11786.0
# Syllable: po, Count: 26918.0
# Syllable: 'sxOrt, Count: 123.0
# Syllable: 'smIt, Count: 119.0
# Syllable: tArt, Count: 9.0
# Syllable: 'mAks, Count: 1.0
# Syllable: 'twA, Count: 2.0
# Syllable: 'l|t, Count: 11.0
# Syllable: Get, Count: 0.0
# Syllable: 'fan, Count: 12.0
# Syllable: 'vLt, Count: 31.0
# Syllable: 'zert, Count: 677.0
# Syllable: 't}r, Count: 692.0
# Syllable: kAk, Count: 4.0
# Syllable: 'drEN, Count: 26.0
# Syllable: 'strEg, Count: 0.0
# Syllable: 'gEd, Count: 140.0
# Syllable: tS@, Count: 224.0
# Syllable: 'k}n, Count: 1276.0
# Syllable: mKl, Count: 5.0
# Syllable: 'slO, Count: 969.0
# Syllable: 'des, Count: 0.0
# Syllable: d@xt, Count: 1655.0
# Syllable: 'putS, Count: 2.0
# Syllable: r}p, Count: 2.0
# Syllable: Gj|, Count: 0.0
# Syllable: 'del, Count: 8346.0
# Syllable: sonz, Count: 26.0
# Syllable: 'j|k, Count: 125.0
# Syllable: 'h)t, Count: 7.0
# Syllable: 'prLg, Count: 0.0
# Syllable: kym, Count: 0.0
# Syllable: 'hAnts, Count: 175.0
# Syllable: 'hOr, Count: 58.0
# Syllable: wInts, Count: 5.0
# Syllable: 'snAp, Count: 9622.0
# Syllable: 'uj, Count: 88.0
# Syllable: jEnt, Count: 0.0
# Syllable: ')n, Count: 0.0
# Syllable: 'dotz, Count: 2.0
# Syllable: 'preg, Count: 0.0
# Syllable: pE, Count: 349.0
# Syllable: spi, Count: 2277.0
# Syllable: sal, Count: 751.0
# Syllable: krE, Count: 13.0
# Syllable: mKn, Count: 2514.0
# Syllable: 'mIr, Count: 0.0
# Syllable: 'Smi, Count: 1.0
# Syllable: 'tAst, Count: 261.0
# Syllable: 'stKf, Count: 446.0
# Syllable: 'ZEn, Count: 0.0
# Syllable: 'boN, Count: 0.0
# Syllable: hEnt, Count: 7.0
# Syllable: nA, Count: 551.0
# Syllable: 'oj, Count: 12.0
# Syllable: v@k, Count: 0.0
# Syllable: An, Count: 1871.0
# Syllable: 'pr}, Count: 79.0
# Syllable: fKn, Count: 63.0
# Syllable: w}, Count: 0.0
# Syllable: dLm, Count: 2.0
# Syllable: 'ky, Count: 906.0
# Syllable: drIk, Count: 0.0
# Syllable: 'kEr, Count: 795.0
# Syllable: 'Erft, Count: 0.0
# Syllable: 'stL, Count: 415.0
# Syllable: wIxts, Count: 4.0
# Syllable: 'nil, Count: 94.0
# Syllable: 'bl}ts, Count: 1.0
# Syllable: 'brugz, Count: 1.0
# Syllable: 'rOl, Count: 2976.0
# Syllable: lOst, Count: 38.0
# Syllable: S), Count: 3.0
# Syllable: 'zwEl, Count: 95.0
# Syllable: trAg, Count: 0.0
# Syllable: 'trit, Count: 5.0
# Syllable: 'Grik, Count: 0.0
# Syllable: zil, Count: 29.0
# Syllable: 'zunz, Count: 0.0
# Syllable: 'vlAG, Count: 1.0
# Syllable: flIkt, Count: 11.0
# Syllable: tAt, Count: 22.0
# Syllable: l@nt, Count: 2669.0
# Syllable: 'li, Count: 42609.0
# Syllable: zAnt, Count: 83.0
# Syllable: 'hEks, Count: 1170.0
# Syllable: 'mAd, Count: 0.0
# Syllable: Af, Count: 3790.0
# Syllable: tInt, Count: 1.0
# Syllable: rEmp, Count: 0.0
# Syllable: 'xe, Count: 22434.0
# Syllable: swAk, Count: 3.0
# Syllable: tem, Count: 621.0
# Syllable: 'lKvz, Count: 2.0
# Syllable: twA, Count: 2049.0
# Syllable: 't}xt, Count: 87.0
# Syllable: 've, Count: 6482.0
# Syllable: 'krEnt, Count: 67.0
# Syllable: 'kwEt, Count: 601.0
# Syllable: rKn, Count: 237.0
# Syllable: 'Gant, Count: 33.0
# Syllable: wAs, Count: 263.0
# Syllable: 'plExt, Count: 0.0
# Syllable: knA, Count: 612.0
# Syllable: 'xruj, Count: 275.0
# Syllable: 'd}g, Count: 0.0
# Syllable: 'sirz, Count: 0.0
# Syllable: Gruf, Count: 0.0
# Syllable: 'vres, Count: 1289.0
# Syllable: 'tSEs, Count: 131.0
# Syllable: 'nar, Count: 195818.0
# Syllable: rKm, Count: 2.0
# Syllable: bKdz, Count: 40.0
# Syllable: Zik, Count: 0.0
# Syllable: 'zAm, Count: 1.0
# Syllable: 'krIs, Count: 539.0
# Syllable: z}s, Count: 701.0
# Syllable: 'vrEk, Count: 59.0
# Syllable: 'waxt, Count: 159.0
# Syllable: z}r, Count: 0.0
# Syllable: 'pKl, Count: 151.0
# Syllable: 'SmiNk, Count: 14.0
# Syllable: 'prONk, Count: 23.0
# Syllable: k@nt, Count: 8003.0
# Syllable: tINs, Count: 365.0
# Syllable: GMw, Count: 0.0
# Syllable: lEt, Count: 454.0
# Syllable: pEs, Count: 33.0
# Syllable: 'Zim, Count: 119.0
# Syllable: 'vIr, Count: 1.0
# Syllable: slo, Count: 1845.0
# Syllable: 'kOrz, Count: 0.0
# Syllable: 'pr}ts, Count: 23.0
# Syllable: 'lO, Count: 3267.0
# Syllable: 'strAnd, Count: 6.0
# Syllable: b}z, Count: 0.0
# Syllable: 'stroj, Count: 5.0
# Syllable: krLk, Count: 1.0
# Syllable: drAjv, Count: 69.0
# Syllable: 'korts, Count: 664.0
# Syllable: 'smAxt, Count: 55.0
# Syllable: 'lAnts, Count: 33.0
# Syllable: 'rIspt, Count: 0.0
# Syllable: 'dral, Count: 85.0
# Syllable: 'h}lp, Count: 11101.0
# Syllable: 'rKks, Count: 113.0
# Syllable: djOp, Count: 0.0
# Syllable: jaN, Count: 21.0
# Syllable: 'Mt, Count: 9504.0
# Syllable: lKk, Count: 671.0
# Syllable: 'Gox, Count: 9.0
# Syllable: 'star, Count: 209.0
# Syllable: wIx, Count: 2.0
# Syllable: kwAnt, Count: 0.0
# Syllable: 'lON, Count: 700.0
# Syllable: 'nj), Count: 0.0
# Syllable: 'smat, Count: 32.0
# Syllable: lIx, Count: 1359.0
# Syllable: 'sprMw, Count: 0.0
# Syllable: 'rEpt, Count: 24.0
# Syllable: 'd)n, Count: 8.0
# Syllable: stO, Count: 322.0
# Syllable: 'pir, Count: 2009.0
# Syllable: 'wIld, Count: 10.0
# Syllable: 'kle, Count: 7253.0
# Syllable: 'fler, Count: 0.0
# Syllable: 'blEk, Count: 0.0
# Syllable: 'flOp, Count: 94.0
# Syllable: 'bAl, Count: 3860.0
# Syllable: 'lAv, Count: 98.0
# Syllable: bEnt, Count: 18.0
# Syllable: 'lMw, Count: 36.0
# Syllable: kOxt, Count: 135.0
# Syllable: wik, Count: 5.0
# Syllable: 'sens, Count: 0.0
# Syllable: 'rKd, Count: 1.0
# Syllable: 'blam, Count: 57.0
# Syllable: 'prAGd, Count: 8.0
# Syllable: 'muf, Count: 14.0
# Syllable: 'tirs, Count: 1.0
# Syllable: j}, Count: 117.0
# Syllable: korts, Count: 110.0
# Syllable: 'fIts, Count: 1.0
# Syllable: 'xAlx, Count: 110.0
# Syllable: loft, Count: 73.0
# Syllable: t@x, Count: 55061.0
# Syllable: 'GEst, Count: 0.0
# Syllable: 'kwEst, Count: 0.0
# Syllable: Glo, Count: 51.0
# Syllable: 'bErk, Count: 10.0
# Syllable: 'z}s, Count: 9739.0
# Syllable: 'brIt, Count: 24.0
# Syllable: x@l, Count: 1915.0
# Syllable: 'kn}l, Count: 2433.0
# Syllable: 'fax, Count: 50.0
# Syllable: 'h}, Count: 516.0
# Syllable: nes, Count: 38.0
# Syllable: xanz, Count: 0.0
# Syllable: k}st, Count: 309.0
# Syllable: kwam, Count: 2.0
# Syllable: 'huf, Count: 5325.0
# Syllable: 'prInz, Count: 2.0
# Syllable: ses, Count: 1.0
# Syllable: dLn, Count: 0.0
# Syllable: fen, Count: 0.0
# Syllable: 'nim, Count: 437.0
# Syllable: z|r, Count: 33.0
# Syllable: 'dEpt, Count: 0.0
# Syllable: 'klof, Count: 186.0
# Syllable: 'leb, Count: 0.0
# Syllable: 'ton, Count: 1954.0
# Syllable: 'hep, Count: 28.0
# Syllable: 'Mk, Count: 0.0
# Syllable: 'sMt, Count: 0.0
# Syllable: 'vAm, Count: 912.0
# Syllable: 'zOrxt, Count: 2786.0
# Syllable: 's<, Count: 12.0
# Syllable: 'xril, Count: 0.0
# Syllable: tle, Count: 0.0
# Syllable: 'tAm, Count: 88.0
# Syllable: 'prOp, Count: 156.0
# Syllable: 'vAlst, Count: 11.0
# Syllable: 'spEk, Count: 544.0
# Syllable: bomt, Count: 0.0
# Syllable: krAmp, Count: 29.0
# Syllable: sL, Count: 453.0
# Syllable: 'trIl, Count: 53.0
# Syllable: GEnt, Count: 810.0
# Syllable: 'lEts, Count: 0.0
# Syllable: bArk, Count: 0.0
# Syllable: k@m, Count: 649.0
# Syllable: t@s, Count: 2892.0
# Syllable: 'telt, Count: 8.0
# Syllable: 'sAz, Count: 0.0
# Syllable: sprakt, Count: 47.0
# Syllable: Ob, Count: 1007.0
# Syllable: sn}, Count: 54.0
# Syllable: SI, Count: 0.0
# Syllable: 'bas, Count: 7422.0
# Syllable: 'hENst, Count: 210.0
# Syllable: 'hywd, Count: 0.0
# Syllable: 'stop, Count: 0.0
# Syllable: G@m, Count: 231.0
# Syllable: GlAns, Count: 0.0
# Syllable: 'pOv, Count: 3.0
# Syllable: flix, Count: 104.0
# Syllable: fAs, Count: 0.0
# Syllable: nast, Count: 0.0
# Syllable: 'lAn, Count: 3799.0
# ...
# Syllable: Glu, Count: 1.0
# Syllable: 'zat, Count: 288.0
# Syllable: 'plEn, Count: 11.0
# Syllable: pa, Count: 25763.0
# Syllable: 'zKN, Count: 0.0
# Syllable: Ar, Count: 3939.0
# Syllable: 'tj), Count: 0.0
# Syllable: 'dwe, Count: 27.0
# Syllable: 'bet, Count: 20687.0
# Syllable: 'dIx, Count: 1284.0
# Syllable: j}Nk, Count: 7.0
# Syllable: fLs, Count: 0.0
# Syllable: 'skob, Count: 23.0
# Syllable: 'r|t, Count: 2.0
# Syllable: 'klANk, Count: 64.0
# Syllable: w@nt, Count: 154.0
# Syllable: brI, Count: 0.0
# Syllable: 'vOxt, Count: 708.0
# Syllable: dAN, Count: 26.0
# Syllable: 'bidz, Count: 0.0
# Syllable: weG, Count: 0.0
# Syllable: 'G}nt, Count: 0.0
# Syllable: 'nirz, Count: 0.0
# Syllable: 'dolt, Count: 1.0
# Syllable: 'kAlg, Count: 0.0
# Syllable: 'Zirs, Count: 76.0
# Syllable: klas, Count: 4.0
# Syllable: 'Elms, Count: 2.0
# Syllable: S@, Count: 2415.0
# Syllable: 'drENk, Count: 0.0
# Syllable: 'blK, Count: 23488.0
# Syllable: klef, Count: 0.0
# Syllable: 'pyr, Count: 1058.0
# Syllable: 'fOn, Count: 25.0
# Syllable: tAjm, Count: 216.0
# Syllable: san, Count: 0.0
# Syllable: grMnt, Count: 14.0
# Syllable: 'fir, Count: 159.0
# Syllable: 'dy, Count: 5698.0
# Syllable: 'zilt, Count: 25.0
# Syllable: NINs, Count: 6.0
# Syllable: 'xryw, Count: 0.0
# Syllable: k@rz, Count: 0.0
# Syllable: 'dumt, Count: 188.0
# Syllable: 'po, Count: 5152.0
# Syllable: xlO, Count: 1.0
# Syllable: rIs, Count: 1042.0
# Syllable: 'vo, Count: 6774.0
# Syllable: lOs, Count: 71.0
# Syllable: bord, Count: 5.0
# Syllable: 'rirz, Count: 11.0
# Syllable: Kn, Count: 110.0
# Syllable: drIf, Count: 0.0
# Syllable: 'rKm, Count: 65.0
# Syllable: 'sxen, Count: 140.0
# Syllable: sxyw, Count: 78.0
# Syllable: 'kIg, Count: 0.0
# Syllable: rat, Count: 1992.0
# Syllable: jes, Count: 0.0
# Syllable: 'Kk, Count: 70.0
# Syllable: 'dyl, Count: 0.0
# Syllable: 'vl}Gd, Count: 0.0
# Syllable: 'dwAN, Count: 331.0
# Syllable: di, Count: 34759.0
# Syllable: bIn, Count: 396.0
# Syllable: l@N, Count: 0.0
# Syllable: 'plOp, Count: 13.0
# Syllable: 'tost, Count: 256.0
# Syllable: 'zuf, Count: 8.0
# Syllable: rOnd, Count: 7.0
# Syllable: 'mAG, Count: 151.0
# Syllable: lu, Count: 293.0
# Syllable: 'tEgzd, Count: 7.0
# Syllable: 'l|, Count: 3196.0
# Syllable: 't}m, Count: 10.0
# Syllable: 'zil, Count: 3868.0
# Syllable: swi, Count: 58.0
# Syllable: 'tit, Count: 215.0
# Syllable: 'spAlk, Count: 16.0
# Syllable: 'jul, Count: 9.0
# Syllable: 'm}lt, Count: 29.0
# Syllable: 'zwer, Count: 3474.0
# Syllable: 'wul, Count: 2.0
# Syllable: 'snLt, Count: 83.0
# Syllable: wrAk, Count: 7.0
# Syllable: blys, Count: 0.0
# Syllable: 'xrus, Count: 0.0
# Syllable: 'x|l, Count: 53.0
# Syllable: dop, Count: 25.0
# Syllable: vL, Count: 15.0
# Syllable: 'kis, Count: 1835.0
# Syllable: 'plAd, Count: 73.0
# Syllable: 'spIN, Count: 0.0
# Syllable: 'sxOl, Count: 24.0
# Syllable: Ks, Count: 85.0
# Syllable: drOn, Count: 2.0
# Syllable: 'bEsk, Count: 6.0
# Syllable: j@z, Count: 17.0
# Syllable: 'pEts, Count: 6.0
# Syllable: xrAf, Count: 15.0
# Syllable: 'xrL, Count: 1.0
# Syllable: 'lup, Count: 12.0
# Syllable: tLn, Count: 927.0
# Syllable: S|r, Count: 16.0
# Syllable: rIgz, Count: 0.0
# Syllable: 'tLm, Count: 20.0
# Syllable: 'xOm, Count: 22.0
# Syllable: 'stOrd, Count: 23.0
# Syllable: 'jam, Count: 0.0
# Syllable: doj, Count: 0.0
# Syllable: 'jist, Count: 4.0
# Syllable: 'GrIp, Count: 669.0
# Syllable: sxots, Count: 30.0
# Syllable: 'sOk, Count: 136.0
# Syllable: plAk, Count: 3.0
# Syllable: 'res, Count: 1251.0
# Syllable: 'AGd, Count: 84.0
# Syllable: xA, Count: 167.0
# Syllable: moj, Count: 32.0
# Syllable: 'grEk, Count: 0.0
# Syllable: Ad, Count: 1171.0
# Syllable: GAlm, Count: 3.0
# Syllable: 'SON, Count: 2.0
# Syllable: 'rK, Count: 19370.0
# Syllable: 'jadz, Count: 0.0
# Syllable: blAn, Count: 0.0
# Syllable: stIx, Count: 258.0
# Syllable: kErks, Count: 0.0
# Syllable: lOf, Count: 98.0
# Syllable: Ert, Count: 3.0
# Syllable: 'nin, Count: 0.0
# Syllable: 'dun, Count: 119035.0
# Syllable: kl|m, Count: 1.0
# Syllable: 'krek, Count: 42.0
# Syllable: 'lEns, Count: 187.0
# Syllable: 'pErt, Count: 0.0
# Syllable: kEtS, Count: 0.0
# Syllable: t@t, Count: 143.0
# Syllable: 'klAs, Count: 2516.0
# Syllable: 'rols, Count: 0.0
# Syllable: 'tik, Count: 3955.0
# Syllable: vr}xt, Count: 9.0
# Syllable: p}n, Count: 25.0
# Syllable: 'hoft, Count: 15502.0
# Syllable: 'bOs, Count: 2973.0
# Syllable: 'stErg, Count: 0.0
# Syllable: 'sxru, Count: 102.0
# Syllable: ve, Count: 906.0
# Syllable: 'l)r, Count: 978.0
# Syllable: 'twIs, Count: 105.0
# Syllable: 'hoG, Count: 86.0
# Syllable: 'wAs, Count: 232330.0
# Syllable: 'pIts, Count: 1.0
# Syllable: 'bKl, Count: 406.0
# Syllable: vlA, Count: 1.0
# Syllable: 'zLp, Count: 160.0
# Syllable: 'zOrx, Count: 9668.0
# Syllable: 'kAlm, Count: 3182.0
# Syllable: 'zul, Count: 0.0
# Syllable: hLt, Count: 86.0
# Syllable: 'vEd, Count: 5.0
# Syllable: xri, Count: 16.0
# Syllable: GElt, Count: 1209.0
# Syllable: 'sxIg, Count: 616.0
# Syllable: kwAp, Count: 26.0
# Syllable: rOkt, Count: 0.0
# Syllable: pwi, Count: 0.0
# Syllable: oft, Count: 0.0
# Syllable: sAlm, Count: 0.0
# Syllable: 'hLd, Count: 22.0
# Syllable: sO, Count: 416.0
# Syllable: brag, Count: 2.0
# Syllable: 'x}lp, Count: 77.0
# Syllable: 'bl}st, Count: 42.0
# Syllable: 'prOpt, Count: 41.0
# Syllable: fro, Count: 197.0
# Syllable: lan, Count: 49.0
# Syllable: dels, Count: 125.0
# Syllable: 'kwKl, Count: 60.0
# Syllable: 'pAjs, Count: 5.0
# Syllable: 'r}rx, Count: 387.0
# Syllable: 'gAj, Count: 17.0
# Syllable: wKl, Count: 0.0
# Syllable: 'kEx, Count: 0.0
# Syllable: 'Ardz, Count: 0.0
# Syllable: 'plEN, Count: 0.0
# Syllable: b}r, Count: 2051.0
# Syllable: 'skrEt, Count: 7.0
# Syllable: twKn, Count: 0.0
# Syllable: 'vlMw, Count: 0.0
# Syllable: tjAr, Count: 0.0
# Syllable: 'nOns, Count: 36.0
# Syllable: gE, Count: 0.0
# Syllable: 'lOl, Count: 2498.0
# Syllable: 'kwen, Count: 0.0
# Syllable: slot, Count: 0.0
# Syllable: kn}, Count: 20.0
# Syllable: sp}n, Count: 0.0
# Syllable: 'b|rz, Count: 0.0
# Syllable: 'lyr, Count: 0.0
# Syllable: p}lt, Count: 64.0
# Syllable: 'spis, Count: 38.0
# Syllable: 'x}t, Count: 66.0
# Syllable: p@rs, Count: 117.0
# Syllable: 'trKl, Count: 0.0
# Syllable: 'jAk, Count: 2066.0
# Syllable: trAnz, Count: 0.0
# Syllable: 'wEns, Count: 2605.0
# Syllable: Se, Count: 24.0
# Syllable: lAn, Count: 1163.0
# Syllable: 'trozd, Count: 23.0
# Syllable: 'ters, Count: 0.0
# Syllable: 'fl}k, Count: 0.0
# Syllable: 'xAs, Count: 1587.0
# Syllable: wENk, Count: 63.0
# Syllable: 'spInt, Count: 27.0
# Syllable: flArt, Count: 1.0
# Syllable: spEl, Count: 934.0
# Syllable: pEls, Count: 0.0
# Syllable: xu, Count: 10962.0
# Syllable: 'nM, Count: 66024.0
# Syllable: drax, Count: 0.0
# Syllable: 'wAlz, Count: 0.0
# Syllable: 'trIp, Count: 402.0
# Syllable: 'spOr, Count: 204.0
# Syllable: 'xefs, Count: 4.0
# Syllable: 'skIn, Count: 22.0
# Syllable: 'GaN, Count: 0.0
# Syllable: 'mOnt, Count: 7493.0
# Syllable: frint, Count: 26.0
# Syllable: 'hAt, Count: 0.0
# Syllable: 'jON, Count: 4087.0
# Syllable: b@s, Count: 816.0
# Syllable: 'hemt, Count: 11.0
# Syllable: 'pik, Count: 271.0
# Syllable: 'kojs, Count: 15.0
# Syllable: 'vler, Count: 141.0
# Syllable: 'sp}r, Count: 8.0
# Syllable: kAlkt, Count: 1.0
# Syllable: sEt, Count: 827.0
# Syllable: 'knir, Count: 0.0
# Syllable: fit, Count: 5.0
# Syllable: st}k, Count: 2213.0
# Syllable: rot, Count: 280.0
# Syllable: 'slo, Count: 5068.0
# Syllable: 'gru, Count: 47.0
# Syllable: 'radz, Count: 0.0
# Syllable: rExt, Count: 3220.0
# Syllable: 'dan, Count: 46645.0
# Syllable: 'wAlk, Count: 58.0
# Syllable: reps, Count: 0.0
# Syllable: 'z}l, Count: 0.0
# Syllable: Zim, Count: 2.0
# Syllable: 'sik, Count: 503.0
# Syllable: bAGdz, Count: 0.0
# Syllable: 'pre, Count: 550.0
# Syllable: 'drOG, Count: 3.0
# Syllable: b@rt, Count: 221.0
# Syllable: 'rAnz, Count: 0.0
# Syllable: 'lez, Count: 85.0
# Syllable: 'zwIl, Count: 0.0
# Syllable: 'bral, Count: 7.0
# Syllable: s@rz, Count: 64.0
# Syllable: 'kard, Count: 0.0
# Syllable: 'pMnt, Count: 2.0
# Syllable: sEns, Count: 1.0
# Syllable: GIst, Count: 0.0
# Syllable: Egz, Count: 2.0
# Syllable: 'tIN, Count: 3.0
# Syllable: 'lANs, Count: 8453.0
# Syllable: 'Arts, Count: 1436.0
# Syllable: 'vlAg, Count: 0.0
# Syllable: 'ses, Count: 7.0
# Syllable: xes, Count: 0.0
# Syllable: 'GrAnt, Count: 61.0
# Syllable: 'sxON, Count: 10.0
# Syllable: 'tAj, Count: 1080.0
# Syllable: knIp, Count: 0.0
# Syllable: Ext, Count: 1.0
# Syllable: 'brod, Count: 158.0
# Syllable: '_Oj, Count: 13.0
# Syllable: 'wAl, Count: 2580.0
# Syllable: sKl, Count: 54.0
# Syllable: 'nI, Count: 980.0
# Syllable: krIpt, Count: 0.0
# Syllable: 'slot, Count: 479.0
# Syllable: kErst, Count: 282.0
# Syllable: 'luj, Count: 8.0
# Syllable: tMw, Count: 41.0
# Syllable: 'f*r, Count: 50.0
# Syllable: 'dOG, Count: 9.0
# Syllable: 'sm|r, Count: 0.0
# Syllable: 'dIk, Count: 2310.0
# Syllable: dris, Count: 3.0
# Syllable: b|rt, Count: 98.0
# Syllable: vrint, Count: 143.0
# Syllable: 'zes, Count: 17.0
# Syllable: tElt, Count: 8.0
# Syllable: 'kMs, Count: 98.0
# Syllable: 'dult, Count: 22.0
# Syllable: 'mer, Count: 89562.0
# Syllable: 'bot, Count: 7974.0
# Syllable: 'ry, Count: 2890.0
# Syllable: 'wLt, Count: 0.0
# Syllable: 'wIz, Count: 6.0
# Syllable: 'GIN, Count: 5.0
# Syllable: 'hOn, Count: 2378.0
# Syllable: z@m, Count: 381.0
# Syllable: drOl, Count: 51.0
# Syllable: bar, Count: 13640.0
# Syllable: 'spAm, Count: 0.0
# Syllable: 'fKl, Count: 45.0
# Syllable: 'pMw, Count: 42.0
# Syllable: r@ns, Count: 133.0
# Syllable: 'snup, Count: 949.0
# Syllable: v@s, Count: 2895.0
# Syllable: smL, Count: 0.0
# Syllable: 'nAp, Count: 7.0
# Syllable: 'kruG, Count: 10.0
# Syllable: 'sprO, Count: 22.0
# Syllable: mu, Count: 2744.0
# Syllable: sprEk, Count: 251.0
# Syllable: delt, Count: 115.0
# Syllable: 'krot, Count: 1.0
# Syllable: 'plANk, Count: 655.0
# Syllable: 'jEs, Count: 106.0
# Syllable: krIs, Count: 456.0
# Syllable: xas, Count: 4.0
# Syllable: 'smEld, Count: 0.0
# Syllable: 'slLk, Count: 2.0
# Syllable: 'zwIx, Count: 33.0
# Syllable: )r, Count: 0.0
# Syllable: 'bOl, Count: 522.0
# Syllable: 'hArts, Count: 156.0
# Syllable: 'lof, Count: 20453.0
# Syllable: 'hLl, Count: 67.0
# Syllable: plKn, Count: 83.0
# Syllable: 'rert, Count: 63.0
# Syllable: smed, Count: 0.0
# Syllable: bA, Count: 4557.0
# Syllable: lum, Count: 0.0
# Syllable: b@rts, Count: 0.0
# Syllable: 'xruv, Count: 0.0
# Syllable: vIs, Count: 490.0
# Syllable: 'p)l, Count: 0.0
# Syllable: 'sxun, Count: 741.0
# Syllable: 'spOrd, Count: 17.0
# Syllable: 'dIG, Count: 139.0
# Syllable: hywt, Count: 0.0
# Syllable: 'reN, Count: 0.0
# Syllable: 'pan, Count: 17.0
# Syllable: 'sk}Nk, Count: 14.0
# Syllable: xKt, Count: 0.0
# Syllable: bEdz, Count: 0.0
# Syllable: 'futs, Count: 36.0
# Syllable: g@n, Count: 62.0
# Syllable: hyr, Count: 28.0
# Syllable: 'nEnt, Count: 417.0
# Syllable: zer, Count: 6.0
# Syllable: 'fEr, Count: 87.0
# Syllable: 'wOrx, Count: 0.0
# Syllable: d@rs, Count: 35208.0
# Syllable: tard, Count: 0.0
# Syllable: 'bran, Count: 11.0
# Syllable: fMt, Count: 93.0
# Syllable: 'lLdz, Count: 21.0
# Syllable: kIk, Count: 41.0
# Syllable: kAS, Count: 0.0
# Syllable: 'nAs, Count: 16.0
# Syllable: 'tyr, Count: 29872.0
# Syllable: blIn, Count: 73.0
# Syllable: 'knOf, Count: 220.0
# Syllable: 'spIt, Count: 65.0
# Syllable: 'woN, Count: 444.0
# Syllable: vliG, Count: 10.0
# Syllable: 's}mp, Count: 33.0
# Syllable: 'mOf, Count: 91.0
# Syllable: ja, Count: 24436.0
# Syllable: mo, Count: 23015.0
# Syllable: 'wekt, Count: 76.0
# Syllable: 'ral, Count: 5609.0
# Syllable: 'jA, Count: 4831.0
# Syllable: 'kwEdz, Count: 585.0
# Syllable: 'spEl, Count: 4773.0
# Syllable: tr}, Count: 0.0
# Syllable: fi, Count: 16404.0
# Syllable: 'snEl, Count: 22220.0
# Syllable: slav, Count: 4.0
# Syllable: 'wIk, Count: 5.0
# Syllable: 'smMt, Count: 0.0
# Syllable: blum, Count: 84.0
# Syllable: gAm, Count: 0.0
# Syllable: vAm, Count: 160.0
# Syllable: 'vaG, Count: 1.0
# Syllable: L, Count: 1547.0
# Syllable: nAGd, Count: 0.0
# Syllable: 'smet, Count: 71.0
# Syllable: 'pat, Count: 432.0
# Syllable: stort, Count: 3.0
# Syllable: 'ter, Count: 279.0
# Syllable: 'fAt, Count: 182.0
# Syllable: 'pis, Count: 137.0
# Syllable: 'dwKm, Count: 1.0
# Syllable: pro, Count: 43197.0
# Syllable: 'hir, Count: 213828.0
# Syllable: 'r)r, Count: 41.0
# Syllable: Gan, Count: 10649.0
# Syllable: 'sO, Count: 28480.0
# Syllable: GIN, Count: 13776.0
# Syllable: 'kwIl, Count: 0.0
# Syllable: klIp, Count: 57.0
# Syllable: 'jLst, Count: 11738.0
# Syllable: 'nE, Count: 416.0
# Syllable: 'k}nz, Count: 0.0
# Syllable: 'vlErk, Count: 20.0
# Syllable: 'pEl, Count: 900.0
# Syllable: vlix, Count: 61.0
# Syllable: 'kraxt, Count: 0.0
# Syllable: 'vlOs, Count: 0.0
# Syllable: rEst, Count: 350.0
# Syllable: 'skyr, Count: 23.0
# Syllable: spu, Count: 267.0
# Syllable: p}ls, Count: 1.0
# Syllable: 'trEx, Count: 23.0
# Syllable: p@l, Count: 8245.0
# Syllable: 'vlK, Count: 180.0
# Syllable: Mts, Count: 14.0
# Syllable: 'lOrt, Count: 949.0
# Syllable: dIs, Count: 2075.0
# Syllable: 'luv, Count: 0.0
# Syllable: 'p}p, Count: 141.0
# Syllable: 'lAg, Count: 0.0
# Syllable: 'krus, Count: 240.0
# Syllable: 'zwu, Count: 70.0
# Syllable: 'lev, Count: 26.0
# Syllable: blO, Count: 687.0
# Syllable: 'pEs, Count: 1067.0
# Syllable: 'krIN, Count: 182.0
# Syllable: 'kl}ns, Count: 90.0
# Syllable: sxrot, Count: 2.0
# Syllable: d}l, Count: 0.0
# Syllable: st@r, Count: 6682.0
# Syllable: pra, Count: 733.0
# Syllable: 'weG, Count: 69.0
# Syllable: r@k, Count: 0.0
# Syllable: sxEts, Count: 13.0
# Syllable: zOl, Count: 5.0
# Syllable: 'pArt, Count: 3733.0
# Syllable: xit, Count: 10.0
# Syllable: xlut, Count: 1.0
# Syllable: gro, Count: 0.0
# Syllable: 'wArm, Count: 3632.0
# Syllable: rEn, Count: 505.0
# Syllable: 'ku, Count: 1454.0
# Syllable: bars, Count: 4.0
# Syllable: 'jAG, Count: 0.0
# Syllable: 'lIps, Count: 1.0
# Syllable: b@rs, Count: 0.0
# Syllable: 'dax, Count: 16791.0
# Syllable: 'smKt, Count: 0.0
# Syllable: 'GlIn, Count: 0.0
# Syllable: 'vam, Count: 0.0
# Syllable: nAx, Count: 0.0
# Syllable: 'plInt, Count: 0.0
# Syllable: knOp, Count: 69.0
# Syllable: 'slup, Count: 88.0
# Syllable: 'kot, Count: 86.0
# Syllable: 'xin, Count: 11.0
# Syllable: 'strK, Count: 1335.0
# Syllable: n@, Count: 266696.0
# Syllable: 'blAn, Count: 0.0
# Syllable: Grujt, Count: 9.0
# Syllable: 'Sunz, Count: 0.0
# Syllable: l)r, Count: 0.0
# Syllable: 'bid, Count: 0.0
# Syllable: 'fAjn, Count: 0.0
# Syllable: 'talt, Count: 3855.0
# Syllable: 'sot, Count: 0.0
# Syllable: 'bra, Count: 370.0
# Syllable: sxeps, Count: 0.0
# Syllable: z@s, Count: 2654.0
# Syllable: 'b|G, Count: 0.0
# Syllable: 'por, Count: 1.0
# Syllable: n}ts, Count: 6.0
# Syllable: 'vElt, Count: 909.0
# Syllable: 'slA, Count: 442.0
# Syllable: vErf, Count: 30.0
# Syllable: 'fti, Count: 0.0
# Syllable: 'ryr, Count: 0.0
# Syllable: 'el, Count: 2.0
# Syllable: 'xO, Count: 1162.0
# Syllable: 'sp|, Count: 72.0
# Syllable: 'oft, Count: 0.0
# Syllable: sels, Count: 0.0
# Syllable: 'dAxt, Count: 2888.0
# Syllable: 'pAlm, Count: 142.0
# Syllable: 'd}rf, Count: 2082.0
# Syllable: 'he, Count: 15399.0
# Syllable: 'lirs, Count: 2.0
# Syllable: 'flest, Count: 1.0
# Syllable: sIst, Count: 0.0
# Syllable: 'tSIr, Count: 2.0
# Syllable: 'pOk, Count: 14.0
# Syllable: 'sxAlks, Count: 0.0
# Syllable: 'jMw, Count: 32133.0
# Syllable: 'kraj, Count: 117.0
# Syllable: 'xrut, Count: 332.0
# Syllable: 'Zirz, Count: 2.0
# Syllable: sti, Count: 561.0
# Syllable: n@nst, Count: 0.0
# Syllable: sxE, Count: 361.0
# Syllable: jys, Count: 789.0
# Syllable: 'tAf, Count: 7.0
# Syllable: 'xEms, Count: 1.0
# Syllable: t}, Count: 696.0
# Syllable: dos, Count: 214.0
# Syllable: l}m, Count: 30.0
# Syllable: N@, Count: 89688.0
# Syllable: nEk, Count: 17.0
# Syllable: 'hofts, Count: 1.0
# Syllable: 'teg, Count: 3.0
# Syllable: sxOts, Count: 13.0
# Syllable: 'ple, Count: 1826.0
# Syllable: 'f|, Count: 97.0
# Syllable: 'zAjn, Count: 38.0
# Syllable: 'spIdz, Count: 0.0
# Syllable: 'snes, Count: 0.0
# Syllable: GrOn, Count: 0.0
# Syllable: 'strEtS, Count: 16.0
# Syllable: 'blax, Count: 11.0
# Syllable: 'wO, Count: 3338.0
# Syllable: 'S|, Count: 589.0
# Syllable: 'snOl, Count: 105.0
# Syllable: 'tOr, Count: 84.0
# Syllable: kwa, Count: 688.0
# Syllable: f)r, Count: 2.0
# Syllable: kuts, Count: 100.0
# Syllable: wu, Count: 7.0
# Syllable: 'plu, Count: 156.0
# Syllable: 'xnOs, Count: 0.0
# Syllable: vrAx, Count: 0.0
# Syllable: 'spans, Count: 0.0
# Syllable: 'rIxt, Count: 3422.0
# Syllable: 'zwel, Count: 0.0
# Syllable: sax, Count: 5.0
# Syllable: 'rirs, Count: 0.0
# Syllable: tan, Count: 783.0
# Syllable: Sow, Count: 18.0
# Syllable: 'wIls, Count: 127.0
# Syllable: 'b), Count: 91.0
# Syllable: 'rAd, Count: 25.0
# Syllable: klIs, Count: 2.0
# Syllable: GIps, Count: 0.0
# Syllable: 'rAr, Count: 0.0
# Syllable: dot, Count: 296.0
# Syllable: wKs, Count: 1532.0
# Syllable: zol, Count: 13.0
# Syllable: 'Glif, Count: 0.0
# Syllable: 'sxer, Count: 585.0
# Syllable: b<, Count: 5.0
# Syllable: slIn, Count: 0.0
# Syllable: ran, Count: 26.0
# Syllable: 'drE, Count: 84.0
# Syllable: 'numt, Count: 1671.0
# Syllable: w@z, Count: 0.0

# %%
len(syllable_counts)
# Out:
# 13034

# %%
#save syllable_counts to a csv file
syllable_counts_df = pd.DataFrame.from_dict(syllable_counts, orient = 'index', columns = ['Count'])
syllable_counts_df.to_csv('syllable_counts.csv')

# %%
# Load the CSV file
csv_file_path = 'syllable_counts.csv'
syllable_counts_df = pd.read_csv(csv_file_path)

# Ensure the column names are valid MATLAB variable names
syllable_counts_df.columns = ['syllable', 'Count']

# Convert the DataFrame to a dictionary of arrays, making sure each column is a separate entry
syllable_table_dict = {}
for col in syllable_counts_df.columns:
    syllable_table_dict[col] = syllable_counts_df[col].values

# Save the dictionary as a MATLAB file
new_mat_file_path = 'syllable_freq_table_new.mat'
scipy.io.savemat(new_mat_file_path, syllable_table_dict)

print(f"Updated .mat file saved at: {new_mat_file_path}")
# Out:
# Updated .mat file saved at: syllable_freq_table_new.mat

# %%
#MOUS word phonetic transcriptions. how many words are there whose syllables are uncounted?

# %%
stimuli = 'stimuli.txt'
#remove all numbers and make every word in the txt a row in a dataframe column
with open(stimuli, 'r') as f:
    words = f.read().splitlines()
#remove all numbers
mous_words = []
for line in words:
    tokens = line.split(" ")
    for token in tokens:
        if token.isdigit():
            tokens.remove(token)
    mous_words.extend([token.lower() for token in tokens if token != ''])
#make a dataframe
mous_words = pd.DataFrame(mous_words, columns = ['Word'])
mous_words.drop_duplicates(inplace = True)
mous_words.reset_index(drop = True, inplace = True)
mous_words
# Out:
#             Word
# 0           toen
# 1             de
# 2      barkeeper
# 3            die
# 4      irritante
# ...          ...
# 1937       blije
# 1938    jongeren
# 1939      intens
# 1940     plezier
# 1941  woonplaats
#
# [1942 rows x 1 columns]

# %%
#find the word in words that contains an apostrophe
for word in mous_words['Word']:
    if "'" in word:
        print(word)
# Out:
# collega's
# fotocamera's
# auto's
# dorien's

# %%
#intersect mous_words with new_df on 'Word'
mous_words = mous_words.merge(new_df[['Word','Syllables']], on = 'Word', how = 'left')
mous_words.drop_duplicates(subset = 'Word', inplace = True)
mous_words = mous_words.reset_index(drop = True)
mous_words
# Out:
#             Word        Syllables
# 0           toen           ['tun]
# 1             de            ['d@]
# 2      barkeeper  ['bAr, ki, p@r]
# 3            die            ['di]
# 4      irritante              NaN
# ...          ...              ...
# 1937       blije              NaN
# 1938    jongeren              NaN
# 1939      intens      [In, 'tEns]
# 1940     plezier      [pl@, 'zir]
# 1941  woonplaats    ['wom, plats]
#
# [1942 rows x 2 columns]

# %%
#drop nan values
#mous_words = mous_words.dropna()
mous_words.reset_index(drop = True, inplace = True)
mous_words
# Out:
#             Word        Syllables
# 0           toen           ['tun]
# 1             de            ['d@]
# 2      barkeeper  ['bAr, ki, p@r]
# 3            die            ['di]
# 4      irritante              NaN
# ...          ...              ...
# 1937       blije              NaN
# 1938    jongeren              NaN
# 1939      intens      [In, 'tEns]
# 1940     plezier      [pl@, 'zir]
# 1941  woonplaats    ['wom, plats]
#
# [1942 rows x 2 columns]

# %%
def handle_syllables(x):
    # Check if x is a list (or any iterable except for strings), then proceed with the original operation.
    if isinstance(x, list):
        return [syllable_counts[syl] for syl in x]
    # If x is not a list, return a default value, e.g., an empty list or a list with a specific value indicating the error.
    else:
        return []  # or return [0] or any other placeholder value that makes sense in your context

# Apply the modified function
mous_words['Syllable Occurrence Counts'] = mous_words['Syllables'].apply(handle_syllables)
mous_words
# Out:
#             Word        Syllables Syllable Occurrence Counts
# 0           toen           ['tun]                  [47826.0]
# 1             de            ['d@]                [1061177.0]
# 2      barkeeper  ['bAr, ki, p@r]  [3329.0, 3669.0, 20167.0]
# 3            die            ['di]                 [325903.0]
# 4      irritante              NaN                         []
# ...          ...              ...                        ...
# 1937       blije              NaN                         []
# 1938    jongeren              NaN                         []
# 1939      intens      [In, 'tEns]           [39087.0, 264.0]
# 1940     plezier      [pl@, 'zir]           [5981.0, 5884.0]
# 1941  woonplaats    ['wom, plats]            [175.0, 2617.0]
#
# [1942 rows x 3 columns]

# %%
mous_words
# Out:
#             Word        Syllables Syllable Occurrence Counts
# 0           toen           ['tun]                  [47826.0]
# 1             de            ['d@]                [1061177.0]
# 2      barkeeper  ['bAr, ki, p@r]  [3329.0, 3669.0, 20167.0]
# 3            die            ['di]                 [325903.0]
# 4      irritante              NaN                         []
# ...          ...              ...                        ...
# 1937       blije              NaN                         []
# 1938    jongeren              NaN                         []
# 1939      intens      [In, 'tEns]           [39087.0, 264.0]
# 1940     plezier      [pl@, 'zir]           [5981.0, 5884.0]
# 1941  woonplaats    ['wom, plats]            [175.0, 2617.0]
#
# [1942 rows x 3 columns]

# %% [markdown]
# Bigrams

# %%
#generate a list of all bigrams possible in the alphabet
import string
alphabet = string.ascii_lowercase
bigrams = []
for letter1 in alphabet:
    for letter2 in alphabet:
        bigrams.append(letter1 + letter2)
bigrams
# Out:
# ['aa',
#  'ab',
#  'ac',
#  'ad',
#  'ae',
#  'af',
#  'ag',
#  'ah',
#  'ai',
#  'aj',
#  'ak',
#  'al',
#  'am',
#  'an',
#  'ao',
#  'ap',
#  'aq',
#  'ar',
#  'as',
#  'at',
#  'au',
#  'av',
#  'aw',
#  'ax',
#  'ay',
#  'az',
#  'ba',
#  'bb',
#  'bc',
#  'bd',
#  'be',
#  'bf',
#  'bg',
#  'bh',
#  'bi',
#  'bj',
#  'bk',
#  'bl',
#  'bm',
#  'bn',
#  'bo',
#  'bp',
#  'bq',
#  'br',
#  'bs',
#  'bt',
#  'bu',
#  'bv',
#  'bw',
#  'bx',
#  'by',
#  'bz',
#  'ca',
#  'cb',
#  'cc',
#  'cd',
#  'ce',
#  'cf',
#  'cg',
#  'ch',
#  'ci',
#  'cj',
#  'ck',
#  'cl',
#  'cm',
#  'cn',
#  'co',
#  'cp',
#  'cq',
#  'cr',
#  'cs',
#  'ct',
#  'cu',
#  'cv',
#  'cw',
#  'cx',
#  'cy',
#  'cz',
#  'da',
#  'db',
#  'dc',
#  'dd',
#  'de',
#  'df',
#  'dg',
#  'dh',
#  'di',
#  'dj',
#  'dk',
#  'dl',
#  'dm',
#  'dn',
#  'do',
#  'dp',
#  'dq',
#  'dr',
#  'ds',
#  'dt',
#  'du',
#  'dv',
#  'dw',
#  'dx',
#  'dy',
#  'dz',
#  'ea',
#  'eb',
#  'ec',
#  'ed',
#  'ee',
#  'ef',
#  'eg',
#  'eh',
#  'ei',
#  'ej',
#  'ek',
#  'el',
#  'em',
#  'en',
#  'eo',
#  'ep',
#  'eq',
#  'er',
#  'es',
#  'et',
#  'eu',
#  'ev',
#  'ew',
#  'ex',
#  'ey',
#  'ez',
#  'fa',
#  'fb',
#  'fc',
#  'fd',
#  'fe',
#  'ff',
#  'fg',
#  'fh',
#  'fi',
#  'fj',
#  'fk',
#  'fl',
#  'fm',
#  'fn',
#  'fo',
#  'fp',
#  'fq',
#  'fr',
#  'fs',
#  'ft',
#  'fu',
#  'fv',
#  'fw',
#  'fx',
#  'fy',
#  'fz',
#  'ga',
#  'gb',
#  'gc',
#  'gd',
#  'ge',
#  'gf',
#  'gg',
#  'gh',
#  'gi',
#  'gj',
#  'gk',
#  'gl',
#  'gm',
#  'gn',
#  'go',
#  'gp',
#  'gq',
#  'gr',
#  'gs',
#  'gt',
#  'gu',
#  'gv',
#  'gw',
#  'gx',
#  'gy',
#  'gz',
#  'ha',
#  'hb',
#  'hc',
#  'hd',
#  'he',
#  'hf',
#  'hg',
#  'hh',
#  'hi',
#  'hj',
#  'hk',
#  'hl',
#  'hm',
#  'hn',
#  'ho',
#  'hp',
#  'hq',
#  'hr',
#  'hs',
#  'ht',
#  'hu',
#  'hv',
#  'hw',
#  'hx',
#  'hy',
#  'hz',
#  'ia',
#  'ib',
#  'ic',
#  'id',
#  'ie',
#  'if',
#  'ig',
#  'ih',
#  'ii',
#  'ij',
#  'ik',
#  'il',
#  'im',
#  'in',
#  'io',
#  'ip',
#  'iq',
#  'ir',
#  'is',
#  'it',
#  'iu',
#  'iv',
#  'iw',
#  'ix',
#  'iy',
#  'iz',
#  'ja',
#  'jb',
#  'jc',
#  'jd',
#  'je',
#  'jf',
#  'jg',
#  'jh',
#  'ji',
#  'jj',
#  'jk',
#  'jl',
#  'jm',
#  'jn',
#  'jo',
#  'jp',
#  'jq',
#  'jr',
#  'js',
#  'jt',
#  'ju',
#  'jv',
#  'jw',
#  'jx',
#  'jy',
#  'jz',
#  'ka',
#  'kb',
#  'kc',
#  'kd',
#  'ke',
#  'kf',
#  'kg',
#  'kh',
#  'ki',
#  'kj',
#  'kk',
#  'kl',
#  'km',
#  'kn',
#  'ko',
#  'kp',
#  'kq',
#  'kr',
#  'ks',
#  'kt',
#  'ku',
#  'kv',
#  'kw',
#  'kx',
#  'ky',
#  'kz',
#  'la',
#  'lb',
#  'lc',
#  'ld',
#  'le',
#  'lf',
#  'lg',
#  'lh',
#  'li',
#  'lj',
#  'lk',
#  'll',
#  'lm',
#  'ln',
#  'lo',
#  'lp',
#  'lq',
#  'lr',
#  'ls',
#  'lt',
#  'lu',
#  'lv',
#  'lw',
#  'lx',
#  'ly',
#  'lz',
#  'ma',
#  'mb',
#  'mc',
#  'md',
#  'me',
#  'mf',
#  'mg',
#  'mh',
#  'mi',
#  'mj',
#  'mk',
#  'ml',
#  'mm',
#  'mn',
#  'mo',
#  'mp',
#  'mq',
#  'mr',
#  'ms',
#  'mt',
#  'mu',
#  'mv',
#  'mw',
#  'mx',
#  'my',
#  'mz',
#  'na',
#  'nb',
#  'nc',
#  'nd',
#  'ne',
#  'nf',
#  'ng',
#  'nh',
#  'ni',
#  'nj',
#  'nk',
#  'nl',
#  'nm',
#  'nn',
#  'no',
#  'np',
#  'nq',
#  'nr',
#  'ns',
#  'nt',
#  'nu',
#  'nv',
#  'nw',
#  'nx',
#  'ny',
#  'nz',
#  'oa',
#  'ob',
#  'oc',
#  'od',
#  'oe',
#  'of',
#  'og',
#  'oh',
#  'oi',
#  'oj',
#  'ok',
#  'ol',
#  'om',
#  'on',
#  'oo',
#  'op',
#  'oq',
#  'or',
#  'os',
#  'ot',
#  'ou',
#  'ov',
#  'ow',
#  'ox',
#  'oy',
#  'oz',
#  'pa',
#  'pb',
#  'pc',
#  'pd',
#  'pe',
#  'pf',
#  'pg',
#  'ph',
#  'pi',
#  'pj',
#  'pk',
#  'pl',
#  'pm',
#  'pn',
#  'po',
#  'pp',
#  'pq',
#  'pr',
#  'ps',
#  'pt',
#  'pu',
#  'pv',
#  'pw',
#  'px',
#  'py',
#  'pz',
#  'qa',
#  'qb',
#  'qc',
#  'qd',
#  'qe',
#  'qf',
#  'qg',
#  'qh',
#  'qi',
#  'qj',
#  'qk',
#  'ql',
#  'qm',
#  'qn',
#  'qo',
#  'qp',
#  'qq',
#  'qr',
#  'qs',
#  'qt',
#  'qu',
#  'qv',
#  'qw',
#  'qx',
#  'qy',
#  'qz',
#  'ra',
#  'rb',
#  'rc',
#  'rd',
#  're',
#  'rf',
#  'rg',
#  'rh',
#  'ri',
#  'rj',
#  'rk',
#  'rl',
#  'rm',
#  'rn',
#  'ro',
#  'rp',
#  'rq',
#  'rr',
#  'rs',
#  'rt',
#  'ru',
#  'rv',
#  'rw',
#  'rx',
#  'ry',
#  'rz',
#  'sa',
#  'sb',
#  'sc',
#  'sd',
#  'se',
#  'sf',
#  'sg',
#  'sh',
#  'si',
#  'sj',
#  'sk',
#  'sl',
#  'sm',
#  'sn',
#  'so',
#  'sp',
#  'sq',
#  'sr',
#  'ss',
#  'st',
#  'su',
#  'sv',
#  'sw',
#  'sx',
#  'sy',
#  'sz',
#  'ta',
#  'tb',
#  'tc',
#  'td',
#  'te',
#  'tf',
#  'tg',
#  'th',
#  'ti',
#  'tj',
#  'tk',
#  'tl',
#  'tm',
#  'tn',
#  'to',
#  'tp',
#  'tq',
#  'tr',
#  'ts',
#  'tt',
#  'tu',
#  'tv',
#  'tw',
#  'tx',
#  'ty',
#  'tz',
#  'ua',
#  'ub',
#  'uc',
#  'ud',
#  'ue',
#  'uf',
#  'ug',
#  'uh',
#  'ui',
#  'uj',
#  'uk',
#  'ul',
#  'um',
#  'un',
#  'uo',
#  'up',
#  'uq',
#  'ur',
#  'us',
#  'ut',
#  'uu',
#  'uv',
#  'uw',
#  'ux',
#  'uy',
#  'uz',
#  'va',
#  'vb',
#  'vc',
#  'vd',
#  've',
#  'vf',
#  'vg',
#  'vh',
#  'vi',
#  'vj',
#  'vk',
#  'vl',
#  'vm',
#  'vn',
#  'vo',
#  'vp',
#  'vq',
#  'vr',
#  'vs',
#  'vt',
#  'vu',
#  'vv',
#  'vw',
#  'vx',
#  'vy',
#  'vz',
#  'wa',
#  'wb',
#  'wc',
#  'wd',
#  'we',
#  'wf',
#  'wg',
#  'wh',
#  'wi',
#  'wj',
#  'wk',
#  'wl',
#  'wm',
#  'wn',
#  'wo',
#  'wp',
#  'wq',
#  'wr',
#  'ws',
#  'wt',
#  'wu',
#  'wv',
#  'ww',
#  'wx',
#  'wy',
#  'wz',
#  'xa',
#  'xb',
#  'xc',
#  'xd',
#  'xe',
#  'xf',
#  'xg',
#  'xh',
#  'xi',
#  'xj',
#  'xk',
#  'xl',
#  'xm',
#  'xn',
#  'xo',
#  'xp',
#  'xq',
#  'xr',
#  'xs',
#  'xt',
#  'xu',
#  'xv',
#  'xw',
#  'xx',
#  'xy',
#  'xz',
#  'ya',
#  'yb',
#  'yc',
#  'yd',
#  'ye',
#  'yf',
#  'yg',
#  'yh',
#  'yi',
#  'yj',
#  'yk',
#  'yl',
#  'ym',
#  'yn',
#  'yo',
#  'yp',
#  'yq',
#  'yr',
#  'ys',
#  'yt',
#  'yu',
#  'yv',
#  'yw',
#  'yx',
#  'yy',
#  'yz',
#  'za',
#  'zb',
#  'zc',
#  'zd',
#  'ze',
#  'zf',
#  'zg',
#  'zh',
#  'zi',
#  'zj',
#  'zk',
#  'zl',
#  'zm',
#  'zn',
#  'zo',
#  'zp',
#  'zq',
#  'zr',
#  'zs',
#  'zt',
#  'zu',
#  'zv',
#  'zw',
#  'zx',
#  'zy',
#  'zz']

# %%
# Find the cumulative occurrence of each bigram in the subtlex dataframe
bigram_counts = {bigram: 0 for bigram in bigrams}
for bigram in bigrams:
    # Ensure x is treated as a string, even if it's originally a float
    mask = subtlex_v2['Word'].apply(lambda x: bigram in str(x))
    bigram_counts[bigram] = new_df.loc[mask, 'FREQcount'].sum()

# %%
#make dataframe and csv from bigram_counts
bigram_counts_df = pd.DataFrame.from_dict(bigram_counts, orient = 'index', columns = ['Count'])
#make index a column
bigram_counts_df.reset_index(inplace = True)
bigram_counts_df.rename(columns = {'index':'Bigram'}, inplace = True)
bigram_counts_df.to_csv('/home/neel/Desktop/sublexical_crossmodal/bigram_counts.csv')
bigram_counts_df
# Out:
#     Bigram      Count
# 0       aa  2730922.0
# 1       ab    53787.0
# 2       ac   404620.0
# 3       ad   474501.0
# 4       ae    32665.0
# ..     ...        ...
# 671     zv       40.0
# 672     zw    26656.0
# 673     zx        0.0
# 674     zy   103803.0
# 675     zz     5766.0
#
# [676 rows x 2 columns]

# %%
def split_word_bigrams(word):
    # Split the word into bigrams
    bigrams = [word[i:i+2] for i in range(len(word) - 1)]
    return bigrams

# %%
mous_words['Bigrams'] = mous_words['Word'].apply(split_word_bigrams)
mous_words
# Out:
#             Word       Syllables  Syllable Occurrence Counts  \
# 0           toen           [tun]                   [47827.0]
# 1             de            [d@]                 [1576822.0]
# 2      barkeeper  [bAr, ki, p@r]  [4067.0, 10732.0, 20167.0]
# 3            die            [di]                  [360662.0]
# 4      irritante             NaN                          []
# ...          ...             ...                         ...
# 1937       blije             NaN                          []
# 1938    jongeren             NaN                          []
# 1939      intens      [In, tEns]           [453814.0, 264.0]
# 1940     plezier      [pl@, zir]            [5981.0, 5890.0]
# 1941  woonplaats    [wom, plats]            [175.0, 12240.0]
#
#                                    Bigrams
# 0                             [to, oe, en]
# 1                                     [de]
# 2         [ba, ar, rk, ke, ee, ep, pe, er]
# 3                                 [di, ie]
# 4         [ir, rr, ri, it, ta, an, nt, te]
# ...                                    ...
# 1937                      [bl, li, ij, je]
# 1938          [jo, on, ng, ge, er, re, en]
# 1939                  [in, nt, te, en, ns]
# 1940              [pl, le, ez, zi, ie, er]
# 1941  [wo, oo, on, np, pl, la, aa, at, ts]
#
# [1942 rows x 4 columns]

# %%
mous_words['Bigram Occurrence Counts'] = mous_words['Bigrams'].apply(lambda x: [bigram_counts.get(bigram, 0) for bigram in x])

# %%
mous_words
# Out:
#             Word       Syllables  Syllable Occurrence Counts  \
# 0           toen           [tun]                   [47827.0]
# 1             de            [d@]                 [1576822.0]
# 2      barkeeper  [bAr, ki, p@r]  [4067.0, 10732.0, 20167.0]
# 3            die            [di]                  [360662.0]
# 4      irritante             NaN                          []
# ...          ...             ...                         ...
# 1937       blije             NaN                          []
# 1938    jongeren             NaN                          []
# 1939      intens      [In, tEns]           [453814.0, 264.0]
# 1940     plezier      [pl@, zir]            [5981.0, 5890.0]
# 1941  woonplaats    [wom, plats]            [175.0, 12240.0]
#
#                                    Bigrams  \
# 0                             [to, oe, en]
# 1                                     [de]
# 2         [ba, ar, rk, ke, ee, ep, pe, er]
# 3                                 [di, ie]
# 4         [ir, rr, ri, it, ta, an, nt, te]
# ...                                    ...
# 1937                      [bl, li, ij, je]
# 1938          [jo, on, ng, ge, er, re, en]
# 1939                  [in, nt, te, en, ns]
# 1940              [pl, le, ez, zi, ie, er]
# 1941  [wo, oo, on, np, pl, la, aa, at, ts]
#
#                                Bigram Occurrence Counts
# 0                      [2236591.0, 837795.0, 8542439.0]
# 1                                           [2559661.0]
# 2     [584273.0, 1754491.0, 2174749.0, 3143026.0, 94...
# 3                                [1050254.0, 2076673.0]
# 4     [2884214.0, 200692.0, 1787712.0, 333345.0, 892...
# ...                                                 ...
# 1937         [152155.0, 3369152.0, 1639122.0, 913788.0]
# 1938  [866375.0, 2451854.0, 2927082.0, 3692145.0, 67...
# 1939  [2264626.0, 1477178.0, 3522714.0, 8542439.0, 6...
# 1940  [97171.0, 4397946.0, 100963.0, 123482.0, 20766...
# 1941  [933919.0, 3901750.0, 2451854.0, 16967.0, 9717...
#
# [1942 rows x 5 columns]

# %%
mous_words['Zipf'] = mous_words['Word'].apply(lambda x: subtlex_v2.loc[subtlex_v2['Word'] == x, 'Zipf'].values[0] if x in subtlex_v2['Word'].values else np.nan)
mous_words
# Out:
#             Word       Syllables  Syllable Occurrence Counts  \
# 0           toen           [tun]                   [47827.0]
# 1             de            [d@]                 [1576822.0]
# 2      barkeeper  [bAr, ki, p@r]  [4067.0, 10732.0, 20167.0]
# 3            die            [di]                  [360662.0]
# 4      irritante             NaN                          []
# ...          ...             ...                         ...
# 1937       blije             NaN                          []
# 1938    jongeren             NaN                          []
# 1939      intens      [In, tEns]           [453814.0, 264.0]
# 1940     plezier      [pl@, zir]            [5981.0, 5890.0]
# 1941  woonplaats    [wom, plats]            [175.0, 12240.0]
#
#                                    Bigrams  \
# 0                             [to, oe, en]
# 1                                     [de]
# 2         [ba, ar, rk, ke, ee, ep, pe, er]
# 3                                 [di, ie]
# 4         [ir, rr, ri, it, ta, an, nt, te]
# ...                                    ...
# 1937                      [bl, li, ij, je]
# 1938          [jo, on, ng, ge, er, re, en]
# 1939                  [in, nt, te, en, ns]
# 1940              [pl, le, ez, zi, ie, er]
# 1941  [wo, oo, on, np, pl, la, aa, at, ts]
#
#                                Bigram Occurrence Counts      Zipf
# 0                      [2236591.0, 837795.0, 8542439.0]  6.032333
# 1                                           [2559661.0]  7.381291
# 2     [584273.0, 1754491.0, 2174749.0, 3143026.0, 94...  3.622674
# 3                                [1050254.0, 2076673.0]  6.853871
# 4     [2884214.0, 200692.0, 1787712.0, 333345.0, 892...  3.284921
# ...                                                 ...       ...
# 1937         [152155.0, 3369152.0, 1639122.0, 913788.0]  3.485836
# 1938  [866375.0, 2451854.0, 2927082.0, 3692145.0, 67...  3.965097
# 1939  [2264626.0, 1477178.0, 3522714.0, 8542439.0, 6...  3.778748
# 1940  [97171.0, 4397946.0, 100963.0, 123482.0, 20766...  5.093966
# 1941  [933919.0, 3901750.0, 2451854.0, 16967.0, 9717...  3.241993
#
# [1942 rows x 6 columns]

# %% [markdown]
# Data summary.
#
# `1942` unique words in the MOUS study.
#
#     `X` have syllable parcellations
#
#     `Y` have bigram parcellations
#
#     `4` have apostrophes (see above)
#
#
# `A` unique words in SUBTLEX, `B` unique words in CELEX
#
#     `C` (overlap) have syllable parcellations from CELEX (matters for syllable frequency calculations)

# %%
#find number of rows in mous_words that are non-Nan in 'Syllables'
X = mous_words['Syllables'].count()
X
# Out:
# 1172

# %%
#Find number of rows in mous_words that are non-Nan in 'Bigrams'
Y = mous_words['Bigrams'].count()
Y
# Out:
# 1942

# %%
A = subtlex_v2['Word'].count()
A
# Out:
# 437501

# %%
B = celex_syllables['Head'].count()
B
# Out:
# 117237

# %%
C = new_df['Zipf'].count()
C
# Out:
# 47981

# %% [markdown]
# TO DO
# 1) Re-run SPM with a) new script b) New sublexical regressors from SUBTLEX_V2
# 2) New colinearity plots
