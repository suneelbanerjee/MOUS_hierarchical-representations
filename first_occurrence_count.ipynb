# %%
import pandas as pd
import csv
from pathlib import Path
import numpy as np

# %%
source = Path('/media/neel/MOUS1/MOUS/MOUS/SynologyDrive/source')
for subject in source.iterdir():
    if subject.name.startswith('sub-A'):
        transcription = subject / 'func' / f'{subject.name}_word_frequencies.csv'
        df = pd.read_csv(transcription)
        df['First?'] = 1
        df['First?'] = (~df['Transcription'].str.lower().duplicated()).astype(int)
        df = df[df['First?']==1]
        #df.to_csv(transcription.parent / f'{subject.name}_first_occurrences.csv')
        # for idx, row in df.iterrows():
        #     if row['Transcription'] in df['Transcription'].iloc[:idx].values:
        #         df.loc[idx,'First?'] = 0

# %%
source = Path('/media/neel/MOUS1/MOUS/MOUS/SynologyDrive/source')
for subject in source.iterdir():
    if subject.name.startswith('sub-A'):
        transcription = subject / 'func' / f'{subject.name}_transcription.csv'
        df = pd.read_csv(transcription)
        df['First?'] = 1
        df['First?'] = (~df['Transcription'].str.lower().duplicated()).astype(int)
        df = df[df['First?']==1]
        df.to_csv(transcription.parent / f'{subject.name}_first_occurrences_transcription.csv')
        # for idx, row in df.iterrows():
        #     if row['Transcription'] in df['Transcription'].iloc[:idx].values:
        #         df.loc[idx,'First?'] = 0

# %%
source = Path('/media/neel/MOUS1/MOUS/MOUS/SynologyDrive/source')
for subject in source.iterdir():
    if subject.name.startswith('sub-V'):
        transcription = subject / 'func' / f'{subject.name}_transcription.csv'
        df = pd.read_csv(transcription)
        df['First?'] = 1
        df['First?'] = (~df['Word'].str.lower().duplicated()).astype(int)
        df = df[df['First?']==1]
        df.to_csv(transcription.parent / f'{subject.name}_first_occurrences_transcription.csv')
        # for idx, row in df.iterrows():
        #     if row['Transcription'] in df['Transcription'].iloc[:idx].values:
        #         df.loc[idx,'First?'] = 0

# %%
source = Path('/media/neel/MOUS1/MOUS/MOUS/SynologyDrive/source')
for subject in source.iterdir():
    if subject.name.startswith('sub-V'):
        transcription = subject / 'func' / f'{subject.name}_word_frequencies.csv'
        df = pd.read_csv(transcription)
        df['First?'] = 1
        df['First?'] = (~df['Word'].str.lower().duplicated()).astype(int)
        df = df[df['First?']==1]
        df.to_csv(transcription.parent / f'{subject.name}_first_occurrences_frequencies.csv')
        # for idx, row in df.iterrows():
        #     if row['Transcription'] in df['Transcription'].iloc[:idx].values:
        #         df.loc[idx,'First?'] = 0
